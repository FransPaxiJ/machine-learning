# %%
# !pip install langdetect

# %%
import os
import glob
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException

def separar_sms_espanol(directorio_dataset, archivo_salida="sms_espanol.txt"):
    # Obtener todos los archivos .txt en el directorio
    archivos_txt = glob.glob(os.path.join(directorio_dataset, "*.txt"))
    
    total_sms = 0
    sms_espanol = 0
    errores_deteccion = 0
    
    # Crear archivo para guardar SMS en español
    with open(archivo_salida, 'w', encoding='utf-8') as archivo_esp:
        for archivo in archivos_txt:
            print(f"Procesando: {os.path.basename(archivo)}")
            
            with open(archivo, 'r', encoding='utf-8', errors='ignore') as f:
                for linea_num, linea in enumerate(f, 1):
                    linea = linea.strip()
                    
                    # Saltar líneas vacías
                    if not linea:
                        continue
                    
                    total_sms += 1
                    
                    try:
                        # Detectar idioma
                        idioma = detect(linea)
                        if idioma == 'es':
                            sms_espanol += 1
                            # Escribir SMS en español al archivo
                            archivo_esp.write(linea + '\n')
                    except LangDetectException:
                        # Si no se puede detectar el idioma
                        errores_deteccion += 1
    
    return total_sms, sms_espanol, errores_deteccion

# Ejecutar análisis y separar SMS en español
directorio = "dataset/tweet_sms"
archivo_salida = "dataset_2/sms_solo_español.txt"

total, espanol, errores = separar_sms_espanol(directorio, archivo_salida)

print(f"\n=== RESULTADOS ===")
print(f"Total de SMS analizados: {total}")
print(f"SMS en español: {espanol}")
print(f"Porcentaje en español: {(espanol/total)*100:.2f}%")
print(f"Errores de detección: {errores}")
print(f"SMS en otros idiomas: {total - espanol - errores}")
print(f"\n✅ SMS en español guardados en: {archivo_salida}")
# Out:
# Procesando: tweet_sms_2018-02.txt
# Procesando: tweet_sms_2020-06.txt
# Procesando: tweet_sms_2020-12.txt
# Procesando: tweet_sms_2022-03.txt
# Procesando: tweet_sms_2022-02.txt
# Procesando: tweet_sms_2020-07.txt
# Procesando: tweet_sms_2018-03.txt
# Procesando: tweet_sms_2018-01.txt
# Procesando: tweet_sms_2020-11.txt
# Procesando: tweet_sms_2020-05.txt
# Procesando: tweet_sms_2022-01.txt
# Procesando: tweet_sms_2020-04.txt
# Procesando: tweet_sms_2020-10.txt
# Procesando: tweet_sms_2018-10.txt
# Procesando: tweet_sms_2018-04.txt
# Procesando: tweet_sms_2022-05.txt
# Procesando: tweet_sms_2022-04.txt
# Procesando: tweet_sms_2020-01.txt
# Procesando: tweet_sms_2018-05.txt
# Procesando: tweet_sms_2018-11.txt
# Procesando: tweet_sms_2018-07.txt
# Procesando: tweet_sms_2020-03.txt
# Procesando: tweet_sms_2022-06.txt
# Procesando: tweet_sms_2022-07.txt
# Procesando: tweet_sms_2020-02.txt
# Procesando: tweet_sms_2018-12.txt
# Procesando: tweet_sms_2018-06.txt
# Procesando: tweet_sms_2019-09.txt
# Procesando: tweet_sms_2019-08.txt
# Procesando: tweet_sms_2021-08.txt
# Procesando: tweet_sms_2021-09.txt
# Procesando: tweet_sms_2021-10.txt
# Procesando: tweet_sms_2021-04.txt
# Procesando: tweet_sms_2021-05.txt
# Procesando: tweet_sms_2021-11.txt
# Procesando: tweet_sms_2019-01.txt
# Procesando: tweet_sms_2019-03.txt
# Procesando: tweet_sms_2021-07.txt
# Procesando: tweet_sms_2021-12.txt
# Procesando: tweet_sms_2021-06.txt
# Procesando: tweet_sms_2019-02.txt
# Procesando: tweet_sms_2019-06.txt
# Procesando: tweet_sms_2019-12.txt
# Procesando: tweet_sms_2021-02.txt
# Procesando: tweet_sms_2021-03.txt
# Procesando: tweet_sms_2019-07.txt
# Procesando: tweet_sms_2019-11.txt
# Procesando: tweet_sms_2019-05.txt
# Procesando: tweet_sms_2021-01.txt
# Procesando: tweet_sms_2019-04.txt
# Procesando: tweet_sms_2019-10.txt
# Procesando: tweet_sms_2018-08.txt
# Procesando: tweet_sms_2022-08.txt
# Procesando: tweet_sms_2018-09.txt
# Procesando: tweet_sms_2020-09.txt
# Procesando: tweet_sms_2020-08.txt
#
# === RESULTADOS ===
# Total de SMS analizados: 25826
# SMS en español: 2676
# Porcentaje en español: 10.36%
# Errores de detección: 2
# SMS en otros idiomas: 23148
#
# ✅ SMS en español guardados en: sms_solo_español.txt

# %%
# !pip install groq
# !pip install ollama

# %%
import ollama
import os

def crear_directorio(directorio):
    """Crea el directorio si no existe"""
    if not os.path.exists(directorio):
        os.makedirs(directorio)

def es_spam_adicional(sms):
    """Verificación adicional para casos que el modelo puede pasar por alto"""
    sms_lower = sms.lower()
    
    # Patrones específicos de SPAM
    patrones_spam = [
        # Phishing bancario con enlaces
        ("banco estado" in sms_lower and "http" in sms_lower),
        ("bbva" in sms_lower and "bit.ly" in sms_lower),
        ("santander" in sms_lower and "http" in sms_lower),
        
        # Sorteos y rankings falsos
        ("ranking" in sms_lower and "http" in sms_lower),
        ("sorteo" in sms_lower and "http" in sms_lower),
        ("has ganado" in sms_lower),
        
        # Publicidad de productos
        ("adelgazante" in sms_lower and "viral" in sms_lower),
        ("unidades limitadas" in sms_lower),
        
        # Enlaces acortados sospechosos
        ("bit.ly" in sms_lower and any(x in sms_lower for x in ["banco", "cuenta", "tarjeta"])),
        ("cutt.ly" in sms_lower and any(x in sms_lower for x in ["banco", "cuenta", "tarjeta"])),
        
        # Paquetes falsos
        ("paquete" in sms_lower and "http" in sms_lower and "direccion" in sms_lower),
        
        # Ofertas comerciales agresivas
        ("jazztel" in sms_lower and "mioferta" in sms_lower),
        
        # NUEVOS PATRONES AÑADIDOS:
        # Servicios técnicos no solicitados
        ("problemas de internet" in sms_lower and any(tel in sms_lower for tel in ["099", "24807739", "telefono"])),
        ("videporteros" in sms_lower and "camaras" in sms_lower),
        ("alarmas" in sms_lower and "respuesta celular" in sms_lower),
        ("amc.com.uy" in sms_lower),
        
        # Publicidad de servicios profesionales
        ("abogados" in sms_lower and "whatsapp" in sms_lower),
        ("lawservice.com" in sms_lower),
    ]
    
    return any(patron for patron in patrones_spam)

def clasificar_sms_spam(archivo_entrada, directorio_salida="dataset_3", limite=None):
    """
    Clasifica SMS como spam o no spam usando Ollama con verificación adicional
    """
    # Crear directorio de salida
    crear_directorio(directorio_salida)
    
    # Rutas de archivos de salida
    archivo_spam = os.path.join(directorio_salida, "spam.txt")
    archivo_no_spam = os.path.join(directorio_salida, "no_spam.txt")
    
    # Leer SMS del archivo
    with open(archivo_entrada, 'r', encoding='utf-8') as f:
        sms_list = [linea.strip() for linea in f if linea.strip()]
    
    # Aplicar límite si se especifica
    if limite:
        sms_list = sms_list[:limite]
        print(f"Procesando {len(sms_list)} SMS (límite: {limite})")
    else:
        print(f"Procesando todos los SMS: {len(sms_list)}")
    
    spam_count = 0
    no_spam_count = 0
    
    # Prompt mejorado
    prompt_template = """Analiza este SMS y determina si es SPAM o NO SPAM. Sé MUY ESTRICTO.

🚨 CRITERIOS PARA SPAM (CUALQUIERA DE ESTOS ES SPAM):
- CUALQUIER enlace pidiendo datos bancarios o personales
- Mensajes de bancos pidiendo "verificar", "activar" o "actualizar" cuentas
- Enlaces sospechosos de empresas bancarias (especialmente con dominios raros)
- Sorteos, premios o "has ganado" no solicitados
- Phishing bancario (BBVA, Santander, BancoEstado, Davivienda, etc.)
- Ofertas de trabajo con salarios irreales
- Urgencia falsa ("cuenta será bloqueada", "suspendida")
- PUBLICIDAD COMERCIAL NO SOLICITADA (productos adelgazantes, servicios técnicos, etc.)
- Mensajes promocionales con WhatsApp o teléfonos
- Ofertas de servicios profesionales (abogados, técnicos, internet, cámaras)
- Mensajes de "paquetes detenidos" pidiendo pagos o datos
- Enlaces acortados sospechosos (bit.ly, cutt.ly con contenido bancario)
- Mensajes pidiendo "confirmar", "verificar" o "actualizar" datos
- Mensajes de "rankings" o "sorteos" con enlaces sospechosos
- SERVICIOS TÉCNICOS NO SOLICITADOS (internet, videoporteros, alarmas)

✅ CRITERIOS PARA NO SPAM (SOLO ESTOS):
- Notificaciones reales de servicios ya contratados SIN enlaces sospechosos
- Información educativa pura (sin enlaces comerciales)
- Alertas de seguridad que NO piden datos ni tienen enlaces
- Mensajes informativos oficiales sin solicitar acciones
- INFORMACIÓN DE SALUD PÚBLICA OFICIAL
- NOTICIAS OFICIALES DE GOBIERNO

⚠️ ESPECIAL ATENCIÓN: 
- Si un mensaje menciona bancos Y tiene enlaces, ES SPAM
- Si menciona "ranking", "sorteo" con enlaces, ES SPAM
- Si es publicidad de productos o servicios, ES SPAM
- Si ofrece servicios técnicos con teléfonos, ES SPAM

SMS: "{sms}"

Responde SOLO "SPAM" o "NO_SPAM"."""

    # Abrir archivos de salida
    with open(archivo_spam, 'w', encoding='utf-8') as f_spam, \
         open(archivo_no_spam, 'w', encoding='utf-8') as f_no_spam:
        
        for i, sms in enumerate(sms_list, 1):
            print(f"Procesando SMS {i}/{len(sms_list)}: {sms[:50]}...")
            
            try:
                # Verificación adicional primero
                if es_spam_adicional(sms):
                    spam_count += 1
                    f_spam.write(sms + '\n')
                    print(f"  → SPAM (detectado por patrones)")
                    continue
                
                # Consultar al modelo
                respuesta = ollama.generate(
                    model='llama3.1:8b',
                    prompt=prompt_template.format(sms=sms),
                    stream=False,
                    options={
                        'num_ctx': 4096,        # Contexto más grande
                        'num_batch': 512,       # Lotes más grandes
                        'num_gpu': 1,           # Forzar GPU
                        'num_thread': 0,        # Usar todos los threads
                    } 
                )
                
                # Clasificar y guardar
                respuesta_texto = respuesta['response'].upper().strip()
                
                if "SPAM" in respuesta_texto and "NO_SPAM" not in respuesta_texto:
                    spam_count += 1
                    f_spam.write(sms + '\n')
                    print(f"  → SPAM")
                else:
                    no_spam_count += 1
                    f_no_spam.write(sms + '\n')
                    print(f"  → NO SPAM")
                    
            except Exception as e:
                print(f"  → ERROR: {e}")
                no_spam_count += 1
                f_no_spam.write(sms + '\n')
    
    # Mostrar resultados
    print(f"\n=== RESULTADOS ===")
    print(f"Total de SMS analizados: {len(sms_list)}")
    print(f"SMS clasificados como SPAM: {spam_count}")
    print(f"SMS clasificados como NO SPAM: {no_spam_count}")
    print(f"Porcentaje de SPAM: {(spam_count/len(sms_list)*100):.1f}%")
    print(f"\n✅ Archivos guardados en:")
    print(f"  - SPAM: {archivo_spam}")
    print(f"  - NO SPAM: {archivo_no_spam}")

# Ejecutar con verificación mejorada
clasificar_sms_spam("dataset_2/sms_solo_español.txt")
# Out:
# Procesando todos los SMS: 2676
# Procesando SMS 1/2676: Son los malware más peligrosos difíciles de detect...
#   → NO SPAM
# Procesando SMS 2/2676: WWW.CLASI.CL Recarga tu Celular en WWW.CLASI.CL Pa...
#   → SPAM
# Procesando SMS 3/2676: El verano no se acaba Ingresa VERANOCABIFY y obten...
#   → SPAM
# Procesando SMS 4/2676: VF Info Este San Valentin Vodafone te regala gigas...
#   → SPAM
# Procesando SMS 5/2676: Regalale flores para San Valentin Usa el codigo VA...
#   → SPAM
# Procesando SMS 6/2676: VF Publi Con la App Mi Vodafone vive el amor todos...
#   → SPAM
# Procesando SMS 7/2676: VF Info Este San Valentin por ser cliente Vodafone...
#   → NO SPAM
# Procesando SMS 8/2676: VE INTO Desde anora deberas usar la App Mi Vodafon...
#   → NO SPAM
# Procesando SMS 9/2676: Regalale flores para San Valentin Usa el codigo VA...
#   → SPAM
# Procesando SMS 10/2676: Busca asesoramiento legal Abogados en todas la esp...
#   → SPAM (detectado por patrones)
# Procesando SMS 11/2676: Regalale flores para San Valentin Usa el codigo VA...
#   → SPAM
# Procesando SMS 12/2676: Estimado cliente agradecemos nos envie copia de su...
#   → SPAM
# Procesando SMS 13/2676: UNIDADES LIMITADAS Producto ADELGAZANTE se hace VI...
#   → SPAM (detectado por patrones)
# Procesando SMS 14/2676: XX jun Cargo a tu cuenta Banorte por 2,800.00 si n...
#   → NO SPAM
# Procesando SMS 15/2676: Su cuenta Santander ha sido bloqueada temporalment...
#   → SPAM (detectado por patrones)
# Procesando SMS 16/2676: AM750 Sintoniza AM750 y termina el dia bien inform...
#   → NO SPAM
# Procesando SMS 17/2676: ¡ Tu paquete de Tienda.com viene en camino Lo reci...
#   → NO SPAM
# Procesando SMS 18/2676: Sergio pensamos en ti y queremos regalarte XX en e...
#   → SPAM
# Procesando SMS 19/2676: Tu Suscripción NETFLIX se ha SUSPENDIDO para volve...
#   → SPAM
# Procesando SMS 20/2676: Davivienda le informa que debido a un mo vimiento ...
#   → SPAM
# Procesando SMS 21/2676: AMAZON.ES ¡ Hola UndamesunDam Hemos tratado de con...
#   → SPAM
# Procesando SMS 22/2676: Estimado Juan Llega pronto Por favor confirme la d...
#   → SPAM
# Procesando SMS 23/2676: VIA BCP Estimado Cliente se ha detectado una activ...
#   → SPAM (detectado por patrones)
# Procesando SMS 24/2676: COMIDA RÁPIDA Obten 99.00 MXN de descuento en tu p...
#   → NO SPAM
# Procesando SMS 25/2676: .146.28.177 c mira_el_descu ento XXX...
#   → NO SPAM
# Procesando SMS 26/2676: BBVA MÉXICO M.X XX JUNIO XXXX Disposicion de retir...
#   → SPAM
# Procesando SMS 27/2676: BANCO ESTADO informa un problema en su cuenta para...
#   → SPAM (detectado por patrones)
# Procesando SMS 28/2676: BANCO ESTADO informa un problema en su cuenta para...
#   → NO SPAM
# Procesando SMS 29/2676: Por seguridad su cuenta BBVA se encuentra bloquead...
#   → SPAM (detectado por patrones)
# Procesando SMS 30/2676: sábado XX de junio de XXXX Servicio al cliente ban...
#   → SPAM (detectado por patrones)
# Procesando SMS 31/2676: BancoEstado informa que su tarjeta COORDENADAS ha ...
#   → SPAM (detectado por patrones)
# Procesando SMS 32/2676: Banco Santander Su cuenta bancaria de Banco Santan...
#   → SPAM (detectado por patrones)
# Procesando SMS 33/2676: elena Confirme sus credenciales de entrega hoy de ...
#   → SPAM
# Procesando SMS 34/2676: Notamos que pago la factura do veces al mismo tiem...
#   → SPAM
# Procesando SMS 35/2676: JAZZTEL Hola Consulta tu resumen de compra aqui ht...
#   → SPAM (detectado por patrones)
# Procesando SMS 36/2676: Santander e Tienes que activar el nuevo sistema de...
#   → SPAM (detectado por patrones)
# Procesando SMS 37/2676: Banco Santander Ponemos su tarjeta en espera Por f...
#   → SPAM (detectado por patrones)
# Procesando SMS 38/2676: correos le informa que su envio N ES XXXXXXX aun e...
#   → SPAM
# Procesando SMS 39/2676: ¡ Tu paquete de Tienda.com viene en camino Lo reci...
#   → NO SPAM
# Procesando SMS 40/2676: Banco Estado INFORMA Tu bono de 100.000 esta dispo...
#   → SPAM (detectado por patrones)
# Procesando SMS 41/2676: Banco Santander Su cuenta bancaria de Banco Santan...
#   → SPAM (detectado por patrones)
# Procesando SMS 42/2676: Estimado Juar la entrega con DHL ha sido detenida ...
#   → SPAM
# Procesando SMS 43/2676: BancoEstado informa que su tarjeta COORDENADAS ha ...
#   → SPAM (detectado por patrones)
# Procesando SMS 44/2676: ¿ Qué tal te fue con tu compra Cuéntanos cómo fue ...
#   → NO SPAM
# Procesando SMS 45/2676: Felicitaciones a nuestros X clien te de Media Mark...
#   → SPAM
# Procesando SMS 46/2676: Notamos que pago la factura do veces al mismo tiem...
#   → SPAM
# Procesando SMS 47/2676: Estimado cliente ha recibido un importante email n...
#   → SPAM
# Procesando SMS 48/2676: Banco de Chile Su DigiPass se ha desincronizado pa...
#   → SPAM
# Procesando SMS 49/2676: Si eres cliente Suscripcion o Cuenta Controlada el...
#   → NO SPAM
# Procesando SMS 50/2676: Alerta BIBVA Se detecto un inicio de sesion sospec...
#   → SPAM
# Procesando SMS 51/2676: Tu acceso ha sido bloqueada Haz click y revisa tu ...
#   → SPAM (detectado por patrones)
# Procesando SMS 52/2676: su paquete ha sido detenida en nuestro almacen par...
#   → SPAM
# Procesando SMS 53/2676: Banco Sant SANTANDER Su Tarjeta esta restringida d...
#   → SPAM
# Procesando SMS 54/2676: Confirme sus credenciales de entrega hoy de lo con...
#   → SPAM
# Procesando SMS 55/2676: Banco Santander Su cuenta bancaria de Banco Santan...
#   → SPAM (detectado por patrones)
# Procesando SMS 56/2676: Es necesario que actualices tus datos personales e...
#   → SPAM
# Procesando SMS 57/2676: JAZZTEL Hola Consulta tu resumen de compra aqui ht...
#   → SPAM (detectado por patrones)
# Procesando SMS 58/2676: XX Junio XXXX Cargo a tu cuenta TDD XXXXXX 4,500.0...
#   → NO SPAM
# Procesando SMS 59/2676: BancoEstado informa que su tarjeta COORDENADAS ha ...
#   → SPAM (detectado por patrones)
# Procesando SMS 60/2676: Estimado Buen Día Harinas CISNE le ofrece ... saco...
#   → SPAM
# Procesando SMS 61/2676: Marc Confirme sus credenciales de entrega hoy de l...
#   → SPAM
# Procesando SMS 62/2676: Comparto con ustedes este mensaje que está llegand...
#   → NO SPAM
# Procesando SMS 63/2676: COMIDA RÁPIDA Obten 99.00 MXN de descuento en tu p...
#   → SPAM
# Procesando SMS 64/2676: Recordatorio ¡MEDIAMARKT le envio un mensaje impor...
#   → SPAM
# Procesando SMS 65/2676: Santander Debido a una actualizacion hemos tenido ...
#   → SPAM (detectado por patrones)
# Procesando SMS 66/2676: Tiene un mensaje referente a su articulo ref AMA27...
#   → SPAM (detectado por patrones)
# Procesando SMS 67/2676: Nunca publiques tus datos personales en REDES SOCI...
#   → NO SPAM
# Procesando SMS 68/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 69/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 70/2676: domingo XX de noviembre de XXXX Su cuenta ha sido ...
#   → SPAM
# Procesando SMS 71/2676: Estimado Cliente BANORTE su cuenta ha sido bloquea...
#   → SPAM (detectado por patrones)
# Procesando SMS 72/2676: NOTA Apoyando a combatir la pandemia MOREN cedera ...
#   → NO SPAM
# Procesando SMS 73/2676: Tu cuenta ha sido bloqueada Para desbloquear tu cu...
#   → SPAM
# Procesando SMS 74/2676: Quieres comprar ese jueguito en PlayStore Hazlo ah...
#   → SPAM
# Procesando SMS 75/2676: Movistar Info Se ha gestionado correctamente su so...
#   → NO SPAM
# Procesando SMS 76/2676: Camaras de seguridad inteligentes HD .099622291 XX...
#   → SPAM (detectado por patrones)
# Procesando SMS 77/2676: Tiene un mensaje referente a su articulo ref AMA27...
#   → SPAM (detectado por patrones)
# Procesando SMS 78/2676: Tiene un mensaje referente a su articulo ref AMA27...
#   → SPAM (detectado por patrones)
# Procesando SMS 79/2676: Apartir del 08/12/2020 No puedes utilizar su cuent...
#   → SPAM (detectado por patrones)
# Procesando SMS 80/2676: Tiene un mensaje referente a su articulo ref AMA27...
#   → SPAM (detectado por patrones)
# Procesando SMS 81/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 82/2676: Si recibís una llamada o mensaje dudoso denuncialo...
#   → NO SPAM
# Procesando SMS 83/2676: Tiene un mensaje referente a su articulo ref ΕΙ 15...
#   → SPAM (detectado por patrones)
# Procesando SMS 84/2676: Nueva musica Spotify LLEGO Crea tu cuenta y paga t...
#   → NO SPAM
# Procesando SMS 85/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 86/2676: Tiene problemas de internet en casa o empresa cons...
#   → SPAM (detectado por patrones)
# Procesando SMS 87/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 88/2676: Tiene problemas de internet en casa o empresa cons...
#   → SPAM (detectado por patrones)
# Procesando SMS 89/2676: Estimado a Joe tenemos su paquete en la cola Direc...
#   → SPAM (detectado por patrones)
# Procesando SMS 90/2676: BBVA Tu cuenta ha sido bloqueada Para desbloquear ...
#   → SPAM
# Procesando SMS 91/2676: Tu Banco nos ha comunicado una incidencia en el re...
#   → SPAM (detectado por patrones)
# Procesando SMS 92/2676: NOTICIA En apoyo a los esfuerzos para combatir la ...
#   → NO SPAM
# Procesando SMS 93/2676: Videporteros ip camaras inteligentes HD Alarmas co...
#   → SPAM (detectado por patrones)
# Procesando SMS 94/2676: Tiene un mensaje referente a su articulo ref AMA27...
#   → SPAM (detectado por patrones)
# Procesando SMS 95/2676: Quieres comprar ese jueguito en PlayStore Hazlo ah...
#   → SPAM
# Procesando SMS 96/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 97/2676: SANTANDER Por seguridad bloqueamos tu Tarjeta de c...
#   → SPAM (detectado por patrones)
# Procesando SMS 98/2676: NETFLIX Cuenta suspendida estamos teniendo problem...
#   → SPAM (detectado por patrones)
# Procesando SMS 99/2676: Por favor no conside res mensaje enviado por error...
#   → SPAM
# Procesando SMS 100/2676: hoy 9:11 a m Evita reunirte con familiares o amigo...
#   → NO SPAM
# Procesando SMS 101/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 102/2676: I retirar en av.valparaiso XXX horario en WWW.corr...
#   → NO SPAM
# Procesando SMS 103/2676: Vente a Orange La mejor FIBRA para tus comunicacio...
#   → SPAM
# Procesando SMS 104/2676: SANTANDER Su Super Clave se encuentra bloqueada po...
#   → SPAM (detectado por patrones)
# Procesando SMS 105/2676: divendres XX de desembre de XXXX...
#   → NO SPAM
# Procesando SMS 106/2676: Ha recibido una notificacion sobre su numero de ar...
#   → SPAM (detectado por patrones)
# Procesando SMS 107/2676: No hemos podido entregar su paquete Siga el enlace...
#   → SPAM
# Procesando SMS 108/2676: ON retirar en av.valparaiso XXX horario en WWW.cor...
#   → NO SPAM
# Procesando SMS 109/2676: Rappi Para que pidas lo que ma te gusta.Te regalam...
#   → NO SPAM
# Procesando SMS 110/2676: Estimado Cliente pensando en tu ultimo/a At emerge...
#   → SPAM
# Procesando SMS 111/2676: Acceso no autorizado en su cuenta online Si no rec...
#   → SPAM (detectado por patrones)
# Procesando SMS 112/2676: Se ha iniciado sesion desde un nuevo DISPOSITIVO s...
#   → SPAM
# Procesando SMS 113/2676: Estimado cliente Su paquete esta listo para la ent...
#   → SPAM
# Procesando SMS 114/2676: Denuncia este mensaje para ayudarnos a prevenir el...
#   → SPAM
# Procesando SMS 115/2676: Texting with XXX XX XX XX SMS/MMS bloqueada para d...
#   → SPAM
# Procesando SMS 116/2676: Banco Santander Informa Su cuenta ha sido temporal...
#   → SPAM (detectado por patrones)
# Procesando SMS 117/2676: Rappi Invitamos el almuerzo Tienes XXXXX Creditos ...
#   → SPAM
# Procesando SMS 118/2676: BBVA Su cuenta ha sido suspendida temporalmente po...
#   → SPAM
# Procesando SMS 119/2676: Banco Santander Informa Su cuenta ha sido temporal...
#   → SPAM (detectado por patrones)
# Procesando SMS 120/2676: A partir del 14/03/2022 No puedes utilizar su cuen...
#   → SPAM
# Procesando SMS 121/2676: BBVA Info Un dispositivo no autorizado esta conect...
#   → SPAM
# Procesando SMS 122/2676: Dispositivo no autorizado se ha conectado a su cue...
#   → SPAM (detectado por patrones)
# Procesando SMS 123/2676: BBVA le informamos que su cuenta ha sido desactiva...
#   → NO SPAM
# Procesando SMS 124/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM
# Procesando SMS 125/2676: Hola El bloqueo de la familia de servicios E Servi...
#   → SPAM
# Procesando SMS 126/2676: iFood Tienes que probarlos Son los platos ma pedid...
#   → NO SPAM
# Procesando SMS 127/2676: Hola El bloqueo de la familia de servicios testtps...
#   → SPAM
# Procesando SMS 128/2676: Notificacion de Caixabank No se puede utilizar su ...
#   → SPAM (detectado por patrones)
# Procesando SMS 129/2676: todo ilimitado o solicita linea nueva y consulta l...
#   → NO SPAM
# Procesando SMS 130/2676: micasabienequipada2022.com C.N.P Comision Nacional...
#   → SPAM
# Procesando SMS 131/2676: notifica de un pre-cargo no autorizado de 398,99 E...
#   → SPAM (detectado por patrones)
# Procesando SMS 132/2676: Su cuenta ha sido bloqueada por razonesde segurida...
#   → SPAM
# Procesando SMS 133/2676: Hola El bloqueo de la familia de servicios E Servi...
#   → SPAM
# Procesando SMS 134/2676: Pide plazaVea por agora SHOP y llevate el servicio...
#   → SPAM
# Procesando SMS 135/2676: Rappi Vuelve que tenemos XXXXX Creditos para que p...
#   → SPAM
# Procesando SMS 136/2676: miércoles XX de oct. de XXXX • 11:21Estimado clien...
#   → SPAM
# Procesando SMS 137/2676: Informa Cliente N XXXXXXX-X con cuenta vencida el ...
#   → SPAM
# Procesando SMS 138/2676: Hola El bloqueo de la familia de servicios E Servi...
#   → SPAM
# Procesando SMS 139/2676: Aviso sobre su Inspeccion periodica Consulta aqui ...
#   → NO SPAM
# Procesando SMS 140/2676: Estimado Cliente pensando en tu ultimo/a At emerge...
#   → SPAM
# Procesando SMS 141/2676: Estimado Cliente pensando en tu ultimo/a At emerge...
#   → SPAM
# Procesando SMS 142/2676: Su DNI esta proximo a caducar 12.12.2021 y necesit...
#   → SPAM
# Procesando SMS 143/2676: no autorizado en su cuenta Si no lo...
#   → NO SPAM
# Procesando SMS 144/2676: En cada amanecer hay un vivo poema de esperanza y ...
#   → NO SPAM
# Procesando SMS 145/2676: No hemos realizado la inspeccion periodica obligat...
#   → NO SPAM
# Procesando SMS 146/2676: Santander Informa Su cuenta ha sido temporalmente ...
#   → SPAM (detectado por patrones)
# Procesando SMS 147/2676: Antes de 24h debe modificaria por una de su elecci...
#   → SPAM
# Procesando SMS 148/2676: Estimado cliente Su paquete esta listo para la ent...
#   → SPAM
# Procesando SMS 149/2676: Servicio Correos Su paquete no podrá entregarse po...
#   → SPAM
# Procesando SMS 150/2676: Pide plazaVea por agora SHOP y llevate el servicio...
#   → SPAM
# Procesando SMS 151/2676: Nuestro sistema no alerta de un cargo no autorizad...
#   → SPAM (detectado por patrones)
# Procesando SMS 152/2676: FERNANDEZ su gestor de Banco Santander Como coment...
#   → SPAM (detectado por patrones)
# Procesando SMS 153/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM
# Procesando SMS 154/2676: Su cuenta ha sido bloqueada temporalmente por...
#   → NO SPAM
# Procesando SMS 155/2676: Mensajes similares se han identificado como spam.e...
#   → SPAM
# Procesando SMS 156/2676: se ha conectado a su cuenta online.Si no reconoce ...
#   → SPAM (detectado por patrones)
# Procesando SMS 157/2676: Nuestro sistema no alerta de un pre-cargo no autor...
#   → SPAM
# Procesando SMS 158/2676: UN DISPOSITIVO NO AUTORIZADO se ha conectado a su ...
#   → SPAM (detectado por patrones)
# Procesando SMS 159/2676: Santander A partir del 23/03/2022 no podra utiliza...
#   → SPAM (detectado por patrones)
# Procesando SMS 160/2676: Nuestro sistema no alerta de un cargo no autorizad...
#   → SPAM (detectado por patrones)
# Procesando SMS 161/2676: Rappi Invitamos el almuerzo Tienes XXXXX Creditos ...
#   → NO SPAM
# Procesando SMS 162/2676: SERVICIO CORREOS Su paquete no se ha podido entreg...
#   → SPAM
# Procesando SMS 163/2676: Mensaje de texto mié X mar 23:08Estimado cliente s...
#   → SPAM
# Procesando SMS 164/2676: Jacqueline en este Dia de la Mujer date el gustito...
#   → SPAM
# Procesando SMS 165/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → NO SPAM
# Procesando SMS 166/2676: En cada amanecer hay un vivo poema de esperanza y ...
#   → NO SPAM
# Procesando SMS 167/2676: BBVA INFO hemos detectado un nuevo acceso NO AUTOR...
#   → NO SPAM
# Procesando SMS 168/2676: Estimado a Cliente se abono los S/350.00 del bono ...
#   → SPAM (detectado por patrones)
# Procesando SMS 169/2676: Nuestro sistema no notifica de un pre cargo no aut...
#   → SPAM (detectado por patrones)
# Procesando SMS 170/2676: autorizado de 398,99 EUR con su cuenta Para cancel...
#   → SPAM (detectado por patrones)
# Procesando SMS 171/2676: Mensaje de texto a XXX XX XX XX SMS/MMS Estimado c...
#   → SPAM
# Procesando SMS 172/2676: Tu paquete esta listo no pierdas la ultima oportun...
#   → NO SPAM
# Procesando SMS 173/2676: Estimado cliente su paquete no se ha podido entreg...
#   → SPAM
# Procesando SMS 174/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM
# Procesando SMS 175/2676: bloqueada temporalmente por razones de seguridad P...
#   → SPAM (detectado por patrones)
# Procesando SMS 176/2676: CaixaBank Queremos informarle que su Tarjeta serum...
#   → NO SPAM
# Procesando SMS 177/2676: Se ha realizado un cargo de 899.99 EUR en su cuent...
#   → SPAM (detectado por patrones)
# Procesando SMS 178/2676: Rappi Para que pidas lo que ma te gusta.Te regalam...
#   → SPAM
# Procesando SMS 179/2676: principios que representa a Cundinamarca vota CAMA...
#   → NO SPAM
# Procesando SMS 180/2676: Su cuenta ha sido bloqueada temporalmente para gar...
#   → SPAM
# Procesando SMS 181/2676: Su cuenta serum inhabilitada debido a un inicio de...
#   → SPAM
# Procesando SMS 182/2676: Friday April X XXXX · 6:20 AM...
#   → NO SPAM
# Procesando SMS 183/2676: sospechoso Verifique su dispositivo unicamente des...
#   → SPAM
# Procesando SMS 184/2676: Hemos detectado una actividad inusual en su cuenta...
#   → SPAM (detectado por patrones)
# Procesando SMS 185/2676: Obten XX dscto en tu plan por X me desde la web aq...
#   → SPAM
# Procesando SMS 186/2676: seleccionado para un puesto de trabajo a tiempo pa...
#   → SPAM
# Procesando SMS 187/2676: Estimado Cliente a Se realizo el deposito del subs...
#   → SPAM (detectado por patrones)
# Procesando SMS 188/2676: STARKEN Su paquete ha sido retenido en nuestro alm...
#   → SPAM (detectado por patrones)
# Procesando SMS 189/2676: Hace XX min Hola El bloqueo de la familia de servi...
#   → SPAM
# Procesando SMS 190/2676: Nuestro sistema no alerta de un pre-cargo no autor...
#   → SPAM (detectado por patrones)
# Procesando SMS 191/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM
# Procesando SMS 192/2676: Un dispositivo no autorizado se ha conectado a su ...
#   → SPAM (detectado por patrones)
# Procesando SMS 193/2676: CaixaBank Queremos informarle que su Tarjeta serum...
#   → SPAM
# Procesando SMS 194/2676: Su DNI esta proximo a caducar 12.12.2021 y necesit...
#   → SPAM
# Procesando SMS 195/2676: Caixa Queremos informarle que su Tarjeta serum sus...
#   → SPAM
# Procesando SMS 196/2676: Rappi Queremos que vuelvas te damos XXXXX Creditos...
#   → SPAM
# Procesando SMS 197/2676: Su cuenta podria quedar Inhabilatada establezca su...
#   → SPAM
# Procesando SMS 198/2676: Rappi Para que no almuerces lo mismo ... Te regala...
#   → SPAM
# Procesando SMS 199/2676: Inicia con la recepción de un enlace a través de S...
#   → SPAM
# Procesando SMS 200/2676: Se ha realizado un cargo de 959.99 EUR en su cuent...
#   → SPAM (detectado por patrones)
# Procesando SMS 201/2676: Ha sido seleccionado para la oferta de trabajo Tra...
#   → SPAM
# Procesando SMS 202/2676: se puede entregar porque no se pagado las tasas ad...
#   → SPAM
# Procesando SMS 203/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM
# Procesando SMS 204/2676: Antes de 24h debe modificaria por una de su elecci...
#   → SPAM (detectado por patrones)
# Procesando SMS 205/2676: http //rappi.app.link/RJC Validos hasta las 22h Ap...
#   → SPAM
# Procesando SMS 206/2676: Rappi Vuelve Y descubre todo lo nuevo que tenemos ...
#   → SPAM
# Procesando SMS 207/2676: Disfruta 6.000 de dscto y pide TOTTUS.CL c/cupon P...
#   → NO SPAM
# Procesando SMS 208/2676: iFood Hoy pruebas nuevos sabores Te van a encantar...
#   → SPAM
# Procesando SMS 209/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM
# Procesando SMS 210/2676: Disfruta 6.000 de dscto y pide TOTTUS.CL c/cupon P...
#   → SPAM
# Procesando SMS 211/2676: su paquete no se ha podido entregar porque no se h...
#   → SPAM
# Procesando SMS 212/2676: Binance Su codigo de verificacion para el retiro e...
#   → SPAM
# Procesando SMS 213/2676: Se ha realizado un cargo de 959.99 EUR en su cuent...
#   → SPAM
# Procesando SMS 214/2676: Estimado cliente su paquete no se ha podido entreg...
#   → NO SPAM
# Procesando SMS 215/2676: Mensaje de texto sáb X feb 19:03Su iPhone ha sido ...
#   → SPAM
# Procesando SMS 216/2676: Interbank Estimado Cliente Tiene un Extracash PreA...
#   → SPAM
# Procesando SMS 217/2676: Por su seguridad su cuenta ha sido desactivada tem...
#   → SPAM
# Procesando SMS 218/2676: CORREOS Su paquete no se puede entregar no se han ...
#   → SPAM
# Procesando SMS 219/2676: Lamentamos informarle que su cuenta ha sido desact...
#   → SPAM (detectado por patrones)
# Procesando SMS 220/2676: Notificacion de Abanca No se puede utilizar su Tar...
#   → SPAM
# Procesando SMS 221/2676: Hemos detectado una actividad sospechosa en su cue...
#   → SPAM
# Procesando SMS 222/2676: BANCOLOMBIA para protegerte ha bloqueado preventiv...
#   → SPAM
# Procesando SMS 223/2676: Su paquete ES73 34B esta listo pague los costos de...
#   → SPAM
# Procesando SMS 224/2676: Este e un mensaje importante Por favor llame a Abo...
#   → SPAM
# Procesando SMS 225/2676: Hemos detectado un inicio sospechoso si no ha sido...
#   → SPAM
# Procesando SMS 226/2676: Carrefour.es Usuario o Contrasena incorrectos comp...
#   → SPAM
# Procesando SMS 227/2676: La estafa consiste en enviar a los usuarios un men...
#   → SPAM
# Procesando SMS 228/2676: Hemos detectado una actividad sospechosa en su cue...
#   → SPAM
# Procesando SMS 229/2676: algunos sueños viajes proyectos ... Llama al XXXXX...
#   → SPAM (detectado por patrones)
# Procesando SMS 230/2676: Su cuenta serum inhabilitada debido a un inicio de...
#   → SPAM
# Procesando SMS 231/2676: Banco Santander Informa Su cuenta ha sido temporal...
#   → SPAM (detectado por patrones)
# Procesando SMS 232/2676: SAUBIDET GARRIDO MAR Nos comunicamos desde Comafi ...
#   → SPAM (detectado por patrones)
# Procesando SMS 233/2676: para completar el registro en Samsung Pay con su t...
#   → SPAM
# Procesando SMS 234/2676: me por solo 0,5€/ me ¿A qué esperas Estas ofertaVF...
#   → SPAM (detectado por patrones)
# Procesando SMS 235/2676: Per treure aquesta conversa de Converses brossa i ...
#   → SPAM (detectado por patrones)
# Procesando SMS 236/2676: CORREOS Su paquete no ha podido ser entregado no s...
#   → NO SPAM
# Procesando SMS 237/2676: Nos comunicamos desde Comafi soluciones por la deu...
#   → SPAM (detectado por patrones)
# Procesando SMS 238/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM (detectado por patrones)
# Procesando SMS 239/2676: y abrazos ala distancia adivina quién te escribe d...
#   → NO SPAM
# Procesando SMS 240/2676: CaixaBank Su cuenta ha sido suspendida La cuenta p...
#   → SPAM (detectado por patrones)
# Procesando SMS 241/2676: Estimado cliente su paquete no se ha podido entreg...
#   → SPAM
# Procesando SMS 242/2676: Hemos suspendido su cuenta temporalmente por motiv...
#   → SPAM
# Procesando SMS 243/2676: SERVICIO CORREOS Su paquete no ha podido ser entre...
#   → NO SPAM
# Procesando SMS 244/2676: Banco de Chile estimado cliente su canal digital h...
#   → SPAM
# Procesando SMS 245/2676: La pandemia ha aportado un gran impulso a Amazon Q...
#   → SPAM
# Procesando SMS 246/2676: sido bloqueada Pa ra activar su cuenta puede acced...
#   → SPAM
# Procesando SMS 247/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM (detectado por patrones)
# Procesando SMS 248/2676: temporalmente por razones de seguridad Para reacti...
#   → SPAM
# Procesando SMS 249/2676: Hemos recibido un cargo inusual de Yoigo por valor...
#   → SPAM (detectado por patrones)
# Procesando SMS 250/2676: Notificacion Correos Le pedimos que confirme su pa...
#   → SPAM
# Procesando SMS 251/2676: ACCESO NO RECONOCIDO esta conectado a su cuenta on...
#   → SPAM (detectado por patrones)
# Procesando SMS 252/2676: CORREOS Su paquete no ha podido ser entregado no s...
#   → SPAM
# Procesando SMS 253/2676: SERVICIO CORREOS su paquete no se hapodido entrega...
#   → SPAM
# Procesando SMS 254/2676: fidelizacion en RIO CASINO disfruta grandes benefi...
#   → SPAM
# Procesando SMS 255/2676: ALERTA Su cuenta ha sido bloqueada temporalmente p...
#   → SPAM (detectado por patrones)
# Procesando SMS 256/2676: Mensaje de texto a XXX XX XX XX SMS/MMS CaixaBank ...
#   → SPAM
# Procesando SMS 257/2676: informarle que su cuenta ha sido temporalmente des...
#   → SPAM (detectado por patrones)
# Procesando SMS 258/2676: Caixabank Lamentamos informarle que su cuenta ha s...
#   → SPAM (detectado por patrones)
# Procesando SMS 259/2676: Mensaje de texto mié XX ene 11:05BBVA Su cuenta ha...
#   → SPAM
# Procesando SMS 260/2676: Texting with XXX XX XX XX SMS/MMS SANTANDER Aparti...
#   → SPAM (detectado por patrones)
# Procesando SMS 261/2676: Caixabank Lamentamos informarle que su cuenta ha s...
#   → SPAM (detectado por patrones)
# Procesando SMS 262/2676: Mensaje de texto a XXX XX XX XX SMS/MMS CORREOS Su...
#   → SPAM
# Procesando SMS 263/2676: Correos Su paquete no ha podido ser entregado porq...
#   → SPAM
# Procesando SMS 264/2676: AVISO Un equipo no autorizado esta conectado a su ...
#   → SPAM
# Procesando SMS 265/2676: algunos sueños viajes proyectos ... Llama al XXXXX...
#   → SPAM
# Procesando SMS 266/2676: Es otra variante de phishing En este caso el canal...
#   → NO SPAM
# Procesando SMS 267/2676: Caixabank Lamentamos informarle que su cuenta ha s...
#   → SPAM (detectado por patrones)
# Procesando SMS 268/2676: para completar el registro en Samsung Pay con su t...
#   → NO SPAM
# Procesando SMS 269/2676: Chilexpress Su paquete ha sido retenido en nuestro...
#   → SPAM
# Procesando SMS 270/2676: Se ha iniciado sesion desde un nuevo DISPOSITIVO s...
#   → NO SPAM
# Procesando SMS 271/2676: temporalmente por razones de seguridad Para reacti...
#   → SPAM
# Procesando SMS 272/2676: Banco Santander Informa Su firma electronica ha si...
#   → SPAM
# Procesando SMS 273/2676: Acceso no autorizado en su cuenta online Si no rec...
#   → SPAM (detectado por patrones)
# Procesando SMS 274/2676: Su cuenta serum inhabilitada debido a un inicio de...
#   → SPAM
# Procesando SMS 275/2676: bloqueada temporalmente por razones de seguridad P...
#   → SPAM
# Procesando SMS 276/2676: Mensajes de texto con X XXXX XXXX SMS/MMS Estimado...
#   → NO SPAM
# Procesando SMS 277/2676: Mensajes de texto con X XXXX XXXX SMS/MMS Banco de...
#   → SPAM (detectado por patrones)
# Procesando SMS 278/2676: Mensaje de texto a XXX XX XX XX SMS/MMS CORREOS Su...
#   → SPAM
# Procesando SMS 279/2676: Su paquete ES73 34B esta listo pague los costos de...
#   → NO SPAM
# Procesando SMS 280/2676: Estimado cliente su paquete no se ha podido entreg...
#   → SPAM
# Procesando SMS 281/2676: Se ha iniciado sesion desde un nuevo DISPOSITIVO s...
#   → SPAM
# Procesando SMS 282/2676: Actividad sospechosa por favor confirme su informa...
#   → NO SPAM
# Procesando SMS 283/2676: Hola tu envio PK 4E Será entregado el 04/02 en el ...
#   → SPAM
# Procesando SMS 284/2676: Banco Santander Informa Su cuenta ha sido temporal...
#   → SPAM (detectado por patrones)
# Procesando SMS 285/2676: Caixabank Lamentamos informarle que su cuenta ha s...
#   → SPAM (detectado por patrones)
# Procesando SMS 286/2676: Su cuenta ha sido bloqueada para desbloquearla ent...
#   → SPAM
# Procesando SMS 287/2676: Su cuenta ha sido suspendida temporalmente por mot...
#   → SPAM (detectado por patrones)
# Procesando SMS 288/2676: 19/02/2022 No puede utilizar su Tarjeta Tienes que...
#   → SPAM (detectado por patrones)
# Procesando SMS 289/2676: Estimado cliente su paquete no se ha podido entreg...
#   → SPAM
# Procesando SMS 290/2676: SANTANDER Hemos suspendido su cuenta tem poralemen...
#   → SPAM (detectado por patrones)
# Procesando SMS 291/2676: SEPE Pago de XXX EURO fallido por falta de actuali...
#   → SPAM
# Procesando SMS 292/2676: Se ha iniciado sesion desde un nuevo DISPOSITIVO s...
#   → SPAM
# Procesando SMS 293/2676: Somos Woocar una aplicacion que mide tu forma de m...
#   → NO SPAM
# Procesando SMS 294/2676: Un nuevo ha iniciado sesion si no have sido tu ver...
#   → SPAM
# Procesando SMS 295/2676: Nuestro sistema no alerta de un pre-cargo no autor...
#   → SPAM
# Procesando SMS 296/2676: Acceso no autorizado en su cuenta online Si no rec...
#   → SPAM (detectado por patrones)
# Procesando SMS 297/2676: Su paquete ES73 esta listo pague los costos de env...
#   → SPAM
# Procesando SMS 298/2676: Banco Santander Informa Su cuenta ha sido temporal...
#   → SPAM (detectado por patrones)
# Procesando SMS 299/2676: Hola ha sido seleccionado para un trabajo a tiempo...
#   → SPAM
# Procesando SMS 300/2676: Apartir del 10/12/2021 No puedes utilizar su cuent...
#   → SPAM
# Procesando SMS 301/2676: no se han cobrado la tasas de aduana 1,79€...
#   → NO SPAM
# Procesando SMS 302/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM (detectado por patrones)
# Procesando SMS 303/2676: Su paquete ES73 34B esta listo pague los costos de...
#   → SPAM
# Procesando SMS 304/2676: Lamentamos informarle que su cuenta ha sido desact...
#   → SPAM (detectado por patrones)
# Procesando SMS 305/2676: BancoEstado Por motivos de seguridad hemos bloquea...
#   → SPAM
# Procesando SMS 306/2676: Amazon ha estado intentando contactarte respecto a...
#   → SPAM
# Procesando SMS 307/2676: lunes XX de julio de XXXX Su tarjeta ha sido bloqu...
#   → SPAM (detectado por patrones)
# Procesando SMS 308/2676: Frankkaster en una entrevista mano a mano con Filo...
#   → NO SPAM
# Procesando SMS 309/2676: Jose en caso de que necesites efectivo en Monge te...
#   → NO SPAM
# Procesando SMS 310/2676: PUEDES GANAR DINERO EN CUARENTENA LIBRA FACEBOOK E...
#   → SPAM
# Procesando SMS 311/2676: Banca Movil Santander Estimado a cliente le invita...
#   → SPAM (detectado por patrones)
# Procesando SMS 312/2676: Uber Eats XXX de regalo hasta la XX h Usa el cupon...
#   → SPAM
# Procesando SMS 313/2676: Actividad sospechosa en su cuenta ScotiaBank Verif...
#   → SPAM
# Procesando SMS 314/2676: C. Madrid Listados provisionales convocatoria sani...
#   → SPAM
# Procesando SMS 315/2676: Carlos en caso de que necesites efectivo en Monge ...
#   → SPAM
# Procesando SMS 316/2676: EXPRESS Aquí encontrará toda la información de env...
#   → NO SPAM
# Procesando SMS 317/2676: Su cuenta bancaria de Santander ha sido bloqueada ...
#   → SPAM (detectado por patrones)
# Procesando SMS 318/2676: Banco Chile Se ha registrado su solicitud de retir...
#   → SPAM
# Procesando SMS 319/2676: Activa tus alertas irecibirás notificaciones de la...
#   → NO SPAM
# Procesando SMS 320/2676: Amazon ha estado intentando contactarte respecto a...
#   → SPAM
# Procesando SMS 321/2676: doble en Dimeburger Don Antonio Portico y muchos m...
#   → SPAM
# Procesando SMS 322/2676: Amazon ha estado intentando contactarte respecto a...
#   → SPAM
# Procesando SMS 323/2676: Amazon ha estado intentando contactarte respecto a...
#   → SPAM
# Procesando SMS 324/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 325/2676: Jose en caso de que necesites efectivo en Monge te...
#   → SPAM
# Procesando SMS 326/2676: `` Sabadell ES `` Usuario deshabilitado por razone...
#   → SPAM
# Procesando SMS 327/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 328/2676: BANCO Bankia Su cuenta ha sido bloqueada temporalm...
#   → SPAM (detectado por patrones)
# Procesando SMS 329/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 330/2676: C. Madrid Listados provisionales convocatoria sani...
#   → SPAM
# Procesando SMS 331/2676: SANTANDER Estimado cliente por motivos de segurida...
#   → SPAM (detectado por patrones)
# Procesando SMS 332/2676: BancoEstado Por motivos de seguridad hemos bloquea...
#   → SPAM
# Procesando SMS 333/2676: Amazon ha estado intentando contactarte respecto a...
#   → SPAM
# Procesando SMS 334/2676: BBVA Estimado Cliente Por Falta De Actualizacion S...
#   → SPAM
# Procesando SMS 335/2676: Hola Natalia Soy Betty agente virtual de Banco Fal...
#   → SPAM
# Procesando SMS 336/2676: CS279003594DE Estimado Inma su paquete ha sido det...
#   → NO SPAM
# Procesando SMS 337/2676: BancoEstado Por motivos de seguridad hemos bloquea...
#   → SPAM
# Procesando SMS 338/2676: Descarga la App BancoEstado y actívala con tu clav...
#   → SPAM
# Procesando SMS 339/2676: Su cuenta ha sido bloqueada temporalmente Para act...
#   → SPAM (detectado por patrones)
# Procesando SMS 340/2676: Rappi Dia de suerte D Te hemos cargado XX en Rappi...
#   → NO SPAM
# Procesando SMS 341/2676: Porque Claro te da Max Desde HOY y para SIEMPRE tu...
#   → SPAM
# Procesando SMS 342/2676: Opina sobre las normas para regular el funcionamie...
#   → NO SPAM
# Procesando SMS 343/2676: APROVECHA tenemos un PRECIO ESPECIAL para ti Y eso...
#   → SPAM
# Procesando SMS 344/2676: Solo hoy Fibra 2lineas moviles con Netflix gratis ...
#   → SPAM
# Procesando SMS 345/2676: Ahorra en tus llamadas al extranjero En Claro tene...
#   → SPAM
# Procesando SMS 346/2676: Quieres mas MEGAS de Internet Cambia hoy tu plan a...
#   → SPAM
# Procesando SMS 347/2676: Contrato XXXXXXXXXXX Deuda 51,62 € Inicio tramite ...
#   → SPAM
# Procesando SMS 348/2676: Muchas gracias Por favor responde enviando el nume...
#   → NO SPAM
# Procesando SMS 349/2676: Quieres mas MEGAS de Internet Cambia hoy tu plan a...
#   → SPAM
# Procesando SMS 350/2676: Aproveite essa oferta especial no Makro Santo Andr...
#   → NO SPAM
# Procesando SMS 351/2676: APROVECHA RENUEVA tu equipo Tenemos un PRECIO ESPE...
#   → SPAM
# Procesando SMS 352/2676: .. MOVISTAR habilito cobertura nacional 4G LTE Ult...
#   → SPAM
# Procesando SMS 353/2676: El Edil Hernando Avila Cortes y su equipo Kennedy ...
#   → NO SPAM
# Procesando SMS 354/2676: Tu eres la esperanza tu voto define el futuro del ...
#   → SPAM
# Procesando SMS 355/2676: Broncos les hice un mensaje compartanlo en todas l...
#   → NO SPAM
# Procesando SMS 356/2676: Este mensaje no e spam para ma info sobre como pro...
#   → NO SPAM
# Procesando SMS 357/2676: SANTANDER Estimado cliente por motivos de segurida...
#   → SPAM (detectado por patrones)
# Procesando SMS 358/2676: Felicidades Canjea este codigo XXXXXXXXXXXX en Cin...
#   → SPAM
# Procesando SMS 359/2676: viernes X de marzo de XXXX APROVECHA tenemos un PR...
#   → NO SPAM
# Procesando SMS 360/2676: Hola Su cuenta de whatsapp caducara para activarla...
#   → SPAM
# Procesando SMS 361/2676: SORPRESA Pasate a los nuevos plane CONEXION XX o S...
#   → SPAM
# Procesando SMS 362/2676: Recargar tu cuenta Vippo es muy facil Envia la pal...
#   → SPAM
# Procesando SMS 363/2676: Orange continuamos sin recibir su pago Acceda a pa...
#   → NO SPAM
# Procesando SMS 364/2676: Amigo Tricolor clique abaixo e saiba por que Pedro...
#   → NO SPAM
# Procesando SMS 365/2676: Financiamos carros usados y seminuevos de todas la...
#   → NO SPAM
# Procesando SMS 366/2676: Empieza el XXXX con todo HOY sorteamos X MILLONES ...
#   → SPAM
# Procesando SMS 367/2676: Recargar tu cuenta Vippo es muy facil Envia la pal...
#   → SPAM
# Procesando SMS 368/2676: ARNALDO RAMON La mejor Financiera te quiere como C...
#   → SPAM
# Procesando SMS 369/2676: Estimado Usuario Hemos detectado Actividad inusual...
#   → SPAM
# Procesando SMS 370/2676: Mensajes 10:19 Orange Orange Para finalizar la com...
#   → SPAM
# Procesando SMS 371/2676: Asunto Error de sesion Remitente Servicio al clien...
#   → SPAM
# Procesando SMS 372/2676: Empieza el XXXX con todo Esta semana sorteamos X m...
#   → SPAM
# Procesando SMS 373/2676: Codigo K2MF1XPN para incorporar su nuevo tfno movi...
#   → SPAM
# Procesando SMS 374/2676: SORPRESA Pasate a los nuevos plane CONEXION XX o S...
#   → SPAM
# Procesando SMS 375/2676: Dile HOLA a todos Con el plan CONEXION XX con full...
#   → SPAM
# Procesando SMS 376/2676: ETECSA informa Del X al XX de noviembre si recarga...
#   → NO SPAM
# Procesando SMS 377/2676: SANTANDER Por motivos de seguridad hemos bloqueado...
#   → SPAM (detectado por patrones)
# Procesando SMS 378/2676: Aprovecha este beneficio Paga hoy y te descontamos...
#   → SPAM
# Procesando SMS 379/2676: CS279003594DE Estimado Giuseppe su paquete ha sido...
#   → SPAM
# Procesando SMS 380/2676: BANKIA.S.A lamentamos informarle que su cuenta ha ...
#   → SPAM (detectado por patrones)
# Procesando SMS 381/2676: Estimado cliente el dia 06/11 no ha sido posible h...
#   → SPAM
# Procesando SMS 382/2676: Aprovecha este beneficio Paga hoy y te descontamos...
#   → SPAM
# Procesando SMS 383/2676: Su cuenta ha sido bloqueada temporalmente por moti...
#   → SPAM
# Procesando SMS 384/2676: CORREOS Su paquete ES29 XX esta listo pague los co...
#   → SPAM
# Procesando SMS 385/2676: XX EXTRA DE SALDO en toda la recargas No dejes esc...
#   → SPAM
# Procesando SMS 386/2676: BBVA informa cobro Uber XXXX cargo TDD XXXXXX duda...
#   → SPAM
# Procesando SMS 387/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 388/2676: Su cuenta ha sido bloqueada temporalmente por moti...
#   → SPAM
# Procesando SMS 389/2676: Bankia Lamentamos informarle que su cuenta serum b...
#   → SPAM (detectado por patrones)
# Procesando SMS 390/2676: SANTANDER Por motivos de seguridad bloqueamos tu T...
#   → SPAM (detectado por patrones)
# Procesando SMS 391/2676: ¿ Puedes trabajar en linea La paga es de hasta 1.6...
#   → SPAM
# Procesando SMS 392/2676: Estimado a cliente Le invitamos a confirmar rapida...
#   → SPAM (detectado por patrones)
# Procesando SMS 393/2676: Publimovil No te pierdas nuestra LVBP Resultados n...
#   → SPAM
# Procesando SMS 394/2676: Su cuenta ha sido bloqueada temporalmente por moti...
#   → SPAM
# Procesando SMS 395/2676: SANTANDER Por motivos de seguridad bloqueamos tu T...
#   → SPAM (detectado por patrones)
# Procesando SMS 396/2676: Necesitamos informacion adicional para el envio de...
#   → SPAM
# Procesando SMS 397/2676: Usuario BANCOMER Tu cuenta se encuentra bloqueada ...
#   → SPAM
# Procesando SMS 398/2676: XX Dic XX Bancomer TDD Bmovil -3,700.00 movimiento...
#   → NO SPAM
# Procesando SMS 399/2676: transacción sospechosa en su cuenta Si no realizó ...
#   → SPAM
# Procesando SMS 400/2676: Tiene un mensaje referente a su articulo ref AMA24...
#   → SPAM (detectado por patrones)
# Procesando SMS 401/2676: BANKIA.S.A lamentamos informarle que su cuenta ha ...
#   → SPAM (detectado por patrones)
# Procesando SMS 402/2676: Swarovski celebra su XXX aniversario de su legado ...
#   → SPAM
# Procesando SMS 403/2676: A saudade de viajar ta batendo MadruGOL com supero...
#   → SPAM
# Procesando SMS 404/2676: Estimado cliente su tarjeta ha sido bloqueada temp...
#   → SPAM
# Procesando SMS 405/2676: Santander Debido a una actualizacion hemos tenido ...
#   → SPAM (detectado por patrones)
# Procesando SMS 406/2676: Su cuenta ha sido bloqueada temporalmente por moti...
#   → SPAM
# Procesando SMS 407/2676: Hola en relacion con la pandemia COVID19 el Estado...
#   → NO SPAM
# Procesando SMS 408/2676: Su paquete ES C2019142 se detuvo en el centro de d...
#   → SPAM
# Procesando SMS 409/2676: Estimado Cliente Su cuenta esta bajo revision Comp...
#   → SPAM
# Procesando SMS 410/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 411/2676: 36_169 16:41 a m +44 to en línea HOLA UN CORDIAL S...
#   → NO SPAM
# Procesando SMS 412/2676: Banco Estado Bono COVID XX para hacer parte de la ...
#   → SPAM (detectado por patrones)
# Procesando SMS 413/2676: Que pasa en Colombia y el mundo Red Mas se lo cuen...
#   → NO SPAM
# Procesando SMS 414/2676: Su paquete esta esperando la entrega Confirme el p...
#   → SPAM
# Procesando SMS 415/2676: Recordatorio ¡ MEDIAMARKT le envio un mensaje impo...
#   → SPAM
# Procesando SMS 416/2676: App COVID XX MX Cuidate a ti ya tu familia Con inf...
#   → SPAM
# Procesando SMS 417/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 418/2676: Tienes un reembolso en espera de confirmacion Mas ...
#   → SPAM
# Procesando SMS 419/2676: jueves XX abr • 13:58 Aprovecha 24/04 al 10/05 TOD...
#   → NO SPAM
# Procesando SMS 420/2676: Banco Santander 06/05/2020 `` Recibos SEPA al CCC ...
#   → SPAM
# Procesando SMS 421/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 422/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 423/2676: Recordatorio ¡ MEDIAMARKT le envio un mensaje impo...
#   → SPAM
# Procesando SMS 424/2676: Seitb.eus Alertan de un SMS para realizar una eval...
#   → SPAM
# Procesando SMS 425/2676: `` Santander ES `` Se ha bloqueado preventivamente...
#   → SPAM
# Procesando SMS 426/2676: `` Santander ES `` Se ha bloqueado preventivamente...
#   → SPAM
# Procesando SMS 427/2676: Estimado cliente debe pagar 2,99E de IVA por su pa...
#   → SPAM
# Procesando SMS 428/2676: miércoles XX de mayo de XXXX ESTIMADO CLIENTE su c...
#   → SPAM
# Procesando SMS 429/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 430/2676: Tu envio de Haede GmbH se entregara el 1/06/2020 S...
#   → NO SPAM
# Procesando SMS 431/2676: `` Santander ES `` Usuario deshabi litado por razo...
#   → SPAM
# Procesando SMS 432/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 433/2676: BANCO ESTADO informa que su cuenta serum bloqueada...
#   → SPAM (detectado por patrones)
# Procesando SMS 434/2676: Banco Estado Su Tarjeta de COORDENADAS ha caducado...
#   → SPAM (detectado por patrones)
# Procesando SMS 435/2676: VF Info Tus consultas acerca de Vodafone desde cua...
#   → NO SPAM
# Procesando SMS 436/2676: Hola en relacion con la pandemia COVID19 el Estado...
#   → NO SPAM
# Procesando SMS 437/2676: Paquete para la familia L Cambre Estimado r Has ga...
#   → SPAM (detectado por patrones)
# Procesando SMS 438/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 439/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 440/2676: Nos encanta que confíes en nosotros por lo que con...
#   → NO SPAM
# Procesando SMS 441/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 442/2676: CaixaBank Pay es im prescindible que ante del XX d...
#   → SPAM
# Procesando SMS 443/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 444/2676: Claro Panama le informa el saldo de su linea celul...
#   → SPAM
# Procesando SMS 445/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 446/2676: Disfruta con Claro ma datos para ti primero porque...
#   → SPAM
# Procesando SMS 447/2676: sábado XX de mayo de XXXX Recientemente hemos bloq...
#   → SPAM (detectado por patrones)
# Procesando SMS 448/2676: Si te cuidas tu nos cuidamos todos Descarga la App...
#   → SPAM
# Procesando SMS 449/2676: ESTIMADO CLIENTE su cuenta ha sido bloqueada por s...
#   → SPAM
# Procesando SMS 450/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 451/2676: Para seguir utilizando la app CaixaBank Pay es imp...
#   → SPAM
# Procesando SMS 452/2676: `` Santander ES `` Usuario deshabilitado por razon...
#   → SPAM
# Procesando SMS 453/2676: Banco de Chile Su DigiPass se ha desincronizado pa...
#   → SPAM
# Procesando SMS 454/2676: BBVA Para realizar tu operacion utiliza el codigoB...
#   → NO SPAM
# Procesando SMS 455/2676: El codigo de seguridad solicitado por usted desde ...
#   → SPAM (detectado por patrones)
# Procesando SMS 456/2676: bloqueada temporalmente por razones de seguridad P...
#   → SPAM
# Procesando SMS 457/2676: Su cuenta serum inhabilitada debido a un inicio de...
#   → SPAM
# Procesando SMS 458/2676: Banco de Chile estimado cliente su canal digital h...
#   → SPAM (detectado por patrones)
# Procesando SMS 459/2676: INCREIBLE Un XIAOMI REDMI 9A XX GB GRATIS pasandot...
#   → SPAM
# Procesando SMS 460/2676: para activar el metodo de acceso a su banca online...
#   → SPAM (detectado por patrones)
# Procesando SMS 461/2676: em produtos selecionados Cancelar SMS envie PARE...
#   → NO SPAM
# Procesando SMS 462/2676: BBVA Para realizar tu operacion utiliza el codigod...
#   → SPAM
# Procesando SMS 463/2676: que su cuenta ha sido desactivada y por su segurid...
#   → SPAM
# Procesando SMS 464/2676: AUTORIZADO se ha conectado a su cuenta Si no recon...
#   → SPAM
# Procesando SMS 465/2676: Banco Santander Informa Le rogamos que confirme su...
#   → SPAM
# Procesando SMS 466/2676: complete los campos requeridos para evitar el bloq...
#   → SPAM
# Procesando SMS 467/2676: Para finalizar su tramite de inscripcion debe real...
#   → SPAM
# Procesando SMS 468/2676: DHL Su paquete ha sido devuelto al remitente Debe ...
#   → SPAM
# Procesando SMS 469/2676: puede entregar no se han cobrado la tasas aduana 1...
#   → SPAM
# Procesando SMS 470/2676: para activar el metodo de acceso a su banca online...
#   → SPAM
# Procesando SMS 471/2676: BBVA Su cuenta ha sido bloqueada temporalmente por...
#   → SPAM (detectado por patrones)
# Procesando SMS 472/2676: Correos Su paquete no podrá entregarse el 18/01/20...
#   → SPAM
# Procesando SMS 473/2676: CORREOS Su paquete no ha podido ser entregado no s...
#   → SPAM
# Procesando SMS 474/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM (detectado por patrones)
# Procesando SMS 475/2676: Banco Santander Informa Le rogamos que confirme ra...
#   → SPAM (detectado por patrones)
# Procesando SMS 476/2676: Un dispositivo no autorizado se ha conectado a su ...
#   → SPAM
# Procesando SMS 477/2676: Notificacion de Caixa Partir del 18/01/2022 No se ...
#   → SPAM
# Procesando SMS 478/2676: seguridad tiene que actualizar su cuenta si no sus...
#   → SPAM
# Procesando SMS 479/2676: seguridad pedimos que actualice sus datos y evite ...
#   → SPAM (detectado por patrones)
# Procesando SMS 480/2676: Notificacion de La CAIXA.BANK No se puede utilizar...
#   → SPAM
# Procesando SMS 481/2676: ACCESO NO RECONOCIDO esta conectado a su cuenta on...
#   → SPAM (detectado por patrones)
# Procesando SMS 482/2676: temporalmente por motivos de seguridad siga los pa...
#   → SPAM
# Procesando SMS 483/2676: ha conectado a su cuenta online Si no reconoce est...
#   → NO SPAM
# Procesando SMS 484/2676: un dispositivo no autorizado se ha conectado a su ...
#   → NO SPAM
# Procesando SMS 485/2676: ALERTA Su cuenta ha sido bloqueada temporalmente p...
#   → SPAM (detectado por patrones)
# Procesando SMS 486/2676: CaixaBank Lamentamos informarle que su cuenta ha s...
#   → SPAM
# Procesando SMS 487/2676: de compra en RENFE por 67.60 EUR 31/08/2020 18:05:...
#   → SPAM (detectado por patrones)
# Procesando SMS 488/2676: BBVA Para confirmar el pago de XX EUR realizado co...
#   → SPAM
# Procesando SMS 489/2676: conectado a su cuenta Laboralkutxa Si no reconoce ...
#   → SPAM
# Procesando SMS 490/2676: de compra en RENFE por 49.75 EUR 22/08/2020 14:33:...
#   → NO SPAM
# Procesando SMS 491/2676: Su cuenta ha sido bloqueada temporalmente por razo...
#   → SPAM (detectado por patrones)
# Procesando SMS 492/2676: para tu nueva clave de acceso en Banco Santander M...
#   → SPAM
# Procesando SMS 493/2676: A partir del XX de enero no podras pagar online co...
#   → SPAM
# Procesando SMS 494/2676: de 44,97 EUR realizado con tu tarjeta BBVA Para re...
#   → SPAM
# Procesando SMS 495/2676: BBVA Su cuenta ha sido suspendida temporalmente po...
#   → SPAM
# Procesando SMS 496/2676: BBVA Para realizar la transferencia de XXX EUR y c...
#   → SPAM
# Procesando SMS 497/2676: el nuevo sistema de seguridad ahora http //cutt.ly...
#   → SPAM
# Procesando SMS 498/2676: Estimado cliente Su paquete esta listo para la ent...
#   → SPAM
# Procesando SMS 499/2676: Notificacion de Caixa Partir del 14/01/2022 No se ...
#   → SPAM (detectado por patrones)
# Procesando SMS 500/2676: Marcos esto no e un SMS es una LANZADERA de Fundac...
#   → SPAM
# Procesando SMS 501/2676: AVISO Se ha detectado movimientos no habituales en...
#   → SPAM
# Procesando SMS 502/2676: Denuncia este mensaje para ayudarnos a prevenir el...
#   → SPAM
# Procesando SMS 503/2676: puede utilizar su Tarjeta Debito Tienes queactivar...
#   → SPAM (detectado por patrones)
# Procesando SMS 504/2676: Estimado a Cliente se abono los S/350.00 del bono ...
#   → SPAM (detectado por patrones)
# Procesando SMS 505/2676: Su cuenta ha sido bloqueada temporalmente por razo...
# ...
#   → SPAM
# Procesando SMS 2511/2676: Agencia Tributaria Te califico para un reembolso d...
#   → SPAM
# Procesando SMS 2512/2676: Hemos detectado un acceso no autorizado en su banc...
#   → SPAM
# Procesando SMS 2513/2676: Se ha iniciado sesion desde un nuevo DISPOSITIVO s...
#   → SPAM
# Procesando SMS 2514/2676: XXX XX XX XX • Mensajes • X minTe califico para un...
#   → SPAM
# Procesando SMS 2515/2676: have realizado tu esta operacion llamanos al 91206...
#   → SPAM
# Procesando SMS 2516/2676: izzería de Donn 07:24 ¡Oferta especial Solo hoy il...
#   → NO SPAM
# Procesando SMS 2517/2676: motivos de seguridad para activar su cuenta inicie...
#   → SPAM
# Procesando SMS 2518/2676: AGENCIA TRIBUTARIA Te califico para un reembolso d...
#   → SPAM
# Procesando SMS 2519/2676: para confirmar tu envio de Bizum de al Si nohas re...
#   → SPAM
# Procesando SMS 2520/2676: SERVEL informa En el Plebiscito el voto e OBLIGATO...
#   → NO SPAM
# Procesando SMS 2521/2676: Mensajes de texto con X XXXX XXXX SMS/MMS BancoEst...
#   → SPAM (detectado por patrones)
# Procesando SMS 2522/2676: JOHRMAN se detecto una operacion inusual en la cue...
#   → SPAM (detectado por patrones)
# Procesando SMS 2523/2676: MENSAJE IMPORTANTE DE MERCEDES-BENZ AG hemos actua...
#   → SPAM
# Procesando SMS 2524/2676: Compra aceptada por importe de 986.45 euro Si no h...
#   → SPAM
# Procesando SMS 2525/2676: Gonzalo ¡ULTIMOS X DIAS S/1,000 pueden ser tuyos o...
#   → SPAM
# Procesando SMS 2526/2676: Colpatria Tu acceso se encuentra bloqueado para po...
#   → SPAM
# Procesando SMS 2527/2676: Mensaje de texto a XXX XX XX XX SMS/MMS Banco BBVA...
#   → SPAM
# Procesando SMS 2528/2676: Banco Estado Ya esta disponible Bono Chile Apoya p...
#   → SPAM (detectado por patrones)
# Procesando SMS 2529/2676: Con WIFI Mesh mejoras la conectividad de tu hogar ...
#   → SPAM
# Procesando SMS 2530/2676: Su paquete esta listo para la entrega confirme...
#   → SPAM
# Procesando SMS 2531/2676: Se ha realizado un cargo de 105,00 EUR en su cuent...
#   → SPAM (detectado por patrones)
# Procesando SMS 2532/2676: `` Agencia Tributaria Os ha calificado para un ree...
#   → NO SPAM
# Procesando SMS 2533/2676: Su tarjeta ha sido bloqueada temporalmente por raz...
#   → SPAM
# Procesando SMS 2534/2676: Juga en http //bit.ly/3PuyDLp por un RENAULT KWID ...
#   → SPAM
# Procesando SMS 2535/2676: have realizado tu esta operacion llamanos al 91206...
#   → SPAM
# Procesando SMS 2536/2676: Estimado cliente Su paquete esta listo para la ent...
#   → SPAM
# Procesando SMS 2537/2676: Notificacion Banco Santander A partir del 19/08/20...
#   → SPAM
# Procesando SMS 2538/2676: Mensaje de texto a XXX XX XX XX SMS/MMS SANTANDER ...
#   → SPAM (detectado por patrones)
# Procesando SMS 2539/2676: Empleo directo en línea independientemente de la r...
#   → SPAM
# Procesando SMS 2540/2676: Su paquete esta listo para la entrega confirmeel p...
#   → SPAM
# Procesando SMS 2541/2676: Se ha iniciado sesion desde un nuevo DISPOSITIVO s...
#   → SPAM
# Procesando SMS 2542/2676: Inicia con la recepción de un enlace a través de S...
#   → SPAM
# Procesando SMS 2543/2676: Estimado cliente a partir del 23/08/2022 No podra ...
#   → NO SPAM
# Procesando SMS 2544/2676: Mensaje de texto a XXX XX XX XX SMS/MMS CORREOS EX...
#   → NO SPAM
# Procesando SMS 2545/2676: Accion requerida en tu tarjeta se han detectado mo...
#   → SPAM
# Procesando SMS 2546/2676: Su paquete no se ha podido entregar porque no se h...
#   → SPAM
# Procesando SMS 2547/2676: +34 XXX XXX XXX Message Aujourd'hui 14:11Estimado ...
#   → SPAM
# Procesando SMS 2548/2676: 105,00 EUR en su cuenta Si no...
#   → SPAM
# Procesando SMS 2549/2676: Los mensajes y la llamadas están cifrados de extre...
#   → NO SPAM
# Procesando SMS 2550/2676: online ha sido anulada por seguridad complete la s...
#   → SPAM
# Procesando SMS 2551/2676: Elija la forma de pago y acepte las condicione...
#   → SPAM
# Procesando SMS 2552/2676: Envies missatges de text a XXX XX XX XX SMS/MMS 24...
#   → SPAM (detectado por patrones)
# Procesando SMS 2553/2676: Mensajes de texto con XX XXXX XXXX SMS/MMS BANAMEX...
#   → SPAM
# Procesando SMS 2554/2676: Correos Estimado cliente Su paquete esta listo par...
#   → SPAM
# Procesando SMS 2555/2676: Estimado cliente A partir del 28/08/2022 no podra ...
#   → SPAM
# Procesando SMS 2556/2676: Mensaje de texto a XXX XX XX XX SMS/MMS Banco Sant...
#   → SPAM (detectado por patrones)
# Procesando SMS 2557/2676: X- Envío de SMS con mensaje alarmante y enlace rec...
#   → SPAM
# Procesando SMS 2558/2676: Tu codigo Uber e XXXX Si no fuiste tu Envia STOP a...
#   → SPAM
# Procesando SMS 2559/2676: Sr Piscicultor mantenga el personal en continuum c...
#   → NO SPAM
# Procesando SMS 2560/2676: ALERTAS BBVA BANCOMER Su tarjeta BBVA BANCOMER ha ...
#   → SPAM
# Procesando SMS 2561/2676: Enhorabuena Los resultados han sa lido y tu codigo...
#   → SPAM
# Procesando SMS 2562/2676: ¿ todavia tiene sus muebles en Milanuncios disponi...
#   → NO SPAM
# Procesando SMS 2563/2676: Rappi.com Activa el cod 5XSHIPPING y te regalamos ...
#   → SPAM
# Procesando SMS 2564/2676: Rosario Robles comparecerá ante el Pleno de Diputa...
#   → NO SPAM
# Procesando SMS 2565/2676: Tu puedes saber la verdad Transmission telepatica ...
#   → NO SPAM
# Procesando SMS 2566/2676: Rappi.com Activa el cod 5XSHIPPING y te regalamos ...
#   → SPAM
# Procesando SMS 2567/2676: Info Codigo de seguridad 55206598.Autorizacion de ...
#   → SPAM
# Procesando SMS 2568/2676: Su cuenta de Santander ha sido restringida Inicie ...
#   → SPAM (detectado por patrones)
# Procesando SMS 2569/2676: ALERTA Su cuenta bancaria Santander ha sido restri...
#   → SPAM (detectado por patrones)
# Procesando SMS 2570/2676: SANTANDER Por motivos de seguridad hemos bloqueado...
#   → SPAM (detectado por patrones)
# Procesando SMS 2571/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2572/2676: Banco Santander su cuenta està actualmente suspend...
#   → SPAM
# Procesando SMS 2573/2676: BANCO BANKIA Su cuenta ha sido bloquea da temporal...
#   → SPAM (detectado por patrones)
# Procesando SMS 2574/2676: BBVA Tu cuenta ha sido bloqueada Para desbloquear ...
#   → SPAM
# Procesando SMS 2575/2676: SANTANDER Por motivos de seguridad hemos bloqueado...
#   → SPAM (detectado por patrones)
# Procesando SMS 2576/2676: BANCO BANKIA Su cuenta ha sido bloqueada temporalm...
#   → SPAM (detectado por patrones)
# Procesando SMS 2577/2676: Lamentablemente su `` Tarjeta `` Ibercaja se ha de...
#   → SPAM (detectado por patrones)
# Procesando SMS 2578/2676: CORREOS Su paquete BC21 W esta listo pague los cos...
#   → SPAM
# Procesando SMS 2579/2676: Aprovecha ahora La Gran Venta de Aniversario Sodim...
#   → SPAM
# Procesando SMS 2580/2676: CORREOS Su paquete DW54 S esta listo pague los cos...
#   → SPAM
# Procesando SMS 2581/2676: CORREOS Su paquete MS77 A esta listo pague los cos...
#   → SPAM
# Procesando SMS 2582/2676: CORREOS Su paquete QG79 X esta listo pague los cos...
#   → SPAM
# Procesando SMS 2583/2676: Ven a la Gran Venta de Aniversario Sodimac y no te...
#   → SPAM
# Procesando SMS 2584/2676: CORREOS Su paquete DW54 S esta listo pague los cos...
#   → SPAM
# Procesando SMS 2585/2676: CORREOS Su paquete BC21 W esta listo pague los cos...
#   → SPAM
# Procesando SMS 2586/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2587/2676: +62 XXX XXXXXXXX X Indonesia...
#   → NO SPAM
# Procesando SMS 2588/2676: Estimado Cliente Su paquete no puedo entregar el 2...
#   → SPAM
# Procesando SMS 2589/2676: SANTANDER Por motivos de seguridad hemos bloqueado...
#   → SPAM (detectado por patrones)
# Procesando SMS 2590/2676: Estamos de Aniversario en Sodimac Ven y aprovecha ...
#   → SPAM
# Procesando SMS 2591/2676: Para agradecerle por utilizar nuestro servicio Fra...
#   → SPAM
# Procesando SMS 2592/2676: CORREOS Su paquete BC21 W esta listo pague los cos...
#   → SPAM
# Procesando SMS 2593/2676: Ismael por favor confirma tus credenciales para la...
#   → SPAM
# Procesando SMS 2594/2676: CORREOS Su paquete MD17 J esta listo pague los cos...
#   → SPAM
# Procesando SMS 2595/2676: SANTANDER A partir del 24/09 No puedo utilizar su ...
#   → SPAM (detectado por patrones)
# Procesando SMS 2596/2676: ¡ Felicidades have ganado la oportunidad de formar...
#   → SPAM
# Procesando SMS 2597/2676: Hola es un timo un fraude Nosotros nunca solicitam...
#   → NO SPAM
# Procesando SMS 2598/2676: ¿ Pensando en que comer descarga YA Ubii Go la sup...
#   → SPAM
# Procesando SMS 2599/2676: ¡ Felicitaciones have ganado un iPhone XX Como par...
#   → SPAM
# Procesando SMS 2600/2676: Tenemos un problema con la entrega de su paquete p...
#   → SPAM
# Procesando SMS 2601/2676: Suscribirse a EL PAIS ahora es ma facil con tu ANT...
#   → NO SPAM
# Procesando SMS 2602/2676: ALERTA Tu cuenta bancaria de santander ha sido blo...
#   → SPAM (detectado por patrones)
# Procesando SMS 2603/2676: HOY 19/09 en Diesel XX dcto en toda la tienda y XX...
#   → SPAM (detectado por patrones)
# Procesando SMS 2604/2676: Hola Conoce UinUin la 1ra financiera para buenos p...
#   → SPAM
# Procesando SMS 2605/2676: SANTANDER Por motivos de seguridad hemos bloqueado...
#   → SPAM (detectado por patrones)
# Procesando SMS 2606/2676: CORREOS Su paquete esta listo Pague los costos de ...
#   → SPAM
# Procesando SMS 2607/2676: María Antonia tiene un mensaje referente a su arti...
#   → SPAM (detectado por patrones)
# Procesando SMS 2608/2676: Su cuenta ha sido bloqueada temporalmente por moti...
#   → SPAM
# Procesando SMS 2609/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → NO SPAM
# Procesando SMS 2610/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2611/2676: SANTANDER A partir del 24/09 No puedo utilizar su ...
#   → SPAM (detectado por patrones)
# Procesando SMS 2612/2676: Rappi Es tu momento de hacer tu primer pedido porq...
#   → SPAM (detectado por patrones)
# Procesando SMS 2613/2676: CORREOS Su paquete QG79 X esta listo pague los cos...
#   → NO SPAM
# Procesando SMS 2614/2676: CS279003594DE Estimado Victor su paquete ha sido d...
#   → SPAM
# Procesando SMS 2615/2676: Su cuenta ha sido bloqueada temporalmente por moti...
#   → SPAM
# Procesando SMS 2616/2676: CORREOS Su paquete GH77 W esta listo pague los cos...
#   → SPAM
# Procesando SMS 2617/2676: Nombre del dominio uinuin.com.uy Contacto Titular ...
#   → NO SPAM
# Procesando SMS 2618/2676: BANCO BANKIA Su cuenta ha sido bloqueada temporalm...
#   → SPAM (detectado por patrones)
# Procesando SMS 2619/2676: Rogamos contacte urgentemente con Medina Cuadros e...
#   → NO SPAM
# Procesando SMS 2620/2676: Tu cuenta de santander ha sido restringida Debe in...
#   → SPAM (detectado por patrones)
# Procesando SMS 2621/2676: CORREOS Su paquete MS77 A esta listo pague los cos...
#   → SPAM
# Procesando SMS 2622/2676: En Sodimac estamos de Aniversario Te esperamos Ent...
#   → SPAM
# Procesando SMS 2623/2676: Aprovecha nuestros precios bajos de Gran Venta de ...
#   → NO SPAM
# Procesando SMS 2624/2676: E Mensajes • cdmx • X min XXX XXX XXXX Rappi Tiene...
#   → SPAM (detectado por patrones)
# Procesando SMS 2625/2676: Determinamos que eres elegible para recibir un ree...
#   → SPAM
# Procesando SMS 2626/2676: Info Codigo de seguridad 89634134.Autorizacion de ...
#   → NO SPAM
# Procesando SMS 2627/2676: SANTANDER Estimado cliente por motivos de segurida...
#   → SPAM (detectado por patrones)
# Procesando SMS 2628/2676: Hola Ofrecemos préstamos de 1,000 a 10.000.000 con...
#   → SPAM
# Procesando SMS 2629/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2630/2676: BBVA Debido a una actualizacion hemos tenido que s...
#   → SPAM
# Procesando SMS 2631/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2632/2676: Genera ya tu Codigo QR Ba colombia y ofrece a tus ...
#   → SPAM
# Procesando SMS 2633/2676: Su cuenta bancaria ha sido bloqueada Para activar ...
#   → SPAM
# Procesando SMS 2634/2676: Hola Claudia su envio se entrego el X XX-XXXX en e...
#   → SPAM
# Procesando SMS 2635/2676: ALERTA Por razones de seguridad hemos bloqueado su...
#   → SPAM
# Procesando SMS 2636/2676: Amazon ES Tienes un reembolso en espera de confirm...
#   → SPAM
# Procesando SMS 2637/2676: Para continuar usando idealista por favor lea los ...
#   → SPAM
# Procesando SMS 2638/2676: XXX XX XX XX CORREOS Su paquete QG79 X esta listo ...
#   → SPAM
# Procesando SMS 2639/2676: SANTANDER Estimado cliente por motivos de segurida...
#   → SPAM (detectado por patrones)
# Procesando SMS 2640/2676: BancoEstado Por motivos de seguridad hemos bloquea...
#   → SPAM
# Procesando SMS 2641/2676: Banco Santander.es Su firma electronica caducara e...
#   → SPAM
# Procesando SMS 2642/2676: E Messages • cdmx • 1h XXX XXX XXXX Rappi Tienes M...
#   → SPAM
# Procesando SMS 2643/2676: Hola Llevate tu crAįdito YA por X millones formali...
#   → SPAM
# Procesando SMS 2644/2676: por favor confirma tus credenciales para la entreg...
#   → SPAM
# Procesando SMS 2645/2676: por favor confirma tus credenciales para la entreg...
#   → SPAM
# Procesando SMS 2646/2676: Recibira su envio de DECATHLON.ES.Si quiere modifi...
#   → SPAM
# Procesando SMS 2647/2676: Monitorea tu hogar d a y noche desde tu celular y ...
#   → SPAM
# Procesando SMS 2648/2676: Zaida por favor confirma tus credenciales para la ...
#   → SPAM
# Procesando SMS 2649/2676: Su cuenta bancaria esta restringida por actividad ...
#   → SPAM
# Procesando SMS 2650/2676: BancoChile Se registro tu solicitud de retiro desd...
#   → NO SPAM
# Procesando SMS 2651/2676: Recibira su envio de PB.Si quiere mo dificar la en...
#   → NO SPAM
# Procesando SMS 2652/2676: BancoChile Se ha registrado con exito tu solicitud...
#   → SPAM
# Procesando SMS 2653/2676: Paquete ES897 XX Le pedimos que nos envie su direc...
#   → SPAM (detectado por patrones)
# Procesando SMS 2654/2676: Le informamos que ha recibido un documento importa...
#   → SPAM
# Procesando SMS 2655/2676: Santander Santander notifica a dia X agosto tiene ...
#   → SPAM (detectado por patrones)
# Procesando SMS 2656/2676: Davivienda le informa que debido a un movimiento i...
#   → SPAM
# Procesando SMS 2657/2676: Rappi Necesitas algo Tienes MXN XX cargados en tu ...
#   → SPAM
# Procesando SMS 2658/2676: Recibira su envio de DECATHLON.ES.Si quiere modifi...
#   → SPAM
# Procesando SMS 2659/2676: CORREOS Su paquete QG79 X esta listo pague los cos...
#   → SPAM
# Procesando SMS 2660/2676: CORREOS Su paquete WNG79 X esta listo pague los co...
#   → SPAM
# Procesando SMS 2661/2676: Ya activaste Pago Automatico XX de dcto en la segu...
#   → SPAM
# Procesando SMS 2662/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2663/2676: Su tarjeta ha sido bloqueada debido a un cargo sos...
#   → SPAM (detectado por patrones)
# Procesando SMS 2664/2676: CORREOS Su paquete QG79 X esta listo pague los cos...
#   → SPAM
# Procesando SMS 2665/2676: BANCOLOMBIA informa por motivos de seguridad su cl...
#   → SPAM
# Procesando SMS 2666/2676: CORREOS le informo que el paquete estaba esperando...
#   → SPAM
# Procesando SMS 2667/2676: Estimado Cliente Su servicio de bancomer movil se ...
#   → SPAM (detectado por patrones)
# Procesando SMS 2668/2676: Quedate EnCasa Disfruta todos los recursos de tu p...
#   → NO SPAM
# Procesando SMS 2669/2676: Sat X Aug 12:53 idealista.com el codigo para entra...
#   → SPAM
# Procesando SMS 2670/2676: CORREOS Su paquete WNG XX X esta listo pague los c...
#   → SPAM
# Procesando SMS 2671/2676: BancoEstado Por motivos de seguridad hemos bloquea...
#   → SPAM
# Procesando SMS 2672/2676: ¡ Felicitaciones estás aquí para ganar hoy con Cor...
#   → SPAM
# Procesando SMS 2673/2676: B Messages • 6h XXX XXX XXXX Rappi Aprovecha que t...
#   → SPAM
# Procesando SMS 2674/2676: sábado XX de septiembre de XXXX XXXXXX e tu codigo...
#   → NO SPAM
# Procesando SMS 2675/2676: Hemos tratado de contactarlo have sido el X ganado...
#   → SPAM
# Procesando SMS 2676/2676: CORREOS Su paquete QFG79 X esta listo pague los co...
#   → SPAM
#
# === RESULTADOS ===
# Total de SMS analizados: 2676
# SMS clasificados como SPAM: 2147
# SMS clasificados como NO SPAM: 529
# Porcentaje de SPAM: 80.2%
#
# ✅ Archivos guardados en:
#   - SPAM: dataset_3/spam.txt
#   - NO SPAM: dataset_3/no_spam.txt

# %%
import ollama
import os

def crear_directorio(directorio):
    """Crea el directorio si no existe"""
    if not os.path.exists(directorio):
        os.makedirs(directorio)

def limpiar_sms(texto):
    """Limpia el SMS eliminando comillas y caracteres no deseados"""
    # Eliminar comillas dobles y simples del inicio y fin
    texto = texto.strip().strip('"').strip("'")
    # Eliminar comillas dobles internas si están al inicio y fin
    if texto.startswith('"') and texto.endswith('"'):
        texto = texto[1:-1]
    if texto.startswith("'") and texto.endswith("'"):
        texto = texto[1:-1]
    return texto.strip()

def generar_sms_no_spam(cantidad=100):
    """
    Genera SMS de NO SPAM en contexto peruano usando Ollama
    """
    crear_directorio("dataset_4")
    archivo_salida = "dataset_4/sms_no_spam_peru.txt"
    
    # Prompt mejorado con ejemplos reales
    prompt = """Genera un SMS legítimo (NO SPAM) en contexto peruano. Debe ser:

📱 TIPOS DE SMS LEGÍTIMOS PERUANOS:
- Notificaciones bancarias reales (Caja Arequipa, BCP, Interbank, Scotiabank, BBVA, INTERBANK) SIN enlaces
- Alertas de transacciones bancarias exitosas
- Códigos de verificación de apps peruanas (Yape y Plin)
- Recordatorios de citas médicas (EsSalud, clínicas)
- 
- Información educativa del MINSA sobre salud
- Alertas del SENAMHI sobre clima
- Notificaciones de servicios públicos (luz (Electro Puno, etc), agua (Sedapal), gas)
- Mensajes informativos del gobierno peruano
- Confirmaciones de compras en tiendas conocidas
- Recordatorios de pagos de servicios

🇵🇪 CONTEXTO PERUANO:
- Usar empresas peruanas conocidas
- Mencionar lugares de Perú
- Usar terminología local
- NO incluir enlaces sospechosos
- NO solicitar datos personales
- NO usar comillas en la respuesta

EJEMPLOS DE SMS LEGALES PERUANOS:
1. [CENTRO DE SALUD] te invita a una consulta programada por Video. Datos del turno: Dr(a): [NOMBRE]] a las [TIME]] [URL]
2. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre
3. Por tu seguridad, no contrates lineas moviles(chips) en la calle. Pueden usar tus datos personales y huella dactilar para involucrarte en fraudes o mas delitos.
4. Si al contratar, migrar o portar tu numero, el operador te ofrece alguna oferta o promoción, verifica que se encuentre indicada en tu contrato.
5. Hola su envio de Mercado Libre con numero de seguimiento (25/1955253) fue asignado a reparto el dia de hoy. [AGENCIA DE ENVIO PERUANO].
6. Hola [NOMBRE], [BANCO PERUANO] te informa sobre la operación TIN LINEA A CELULAR por [monto en soles] hoy a las [time] realizada en CAJA MOVIL.
7. Has solicitado un codigo de validación para ingresar a [APPS PERUANAS]. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: [CODIGO].
8. [CODIGO DE GOOGLE]: codigo de verificación de Google. No lo compartas.
9. Hola, recuerda pagar tu recibo Movil de [monto en soles] que vence [TIME] x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de [monto en soles].

Responde SOLO con el texto del SMS, sin comillas, sin explicaciones adicionales (máximo 160 caracteres):"""

    print(f"🚀 Generando {cantidad} SMS de NO SPAM peruanos...")
    
    with open(archivo_salida, 'w', encoding='utf-8') as archivo:
        for i in range(cantidad):
            try:
                respuesta = ollama.generate(
                    model='llama3.1:8b',
                    prompt=prompt,
                    stream=False,
                    options={
                        'temperature': 0.8,      # Más creatividad
                        'num_ctx': 4096,         # Contexto más grande
                        'num_batch': 512,        # Lotes más grandes
                        'num_gpu': 1,            # Forzar GPU
                        'num_thread': 0,         # Usar todos los threads
                    }
                )
                
                sms_crudo = respuesta['response'].strip()
                sms_limpio = limpiar_sms(sms_crudo)
                
                # Solo escribir si el SMS tiene contenido válido
                if sms_limpio and len(sms_limpio) > 10:
                    archivo.write(sms_limpio + '\n')
                    print(f"{i+1:3d}. {sms_limpio}")
                else:
                    print(f"{i+1:3d}. DESCARTADO: {sms_crudo}")
                    
            except Exception as e:
                print(f"{i+1:3d}. ERROR: {e}")
    
    print(f"\n✅ SMS generados guardados en: {archivo_salida}")


print("\n" + "="*50 + "\n")

# Generar nuevos SMS limpios
generar_sms_no_spam(2000)
# Out:
# ==================================================
#
# 🚀 Generando 2000 SMS de NO SPAM peruanos...
#   1. Tu recibo de luz de Electro Puno vence el proximo dia 15, puedes pagar en la app Mi Movistar o directamente en nuestra oficina.
#   2. ¡Atención! El SENAMHI te informa que se prevé una tormenta eléctrica en Lima para mañana a las 10:00 am. Evita áreas de riesgo".
#   3. Hasta el próximo viernes tienes un descuento del 10% en tu cuenta Scotiabank. Utiliza el código: SB1009 al pagar tus compras a través de Yape o la App del Banco. No lo compartas con nadie.
#   4. Has solicitado un codigo de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: 1234
#   5. Te informamos que tu cuenta de agua Sedapal ha sido pagada hasta el día 15/08. Gracias por pago a tiempo.
#   6. Recuerda pagar tu recibo Movil de 50 soles que vence mañana x la app MiMovistar.
#   7. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce más beneficios en la app Mi Movistar.
#   8. ¡Felicidades! Has aprobado el préstamo de $10,000.00 S/ con un interés del 12% anual. Revisa tus cuentas en la App Mi Movistar.
#   9. Ha sido asignado a reparto tu paquete de 100MB x 1 día. Conoce más beneficios en la App Mi Movistar.
#  10. Hola, te informamos que tu cuenta de luz con Electro Puno fue cargada exitosamente.
#  11. Recuerda pagar tu recibo Sedapal de S/20.00 que vence mañana. Puedes hacerlo por la app Yape o en el sitio oficial.
#  12. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: ABC123
#  13. Has solicitado un código de validación para ingresar a Yape. Código: 1234. Utilízalo solo en tu APP.
#  14. **SMS LEGITIMO**
#
# Hola, Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/1200 hoy a las 10:30am realizada en CAJA MOVIL.
#  15. Has solicitado un codigo de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: 123456
#  16. Se ha generado tu código de verificación para ingresar a Yape. Código: 1234. Utiliza solo en la app.
#  17. ¡Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre
#  18. ¡Atención! Has solicitado un código de validación para ingresar a Yape. Código: 3456
#  19. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence el domingo.
#  20. El SENAMHI te informa que esta noche se esperan lluvias intensas en Lima. Evita circulación y sigue nuestras recomendaciones para mantener tu seguridad.
#  21. Hola, recuerda pagar tu recibo Movil de S/ 50.00 que vence hoy x la app MiMovistar o Yape.
#  22. ¡Atención! Caja Arequipa te informa sobre la operación realizada hoy a las 10:00 horas por [monto en soles] para tu tarjeta de crédito. Verifica tus estados financieros en nuestra app.
#  23. Tienes una cita programada para el lunes a las 10:00 horas en la Clínica Hipocampus, ubicada en Av. Pardo 1250, Lima.
#  24. Hola, recuerda pagar tu recibo Movil de 50.00 S/ que vence hoy x la app MiMovistar o Yape
#  25. Hola, recuerda pagar tu recibo Movil de 45.50 soles que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 10 soles.
#  26. Hola, Scotiabank te informa sobre la operación TIN LINEA A CELULAR por S/. 100.00 hoy a las 10:00 realizada en Scotiabank Online.
#  27. ¡Atención! Scotiabank te informa que se realizó una transferencia de $500 desde tu cuenta a la cuenta de tu hermano.
#  28. Hola, recuerda pagar tu recibo Movil de S/ 120.00 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/ 50.00.
#  29. Hola, Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/1000 hoy a las 10:00 realizada en CAJA MOVIL
#  30. Señor, recordamos que su recibo de luz vence mañana. Por favor haga el pago a través de la app Mi Movistar o en línea.
#  31. Bienvenido a Scotiabank. Tu saldo actual es S/. 500.00 Soles
#  32. Hola, recuerda pagar tu recibo Movil de 15.00 soles que vence mañana x la app MiMovistar o Yape.
#  33. Tu cuenta de EsSalud tiene un turno pendiente para mañana a las 9:00 am. Verifica en la app o en nuestro sitio web.
#  34. ¡Bien hecho! Aquí te dejo un ejemplo de un SMS legítimo peruano:
#
# "Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
#  35. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 54321".
#  36. Se te agradece por tu participación en el programa de vacunación contra la influenza. Para más información, visitá el sitio web de Salud Pública.
#  37. Hola, te informamos que tu cuenta de luz estará apagada mañana a las 8am. Por favor, verifica la cantidad adeudada en nuestra app o sitio web oficial.
#  38. Hola. El Servicio Nacional de Meteorología (SENAMHI) informa que hoy se esperan lluvias intensas en Lima.
#  39. Hola, recuerda pagar tu recibo de luz Electro Puno que vence hoy. Evita la suspensión y cobro de reconexion.
#  40. ¡Atención! Se ha realizado una transacción de $120.00 en tu cuenta BCP hoy a las 10:45am. Verifica en MiBCP.
#  41. ¡Felicidades! Se ha aprobado tu solicitud de tarjeta de crédito Scotiabank. Número de tarjeta: 12345678. PIN: 9876543.
#  42. Hola, te recordamos pagar tu recibo de luz vence hoy por Electro Puno x la app MiMovistar o Yape.
#  43. ¡Tienes un crédito disponible en Yape! Puedes pagar tu recibo o hacer una transferencia. Verifica la app de Yape.
#  44. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 15.00 soles
#  45. ¡Hola! Scotiabank te informa sobre la operación a través de Caja Móvil por S/200 hoy a las 14:00.
#  46. Te recordamos que pagas tu cuenta de luz Electro Puno antes del 15 de este mes para evitar cobros extras.
#  47. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
#  48. Hola, recuerda pagar tu recibo Movil de 30.00 soles que vence hoy a las 12:00hs x la app MiMovistar, Yape o app de banco.
#  49. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 30.00 soles.
#  50. Hola, recuerda pagar tu recibo Movil de S/. 100 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/. 50
#  51. Tu paquete de datos movistar ha sido activado exitosamente. Conoce más beneficios en la app Mi Movistar
#  52. Solicitaste un código de verificación para Yape. Utiliza solo este código en la app Yape: 54321
#  53. Recuerda pagar tu recibo Movil de 120.50 soles que vence el lunes a las 00:00 horas x la app MiMovistar o Yape.
#  54. Se ha realizado un pago de S/ 100 a tu cuenta BCP. Fecha: hoy. Hora: 14:30. Ref.: 123456"
#
# o
# "Tu cuenta Scotiabank tiene S/ 5000 disponibles. Retire en una sucursal o con Caja Movil"
#
# o
# "Felicidades, has ganado un premio en la lotería del Ministerio de Educación. Revisa tus detalles en nuestra página web."
#
# o
# "Hola, recuerda pagar tu recibo Sedapal de S/ 200 que vence el 15 de mayo a través de Yape o app de banco.
#  55. Hola, recuerda pagar tu recibo Movil de S/.15 que vence hoy x la app MiMovistar
#  56. La Caja Arequipa te informa sobre una transferencia exitosa de S/. 500 a tu cuenta. Consulta más detalles en tu App o en cajaarequipa.com.pe
#  57. ¡Felicidades! Se ha realizado una transacción exitosa por S/100.00 en tu cuenta BBVA. Consulta más detalles en nuestra app o en nuestro sitio web oficial.
#  58. Hola, recuerda pagar tu recibo Movil de 150 soles que vence mañana x la app MiMovistar.
#  59. Atención: se le ha retirado una cantidad de S/.50 por débito directo hoy a las 10:00. Favor verificar tu estado en la App Mi Banco o sitio web oficial.
#  60. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 123456
#  61. Tu cuenta de Scotiabank ha sido actualizada con un depósito de S/100.00. Consulta tus movimientos en la app o sitio web oficial de la institución.
#  62. Hola, te recordamos pagar tu recibo de luz de Electro Puno que vence mañana a través de la app MiMovistar o Yape.
#  63. Hola, te recordamos que pagas tus servicios de luz con Electro Puno antes del vencimiento para evitar inconvenientes.
#  64. No olvides pagar tu recibo de luz de Electro Puno que vence mañana. Evita la suspensión y cobro de reconexion.
#  65. Se ha efectuado una transferencia a tu cuenta en Scotiabank por S/. 150.00. Fecha: hoy
#  66. Solo un recordatorio: tu pago del agua por valor de S/ 50 vence mañana. Puedes pagar a través de la app Sedapal o en cualquiera de nuestras oficinas.
#  67. Tu recibo de servicio de luz Electro Puno vence el próximo día. Verifica tu cuenta en la app MiMovistar o en nuestro sitio web.
#  68. Buenos días, recuerda pagar tu recibo Movil de 100.00 soles que vence mañana x la app MiMovistar, Yape o app de banco.
#  69. Se han realizado 2 cargos exitosos a tu cuenta Scotiabank. Número de transacción: #123456
#  70. Tienes una cita programada para mañana a las 9:00 am en el Centro Medico EsSalud. Verifica tus datos e ingresa a la aplicación de EsSalud para más detalles
#  71. ¡Hola! Recuerda pagar tu recibo Movil de 120.50 soles que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 15 soles.
#  72. ¡Tienes un pago pendiente por $100 en tu cuenta de Scotiabank! Paga ahora en la app de Scotiabank o en caja.
#  73. Felicidades! Tu recibo de agua vence hoy. Paga a través de la app Sedapal o en www.sedapal.gob.pe.
#  74. Felicidades! Tu pago de servicios de luz de Electro Puno ha sido recibido. Gracias por tu confianza.
#  75. Solicitudes pendientes de pago: $200 en tu factura de luz Electro Puno. Paga online en electroperu.com o en la app Mi Movistar.
#  76. Hola, recuerda pagar tu recibo de luz Sedapal que vence mañana. Evita la suspensión y cobro de reconexion.
#  77. Has solicitado un codigo de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: 1234.
#  78. ¡Atención! Has realizado un pago de $15.50 a la tarjeta de crédito Scotiabank #3456. Fecha: hoy, hora: 14:30. Gracias por tu confianza en BCP.
#  79. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y úsalo solo en tu APP. Código: 4567".
#
# Espero que esto sea de ayuda. Si necesitas algo más, no dudes en preguntar.
#  80. Hola, recuerda pagar tu recibo de agua Sedapal que vence mañana. Evita la suspensión y cobro de reconexion.
#  81. Te recordamos pagar tu recibo Movil de S/ 120.00 que vence mañana, x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de S/ 50.00.
#  82. Te recordamos que el pago de tu servicio de luz vence mañana. Puedes pagar en la app Electro Puno o en nuestro sitio web. Favor verificar detalles en tu cuenta.
#  83. ¿Deseas recibir recordatorio de pago de servicios a través de nuestra app? Registra tus servicios para estar informado. Gracias por tu preferencia.
#  84. ¡Felicidades! La operación TIN LINEA A CELULAR por S/.150.00 fue realizada hoy a las 10:30 en CAJA MOVIL.
#  85. Caja Arequipa te informa sobre la operación exitosa por S/.500,00 a las 10:00 horas de hoy.
#  86. Se te ha realizado un cargo de S/.50 por servicio de agua de Sedapal en Lima.
#  87. Hola, recuerda pagar tu recibo Movil de 120.50 soles que vence hoy x la app MiMovistar o Yape
#  88. Buenos días, te recordamos que tu cuenta de luz con Electro Puno vence hoy. Por favor, realiza un pago a tiempo para evitar suspensiones.
#  89. ¡Atención! Hemos detectado una transacción sospechosa en tu cuenta. Por favor, ingresa al sitio web de [BANCO] para verificar tus actividades bancarias.
#  90. Felicidades! Activaste tu paquete de 100MB x 1 día. Conoce más beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre
#  91. Tu cuenta en Caja Arequipa ha sido debida con éxito por S/. 100.00
#  92. Has solicitado un codigo de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: 1234
#  93. ¡Hola! Te recordamos que tu recibo de agua vence el 15 de febrero. Puedes pagarlo a través de la app Sedapal o en nuestra oficina en Lima. ¡No te olvides para evitar suspensiones y cobros adicionales!
#  94. Se te solicita pagar tu cuenta de luz Electro Puno por 120 soles. Paga en nuestra app o en el sitio web oficial.
#  95. Hola, recuerda pagar tu recibo Movil de 80.50 soles que vence mañana x la app MiMovistar o Yape.
#  96. Te informamos que se ha realizado una transacción exitosa por S/100 en tu cuenta en BCP. Fecha: 20/05/2023. Hora: 14:45.
#  97. Hola, recuerda pagar tu recibo Movil de 35.50 soles que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 10 soles.
#  98. Hola, recuerda pagar tu recibo Movil de 25.00 soles que vence hoy x la app MiMovistar o Yape.
#  99. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 98765".
# 100. Solicito confirmar la compra de un boleto a Machu Picchu por S/. 120.00 en la tienda Virtual Perú. El código de seguimiento es #4756789
# 101. Hola, recuerda pagar tu recibo Movil de S/.20.00 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/.10.00
# 102. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234".
# 103. Te informamos que se realizará un mantenimiento técnico en nuestra plataforma mañana a las 6:00 am. No afectará tus servicios. Gracias por tu comprensión.
# 104. Hola, recuerda pagar tu recibo Movil de 120 soles que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 15 soles.
# 105. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en la App Mi Movistar o aquí www.smvst.com/recargapre
# 106. Felicidades! Se ha realizado con éxito tu pago a Sedapal por 200 soles. Fecha de vencimiento: 15/03
# 107. Hola. Te recordamos que tienes un pago pendiente por servicio de luz Electro Puno valor de S/. 50.00 vence en 3 días a través de la app Mi Movistar.
# 108. Hola, recuerda pagar tu recibo Movil de 100.00 soles que vence mañana x la app MiMovistar.
# 109. Buen día, Caja Arequipa te informa sobre la operación de transferencia a tu cuenta por S/. 500.00 realizada hoy a las 12:00.
# 110. Recordatorio: Pagá tu recibo de luz Electro Puno que vence mañana. Accede a la cuenta en Mi Movistar o en la app Yape.
# 111. ¡Atención! Caja Arequipa notifica una transferencia exitosa de S/1000 a tu cuenta.
#
# Otra posible opción:
#
# Se te recuerda pagar tu recibo Movil de S/50 que vence el día martes. Paga en MiMovistar, Yape o app del banco para evitar la suspensión y cobro de reconexion.
# 112. Hola, recuerda pagar tu recibo Movil de 120 soles que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 50 soles.
# 113. Hola, recuerda pagar tu recibo Movil de S/25.00 que vence mañana x la app MiMovistar
# 114. Recuerda pagar tu recibo de luz de Electro Arequipa que vence hoy a las 20:00 hrs.
# 115. No puedes realizar operaciones financieras si no tienes saldo en tu cuenta BCP. Verifica tus datos en nuestra plataforma web.
# 116. Hola, recuerda pagar tu recibo de luz Electro Puno de S/.50 que vence mañana. Evita la suspensión y cobro de reconexion.
# 117. Se ha realizado una transacción exitosa por $500 en tu cuenta BCP. Verifica tus estados de cuenta en la app BCP o en nuestro sitio web.
# 118. Recuerda pagar tu recibo Movil de S/.20 que vence hoy x la app MiMovistar. Evita la suspensión y cobro de reconexion de S/.10.
# 119. Hola, recuerda pagar tu recibo Movil de S/. 100 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/. 50
# 120. Hola, has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 121. Te recordamos que pagas tu recibo de agua de Sedapal que vence hoy. Puedes hacerlo a través de la app Yape o en nuestra página web.
# 122. Hola, recuerda pagar tu recibo Movil de 25.00 soles que vence hoy x la app MiMovistar.
# 123. Hola, recuerda pagar tu recibo Movil de 120 soles que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de 50 soles
# 124. Se te envió 5000S/ a tu cuenta Scotiabank, número de operación: SBCA123456. Verifica tus transacciones en la app o en nuestro sitio web.
# 125. Hola, recuerda pagar tu recibo Movil de S/.30.00 que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/.10.00
# 126. Se ha realizado una transferencia exitosa de S/100.00 a tu cuenta en BCP.
# 127. Hola, recuerda pagar tu recibo Movil de 120 soles que vence hoy x la app MiMovistar. Evita la suspensión y cobro de reconexion de 40 soles.
# 128. ¡Tienes un recibo de luz pendiente en Electro Puno! Favor pagar hasta el día 20 para evitar multas. Consulta tu cuenta en app Yape.
# 129. Hola, recuerda pagar tu recibo Movil de S/.50 que vence hoy x la app MiMovistar
# 130. Hola, recuerda pagar tu recibo Movil de S/.20 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/.10.
# 131. Hola, te recordamos que pagas tu recibo Sedapal de $200 que vence mañana. Puedes pagar a través de Yape o app de banco para evitar la suspensión
# 132. Solicito que verifiques tu cuenta en Yape para evitar posibles problemas con tus transacciones financieras.
# 133. Se te ha asignado un turno para vacunación COVID-19 en el Hospital Regional Arequipa. Lugar: Pabellón 3, Fecha: mañana a las 9:00 am.
# 134. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence mañana x la app MiMovistar.
# 135. Atención: recibo de luz de Electro Puno vence el 15 de mayo. Paga a través de la app Mi Movistar o en sucursal Sedapal.
# 136. ¡CUIDADO! No contrates lineas móviles en la calle. Pueden usar tus datos personales y huella dactilar para involucrarte en fraudes.
# 137. Hola, recuerda pagar tu recibo Movil de S/.45 que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de S/.20.
# 138. Se te notifica una operación TIN Linea A Celular por S/.50.00 hoy a las 08:30 horas realizada en Caja Movil.
# 139. Sucedio una transferencia a tu cuenta Scotiabank por $500. Verifica tus estados de cuenta
# 140. Hola, Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/100 hoy a las 15:00 realizada en CAJA MOVIL.
# 141. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: #123456".
# 142. Hola, tu cuenta Scotiabank tiene un saldo disponible por S/. 1000.00. Puedes consultar tus movimientos y balances en la app Scotiabank
# 143. El SENAMHI te informa que hoy esperas tormentas eléctricas en Lima. Mantén la calma y sigue las instrucciones de seguridad.
# 144. Hola, recuerda pagar tu recibo Movil de 45.50 soles que vence mañana a las 12:00 h x la app MiMovistar o Yape
# 145. ¡Hola! Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234.
# 146. Buenos días, te recordamos que debes pagar tu recibo de luz de Electro Arequipa que vence mañana a través de la app MiMovistar o en la sucursal más cercana.
# 147. Se te agradece por utilizar tu tarjeta de crédito Scotiabank. Se ha bloqueado una transacción sospechosa en US$100,00.
# 148. Hasta la fecha, Scotiabank te informa sobre la operación realizada con tu tarjeta Visa en Cusco. Monto: S/. 500.00 Fecha: hoy a las 12:30.
# 149. Bienvenido a EsSalud. Esta es una notificación para recordarte tu cita médica programada para el día 10 de febrero a las 9:00 AM en nuestro centro de salud.
# 150. ¡Felicitaciones! Has pagado tu recibo de luz Electro Puno por S/ 120.00 hasta el 15 de febrero.
# 151. Ha sido asignado a reparto tu envío de Mercado Libre con nro. de seguimiento: 25/1955253
# 152. Tu pago de luz de Electro Puno se aprobó por S/50.00.
# 153. Solicito confirmar su pago del recibo de luz de Electro Puno por S/.50.00 que vence mañana a las 10:00 am.
# 154. Tienes un pago pendiente por luz en Electro Puno, monto: S/ 150.00, fecha vencimiento: hoy a las 18:00
# 155. Recuerda pagar tu recibo de luz Electro Puno que vence mañana.
# 156. Felicidades! Activaste tu paquete de 100MB x 1 día. Conoce más beneficios en la app Mi Movistar o aquí smvst.com/recargapre
# 157. Has solicitado un recibo de agua de Sedapal por S/. 120.00. Puedes pagar en la app Yape o en línea en www.sedapal.gob.pe.
# 158. Hola, recuerda pagar tu recibo Movil de 120.00 soles que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 159. Se ha realizado un pago a tu cuenta en Scotiabank por 500 Soles. Tu saldo actual es 12,000 Soles.
# 160. Bienvenido a Scotiabank: se ha depositado S/.200 en tu cuenta N°123456. Consulta tu estado de cuenta en la App Scotibank.
# 161. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 123456
# 162. Recuerda pagar tu recibo Movil de 250.00 soles que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 163. Felicidades! Tu recibo de luz de Electro Puno ha sido pagado con éxito. Gracias por pagar a tiempo.
# 164. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 54321.
# 165. ¡Atención! Hemos recibido tu pago de servicio público Sedapal por S/100.00. Puedes consultar detalles en nuestra app y sitio web oficial.
# 166. Hola, recuerda pagar tu recibo Movil de S/.50.00 que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/.20.00.
# 167. Tu recibo de Luz e Fuerza vence mañana a las 12:00 hs. Paga en la app Mi Movistar o en cualquier agencia.
# 168. Has solicitado un código de validación para ingresar a Plin. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 456789".
# 169. Tu recibo de luz por $120 vence mañana. Paga en la app Electro Puno o en una sucursal bancaria para evitar la suspensión.
# 170. Hola, recuerda pagar tu recibo Movil de S/10.00 que vence mañana x la app MiMovistar, Yape o app de banco.
# 171. Recuerda pagar tu recibo Movil de S/.50 que vence mañana a las 17:00. Evita la suspensión y cobro de reconexion de S/.20.
# 172. ¡Felicitaciones! Se ha asignado tu paquete de 50MB x 3 días. Conoce más beneficios en la App Yape o aquí smvst.com/recargapre
# 173. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y úsalo solo en tu APP. Código: 1234
# 174. Solo para recordarte que tu recibo de luz vence mañana. Puedes pagar a través de la app Mi Movistar o en efectivo en Electro Arequipa.
# 175. Hola, tienes un pago pendiente por $20 para tu servicios de luz en Electro Puno. Verifica en app Mi Movistar
# 176. Recordatorio: Pago de recibo de luz por S/50 vence mañana. Conoce detalles y pagar aquí https://www.electropuno.com.pe/recibos"
#
# Nota: El ejemplo anterior NO cumple con el contexto peruano, ya que incluye un enlace sospechoso. A continuación te proporciono otro ejemplo válido:
#
# Hoy 15/12 a las 9:00 am se recibió en tu cuenta de Scotiabank una transferencia por S/.200 desde [NOMBRE].
# 177. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 100.00 soles.
# 178. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre
# 179. Hola, te recordamos que tu recibo de agua Sedapal vence mañana. Puedes pagar en la app Yape o en el sitio web oficial.
# 180. ¡Hola! Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/150 hoy a las 10:00 realizada en CAJA MOVIL.
# 181. Hola, recuerda pagar tu recibo Movil de S/.20.00 que vence mañana x la app MiMovistar.
# 182. Bcp te informa sobre la operación de transferencia a tu cuenta hoy a las 15:30. Monto totalizado en S/.5000.00.
# 183. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre
# 184. Has solicitado un codigo de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: 1234".
# 185. Atención, tu cuenta Scotiabank ha sido actualizada con un crédito adicional por $1.000 Soles. Verifica tus movimientos en la app de Scotiabank.
# 186. Hola, recuerda pagar tu recibo Movil de $200 que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de $50.
# 187. Bienvenido a Scotiabank. Tu depósito de $500 ha sido procesado exitosamente en tu cuenta.
# 188. Hola, recuerda pagar tu recibo Movil de $120 que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de $30.
# 189. Recuerda pagar tu recibo Movil de S/ 100 que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de S/20.
# 190. Bienvenido a Scotiabank! Te notificamos que tu pago de servicios de luz ha sido realizado correctamente. Número de transacción: 123456
# 191. Hola, recuerda pagar tu recibo Movil de S/. 50 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/. 20.
# 192. ¡Hola! Recuerda pagar tu recibo Sedapal de $120 que vence mañana. Evita la suspensión y cobro de reconexion de $50.
# 193. Tienes una cuenta pendiente de pago por S/.50 en Sedapal. Paga a través de la app Yape o en la sucursal más cercana
# 194. Te informamos que tu cuenta en Caja Arequipa tiene un saldo disponible de S/ 1.500.00.
# 195. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: ABCD1234".
# 196. Hola, recuerda pagar tu recibo Movil de 55.00 soles que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 10.00 soles".
# 197. Se ha recibido un pago de $500 hacia tu cuenta BBVA. Consulta tus transacciones bancarias en el sitio web oficial del banco.
# 198. Recuerda pagar tu recibo de luz Electro Puno que vence mañana a través de la app Mi Movistar o Yape.
# 199. Te recordamos que el recibo de luz Electro Puno vence hoy. Por favor, paga para evitar la suspensión y cobro de reconexion.
# 200. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 201. Hola, recuerda pagar tu recibo Sedapal de 150.00 soles que vence mañana x la app Yape o app de banco. Evita la suspensión y cobro de reconexion de 30.00 soles.
# 202. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas y úsalo solo en tu APP. Código: 54321.
# 203. ¡Felicidades! Se ha realizado con éxito tu pago de servicio de luz Electro Puno. No olvides verificar tu cuenta en la app de Electro Puno.
# 204. Se ha realizado una transferencia de S/100 desde tu cuenta BCP a la cuenta de Juan Pérez en Scotiabank Arequipa. Revisa tus movimientos.
# 205. Hola, recordamos que tu recibo de luz Electro Puno vence hoy a las 18:00. Verifica y paga en app Mi Movistar o Yape para evitar la suspensión.
# 206. Ha sido asignado a reparto tu paquete de 10Kb x 1 dia. Conoce mas beneficios en el App Mi Movistar o aqui http://www.smvst.com/recargapre"
#
# (Este SMS no es completamente legítimo ya que incluye un enlace, por lo tanto, te propongo otro ejemplo)
#
# "Hola, recuerda pagar tu recibo de servicios de luz de [monto en soles] que vence [TIME] x la app MiMovistar o Yape.
# 207. Hola, Scotiabank te informa sobre la operación de transferencia bancaria por S/500.00 hoy a las 14:30 realizada en sucursal Miraflores.
# 208. Tu cuenta de Scotiabank tiene un saldo disponible de S/200.00. Consulta tu estado financiero en la app Scotiabank".
# 209. Hola, recuerda pagar tu recibo Movil de S/.20 que vence hoy. Evita la suspensión y cobro de reconexion de S/.5.
# 210. Te informamos que tu recibo de luz de Electro Puno vence mañana. Puedes pagar online en www.electropuno.com.pe o en la app Mi Movistar.
# 211. Hola su envio de Mercado Libre con numero de seguimiento (25/1955253) fue asignado a reparto el dia de hoy.
# 212. Solicito recordarte que tu recibo de agua vence el 15 de febrero. Por favor, lo puedes pagar a través de la app Sedapal o en nuestra sucursal más cercana.
# 213. Hola, recuerda pagar tu recibo Movil de 25.50 soles que vence hoy a las 18:00 x la app MiMovistar, Yape o app de banco.
# 214. Hola, recuerda pagar tu recibo de luz de Electro Puno que vence hoy x la app Mi Movistar. Evita la suspensión y cobro de reconexion.
# 215. ¡Atención! Hemos detectado una transacción sospechosa en tu cuenta Scotiabank. Verifica tus movimientos y llama al 0-800-1111 para más detalles.
# 216. Confirmamos que recibiste un pago exitoso de $100 por tienda InkaFarma en Tarapoto. Gracias por usar nuestra plataforma.
# 217. Hola, recuerda pagar tu recibo Movil de $150 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de $50.
# 218. Hola, recuerda pagar tu recibo Movil de 25.00 soles que vence el día 12 por la app MiMovistar
# 219. Buenos días, te recordamos que tu recibo de luz de Electro Puno vence mañana. Paga ahora a través de la app Mi Movistar o Yape y evita la suspensión.
# 220. ATENCIÓN: Tus pagos a Sedapal son confirmados. En la aplicación MiSedapal puedes consultar detalles de tus servicios. Gracias por confiar en nosotros.
# 221. Recuerda pagar tu recibo de agua Sedapal que vence mañana. Puedes hacerlo en la app Yape o en nuestra página web.
# 222. Se te ha realizado una transferencia exitosa por S/. 500 en tu cuenta Caja Arequipa. Favor verificar en el sistema bancario.
# 223. Recibiste un crédito de $100 a través de Mi Movistar. Verifica más detalles en la app o en nuestro sitio web.
# 224. Recuerda pagar tu recibo Sedapal de [monto] que vence mañana. Evita la suspensión y cobro de reconexion de [monto].
# 225. ATENCIÓN: El recibo de luz de Electro Puno vence mañana. Paga en la app Mi Movistar o Yape para evitar suspensión.
# 226. Hola, recuerda pagar tu recibo Movil de 100.50 soles que vence mañana x la app MiMovistar o Yape.
# 227. Atención: El pago de tu servicio de luz de Electro Puno está vencido. Paga en la app MiMovistar o en cajero automatico.
# 228. Banco Caja Arequipa: tu deposito de 500 soles fue realizado exitosamente hoy a las 10am.
# 229. ¡Hola! Scotiabank te informa que hemos realizado una transferencia de S/100.00 a tu cuenta. Código de transacción: [12345]
# 230. Felicidades! Tu pago de agua Sedapal ha sido exitoso. Número de cuenta: XXXXXXXX
# 231. Hoy tienes un cargo de $50 por servicio de luz en tu cuenta Electro Puno. Puedes pagar a través de la app Mi Movistar o en caja.
# 232. Solicito el código de verificación para ingresar a Yape. Código: 4567
# 233. Tienes un pago pendiente por $100 en tu recibo de luz Electro Puno. Ingresa a Mi Movistar para más detalles
# 234. Recuerda pagar tu recibo de luz de Electro Puno que vence mañana.
# 235. Buenos días, tienes un pago pendiente en tu cuenta de EsSalud por S/.15.00. Paga en nuestra app o en nuestro sitio web.
# 236. Se te notifico que se ha realizado una operación TIN LINEA A CELULAR por S/. 100 hoy a las 15:00 horas en CAJA MOVIL.
# 237. Se te envió un recibo de luz por $20.00 por Electro Puno. Puedes pagar a través de la app Mi Movistar o en sucursal.
# 238. ATENCIÓN: Tienes un pago pendiente en tu cuenta de Sedapal por $150, vence el 15/02 a las 18hs. Paga aquí o en la app Yape.
# 239. Se te ha asignado un turno para vacunación contra COVID-19 en la Clínica Sanatorio Sur, Lomas de la Encarnación. Fecha: hoy a las 15:00 horas.
# 240. Te recordamos que tu factura de luz vence el día de mañana. Puedes pagarla a través de la aplicación de Electro Sur o en un banco.
# 241. Felicidades! Se ha generado tu recibo de luz para este mes. Puedes pagar a través de la app Mi Movistar o en una de nuestras sucursales.
# 242. Señor(a), se le notifica que su recibo de luz vence el día 25/02 y monto a pagar es de S/.120.00 por favor hacer efectivo antes del vencimiento para evitar suspension y cobro de reconexion.
# 243. ¡Hola! Recuerda pagar tu recibo de luz Electro Puno que vence mañana. Evita la suspensión y cobro de reconexion de S/.50.
# 244. Se ha realizado una transferencia por S/100 desde tu cuenta BCP a la cuenta de tu hermano. ¿Deseas confirmar esta operación?
# 245. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 4567".
# 246. Felicidades! Tu pago de recibo Movil fue aprobado por $50.00 vencido el día de hoy. Verifica en la app MiMovistar o Yape
# 247. Hola, recuerda pagar tu recibo Movil de S/.50.00 que vence mañana x la app MiMovistar.
# 248. Felicidades! Tu pago de agua de Sedapal ha sido confirmado. Puedes verificar en la app Yape o en nuestro sitio web oficial.
# 249. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar
# 250. Recuerda pagar tu recibo Movil de 150 soles que vence mañana. Evita la suspensión y cobro de reconexion de 30 soles.
# 251. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence mañana x la app MiMovistar.
# 252. Recuerda pagar tu recibo de servicios públicos de Sedapal que vence hoy a través de la app Mi Movistar o página web oficial.
# 253. Recuerda pagar tu recibo Movil de S/.20 que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de S/.15.
# 254. Recuerda pagar tu recibo Movil de S/. 50 vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion.
# 255. Hola, recuerda pagar tu recibo Movil de S/. 150 que vence hoy. Evita la suspensión y cobro de reconexion de S/. 100.
# 256. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 5432".
# 257. Recuerda pagar tu recibo Sedapal de S/.100 que vence mañana. Evita la suspensión y cobro de reconexion de S/.50.
# 258. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 259. Se agradece tu pago por servicios de agua Sedapal. Número de referencia: #001234
# 260. Buenos días, te recordamos que tu recibo de Luz eléctrica Electro Puno vence el día 15 de febrero. Puedes pagar en línea a través de nuestra app o en nuestras oficinas cercanas.
# 261. Hasta la fecha de hoy no encontré un ejemplo que cumpla con los criterios solicitados. A continuación, te dejo uno creado:
#
# Atención: por favor paga tu recibo de servicios de Sedapal para agua en tus cuentas bancarias o en nuestra app. Informes en www.sedapal.com.pe.
# 262. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, no lo compartas con nadie y úsalo solo en tu APP. Código: 123456".
# 263. Hola, recuerda pagar tu recibo Movil de 50 soles que vence hoy x la app MiMovistar.
# 264. Se ha realizado un pago exitoso por S/200 en tu cuenta Caja Arequipa. Fecha: 12-02-2023 Hora: 14:45
# 265. Recordatorio: tu recibo de luz de Electro Puno vence el día 15. Paga a tiempo para evitar suspensiones.
# 266. Se te agradece por utilizar nuestro servicio de atención al cliente. Recuerda pagar tu recibo de luz de Electro Puno que vence mañana
# 267. Hola, recuerda pagar tu recibo Movil de $150 que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de $50".
# 268. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence hoy x la app MiMovistar".
# 269. Hola, recuerda pagar tu recibo Movil de $120 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de $50.
# 270. Síntomas de COVID-19: fiebre, tos y dolor corporal. Consulta a un profesional de la salud si tienes síntomas. Fuente: MINSA
# 271. Hasta las 14:00 hrs de hoy no se han realizado movimientos en tu cuenta de Caja Arequipa.
# 272. ¡Atención! La tarifa básica para llamadas en electro Puno será $1.50 a partir del próximo mes. Consulta tus facturas en la app de Electro Puno.
# 273. Hola, recuerda pagar tu recibo Movil de 30.50 soles que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 10.00 soles.
# 274. Buenos días, tienes un recibo pendiente de pago de $150.00 por servicios de agua en Sedapal Lima que vence el día martes a las 23:59 horas. Puedes pagar a través de la app Yape o nuestra página web.
# 275. ¡Atención! Se ha realizado una transferencia exitosa por $1.500 desde tu cuenta BCP a la cuenta de tu hermano en Scotiabank.
# 276. Bienvenido a Scotiabank Perú. Tu depósito de S/500 ha sido procesado exitosamente. Gracias por confiar en nosotros.
# 277. Hola, Scotiabank te informa sobre la operación TIN LINEA A CELULAR por 100.00 soles hoy a las 09:00 horas realizada en Scotiabank.
# 278. Hola, recordamos que tu recibo de luz vence hoy. Puedes pagar a través de la app MiMovistar o Yape.
# 279. Sabias que puedes verificar el clima actualizado con SENAMHI en tu APP favorita.
# 280. Solo un recordatorio: tus facturas de luz con Electro Puno deben ser pagadas antes de que vencen el próximo sábado. Evita la suspensión y cobro de reconexion. ¡Paga en línea o en cualquier agencia!
# 281. Te informamos que tu cuenta de luz con Electro Puno fue pagada con éxito. Gracias por ser cliente responsable.
# 282. ¡Atención! Tu recibo de luz con electro Puno vence mañana. Paga aquí: Yape o app MiMovistar para evitar la suspensión y cobro de reconexion.
# 283. Solicito confirmar código de verificación para ingresar a Yape. Código: 4567
# 284. Hola, recuerda pagar tu recibo Movil de 150.50 soles que vence mañana. Evita la suspensión y cobro de reconexion de 20 soles.
# 285. ¡Atención! Se te ha realizado una transferencia exitosa por S/.200 a tu cuenta de Caja Arequipa. Consulta tus movimientos en nuestra app o en nuestro sitio web.
# 286. Te recordamos pagar tu recibo de luz de Electro Puno que vence mañana.
# 287. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence hoy x la app MiMovistar
# 288. Hasta los lunes. Te recordamos pagar tu recibo de luz de Electro Puno antes del viernes para evitar la suspensión. Puedes hacerlo en nuestra app o en línea en sedapal.gob.pe.
# 289. Se te ha asignado un turno para vacunación contra la COVID-19 en EsSalud. Llamar al 101"
#
# o
#
# "Felicidades! Tus servicios de luz con Electro Puno han sido reactivados. Verifica el estado de tu cuenta en miElectroPuno
# 290. ATENCIÓN: Se ha realizado una transacción exitosa por $500 en tu cuenta en BCP. Consulta el estado de tus operaciones en nuestra app móvil o sitio web BCPonline.
# 291. Hola, recuerda pagar tu recibo Movil de S/. 50 que vence mañana. Evita la suspensión y cobro de reconexion de S/. 10.
# 292. Recuerda pagar tu recibo de agua vence el día 15. Por favor verifica tu cuenta en la app Sedapal.
# 293. Tu recibo de luz de Electro Puno vence mañana. Verifica el monto y paga a tiempo para evitar suspensiones.
# 294. Bienvenido a EsSalud. Recordatorio de tu cita programada para mañana a las 9:00 am. Por favor, no olvides llegar con tiempo suficiente
# 295. Hola, recuerda pagar tu recibo de luz vence hoy x app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 30 soles.
# 296. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234".
# 297. Tu recibo Movil de S/20 vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de S/10.
# 298. Señor(a), se ha realizado una transferencia de S/. 500 a su cuenta en BCP hoy a las 10:00. Favor verificar en www.bcp.com.pe".
# 299. Banco Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/120.00 hoy a las 12:30 horas.
# 300. Tu recibo de luz Electro Puno vence hoy. Paga a través de la app Mi Movistar o en nuestro sitio web.
# 301. Hola, Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por 150.00 soles hoy a las 10:45 realizada en CAJA MOVIL.
# 302. Felicidades! Has aprobado para pagar tu recibo de luz Electro Puno. Puedes realizar el pago por la app Mi Movistar o en sucursal Sedapal.
# 303. Se ha realizado una descarga de fondos de tu cuenta Scotiabank por S/ 500.00. Verifica tus estados de cuenta en la App Scotiabank.
# 304. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 4321.
# 305. Recuerda pagar tu recibo Movil de S/50.00 que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/20.00
# 306. Se ha asignado un nuevo saldo a tu cuenta de Yape. Verifica tus transacciones en la app.
# 307. Buenos días, has realizado una transacción exitosa por $500,00 con tu tarjeta de crédito Scotiabank. Verifica tus estados de cuenta en la App MyScotiabank
# 308. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234.
# 309. Hola, recuerda pagar tu recibo Movil de $50 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de $30
# 310. Hola, recuerda pagar tu recibo Movil de 120.50 soles que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 30 soles
# 311. Has solicitado un recibo de luz para tu vivienda en Lima. Puedes pagar a través de la aplicación MiMovistar o en efectivo en la sucursal Electro Arequipa.
# 312. Has solicitado un código de validación para ingresar a Yape. Código: 1234. No lo compartas.
# 313. Hola su envio de Mercado Libre con numero de seguimiento (25/1955253) fue asignado a reparto el dia de hoy. [AGENCIA DE ENVIO PERUANO]".
# 314. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre"
#
# [Nota: La respuesta debe incluir la información que se solicita en el ejemplo, pero sin comillas y dentro del límite de caracteres (160).]
# 315. ¡Prepárate para una nueva entrega de paquetes de gas! Recuerda pagar tu recibo Sedapal de S/100 que vence hoy a las 12h. Evita la suspensión y cobro de reconexion de S/20.
# 316. Se ha realizado una transferencia de S/150 desde tu cuenta BCP a tu tarjeta de crédito Scotiabank. Fecha: hoy a las 10:00 horas.
# 317. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence hoy x la app MiMovistar.
# 318. Hola, has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 3456".
# 319. Se te envío un código de verificación: 1234. Usalo solo en Yape.
# 320. Hola, te informamos que se ha realizado una transferencia de S/. 500 a tu cuenta en Scotiabank. Consulta más detalles en la app de Scotiabank
# 321. Solicito recordatorio para pago de recibo Movil de S/. 150 que vence mañana. Puedes pagar a través de la app MiMovistar o Yape
# 322. Hola, te recordamos que debes pagar tu recibo de luz vencido el día de hoy. Conoce mas información y cómo proceder en nuestra app Mi Movistar.
# 323. Se ha realizado una operación de $500 en tu cuenta Caja Arequipa. Fecha: hoy a las 14:00 horas.
# 324. Alerta: hemos realizado una transacción exitosa por S/100 a las 10:00 am mediante Caja Arequipa. Verifica tu cuenta en la app de Caja Arequipa.
# 325. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 200.00 soles.
# 326. Se te agradece por pagar tu recibo de luz de Electro Puno. Su saldo actual es de S/.50.00 y se encuentra al dia.
# 327. Hola, has solicitado un código de verificación para ingresar a Yape. Código: 54321
# 328. ¡Atención! La operación de transferencia de $500 a tu cuenta Caja Arequipa ha sido exitosa. Verifica tus estados de cuenta en nuestra App o sitio web.
# 329. Hola, Scotiabank te informa sobre la operación TIN LINEA A CELULAR por S/. 500 hoy a las 10:00 horas.
# 330. Alerta de clima: lluvias intensas para Lima y Callao. Verifica el boletín del SENAMHI para más detalles.
# 331. Has realizado un pago de S/20 al proveedor 'Servicios Públicos' en tu cuenta en BCP. Número de transacción: 123456.
# 332. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 30.00 soles.
# 333. Recuerda pagar tu recibo de luz de Electro Puno que vence mañana.
# 334. Tu cuenta Caja Arequipa tiene saldo suficiente para realizar transacciones. Verifica en la App Caja Movil o en un cajero de la red.
# 335. Hola su envio de Mercado Libre con numero de seguimiento (25/1955253) fue asignado a reparto el dia de hoy. Correos Peruanos.
# 336. Se ha procesado exitosamente tu pago de Luz en Electro Puno. Número de folio: LP001. Fecha: hoy
# 337. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234.
# 338. Tu cuenta Scotiabank tiene un movimiento de $1500. Verifica tu estado en la app o en nuestra página web.
# 339. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 340. **SMS 1**
# "Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/100.00 hoy a las 10:00 am realizada en cajamovil."
#
# **SMS 2**
# "Felicidades! Has solicitado un código de validación para ingresar a Yape. Código: ABC123"
#
# **SMS 3**
# "Electro Puno te recuerda pagar tu recibo de luz que vence el 20/02 x la app MiMovistar.
# 341. Recuerda pagar tu recibo Movil de 50 soles que vence hoy. Evita la suspensión y cobro de reconexion de 20 soles.
# 342. Recuerda pagar tu recibo Movil de S/50.00 que vence mañana x la app MiMovistar o Yape.
# 343. ¡Atención! El SENAMHI ha emitido una alerta por lluvias intensas en Lima a partir de hoy. Vigile la actualización del estado del tiempo en su aplicación móvil.
# 344. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 123456".
# 345. Hola, recordamos que tu recibo de servicios de agua vence mañana. Puedes pagar a través de la app Sedapal o en nuestro sitio web.
# 346. Hola, recuerda pagar tu recibo Sedapal de S/ 150 que vence mañana. Evita la suspensión y cobro de reconexion de S/ 50.
# 347. Hola, recuerda pagar tu recibo Movil de S/.20 que vence hoy x la app MiMovistar
# 348. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234".
# 349. Tu cuenta de Scotiabank tiene S/1500 disponibles para transferir. Verifica la App o llamada gratuita al 0800-12345.
# 350. ¡Atención! El pago de tu servicio de luz en Electro Puno es debido hoy a las 18:00 hs. No te quedes sin energía. Paga en la app Mi Movistar o en línea.
# 351. Se confirmó exitosamente tu pago en tienda Ripley. Verifica tus compras en la app Ripley o en www.ripley.pe.
# 352. ¡Atención! Caja Arequipa te informa sobre operación TIN LINEA A CELULAR por S/100.00 hoy a las 14:30 horas realizada en CAJA MOVIL.
# 353. Recordatorio: pago de recibo de luz Electro Puno por S/. 150 vence el 15/08. Realiza el pago a través de la app Mi Movistar o en línea.
# 354. Te recordamos que el pago de tu recibo de Luz Electro Puno vence mañana a las 18:00 hs. Por favor, accede a MiMovistar para realizar el pago.
# 355. El clima para hoy en Lima es soleado con una temperatura máxima de 22°C. Recomendamos llevar sombrero y lentes de sol.
# 356. Te recordamos pagar tu recibo de luz de Electro Puno que vence el 15/03. Puedes hacerlo en la app MiMovistar o Yape.
# ...
# 1882. Se te invita a una consulta en el Hospital Nacional Arzobispo Loayza, Dr. Pérez a las 09:00 am. Consulta tu turno en la app Mi Movistar o Sedapal.
# 1883. Caja Arequipa te informa sobre la operación de $1000 realizada hoy a las 10:00 am en tu cuenta. Verifica tus transacciones en la app Caja Movil
# 1884. Tienes una nueva alerta climática en Arequipa, temperatura máxima esperada para mañana es de 32°C. Verifica en nuestra app oficial del SENAMHI
# 1885. Bienvenido a tu nuevo servicio de luz Electro Puno. Tu consumo promedio es 150kWh/mes. Puedes verificar tus detalles en nuestra app o sitio web
# 1886. Hola, recordamos que tu recibo de agua vence mañana. Puedes pagar a través de la app Sedapal o en nuestra tienda.
# 1887. Buenos días, te recordamos que tu recibo de luz de Electro Puno vence el próximo 15 de marzo. Puedes pagar en la app MiMovistar o en caja
# 1888. Hola, recuerda pagar tu recibo Movil de 85.00 soles que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 1889. Se canceló tu pago por $150 a tu cuenta de Scotiabank. Verifica tus estados de cuenta en internet banking o app Scotiabank.
# 1890. ¡Atención! Tu cuenta Scotiabank fue debidamente verificada, no es necesario realizar ninguna acción adicional.
# 1891. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 1892. Hola, te recordamos que tienes un recibo vencido por $50 en Sedapal, por favor ingresa a la app Mi Movistar para pago
# 1893. Hola, recuerda pagar tu recibo Movil de 120.50 soles que vence mañana x la app MiMovistar
# 1894. ¡ATENCIÓN! Te informamos que tu cuenta Scotiabank tendrá un descuento de 10% en compras en tiendas peruanas. Utiliza la app MyScotiabank para más detalles.
# 1895. ¡Atención! Has realizado una transferencia de $100 a través de Caja Arequipa. Número de referencia: TRF123456.
# 1896. Recuerda pagar tu recibo Movil de S/.20.00 que vence mañana x la app MiMovistar.
# 1897. Buenos días, se ha realizado una carga exitosa en tu tarjeta BCP. No es necesario realizar ninguna acción adicional.
# 1898. ¡Hola! Tu paquete de datos vence hoy a las 23:59. Recarga o actualiza tu plan en la app Mi Movistar para evitar interrupciones en tu servicio.
# 1899. Banco Interbank: tu saldo disponible es S/1.500.00
# 1900. ¡Hola! El pago de tu recibo Movil de S/. 150 vence el 15/02 a las 23:59. Paga en la app MiMovistar o en Yape para evitar suspensión y cobro reconexion de S/. 20.
# 1901. Se te informa que tu cuenta Scotiabank tiene disponible un crédito de S/.50.00. Consulta la aplicación de Scotiabank para más detalles.
# 1902. Hasta pronto! Tu pago por gas de Electro Puno ha sido aprobado. Se te factura S/. 50.00 para la próxima semana.
# 1903. Hola, Scotiabank te informa sobre la operación TIN LINEA A CELULAR por $200 hoy a las 10:00hs realizada en CAJA MOVIL.
# 1904. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 4567
# 1905. ¡Atención! La cuenta #12345678 de Scotiabank ha sido actualizada con éxito. Favor verificar en tu app bancaria.
# 1906. ¡Atención! El pago de tu recibo de luz es inminente. Puedes pagar a través de la app de Electro Puno o en caja contando con una tarifa de $0.50 por cada transacción.
# 1907. Hola, Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por $200 hoy a las 12:00 realizada en CAJA MOVIL.
# 1908. Hola, recuerda pagar tu recibo Movil de S/.20 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/.10.
# 1909. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 1910. Has realizado una transferencia por S/100 a cuenta de Juan Pérez en BCP. Fecha: hoy. Hora: 14:30
# 1911. Recordatorio: tu recibo de agua Sedapal vence mañana. Paga con la app Yape o en nuestro sitio web.
# 1912. Atención: Recuerda pagar tu recibo Movil de 45.00 soles que vence hoy x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 10.00 soles.
# 1913. Felicidades! Activaste tu paquete de 100MB x 1 día. Conoce más beneficios en el App Mi Movistar o aquí www.smvst.com/recargapre
# 1914. Recuerda pagar tu recibo Movil de 100 soles que vence mañana. Evita la suspensión y cobro de reconexion de 50 soles.
# 1915. Hola, recuerda pagar tu recibo Movil de S/ 50.00 que vence mañana x la app MiMovistar".
# 1916. ¡Hola! Te informamos que tu recibo de luz de Electro Puno vence mañana. Puedes pagar a través de la app Mi Movistar o en sucursal.
# 1917. Banco Caja Arequipa: tu transferencia a "Juan Pío" por S/150 fue realizada exitosamente hoy a las 14:45 horas.
# 1918. La temperatura mínima para hoy es 18°C. Verifica las condiciones climáticas actualizadas en el app SENAMHI.
# 1919. Se ha asignado un crédito de S/100 a tu línea movil. Puedes verificarlo en la app Mi Movistar.
# 1920. **SMS LEGÍTIMO PERUANO**
#
# "Hola, recuerda pagar tu recibo de luz de Electro Arequipa que vence mañana. Puedes hacerlo en la app Mi Movistar o en nuestra página web.
# 1921. El SENAMHI te informa que se prevén lluvias en Lima durante las próximas horas. Por favor, mantén una vigilancia especial en tu zona.
# 1922. Buen día, te recordamos que debes pagar tu recibo de servicios de luz y agua con Sedapal, por favor atiende a este requerimiento para evitar problemas.
# 1923. Felicidades! Se ha realizado una transferencia exitosa por S/100 desde tu cuenta BCP al número de celular **986754321**. Fecha: hoy a las 10:00 hrs.
# 1924. Se ha generado un cargo en tu cuenta Scotiabank por S/120.00 para pago de servicios públicos. Verifica en la app o sitio web oficial.
# 1925. ¡Atención! Caja Arequipa te notifica que realizaste un retiro de $1000. Verifica tu cuenta en nuestra app o en nuestro sitio web.
# 1926. Se ha realizado un pago exitoso por $50 en tu cuenta BCP. Fecha: Hoy a las 10:00hs. Código de referencia: 123456
# 1927. Felicidades! Tu pago de servicios de luz de Electro Puno fue exitoso. Gracias por tu colaboración y por confiar en nosotros.
# 1928. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence el 10 de marzo x la app MiMovistar o Yape
# 1929. Felicidades por tu pago exitoso a Sedapal. Tu cuenta será reactivada con efecto inmediato.
# 1930. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence mañana. Evita la suspensión y cobro de reconexion de 10.00 soles.
# 1931. ¡Atención! Recordatorio: pago de recibo de luz vence hoy. Paga a través de la app MiMovistar o en la oficina de Electro Puno.
# 1932. Este es un recordatorio para pagar tu recibo de luz de Electro Puno, que vence mañana a las 18:00. Puedes realizar el pago en la app Mi Movistar o en la sucursal más cercana.
# 1933. Tu recibo de luz de Electro Puno vence hoy a las 6pm. Paga en línea o en la app MiMovistar para evitar la suspensión y cobro de reconexión.
# 1934. Caja Arequipa te informa sobre la operación exitosa de transferencia de $500 a tu cuenta. Número de transacción: 123456
# 1935. Tu recibo de luz vence hoy, revisa detalles en Mi Electro Puno o en nuestra app.
# 1936. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234.
# 1937. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en el App Mi Movistar
# 1938. ATENCIÓN: Se ha realizado una transferencia de S/ 500 desde tu cuenta Caja Arequipa al día de hoy. Verifica tus movimientos en la app de caja movil.
# 1939. Felicidades! Activaste tu paquete de 100MB x 1 dia. Conoce mas beneficios en la App Mi Movistar o aquí smvst.com/recargapre
# 1940. Recuerda pagar tu recibo Movil de 150 soles que vence hoy x la app MiMovistar o Yape.
# 1941. Felicidades! Tu pago de servicios de luz de Electro Puno ha sido procesado exitosamente. Gracias por confiar en nosotros.
# 1942. Recuerda pagar tu recibo de servicios de Sedapal que vence dentro de los próximos días.
# 1943. El SENAMHI informa que se prevé lluvia intensa para Lima mañana a las 10:00 horas. Evita viajes inútiles.
# 1944. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, no lo compartas con nadie y úsalo solo en tu APP. Código: 1234.
# 1945. Hola, recuerda pagar tu recibo Movil de S/50 que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de S/20.
# 1946. Recuerda pagar tu recibo Sedapal de 150.00 soles que vence mañana por la app Yape o app de banco. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 1947. Hola, recuerda pagar tu recibo Movil de 55.50 soles que vence mañana x la app MiMovistar
# 1948. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 4567".
# 1949. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 1950. Recuerda pagar tu recibo Sedapal de 120.50 soles que vence mañana, evita la suspensión y cobro de reconexion.
# 1951. ¡Prepárate para la temporada de lluvias! SENAMHI te informa que se esperan fuertes tormentas en Lima y Callao durante los próximos días.
# 1952. ¡Hola! Tu recibo de servicios de luz por $50.00 vence hoy. Paga a través de MiMovistar o Yape para evitar suspensiones y reconexiones.
# 1953. Hola, recuerda pagar tu recibo Movil de S/.50 que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de S/.10
# 1954. ¡Atención! Tu tarjeta de crédito fue usada con éxito en la tienda Wong. ¿Qué producto compraste? Confirmá tu pago en nuestra app o llámame al 600 2222.
# 1955. Hola, recuerda pagar tu recibo Movil de 120.50 soles que vence mañana x la app MiMovistar
# 1956. Se ha realizado un pago a tu cuenta Scotiabank por S/500.00 con recibo #123456789.
# 1957. ¡Hola! Tienes una cita médica programada por Video para mañana a las 10:00 am. Verifica tus datos en la aplicación EsSalud.
# 1958. Tu cuenta Caja Arequipa ha sido actualizada para recibir un ingreso de S/500. Verifica tus transacciones en línea o en la app.
# 1959. ¡Atención! Tu recibo de luz de Electro Puno vence mañana a las 6:00 am. Paga en línea en nuestra app o en cualquier sucursal. No te olvides y evita el cobro de reconexion.
# 1960. Se ha realizado una transferencia de S/. 100 desde tu cuenta de Caja Arequipa. Verifica en Internet Banking o app
# 1961. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234.
# 1962. ¡Noticia importante! El SENAMHI informa que se prevén lluvias intensas en Lima y Cusco por las próximas horas. Mantente seguro.
# 1963. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 456789
# 1964. Hola, recuerda pagar tu recibo Movil de S/50 que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de S/20
# 1965. Has solicitado un código de validación para ingresar a Plin. Código: 98765
# 1966. Hola, recuerda pagar tu recibo Movil de 100.00 soles que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 1967. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, no lo compartas con nadie y úsalo solo en tu APP. Código: 4567".
# 1968. Hoy se realizó una transacción exitosa por S/100 en tu cuenta BCP. Consulta más detalles en la App de BCP o en cajaarequipa.com/bcp.
# 1969. Hola, recuerda pagar tu recibo Movil de S/.50 que vence hoy x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de S/.20.
# 1970. Se ha realizado una transacción exitosa por S/200 en tu cuenta BCP. Fecha: 12/02/2023 Hora: 14:30. N° de Transacción: #321456".
# 1971. Has solicitado un código de validación para ingresar a Yape. Código: 4567".
# 1972. Buenos días. Esta es una notificación de Scotiabank Perú sobre la operación exitosa de tu tarjeta de crédito por [monto en soles] a las [time]
# 1973. Se te notifica un recibo por $50.00 a pagar antes del 20/05. Puedes pagar en app MiMovistar o Yape.
# 1974. Hola, recuerda pagar tu recibo Movil de S/.50.00 que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de S/.20.00
# 1975. ¡Hola! Tu recibo de luz vence hoy a las 12:00 hs. Paga desde la app Mi Movistar o Yape para evitar la suspensión y cobro de reconexión.
# 1976. Hola su envio de Mercado Libre con numero de seguimiento (25/1955253) fue asignado a reparto el dia de hoy. Serv-Estafeta".
# 1977. Hola, recuerda pagar tu recibo Movil de 50.00 soles que vence mañana x la app MiMovistar.
# 1978. Buenos días, recuerda pagar tu recibo Movil de S/. 50.00 que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de S/. 30.00.
# 1979. Banco Scotiabank te informa sobre la operación TIN LINEA A CELULAR por S/.500.00 hoy a las 10:00 am realizada en caja movil.
# 1980. Has solicitado un código de validación para ingresar a Plin. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 456789
# 1981. Has solicitado un codigo de validación para ingresar a Plin. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Codigo: 1234
# 1982. Has solicitado un código de validación para ingresar a Plin. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 1983. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y úsalo solo en tu APP. Código: #1234".
# 1984. Se te envía recibo agua Sedapal del mes de junio por S/. 120.00 para pago a través Yape o app Sedapal.
# 1985. Has solicitado un código de validación para ingresar a Yape. EVITA LOS FRAUDES, NO lo compartas con nadie y usalo solo en tu APP. Código: 1234
# 1986. Hola, Caja Arequipa te informa sobre la operación TIN LINEA A CELULAR por S/. 150 hoy a las 10:00 am realizada en CAJA MOVIL.
# 1987. Recuerda pagar tu recibo Movil de 50.00 soles que vence mañana x la app MiMovistar, Yape o app de banco. Evita la suspensión y cobro de reconexion de 20.00 soles".
# 1988. Se ha realizado una transferencia de S/.150 a tu cuenta en BBVA. Consulta tus movimientos en Internet Banking o la app BBVA.
# 1989. Hola, te recordamos que debes pagar tu recibo de agua de Sedapal. Puedes hacerlo a través de la app Yape o en nuestra página web.
# 1990. Se te ha asignado un turno médico a las 10:00 am en Clínica Cusco. Por favor, llega 15 minutos antes.
# 1991. Hola, recuerda pagar tu recibo Movil de $30 que vence mañana x la app MiMovistar o Yape. Evita la suspensión y cobro de reconexion de $10.
# 1992. Felicidades! Activaste tu paquete de 100MB x 1 día. Conoce más beneficios en la App Mi Movistar
# 1993. Te recordamos que el recibo de agua vence el día de hoy. Puedes pagar a través de la app Sedapal o en cualquier agencia de Servicios Postales. Favor de no dejarlo para la fecha última.
# 1994. Atención, tu cuenta Scotiabank fue actualizada exitosamente. Consulta más detalles en la app o en nuestro sitio web oficial.
# 1995. Se ha realizado una transacción exitosa en tu cuenta Scotiabank. ¡Felicidades! Detalles: fecha 12/03/2023, monto S/. 500.00.
# 1996. Hola, recordamos que tu recibo de servicio de agua Sedapal vence mañana a las 12:00 pm. Paga en tiempo hábil para evitar suspension y cobro adicional.
# 1997. Hola, recuerda pagar tu recibo Movil de 150.00 soles que vence mañana x la app MiMovistar. Evita la suspensión y cobro de reconexion de 50.00 soles.
# 1998. Tu recibo de agua vence el próximo día. Paga ahora en nuestra app o en sedapal.com para evitar suspensiones.
# 1999. Sabado a las 10:00 tienes una cita en el Hospital Nacional Arzobispo Loayza en Lima. Por favor, llegar con anticipación".
# 2000. Se ha efectuado una transacción por S/.200 en tu cuenta Scotiabank. Verifica tus estados de cuenta y movimientos en internet banking o en la App Scotiabank.
#
# ✅ SMS generados guardados en: dataset_4/sms_no_spam_peru.txt

# %%
# Eliminar los duplicados del archivo .txt
def eliminar_duplicados(archivo_entrada, archivo_salida):
    """Elimina líneas duplicadas de un archivo de texto"""
    # Convertir a rutas absolutas para mostrar la ubicación completa
    ruta_entrada = os.path.abspath(archivo_entrada)
    ruta_salida = os.path.abspath(archivo_salida)
    
    print(f"🔍 Procesando archivo: {ruta_entrada}")
    
    # Contador de líneas procesadas y eliminadas
    total_lineas = 0
    duplicados = 0
    lineas_vistas = set()
    
    with open(archivo_entrada, 'r', encoding='utf-8') as f_in, \
         open(archivo_salida, 'w', encoding='utf-8') as f_out:
        for linea in f_in:
            linea = linea.strip()
            total_lineas += 1
            
            if not linea:
                continue
                
            if linea in lineas_vistas:
                duplicados += 1
            else:
                f_out.write(linea + '\n')
                lineas_vistas.add(linea)
    
    print(f"✅ Duplicados eliminados:")
    print(f"   - Archivo de entrada: {ruta_entrada}")
    print(f"   - Archivo de salida: {ruta_salida}")
    print(f"   - Total líneas procesadas: {total_lineas}")
    print(f"   - Líneas únicas: {len(lineas_vistas)}")
    print(f"   - Duplicados eliminados: {duplicados}")

# Ejemplo de uso:
eliminar_duplicados("dataset_4/sms_no_spam_peru.txt", "dataset_4/sms_no_spam_peru_clean.txt")
# Out:
# 🔍 Procesando archivo: /Users/franspaxi/machine-learning/dataset_4/sms_no_spam_peru.txt
# ✅ Duplicados eliminados:
#    - Archivo de entrada: /Users/franspaxi/machine-learning/dataset_4/sms_no_spam_peru.txt
#    - Archivo de salida: /Users/franspaxi/machine-learning/dataset_4/sms_no_spam_peru_clean.txt
#    - Total líneas procesadas: 50
#    - Líneas únicas: 50
#    - Duplicados eliminados: 0
