# %% [markdown]
# ## Inteligencia de reconocimiento de Personas Sospechosas

# %%
from ultralytics import YOLO
import os

def main():
    # Cargar modelo base YOLOv11 (yolo12n.pt no existe)
    model = YOLO("yolo12n.pt")  # Se descarga automáticamente
    
    # Verificar que el archivo data.yaml existe
    data_path = "data.yaml"  # Archivo en la misma carpeta
    if not os.path.exists(data_path):
        print(f"Error: No se encuentra {data_path}")
        print(f"Directorio actual: {os.getcwd()}")
        print(f"Archivos en el directorio: {os.listdir('.')}")
        return
    
    # Entrenar con tu dataset
    model.train(
        data=data_path,  # Ruta corregida
        epochs=1,  # Aumenté las épocas
        batch=8,
        imgsz=640,
        name="detector_comportamiento_sospechoso"  # Nombre más apropiado
    )

if __name__ == "__main__":
    main()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.10.18 torch-2.8.0 CPU (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=detector_comportamiento_sospechoso2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/opt/homebrew/runs/detect/detector_comportamiento_sospechoso2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,828 parameters, 2,568,812 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 75.8±50.8 MB/s, size: 19.8 KB)
# train: Scanning /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/labels.cache... 2721 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2721/2721 7.9Mit/s 0.0s0s
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/106473821-1585931052853woman-makes-purchases-in-the-store-novelty-consultation-woman-adult-fashion-consumer-indoor-human_t20_2j43do_jpg.rf.0b1ba8b7a2ed8c803456ae287ad453d4.jpg: 1 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/106473821-1585931052853woman-makes-purchases-in-the-store-novelty-consultation-woman-adult-fashion-consumer-indoor-human_t20_2j43do_jpg.rf.92ea7595e4e5cede13e0a0420d1d85c6.jpg: 1 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/106473821-1585931052853woman-makes-purchases-in-the-store-novelty-consultation-woman-adult-fashion-consumer-indoor-human_t20_2j43do_jpg.rf.b8ad50e3d18afb28d2710251b581baa4.jpg: 1 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/3205-23-Robbery-108-Pct-11-24-23-1_webp.rf.17542042955ab82c44644b64b301971c.jpg: 9 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/3205-23-Robbery-108-Pct-11-24-23-1_webp.rf.86b429e2a58f8068a8dc2e88dbc34b53.jpg: 9 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/3205-23-Robbery-108-Pct-11-24-23-1_webp.rf.f7b0fb16244ff1d83b767c8893b1e929.jpg: 9 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/hq720-1-_jpg.rf.00a59388df6bc1e61a447857e0b60e5d.jpg: 2 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/hq720-1-_jpg.rf.70cf65ad4f077c25f1fdf79bfa9425af.jpg: 2 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/hq720-1-_jpg.rf.b84dcd45c821b3425139706f9746066c.jpg: 2 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/person-detection-ai-camera_jpg.rf.43a0f61f5943c15095d5f95fc91335bd.jpg: 3 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/person-detection-ai-camera_jpg.rf.cfd3ecb960c5ea9f26c5d4e59a02bb7b.jpg: 3 duplicate labels removed
# train: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/train/images/person-detection-ai-camera_jpg.rf.f69ed2b40a6f40a2d822d2235c9d27a1.jpg: 3 duplicate labels removed
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 122.9±40.8 MB/s, size: 20.4 KB)
# val: Scanning /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/valid/labels.cache... 672 images, 4 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 672/672 3.3Mit/s 0.0s0s
# val: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/valid/images/images-11-_jpg.rf.c775161185f1be74c27b8fad17bb5e2e.jpg: 2 duplicate labels removed
# val: /Users/franspaxi/machine-learning/unidad_2/Suspicious Behavior/valid/images/images-16-_jpg.rf.213088027b12378cdce1c6afbfd45257.jpg: 1 duplicate labels removed
# Plotting labels to /opt/homebrew/runs/detect/detector_comportamiento_sospechoso2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /opt/homebrew/runs/detect/detector_comportamiento_sospechoso2
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G      1.374      2.513       1.57          3        640: 100% ━━━━━━━━━━━━ 341/341 0.5it/s 12:06<1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 0.3it/s 2:022.9ss
#                    all        672       2001      0.476      0.373      0.353      0.182
#
# 1 epochs completed in 0.236 hours.
# Optimizer stripped from /opt/homebrew/runs/detect/detector_comportamiento_sospechoso2/weights/last.pt, 5.5MB
# Optimizer stripped from /opt/homebrew/runs/detect/detector_comportamiento_sospechoso2/weights/best.pt, 5.5MB
#
# Validating /opt/homebrew/runs/detect/detector_comportamiento_sospechoso2/weights/best.pt...
# Ultralytics 8.3.203 🚀 Python-3.10.18 torch-2.8.0 CPU (Apple M4 Pro)
# YOLOv12n summary (fused): 159 layers, 2,557,508 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 0.4it/s 1:542.7sss
#                    all        672       2001      0.474      0.373      0.353      0.182
#         Accion anormal        400        441      0.341      0.619      0.453      0.242
#                   Arma        366        423       0.46      0.139      0.175     0.0835
#               Cubierto        373        467      0.551      0.407      0.408      0.208
#         Persona normal        301        670      0.545      0.325      0.374      0.194
# Speed: 0.4ms preprocess, 163.7ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to /opt/homebrew/runs/detect/detector_comportamiento_sospechoso2

# %%
from ultralytics import YOLO
# intenta cargar el checkpoint (asegúrate que yolo12n.pt esté en el cwd o pon ruta completa)
m = YOLO("yolo12n.pt")
print("Modelo cargado:", type(m), m.model is not None)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/franspaxi/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Modelo cargado: <class 'ultralytics.models.yolo.model.YOLO'> True

# %%
from ultralytics import YOLO
import cv2

def probar_modelo_con_camara():
    # Cargar tu modelo entrenado
    modelo_path = "best.pt"
    model = YOLO(modelo_path)

    # Inicializar la cámara (0 = cámara predeterminada de la cámara)
    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("❌ Error: No se pudo abrir la cámara")
        return
    
    print("🎥 Presiona 'q' para salir")
    
    while True:
        # Capturar frame de la cámara
        ret, frame = cap.read()
        if not ret:
            print("❌ Error al capturar frame")
            break
        
        # Hacer predicción en tiempo real
        results = model(frame)
        
        # Dibujar las detecciones en el frame
        annotated_frame = results[0].plot()
        
        # Mostrar el frame con detecciones
        cv2.imshow('Detector de Comportamiento Sospechoso', annotated_frame)
        
        # Salir con 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Limpiar
    cap.release()
    cv2.destroyAllWindows()
    print("✅ Cámara cerrada")

# Ejecutar la función
probar_modelo_con_camara()
# Out:
# 🎥 Presiona 'q' para salir
#
# 0: 384x640 5 Accion anormals, 1 Arma, 1 Cubierto, 68.9ms
# Speed: 5.2ms preprocess, 68.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 59.9ms
# Speed: 1.1ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 61.7ms
# Speed: 1.2ms preprocess, 61.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 59.0ms
# Speed: 1.2ms preprocess, 59.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 59.3ms
# Speed: 1.3ms preprocess, 59.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 60.2ms
# Speed: 1.0ms preprocess, 60.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 55.8ms
# Speed: 1.2ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Accion anormals, 2 Armas, 1 Cubierto, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Cubierto, 55.9ms
# Speed: 1.3ms preprocess, 55.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 
ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 57.4ms
# Speed: 1.7ms preprocess, 57.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Accion anormals, 1 Arma, 1 Cubierto, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 57.1ms
# Speed: 1.3ms preprocess, 57.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 62.4ms
# Speed: 1.2ms preprocess, 62.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 64.3ms
# Speed: 1.2ms preprocess, 64.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Accion anormals, 1 Arma, 1 Cubierto, 55.7ms
# Speed: 1.7ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 44
#      41     print("✅ Cámara cerrada")
#      43 # Ejecutar la función
# ---> 44 probar_modelo_con_camara()
#
# Cell In[6], line 26, in probar_modelo_con_camara()
#      23     break
#      25 # Hacer predicción en tiempo real
# ---> 26 results = model(frame)
#      28 # Dibujar las detecciones en el frame
#      29 annotated_frame = results[0].plot()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/engine/model.py:187, in Model.__call__(self, source, stream, **kwargs)
#     158 def __call__(
#     159     self,
#     160     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     161     stream: bool = False,
#     162     **kwargs: Any,
#     163 ) -> list:
#     164     """
#     165     Alias for the predict method, enabling the model instance to be callable for predictions.
#     166
#    (...)
#     185         ...     print(f"Detected {len(r)} objects in image")
#     186     """
# --> 187     return self.predict(source, stream, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/engine/model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/engine/predictor.py:229, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     227     return self.stream_inference(source, model, *args, **kwargs)
#     228 else:
# --> 229     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/utils/_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/engine/predictor.py:336, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     334 # Inference
#     335 with profilers[1]:
# --> 336     preds = self.inference(im, *args, **kwargs)
#     337     if self.args.embed:
#     338         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/engine/predictor.py:184, in BasePredictor.inference(self, im, *args, **kwargs)
#     178 """Run inference on a given image using the specified model and arguments."""
#     179 visualize = (
#     180     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     181     if self.args.visualize and (not self.source_type.tensor)
#     182     else False
#     183 )
# --> 184 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:637, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     635 # PyTorch
#     636 if self.pt or self.nn_module:
# --> 637     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     639 # TorchScript
#     640 elif self.jit:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/nn/tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/nn/tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/nn/tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/ultralytics/nn/modules/head.py:122, in Detect.forward(self, x)
#     119     return self.forward_end2end(x)
#     121 for i in range(self.nl):
# --> 122     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     123 if self.training:  # Training path
#     124     return x
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %% [markdown]
# ## Inteligencia de reconocimiento de detalles de Facturas Peruanas

# %%
from ultralytics import YOLO

# Cargar el modelo
model = YOLO("best.pt")

# Ver todas las clases
print("📊 Clases del modelo:")
print(f"Total de clases: {len(model.names)}")
print("\nLista de clases:")
for idx, nombre in model.names.items():
    print(f"  {idx}: {nombre}")
# Out:
# 📊 Clases del modelo:
# Total de clases: 9
#
# Lista de clases:
#   0: bank_info
#   1: communication
#   2: customer_info
#   3: invoice_detail
#   4: logo
#   5: paragraph
#   6: table
#   7: total_price
#   8: vendor_info

# %%
from ultralytics import YOLO
import cv2
import os
from pdf2image import convert_from_path
from pathlib import Path

def clasificar_pdfs():
    # Configuración de rutas
    modelo_path = "best.pt"
    carpeta_pdfs = "dataset_analisis"
    carpeta_salida = "resultados_clasificacion"
    
    # Cargar modelo
    print("🔄 Cargando modelo...")
    model = YOLO(modelo_path)
    
    # Crear carpeta de salida
    os.makedirs(carpeta_salida, exist_ok=True)
    
    # Obtener todos los PDFs
    pdfs = [f for f in os.listdir(carpeta_pdfs) if f.endswith('.pdf')]
    
    print(f"📄 Se encontraron {len(pdfs)} archivos PDF")
    
    for pdf_file in pdfs:
        print(f"\n🔍 Procesando: {pdf_file}")
        pdf_path = os.path.join(carpeta_pdfs, pdf_file)
        
        # Crear carpeta para este PDF
        nombre_sin_ext = Path(pdf_file).stem
        carpeta_pdf = os.path.join(carpeta_salida, nombre_sin_ext)
        os.makedirs(carpeta_pdf, exist_ok=True)
        
        try:
            # Convertir PDF a imágenes (una por página)
            imagenes = convert_from_path(pdf_path, dpi=300)
            
            for idx_pagina, imagen_pil in enumerate(imagenes):
                print(f"  📄 Procesando página {idx_pagina + 1}/{len(imagenes)}")
                
                # Convertir PIL Image a formato OpenCV
                imagen_cv = cv2.cvtColor(np.array(imagen_pil), cv2.COLOR_RGB2BGR)
                
                # Hacer predicción
                results = model(imagen_cv)
                
                # Extraer detecciones
                detecciones = results[0].boxes
                
                if len(detecciones) > 0:
                    print(f"    ✅ Se encontraron {len(detecciones)} detecciones")
                    
                    for idx_det, box in enumerate(detecciones):
                        # Obtener coordenadas
                        x1, y1, x2, y2 = map(int, box.xyxy[0])
                        confianza = float(box.conf[0])
                        clase = int(box.cls[0])
                        nombre_clase = model.names[clase]
                        
                        # Recortar región detectada
                        recorte = imagen_cv[y1:y2, x1:x2]
                        
                        # Guardar recorte
                        nombre_archivo = f"pag{idx_pagina + 1}_det{idx_det + 1}_{nombre_clase}_conf{confianza:.2f}.jpg"
                        ruta_guardado = os.path.join(carpeta_pdf, nombre_archivo)
                        cv2.imwrite(ruta_guardado, recorte)
                        
                        print(f"      💾 Guardado: {nombre_archivo}")
                else:
                    print(f"    ⚠️  No se encontraron detecciones en esta página")
                    
        except Exception as e:
            print(f"  ❌ Error procesando {pdf_file}: {e}")
    
    print(f"\n✅ Proceso completado. Resultados en: {carpeta_salida}/")

if __name__ == "__main__":
    import numpy as np
    clasificar_pdfs()
# Out:
# 🔄 Cargando modelo...
# 📄 Se encontraron 3 archivos PDF
#
# 🔍 Procesando: 20427799973-03-b090-00053521_uzw3qr4qjh.pdf
#   📄 Procesando página 1/1
#
# 0: 640x480 1 customer_info, 3 invoice_details, 2 logos, 5 paragraphs, 3 tables, 66.6ms
# Speed: 2.2ms preprocess, 66.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#     ✅ Se encontraron 14 detecciones
#       💾 Guardado: pag1_det1_logo_conf0.83.jpg
#       💾 Guardado: pag1_det2_customer_info_conf0.74.jpg
#       💾 Guardado: pag1_det3_paragraph_conf0.69.jpg
#       💾 Guardado: pag1_det4_invoice_detail_conf0.66.jpg
#       💾 Guardado: pag1_det5_table_conf0.59.jpg
#       💾 Guardado: pag1_det6_invoice_detail_conf0.54.jpg
#       💾 Guardado: pag1_det7_paragraph_conf0.51.jpg
#       💾 Guardado: pag1_det8_paragraph_conf0.46.jpg
#       💾 Guardado: pag1_det9_table_conf0.46.jpg
#       💾 Guardado: pag1_det10_paragraph_conf0.39.jpg
#       💾 Guardado: pag1_det11_logo_conf0.36.jpg
#       💾 Guardado: pag1_det12_table_conf0.33.jpg
#       💾 Guardado: pag1_det13_paragraph_conf0.31.jpg
#       💾 Guardado: pag1_det14_invoice_detail_conf0.25.jpg
#
# 🔍 Procesando: factura-5053_jr0yl0l5jp.pdf
#   📄 Procesando página 1/1
#
# 0: 640x480 1 bank_info, 2 customer_infos, 1 logo, 1 paragraph, 1 table, 2 total_prices, 1 vendor_info, 66.7ms
# Speed: 1.5ms preprocess, 66.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#     ✅ Se encontraron 9 detecciones
#       💾 Guardado: pag1_det1_customer_info_conf0.80.jpg
#       💾 Guardado: pag1_det2_logo_conf0.73.jpg
#       💾 Guardado: pag1_det3_vendor_info_conf0.56.jpg
#       💾 Guardado: pag1_det4_customer_info_conf0.52.jpg
#       💾 Guardado: pag1_det5_bank_info_conf0.50.jpg
#       💾 Guardado: pag1_det6_paragraph_conf0.45.jpg
#       💾 Guardado: pag1_det7_table_conf0.37.jpg
#       💾 Guardado: pag1_det8_total_price_conf0.33.jpg
#       💾 Guardado: pag1_det9_total_price_conf0.29.jpg
#
# 🔍 Procesando: op-1632031_ufzh8cap6i.pdf
#   📄 Procesando página 1/2
#
# 0: 640x480 1 invoice_detail, 2 logos, 3 paragraphs, 1 table, 4 total_prices, 1 vendor_info, 66.5ms
# Speed: 1.5ms preprocess, 66.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#     ✅ Se encontraron 12 detecciones
#       💾 Guardado: pag1_det1_vendor_info_conf0.60.jpg
#       💾 Guardado: pag1_det2_total_price_conf0.58.jpg
#       💾 Guardado: pag1_det3_total_price_conf0.56.jpg
#       💾 Guardado: pag1_det4_total_price_conf0.54.jpg
#       💾 Guardado: pag1_det5_table_conf0.51.jpg
#       💾 Guardado: pag1_det6_paragraph_conf0.48.jpg
#       💾 Guardado: pag1_det7_invoice_detail_conf0.48.jpg
#       💾 Guardado: pag1_det8_total_price_conf0.45.jpg
#       💾 Guardado: pag1_det9_logo_conf0.40.jpg
#       💾 Guardado: pag1_det10_paragraph_conf0.38.jpg
#       💾 Guardado: pag1_det11_logo_conf0.34.jpg
#       💾 Guardado: pag1_det12_paragraph_conf0.27.jpg
#   📄 Procesando página 2/2
#
# 0: 640x480 1 customer_info, 1 invoice_detail, 4 logos, 6 paragraphs, 1 total_price, 2 vendor_infos, 65.5ms
# Speed: 1.4ms preprocess, 65.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#     ✅ Se encontraron 15 detecciones
#       💾 Guardado: pag2_det1_vendor_info_conf0.76.jpg
#       💾 Guardado: pag2_det2_paragraph_conf0.73.jpg
#       💾 Guardado: pag2_det3_logo_conf0.69.jpg
#       💾 Guardado: pag2_det4_vendor_info_conf0.60.jpg
#       💾 Guardado: pag2_det5_logo_conf0.59.jpg
#       💾 Guardado: pag2_det6_logo_conf0.51.jpg
#       💾 Guardado: pag2_det7_paragraph_conf0.48.jpg
#       💾 Guardado: pag2_det8_paragraph_conf0.44.jpg
#       💾 Guardado: pag2_det9_total_price_conf0.37.jpg
#       💾 Guardado: pag2_det10_invoice_detail_conf0.36.jpg
#       💾 Guardado: pag2_det11_paragraph_conf0.33.jpg
#       💾 Guardado: pag2_det12_customer_info_conf0.31.jpg
#       💾 Guardado: pag2_det13_logo_conf0.30.jpg
#       💾 Guardado: pag2_det14_paragraph_conf0.27.jpg
#       💾 Guardado: pag2_det15_paragraph_conf0.27.jpg
#
# ✅ Proceso completado. Resultados en: resultados_clasificacion/

# %%
import easyocr
import os
from pathlib import Path
import json
import cv2

def extraer_texto_con_ocr():
    # Configuración de rutas
    carpeta_imagenes = "resultados_clasificacion"
    carpeta_salida = "resultados_ocr"
    
    # Crear carpeta de salida
    os.makedirs(carpeta_salida, exist_ok=True)
    
    # Inicializar EasyOCR (español e inglés)
    print("🔄 Inicializando EasyOCR...")
    reader = easyocr.Reader(['es', 'en'], gpu=False)
    
    print("✅ EasyOCR listo\n")
    
    # Recorrer todas las carpetas de PDFs
    carpetas_pdfs = [d for d in os.listdir(carpeta_imagenes) 
                     if os.path.isdir(os.path.join(carpeta_imagenes, d))]
    
    print(f"📁 Se encontraron {len(carpetas_pdfs)} carpetas de PDFs\n")
    
    for carpeta_pdf in carpetas_pdfs:
        print(f"🔍 Procesando carpeta: {carpeta_pdf}")
        
        ruta_carpeta_pdf = os.path.join(carpeta_imagenes, carpeta_pdf)
        
        # Crear carpeta de salida para este PDF
        carpeta_salida_pdf = os.path.join(carpeta_salida, carpeta_pdf)
        os.makedirs(carpeta_salida_pdf, exist_ok=True)
        
        # Obtener todas las imágenes
        imagenes = [f for f in os.listdir(ruta_carpeta_pdf) 
                   if f.endswith(('.jpg', '.png', '.jpeg'))]
        
        print(f"  📷 Total de imágenes: {len(imagenes)}")
        
        # Resultados consolidados
        resultados_pdf = []
        
        for idx, imagen_file in enumerate(sorted(imagenes), 1):
            ruta_imagen = os.path.join(ruta_carpeta_pdf, imagen_file)
            
            print(f"    🔎 [{idx}/{len(imagenes)}] Procesando: {imagen_file}")
            
            try:
                # Leer texto con EasyOCR
                resultado = reader.readtext(ruta_imagen)
                
                # Extraer solo el texto
                textos = [deteccion[1] for deteccion in resultado]
                texto_completo = " ".join(textos)
                
                # Calcular precisión promedio
                if resultado:
                    precision_promedio = sum(det[2] for det in resultado) / len(resultado)
                else:
                    precision_promedio = 0.0
                
                # Información detallada
                info_detallada = {
                    "archivo": imagen_file,
                    "texto_completo": texto_completo,
                    "precision_promedio": float(precision_promedio),
                    "num_detecciones": len(resultado),
                    "detecciones": [
                        {
                            "texto": det[1],
                            "confianza": float(det[2]),
                            "coordenadas": [int(coord) for punto in det[0] for coord in punto]
                        }
                        for det in resultado
                    ]
                }
                
                resultados_pdf.append(info_detallada)
                
                # Guardar texto en archivo individual CON PRECISIÓN PROMEDIO
                nombre_txt = Path(imagen_file).stem + ".txt"
                ruta_txt = os.path.join(carpeta_salida_pdf, nombre_txt)
                with open(ruta_txt, 'w', encoding='utf-8') as f:
                    if texto_completo:
                        f.write(f"{texto_completo} (precisión OCR: {precision_promedio:.2%})")
                    else:
                        f.write("No se detectó texto")
                
                if texto_completo:
                    print(f"      ✅ Texto extraído: {len(textos)} líneas")
                    print(f"      📊 Precisión promedio: {precision_promedio:.2%}")
                    print(f"      📝 Preview: {texto_completo[:100]}...")
                else:
                    print(f"      ⚠️  No se detectó texto")
                    
            except Exception as e:
                print(f"      ❌ Error: {e}")
                resultados_pdf.append({
                    "archivo": imagen_file,
                    "error": str(e)
                })
        
        # Guardar resultados consolidados en JSON
        archivo_json = os.path.join(carpeta_salida_pdf, "resultados_completos.json")
        with open(archivo_json, 'w', encoding='utf-8') as f:
            json.dump(resultados_pdf, f, ensure_ascii=False, indent=2)
        
        print(f"  💾 Resultados guardados en: {carpeta_salida_pdf}/\n")
    
    print(f"✅ Proceso completado. Resultados en: {carpeta_salida}/")
    
    # Crear resumen general
    crear_resumen_general(carpeta_salida)

def crear_resumen_general(carpeta_salida):
    """Crea un resumen de todos los textos extraídos"""
    print("\n📊 Generando resumen general...")
    
    resumen = {}
    
    carpetas = [d for d in os.listdir(carpeta_salida) 
                if os.path.isdir(os.path.join(carpeta_salida, d))]
    
    for carpeta in carpetas:
        ruta_json = os.path.join(carpeta_salida, carpeta, "resultados_completos.json")
        
        if os.path.exists(ruta_json):
            with open(ruta_json, 'r', encoding='utf-8') as f:
                datos = json.load(f)
                
            # Calcular precisión promedio general
            precisiones = [d.get("precision_promedio", 0) for d in datos if "precision_promedio" in d]
            precision_general = sum(precisiones) / len(precisiones) if precisiones else 0
                
            resumen[carpeta] = {
                "total_imagenes": len(datos),
                "imagenes_con_texto": sum(1 for d in datos if d.get("texto_completo")),
                "total_detecciones": sum(d.get("num_detecciones", 0) for d in datos),
                "precision_promedio": f"{precision_general:.2%}"
            }
    
    # Guardar resumen
    archivo_resumen = os.path.join(carpeta_salida, "resumen_general.json")
    with open(archivo_resumen, 'w', encoding='utf-8') as f:
        json.dump(resumen, f, ensure_ascii=False, indent=2)
    
    print(f"✅ Resumen guardado en: {archivo_resumen}")
    
    # Mostrar resumen en consola
    print("\n" + "="*50)
    print("RESUMEN GENERAL")
    print("="*50)
    for pdf, stats in resumen.items():
        print(f"\n📄 {pdf}:")
        print(f"   Total imágenes: {stats['total_imagenes']}")
        print(f"   Con texto: {stats['imagenes_con_texto']}")
        print(f"   Detecciones: {stats['total_detecciones']}")
        print(f"   Precisión promedio: {stats['precision_promedio']}")

if __name__ == "__main__":
    extraer_texto_con_ocr()

# %%
# Ahora ejecuta tu código FastAPI
from fastapi import FastAPI, File, UploadFile, HTTPException
import nest_asyncio
nest_asyncio.apply()
from fastapi.responses import JSONResponse
from ultralytics import YOLO
import easyocr
import cv2
import numpy as np
import fitz  # PyMuPDF
from pathlib import Path
import tempfile
import os
from typing import Dict
import uvicorn

# Inicializar FastAPI
app = FastAPI(title="PDF OCR API", version="1.0.0")

# Cargar modelo YOLO y EasyOCR al inicio
print("🔄 Cargando modelos...")
modelo_yolo = YOLO("best.pt")
reader_ocr = easyocr.Reader(['es', 'en'], gpu=False)
print("✅ Modelos cargados\n")

def procesar_pdf(pdf_path: str) -> Dict[str, list]:
    """
    Procesa un PDF: extrae imágenes, clasifica con YOLO, aplica OCR
    Retorna diccionario con resultados por clase (acumulando múltiples detecciones)
    """
    resultados = {}
    
    try:
        # Abrir PDF con PyMuPDF
        doc = fitz.open(pdf_path)
        
        for idx_pagina in range(len(doc)):
            # Obtener la página
            pagina = doc[idx_pagina]
            
            # Convertir página a imagen
            mat = fitz.Matrix(2, 2)
            pix = pagina.get_pixmap(matrix=mat)
            
            # Convertir a numpy array
            img_data = np.frombuffer(pix.samples, dtype=np.uint8).reshape(
                pix.height, pix.width, pix.n
            )
            
            # Convertir a BGR (OpenCV)
            if pix.n == 4:  # RGBA
                imagen_cv = cv2.cvtColor(img_data, cv2.COLOR_RGBA2BGR)
            else:  # RGB
                imagen_cv = cv2.cvtColor(img_data, cv2.COLOR_RGB2BGR)
            
            # Hacer predicción con YOLO
            results = modelo_yolo(imagen_cv)
            detecciones = results[0].boxes
            
            # Procesar cada detección
            for box in detecciones:
                # Obtener coordenadas y clase
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                confianza_yolo = float(box.conf[0])
                clase = int(box.cls[0])
                nombre_clase = modelo_yolo.names[clase]
                
                # Validar coordenadas
                if x2 > x1 and y2 > y1:
                    # Recortar región detectada
                    recorte = imagen_cv[y1:y2, x1:x2]
                    
                    # Aplicar OCR al recorte
                    resultado_ocr = reader_ocr.readtext(recorte)
                    
                    if resultado_ocr:
                        # Extraer texto y calcular precisión promedio
                        textos = [det[1] for det in resultado_ocr]
                        texto_completo = " ".join(textos)
                        precision_promedio = sum(det[2] for det in resultado_ocr) / len(resultado_ocr)
                        
                        # NUEVA ESTRUCTURA: Diccionario con texto y precisión
                        if texto_completo.strip():
                            deteccion = {
                                "text": texto_completo,
                                "precision": f"{precision_promedio:.2%}",
                                # "precision_raw": round(precision_promedio, 4),
                                # "pagina": idx_pagina + 1,
                                # "confianza_yolo": f"{confianza_yolo:.2%}"
                            }
                            
                            # Inicializar lista si no existe
                            if nombre_clase not in resultados:
                                resultados[nombre_clase] = []
                            
                            # Agregar a la lista
                            resultados[nombre_clase].append(deteccion)
        
        doc.close()
        
    except Exception as e:
        raise HTTPException(status_code=500, detail=f"Error procesando PDF: {str(e)}")
    
    return resultados

@app.post("/procesar-pdf/")
async def procesar_pdf_endpoint(file: UploadFile = File(...)):
    """
    Endpoint para procesar un archivo PDF
    
    Parámetros:
    - file: Archivo PDF a procesar
    
    Retorna:
    - JSON con resultados del OCR organizados por clase
    """
    # Validar que sea un PDF
    if not file.filename.endswith('.pdf'):
        raise HTTPException(status_code=400, detail="El archivo debe ser un PDF")
    
    # Crear archivo temporal
    with tempfile.NamedTemporaryFile(delete=False, suffix='.pdf') as temp_file:
        # Guardar archivo subido
        contenido = await file.read()
        temp_file.write(contenido)
        temp_path = temp_file.name
    
    try:
        # Procesar PDF
        resultados = procesar_pdf(temp_path)
        
        if not resultados:
            return JSONResponse(
                content={"mensaje": "No se detectó texto en el PDF"},
                status_code=200
            )
        
        return JSONResponse(content=resultados, status_code=200)
        
    finally:
        # Limpiar archivo temporal
        if os.path.exists(temp_path):
            os.remove(temp_path)

@app.get("/")
async def root():
    """Endpoint de bienvenida"""
    return {
        "mensaje": "API de procesamiento de PDFs con YOLO y OCR",
        "version": "1.0.0",
        "endpoints": {
            "/procesar-pdf/": "POST - Sube un PDF para extraer texto",
            "/docs": "GET - Documentación interactiva"
        }
    }

@app.get("/health")
async def health_check():
    """Verificar estado de la API"""
    return {
        "status": "ok",
        "modelo_yolo": "cargado",
        "ocr": "cargado"
    }

# Ejecutar con nest_asyncio en Jupyter
if __name__ == "__main__":
    import asyncio
    from threading import Thread
    
    def run_server():
        uvicorn.run(app, host="0.0.0.0", port=8090)
    
    # Ejecutar el servidor en un hilo separado para Jupyter
    server_thread = Thread(target=run_server, daemon=True)
    server_thread.start()
    
    print("🚀 Servidor FastAPI iniciado en http://0.0.0.0:8090")
    print("📖 Documentación disponible en http://0.0.0.0:8090/docs")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 🔄 Cargando modelos...
# ✅ Modelos cargados
#
# 🚀 Servidor FastAPI iniciado en http://0.0.0.0:8090
# 📖 Documentación disponible en http://0.0.0.0:8090/docs
# INFO:     Started server process [13866]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8090 (Press CTRL+C to quit)
# 0: 640x480 2 customer_infos, 2 invoice_details, 2 logos, 5 paragraphs, 2 tables, 77.1ms
# Speed: 3.3ms preprocess, 77.1ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
# /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# INFO:     127.0.0.1:52735 - "POST /procesar-pdf/ HTTP/1.1" 200 OK
#
# 0: 640x480 2 customer_infos, 2 invoice_details, 2 logos, 5 paragraphs, 2 tables, 92.9ms
# Speed: 2.4ms preprocess, 92.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# INFO:     127.0.0.1:53192 - "POST /procesar-pdf/ HTTP/1.1" 200 OK
#
# 0: 640x480 2 customer_infos, 2 invoice_details, 2 logos, 5 paragraphs, 2 tables, 77.8ms
# Speed: 2.3ms preprocess, 77.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# INFO:     127.0.0.1:53192 - "POST /procesar-pdf/ HTTP/1.1" 200 OK

# %% [markdown]
# ## Inteligencia de reconocimiento de Placas peruanas

# %%
import pytesseract
import cv2
import os
from pathlib import Path

def test_tesseract_placas():
    """
    Prueba simple de Tesseract OCR en dataset de placas peruanas
    """
    # Configuración de rutas
    carpeta_dataset = "../../unidad_2/Placas-peruanas/dataset"
    archivo_salida = "../../unidad_2/Placas-peruanas/dataset/resultados_ocr.txt"
    
    # Verificar que existe la carpeta
    if not os.path.exists(carpeta_dataset):
        print(f"❌ Error: No se encuentra la carpeta {carpeta_dataset}")
        return
    
    # Configuración de Tesseract para placas
    # --psm 7: Tratar la imagen como una sola línea de texto
    # -c tessedit_char_whitelist: Solo permitir caracteres específicos
    config_tesseract = '-l spa --psm 7 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-'
    
    # Obtener todas las imágenes
    extensiones = ('.jpg', '.jpeg', '.png', '.bmp')
    imagenes = [f for f in os.listdir(carpeta_dataset) 
                if f.lower().endswith(extensiones)]
    
    print(f"🔍 Se encontraron {len(imagenes)} imágenes")
    print(f"📂 Procesando carpeta: {carpeta_dataset}\n")
    
    # Abrir archivo de salida
    with open(archivo_salida, 'w', encoding='utf-8') as archivo:
        archivo.write("="*60 + "\n")
        archivo.write("RESULTADOS DE OCR - PLACAS PERUANAS\n")
        archivo.write("="*60 + "\n\n")
        
        # Procesar cada imagen
        for idx, imagen_file in enumerate(sorted(imagenes), 1):
            ruta_imagen = os.path.join(carpeta_dataset, imagen_file)
            
            print(f"[{idx}/{len(imagenes)}] Procesando: {imagen_file}")
            
            try:
                # Leer imagen
                imagen = cv2.imread(ruta_imagen)
                
                if imagen is None:
                    resultado = "ERROR: No se pudo leer la imagen"
                    print(f"  ❌ {resultado}")
                else:
                    # Preprocesamiento
                    gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
                    
                    # Aplicar threshold para mejorar contraste
                    _, thresh = cv2.threshold(gris, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
                    
                    # Extraer texto con Tesseract
                    texto = pytesseract.image_to_string(thresh, config=config_tesseract)
                    texto_limpio = texto.strip().replace('\n', ' ').replace('\f', '')
                    
                    if texto_limpio:
                        resultado = texto_limpio
                        print(f"  ✅ Texto detectado: {resultado}")
                    else:
                        resultado = "NO SE DETECTÓ TEXTO"
                        print(f"  ⚠️  {resultado}")
                
                # Escribir resultado en archivo
                archivo.write(f"Imagen: {imagen_file}\n")
                archivo.write(f"Resultado: {resultado}\n")
                archivo.write("-"*60 + "\n\n")
                
            except Exception as e:
                error_msg = f"ERROR: {str(e)}"
                print(f"  ❌ {error_msg}")
                archivo.write(f"Imagen: {imagen_file}\n")
                archivo.write(f"Resultado: {error_msg}\n")
                archivo.write("-"*60 + "\n\n")
        
        # Resumen final
        archivo.write("\n" + "="*60 + "\n")
        archivo.write(f"RESUMEN\n")
        archivo.write(f"Total de imágenes procesadas: {len(imagenes)}\n")
        archivo.write("="*60 + "\n")
    
    print(f"\n✅ Proceso completado")
    print(f"📄 Resultados guardados en: {archivo_salida}")

# Ejecutar la prueba
if __name__ == "__main__":
    test_tesseract_placas()
# Out:
# 🔍 Se encontraron 4011 imágenes
# 📂 Procesando carpeta: ../../unidad_2/Placas-peruanas/dataset
#
# [1/4011] Procesando: 1756725331_0.9_(56, 107, 3)_B2C-509.jpg
#   ✅ Texto detectado: 820-509
# [2/4011] Procesando: 1756726056_0.91_(65, 124, 3)_A4S-720.jpg
#   ✅ Texto detectado: 145-720
# [3/4011] Procesando: 1756726533_0.91_(51, 99, 3)_Z8C-206.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [
jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [3997/4011] Procesando: 1758029325_0.93_(39, 83, 3)_VBS-878.jpg
#   ✅ Texto detectado: 1BS-878
# [3998/4011] Procesando: 1758029343_0.92_(35, 85, 3)_63C-338.jpg
#   ✅ Texto detectado: 630-390
# [3999/4011] Procesando: 1758029422_0.92_(45, 88, 3)_A1V-713.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4000/4011] Procesando: 1758029423_0.93_(48, 94, 3)_41Y-713.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4001/4011] Procesando: 1758029426_0.92_(37, 91, 3)_B30-733.jpg
#   ✅ Texto detectado: 1830-733
# [4002/4011] Procesando: 1758029444_0.92_(47, 109, 3)_BTC-739.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4003/4011] Procesando: 1758029450_0.91_(48, 100, 3)_Z1C-941.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4004/4011] Procesando: 1758029457_0.92_(46, 97, 3)_BCK-946.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4005/4011] Procesando: 1758029507_0.93_(111, 119, 3)_Z10-782.jpg
#   ✅ Texto detectado: UU
# [4006/4011] Procesando: 1758029586_0.93_(42, 84, 3)_BWQ-500.jpg
#   ✅ Texto detectado: BH0-500
# [4007/4011] Procesando: 1758029718_0.92_(40, 80, 3)_15U-848.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4008/4011] Procesando: 1758029720_0.93_(58, 94, 3)_75L-848.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4009/4011] Procesando: 1758029721_0.93_(127, 142, 3)_V50-848.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4010/4011] Procesando: 1758029815_0.92_(45, 88, 3)_72M-797.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
# [4011/4011] Procesando: 1758029818_0.91_(66, 103, 3)_Z2M-792.jpg
#   ⚠️  NO SE DETECTÓ TEXTO
#
# ✅ Proceso completado
# 📄 Resultados guardados en: ../../unidad_2/Placas-peruanas/dataset/resultados_ocr.txt

# %%
# !pip show paddleocr
# Out:
# Name: paddleocr
# Version: 3.2.0
# Summary: Awesome multilingual OCR and document parsing toolkits based on PaddlePaddle
# Home-page: https://github.com/PaddlePaddle/PaddleOCR
# Author:
# Author-email: PaddlePaddle <Paddle-better@baidu.com>
# License: Apache License 2.0
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages
# Requires: paddlex, PyYAML, typing-extensions
# Required-by:

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang="es", use_angle_cls=True)
ruta_imagen = "../../unidad_2/Placas-peruanas/dataset/1756725331_0.9_(56, 107, 3)_B2C-509.jpg" 

resultados = ocr.ocr(ruta_imagen)
for bloque in resultados:
    for texto, confianza in zip(bloque['rec_texts'], bloque['rec_scores']):
        print(f"{confianza:.2f} -> {texto}")
# Out:
# /var/folders/qb/k145lbr965z5vj4mc4643wq00000gn/T/ipykernel_25629/3998433899.py:3: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr = PaddleOCR(lang="es", use_angle_cls=True)
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-LCNet_x1_0_doc_ori`.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/UVDoc`.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-LCNet_x1_0_textline_ori`.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-OCRv5_server_det`.
# Creating model: ('latin_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/latin_PP-OCRv5_mobile_rec`.
# /var/folders/qb/k145lbr965z5vj4mc4643wq00000gn/T/ipykernel_25629/3998433899.py:6: DeprecationWarning: Please use `predict` instead.
#   resultados = ocr.ocr(ruta_imagen)
# 1.00 -> B2C-50
