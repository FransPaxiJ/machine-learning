# %% [markdown]
# # Tarea U2S4-ComparaciónOCR

# %% [markdown]
# ## easyOCR

# %% [markdown]
# ### Instalacion de easyOCR

# %%
# !pip install easyOCR

# %% [markdown]
# ### Comprobar version de easyOCR

# %%
# !pip show easyOCR
# Out:
# Name: easyocr
# Version: 1.7.2
# Summary: End-to-End Multi-Lingual Optical Character Recognition (OCR) Solution
# Home-page: https://github.com/jaidedai/easyocr
# Author: Rakpong Kittinaradorn
# Author-email: r.kittinaradorn@gmail.com
# License: Apache License 2.0
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages
# Requires: ninja, numpy, opencv-python-headless, Pillow, pyclipper, python-bidi, PyYAML, scikit-image, scipy, Shapely, torch, torchvision
# Required-by:

# %% [markdown]
# ### Probar con una imagen easyOCR (presicion y tiempo de inferencia)

# %%
import easyocr
import time
import warnings
import os

# Suprimir warnings y mensajes de info
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Configuración
image_path = 'dataset/1755800220_0.9_(48, 104, 3)_BYJ-567.jpg'
expected_text = "BYJ-567"

# Inicializar easyOCR
reader = easyocr.Reader(['es', 'en'], gpu=False, verbose=False)

# Realizar OCR y medir tiempo
start_time = time.time()
results = reader.readtext(image_path)
inference_time = time.time() - start_time

# Filtrar detecciones que tengan exactamente 7 caracteres
valid_detections = [text for _, text, conf in results if len(text.replace(' ', '').replace('-', '')) == 6 and len(text) == 7]
detected_text = valid_detections[0] if valid_detections else ""

# Calcular precisión
precision = 100.0 if expected_text.lower() == detected_text.lower() else 0.0
resultado = "✅ Correcto" if precision == 100.0 else "❌ Incorrecto"

# Mostrar resultados en tabla
print("\n" + "=" * 120)
print("RESULTADOS easyOCR")
print("=" * 120)
print(f"{'Imagen':<45} | {'Texto Detectado':<15} | {'Texto Esperado':<15} | {'Tiempo (s)':<12} | {'Precisión':<10} | {'Resultado':<12}")
print("-" * 120)
print(f"{image_path:<45} | {detected_text:<15} | {expected_text:<15} | {inference_time:<12.4f} | {precision:<10.1f}% | {resultado:<12}")
print("=" * 120)
# Out:
# ========================================================================================================================
# RESULTADOS easyOCR
# ========================================================================================================================
# Imagen                                        | Texto Detectado | Texto Esperado  | Tiempo (s)   | Precisión  | Resultado
# ------------------------------------------------------------------------------------------------------------------------
# dataset/1755800220_0.9_(48, 104, 3)_BYJ-567.jpg | BYJ-567         | BYJ-567         | 0.0734       | 100.0     % | ✅ Correcto
# ========================================================================================================================

# %% [markdown]
# ### Probar con el dataset easyOCR (presicion y tiempo de inferencia)

# %%
import easyocr
import time
import warnings
import os
import glob
import re
import csv

# Suprimir warnings y mensajes de info
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Configuración
dataset_path = 'dataset/'
image_extensions = ['*.jpg', '*.jpeg', '*.png', '*.bmp']
csv_filename = 'resultados_easyOCR/resultados_easyocr.csv'

# Obtener todas las imágenes del dataset
image_files = []
for ext in image_extensions:
    image_files.extend(glob.glob(os.path.join(dataset_path, ext)))

# Inicializar easyOCR
print("Inicializando easyOCR...")
reader = easyocr.Reader(['es', 'en'], gpu=False, verbose=False)

# Almacenar resultados
results_data = []
total_time = 0
correct_count = 0
total_images = len(image_files)

# Procesar cada imagen
for image_path in sorted(image_files):
    
    # Extraer el texto esperado del nombre del archivo
    filename = os.path.basename(image_path)
    match = re.search(r'_([A-Z0-9-]+)\.(jpg|jpeg|png|bmp)$', filename, re.IGNORECASE)
    expected_text = match.group(1) if match else "UNKNOWN"
    
    # Realizar OCR y medir tiempo
    start_time = time.time()
    results = reader.readtext(image_path)
    inference_time = time.time() - start_time
    total_time += inference_time

    # Filtrar detecciones que tengan exactamente 7 caracteres
    valid_detections = [text for _, text, conf in results if len(text.replace(' ', '').replace('-', '')) == 6 and len(text) == 7]
    detected_text = valid_detections[0] if valid_detections else ""

    # Calcular precisión
    precision = 100.0 if expected_text.lower() == detected_text.lower() else 0.0
    resultado = "✅ Correcto" if precision == 100.0 else "❌ Incorrecto"
    
    if precision == 100.0:
        correct_count += 1

    # Guardar resultado
    results_data.append({
        'Imagen': image_path,
        'Texto Detectado': detected_text,
        'Texto Esperado': expected_text,
        'Tiempo (s)': f"{inference_time:.4f}",
        'Precisión (%)': f"{precision:.1f}",
        'Resultado': resultado
    })

    print(f"Procesado: {filename} | Detectado: {detected_text} | Esperado: {expected_text} | Tiempo: {inference_time:.4f}s | Precisión: {precision:.1f}% | {resultado}")

# Guardar resultados en CSV
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Imagen', 'Texto Detectado', 'Texto Esperado', 'Tiempo (s)', 'Precisión (%)', 'Resultado']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    writer.writerows(results_data)
    
    # Agregar línea vacía
    writer.writerow({})
    
    # Agregar resumen final
    incorrect_count = total_images - correct_count
    writer.writerow({
        'Imagen': '=== RESUMEN FINAL ===',
        'Texto Detectado': '',
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Total de imágenes',
        'Texto Detectado': str(total_images),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Correctos',
        'Texto Detectado': str(correct_count),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': f"{(correct_count/total_images)*100:.1f}",
        'Resultado': '✅'
    })
    writer.writerow({
        'Imagen': 'Incorrectos',
        'Texto Detectado': str(incorrect_count),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': f"{(incorrect_count/total_images)*100:.1f}",
        'Resultado': '❌'
    })
    writer.writerow({
        'Imagen': 'Tiempo total',
        'Texto Detectado': f"{total_time:.4f}s",
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Tiempo promedio',
        'Texto Detectado': f"{total_time/total_images:.4f}s",
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })

print(f"\n✅ Resultados guardados en: {csv_filename}")
print(f"📊 Resumen: {correct_count}/{total_images} correctos ({(correct_count/total_images)*100:.1f}%)")
print(f"⏱️  Tiempo total: {total_time:.4f}s | Tiempo promedio: {total_time/total_images:.4f}s")
# Out:
# Inicializando easyOCR...
# Procesado: 1755800220_0.9_(48, 104, 3)_BYJ-567.jpg | Detectado: BYJ-567 | Esperado: BYJ-567 | Tiempo: 0.0307s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755800225_0.91_(44, 95, 3)_V71-023.jpg | Detectado:  | Esperado: V71-023 | Tiempo: 0.0253s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800256_0.9_(49, 104, 3)_Z4X-018.jpg | Detectado: 74X-018 | Esperado: Z4X-018 | Tiempo: 0.0217s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800279_0.93_(64, 113, 3)_A8D-757.jpg | Detectado: [80-757 | Esperado: A8D-757 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800317_0.9_(45, 93, 3)_VAJ-632.jpg | Detectado:  | Esperado: VAJ-632 | Tiempo: 0.0195s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800323_0.9_(52, 105, 3)_CRO-577.jpg | Detectado: [RO-577 | Esperado: CRO-577 | Tiempo: 0.0370s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800341_0.9_(44, 91, 3)_V8U-524.jpg | Detectado: 18u-524 | Esperado: V8U-524 | Tiempo: 0.0201s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800344_0.91_(47, 96, 3)_Z7U-204.jpg | Detectado:  | Esperado: Z7U-204 | Tiempo: 0.0271s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800351_0.91_(47, 93, 3)_BSV-176.jpg | Detectado: BSI-170 | Esperado: BSV-176 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800370_0.91_(52, 105, 3)_Z7P-666.jpg | Detectado: [7P-666 | Esperado: Z7P-666 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800418_0.9_(53, 106, 3)_Z6A-203.jpg | Detectado:  | Esperado: Z6A-203 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800425_0.9_(58, 119, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800437_0.9_(60, 107, 3)_Z5B-752.jpg | Detectado:  | Esperado: Z5B-752 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800446_0.9_(49, 100, 3)_Z8Y-837.jpg | Detectado: Z8Y-837 | Esperado: Z8Y-837 | Tiempo: 0.0207s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755800450_0.9_(48, 96, 3)_Z7V-290.jpg | Detectado:  | Esperado: Z7V-290 | Tiempo: 0.0190s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800459_0.9_(46, 92, 3)_Z6S-279.jpg | Detectado: 465-279 | Esperado: Z6S-279 | Tiempo: 0.0179s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800467_0.91_(58, 105, 3)_B1B-164.jpg | Detectado:  | Esperado: B1B-164 | Tiempo: 0.0231s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800525_0.91_(45, 92, 3)_V9W-422.jpg | Detectado:  | Esperado: V9W-422 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800555_0.9_(44, 90, 3)_V8M-368.jpg | Detectado:  | Esperado: V8M-368 | Tiempo: 0.0195s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800589_0.9_(46, 98, 3)_A8D-757.jpg | Detectado:  | Esperado: A8D-757 | Tiempo: 0.0286s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800590_0.9_(54, 109, 3)_A80-757.jpg | Detectado:  | Esperado: A80-757 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800700_0.91_(48, 100, 3)_Z5Q-106.jpg | Detectado: (50-106 | Esperado: Z5Q-106 | Tiempo: 0.0226s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800790_0.9_(43, 90, 3)_X4N-230.jpg | Detectado:  | Esperado: X4N-230 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800793_0.91_(46, 92, 3)_V1I-104.jpg | Detectado: Mii-jo4 | Esperado: V1I-104 | Tiempo: 0.0231s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800797_0.9_(52, 103, 3)_AUU-101.jpg | Detectado:  | Esperado: AUU-101 | Tiempo: 0.0261s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800807_0.9_(50, 104, 3)_X20-934.jpg | Detectado: K20-934 | Esperado: X20-934 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800880_0.9_(44, 92, 3)_V31-163.jpg | Detectado:  | Esperado: V31-163 | Tiempo: 0.0191s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800883_0.9_(54, 104, 3)_Z6L-717.jpg | Detectado:  | Esperado: Z6L-717 | Tiempo: 0.0288s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800887_0.9_(47, 97, 3)_Z7K-549.jpg | Detectado: 77K-542 | Esperado: Z7K-549 | Tiempo: 0.0218s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800893_0.9_(71, 106, 3)_Y3Q-595.jpg | Detectado:  | Esperado: Y3Q-595 | Tiempo: 0.0251s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800912_0.9_(41, 96, 3)_F51-233.jpg | Detectado: F51-233 | Esperado: F51-233 | Tiempo: 0.0193s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755800941_0.9_(50, 100, 3)_B1N-742.jpg | Detectado:  | Esperado: B1N-742 | Tiempo: 0.0267s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800975_0.91_(58, 106, 3)_V7R-826.jpg | Detectado:  | Esperado: V7R-826 | Tiempo: 0.0201s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800978_0.91_(47, 96, 3)_Z4Q-197.jpg | Detectado: 240-797 | Esperado: Z4Q-197 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801015_0.9_(48, 98, 3)_Z5G-496.jpg | Detectado: 756-496 | Esperado: Z5G-496 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801088_0.9_(50, 109, 3)_Z5T-282.jpg | Detectado:  | Esperado: Z5T-282 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801091_0.91_(46, 101, 3)_Z5V-445.jpg | Detectado:  | Esperado: Z5V-445 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801123_0.9_(52, 100, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801131_0.9_(56, 113, 3)_A9K-715.jpg | Detectado:  | Esperado: A9K-715 | Tiempo: 0.0304s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801139_0.9_(47, 97, 3)_CBM-487.jpg | Detectado:  | Esperado: CBM-487 | Tiempo: 0.0652s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801176_0.9_(50, 108, 3)_Z2G-146.jpg | Detectado:  | Esperado: Z2G-146 | Tiempo: 0.0258s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801183_0.9_(61, 112, 3)_Z2N-051.jpg | Detectado:  | Esperado: Z2N-051 | Tiempo: 0.0232s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801190_0.9_(46, 98, 3)_V9K-468.jpg | Detectado: [ok-468 | Esperado: V9K-468 | Tiempo: 0.0215s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801207_0.91_(48, 101, 3)_Z3P-791.jpg | Detectado: 73p-791 | Esperado: Z3P-791 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801210_0.9_(49, 104, 3)_X3A-006.jpg | Detectado: KBA-006 | Esperado: X3A-006 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801223_0.91_(51, 101, 3)_Z8B-641.jpg | Detectado: 788-64] | Esperado: Z8B-641 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801236_0.9_(48, 97, 3)_X1J-790.jpg | Detectado: 81j-790 | Esperado: X1J-790 | Tiempo: 0.0225s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801286_0.9_(71, 116, 3)_F7F-087.jpg | Detectado:  | Esperado: F7F-087 | Tiempo: 0.0287s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801294_0.91_(52, 106, 3)_A5G-752.jpg | Detectado:  | Esperado: A5G-752 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801305_0.91_(48, 98, 3)_Z8U-888.jpg | Detectado:  | Esperado: Z8U-888 | Tiempo: 0.0284s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801306_0.91_(47, 102, 3)_Z8L-888.jpg | Detectado:  | Esperado: Z8L-888 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801314_0.91_(50, 103, 3)_AUJ-187.jpg | Detectado:  | Esperado: AUJ-187 | Tiempo: 0.0278s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801315_0.9_(57, 110, 3)_AUJ-182.jpg | Detectado:  | Esperado: AUJ-182 | Tiempo: 0.0250s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801327_0.91_(49, 100, 3)_Z6X-411.jpg | Detectado: 76x-411 | Esperado: Z6X-411 | Tiempo: 0.0215s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801335_0.9_(62, 110, 3)_V71-023.jpg | Detectado:  | Esperado: V71-023 | Tiempo: 0.0204s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801348_0.9_(50, 97, 3)_X1S-070.jpg | Detectado: KiS-070 | Esperado: X1S-070 | Tiempo: 0.0286s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801389_0.91_(45, 93, 3)_VDS-785.jpg | Detectado:  | Esperado: VDS-785 | Tiempo: 0.0279s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801392_0.91_(54, 107, 3)_Z7M-355.jpg | Detectado:  | Esperado: Z7M-355 | Tiempo: 0.0220s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801403_0.91_(54, 106, 3)_Z8B-617.jpg | Detectado: 78B-617 | Esperado: Z8B-617 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801417_0.91_(51, 103, 3)_D7W-870.jpg | Detectado:  | Esperado: D7W-870 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801418_0.9_(57, 108, 3)_07W-870.jpg | Detectado:  | Esperado: 07W-870 | Tiempo: 0.0190s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801426_0.9_(50, 102, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801434_0.91_(63, 120, 3)_A9K-715.jpg | Detectado:  | Esperado: A9K-715 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801483_0.91_(50, 100, 3)_X4H-470.jpg | Detectado:  | Esperado: X4H-470 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801491_0.91_(47, 94, 3)_VCS-856.jpg | Detectado: DCS-850 | Esperado: VCS-856 | Tiempo: 0.0194s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801494_0.91_(48, 101, 3)_BCF-122.jpg | Detectado: BCF-122 | Esperado: BCF-122 | Tiempo: 0.0217s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801529_0.9_(55, 104, 3)_Z5K-681.jpg | Detectado:  | Esperado: Z5K-681 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801534_0.91_(60, 117, 3)_Z2G-323.jpg | Detectado: 726-323 | Esperado: Z2G-323 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801565_0.91_(64, 115, 3)_Z5Q-118.jpg | Detectado: 750-118 | Esperado: Z5Q-118 | Tiempo: 0.0282s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801570_0.9_(48, 97, 3)_X1J-790.jpg | Detectado: K1j-790 | Esperado: X1J-790 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801578_0.9_(46, 94, 3)_VAN-508.jpg | Detectado:  | Esperado: VAN-508 | Tiempo: 0.0404s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801584_0.9_(48, 99, 3)_CHH-339.jpg | Detectado:  | Esperado: CHH-339 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801586_0.9_(53, 100, 3)_Z6M-106.jpg | Detectado:  | Esperado: Z6M-106 | Tiempo: 0.0193s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801598_0.92_(53, 108, 3)_A5G-752.jpg | Detectado: 756-752 | Esperado: A5G-752 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801647_0.92_(59, 102, 3)_Z7U-204.jpg | Detectado:  | Esperado: Z7U-204 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801654_0.9_(49, 99, 3)_Z5G-467.jpg | Detectado: 756-467 | Esperado: Z5G-467 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801662_0.91_(73, 117, 3)_598-655.jpg | Detectado: F9b-655 | Esperado: 598-655 | Tiempo: 0.0243s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801663_0.9_(44, 89, 3)_71C-465.jpg | Detectado:  | Esperado: 71C-465 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801690_0.9_(41, 89, 3)_AXF-317.jpg | Detectado: AXF-317 | Esperado: AXF-317 | Tiempo: 0.0196s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801695_0.9_(46, 96, 3)_X1Q-323.jpg | Detectado:  | Esperado: X1Q-323 | Tiempo: 0.0193s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801744_0.9_(66, 118, 3)_Z20-326.jpg | Detectado:  | Esperado: Z20-326 | Tiempo: 0.0328s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801790_0.91_(49, 103, 3)_Z6C-695.jpg | Detectado: Z6C-695 | Esperado: Z6C-695 | Tiempo: 0.0362s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801795_0.91_(46, 94, 3)_Z3F-113.jpg | Detectado:  | Esperado: Z3F-113 | Tiempo: 0.0282s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801798_0.92_(53, 103, 3)_Z6K-059.jpg | Detectado: i6k-059 | Esperado: Z6K-059 | Tiempo: 0.0196s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801801_0.91_(46, 97, 3)_D70-364.jpg | Detectado:  | Esperado: D70-364 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801812_0.91_(49, 101, 3)_Z7V-467.jpg | Detectado:  | Esperado: Z7V-467 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801843_0.91_(49, 100, 3)_Z7S-416.jpg | Detectado: 775-426 | Esperado: Z7S-416 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801846_0.9_(49, 95, 3)_F4B-067.jpg | Detectado: F4B-067 | Esperado: F4B-067 | Tiempo: 0.0192s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801849_0.91_(53, 105, 3)_Z3V-367.jpg | Detectado:  | Esperado: Z3V-367 | Tiempo: 0.0268s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801852_0.9_(52, 97, 3)_V71-420.jpg | Detectado: [7!-420 | Esperado: V71-420 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801939_0.9_(48, 90, 3)_AYJ-561.jpg | Detectado:  | Esperado: AYJ-561 | Tiempo: 0.0173s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802000_0.91_(48, 101, 3)_AMO-819.jpg | Detectado:  | Esperado: AMO-819 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802022_0.9_(53, 103, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802033_0.91_(56, 107, 3)_CKS-489.jpg | Detectado:  | Esperado: CKS-489 | Tiempo: 0.0254s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802038_0.9_(54, 103, 3)_C3S-449.jpg | Detectado:  | Esperado: C3S-449 | Tiempo: 0.0224s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802073_0.91_(54, 106, 3)_Z7C-049.jpg | Detectado: 77C-049 | Esperado: Z7C-049 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802099_0.91_(54, 108, 3)_Z6B-834.jpg | Detectado: 26B-834 | Esperado: Z6B-834 | Tiempo: 0.0195s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802124_0.9_(60, 112, 3)_X3T-626.jpg | Detectado: K3i-626 | Esperado: X3T-626 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802133_0.91_(49, 97, 3)_VCF-677.jpg | Detectado: DCF-677 | Esperado: VCF-677 | Tiempo: 0.0204s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802142_0.9_(50, 100, 3)_D1I-153.jpg | Detectado:  | Esperado: D1I-153 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802147_0.91_(46, 90, 3)_VBI-497.jpg | Detectado: 1BI-492 | Esperado: VBI-497 | Tiempo: 0.0170s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802161_0.91_(50, 99, 3)_V9N-697.jpg | Detectado: [9N-622 | Esperado: V9N-697 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802166_0.9_(45, 102, 3)_V2N-829.jpg | Detectado: 12N-829 | Esperado: V2N-829 | Tiempo: 0.0206s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802269_0.91_(45, 93, 3)_ARE-297.jpg | Detectado:  | Esperado: ARE-297 | Tiempo: 0.0199s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802328_0.9_(49, 98, 3)_Z7N-143.jpg | Detectado:  | Esperado: Z7N-143 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802353_0.9_(62, 107, 3)_AAO-576.jpg | Detectado:  | Esperado: AAO-576 | Tiempo: 0.0291s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802410_0.91_(48, 95, 3)_BTB-292.jpg | Detectado:  | Esperado: BTB-292 | Tiempo: 0.0293s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802415_0.91_(44, 95, 3)_Z7Y-245.jpg | Detectado:  | Esperado: Z7Y-245 | Tiempo: 0.0197s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802418_0.9_(50, 104, 3)_BPW-164.jpg | Detectado:  | Esperado: BPW-164 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802421_0.91_(47, 92, 3)_BXI-161.jpg | Detectado:  | Esperado: BXI-161 | Tiempo: 0.0222s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802433_0.9_(50, 98, 3)_V6Y-151.jpg | Detectado: [6y-151 | Esperado: V6Y-151 | Tiempo: 0.0192s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802437_0.92_(48, 98, 3)_Z6Y-080.jpg | Detectado:  | Esperado: Z6Y-080 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802496_0.91_(42, 90, 3)_Z5D-490.jpg | Detectado: 750-490 | Esperado: Z5D-490 | Tiempo: 0.0199s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802534_0.9_(41, 91, 3)_V4E-442.jpg | Detectado: 14E-442 | Esperado: V4E-442 | Tiempo: 0.0185s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802585_0.91_(42, 94, 3)_VBX-425.jpg | Detectado:  | Esperado: VBX-425 | Tiempo: 0.0191s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802589_0.9_(48, 98, 3)_Z4Q-264.jpg | Detectado: 240-264 | Esperado: Z4Q-264 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802592_0.91_(48, 98, 3)_BKQ-659.jpg | Detectado: BKO-650 | Esperado: BKQ-659 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802597_0.9_(48, 98, 3)_S1B-589.jpg | Detectado:  | Esperado: S1B-589 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802608_0.91_(49, 97, 3)_BKM-032.jpg | Detectado:  | Esperado: BKM-032 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802629_0.9_(50, 106, 3)_AFL-039.jpg | Detectado:  | Esperado: AFL-039 | Tiempo: 0.0206s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802632_0.9_(47, 101, 3)_Z7F-326.jpg | Detectado: 77F-326 | Esperado: Z7F-326 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802646_0.9_(65, 114, 3)_CJS-468.jpg | Detectado:  | Esperado: CJS-468 | Tiempo: 0.0253s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802650_0.9_(58, 114, 3)_A2E-705.jpg | Detectado:  | Esperado: A2E-705 | Tiempo: 0.0287s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802708_0.9_(52, 102, 3)_BHG-267.jpg | Detectado:  | Esperado: BHG-267 | Tiempo: 0.0241s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802716_0.91_(47, 95, 3)_V4L-658.jpg | Detectado: M4L-658 | Esperado: V4L-658 | Tiempo: 0.0261s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802759_0.91_(54, 107, 3)_Z8V-787.jpg | Detectado: 78V-787 | Esperado: Z8V-787 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802859_0.9_(50, 97, 3)_Z3P-000.jpg | Detectado: 73p-000 | Esperado: Z3P-000 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802962_0.91_(63, 114, 3)_Z6D-367.jpg | Detectado:  | Esperado: Z6D-367 | Tiempo: 0.0236s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803016_0.9_(43, 91, 3)_V6J-526.jpg | Detectado:  | Esperado: V6J-526 | Tiempo: 0.0183s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803044_0.9_(63, 111, 3)_Z6U-717.jpg | Detectado:  | Esperado: Z6U-717 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803089_0.9_(49, 97, 3)_Z7N-143.jpg | Detectado:  | Esperado: Z7N-143 | Tiempo: 0.0277s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803106_0.9_(58, 113, 3)_Z7W-178.jpg | Detectado:  | Esperado: Z7W-178 | Tiempo: 0.0220s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803124_0.9_(46, 92, 3)_Z1E-728.jpg | Detectado:  | Esperado: Z1E-728 | Tiempo: 0.0170s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803163_0.9_(54, 107, 3)_V1H-723.jpg | Detectado:  | Esperado: V1H-723 | Tiempo: 0.0240s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803168_0.91_(53, 106, 3)_Z4Y-573.jpg | Detectado: 24y-573 | Esperado: Z4Y-573 | Tiempo: 0.0277s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803170_0.9_(45, 89, 3)_X3T-194.jpg | Detectado: K3t-194 | Esperado: X3T-194 | Tiempo: 0.0169s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803288_0.91_(47, 96, 3)_ASJ-523.jpg | Detectado:  | Esperado: ASJ-523 | Tiempo: 0.0188s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803327_0.9_(50, 100, 3)_X3E-141.jpg | Detectado:  | Esperado: X3E-141 | Tiempo: 0.0236s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803417_0.9_(46, 96, 3)_Z1E-728.jpg | Detectado:  | Esperado: Z1E-728 | Tiempo: 0.0184s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803618_0.9_(61, 105, 3)_CEX-325.jpg | Detectado:  | Esperado: CEX-325 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803678_0.9_(46, 103, 3)_V1W-327.jpg | Detectado: 11k 327 | Esperado: V1W-327 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803683_0.9_(59, 118, 3)_Z5D-845.jpg | Detectado:  | Esperado: Z5D-845 | Tiempo: 0.0196s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803692_0.9_(60, 105, 3)_BBT-930.jpg | Detectado: BBT-930 | Esperado: BBT-930 | Tiempo: 0.0221s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755803697_0.9_(67, 126, 3)_Z2E-770.jpg | Detectado:  | Esperado: Z2E-770 | Tiempo: 0.0259s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803736_0.9_(50, 103, 3)_BTQ-272.jpg | Detectado: Br0-272 | Esperado: BTQ-272 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803790_0.9_(66, 113, 3)_Z3J-707.jpg | Detectado:  | Esperado: Z3J-707 | Tiempo: 0.0240s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803875_0.91_(47, 102, 3)_ANJ-150.jpg | Detectado: [NJ-150 | Esperado: ANJ-150 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803886_0.9_(45, 94, 3)_Z7X-826.jpg | Detectado:  | Esperado: Z7X-826 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803979_0.9_(45, 90, 3)_BVH-663.jpg | Detectado:  | Esperado: BVH-663 | Tiempo: 0.0268s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803979_0.9_(48, 97, 3)_8VH-663.jpg | Detectado:  | Esperado: 8VH-663 | Tiempo: 0.0284s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803985_0.9_(127, 139, 3)_L2E-770.jpg | Detectado:  | Esperado: L2E-770 | Tiempo: 0.0402s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804033_0.91_(51, 96, 3)_V4E-661.jpg | Detectado: M4e-661 | Esperado: V4E-661 | Tiempo: 0.0176s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804052_0.9_(54, 101, 3)_AUU-101.jpg | Detectado:  | Esperado: AUU-101 | Tiempo: 0.0221s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804067_0.91_(63, 110, 3)_Z7G-042.jpg | Detectado:  | Esperado: Z7G-042 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804076_0.9_(51, 103, 3)_BJG-541.jpg | Detectado: BJ6-542 | Esperado: BJG-541 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804125_0.91_(48, 101, 3)_Z3J-707.jpg | Detectado:  | Esperado: Z3J-707 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804178_0.91_(38, 89, 3)_AYH-261.jpg | Detectado:  | Esperado: AYH-261 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804192_0.9_(65, 116, 3)_V7C-801.jpg | Detectado: [7c-80] | Esperado: V7C-801 | Tiempo: 0.0240s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804243_0.9_(49, 94, 3)_Z7Y-445.jpg | Detectado: 77Y-445 | Esperado: Z7Y-445 | Tiempo: 0.0197s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804326_0.9_(47, 98, 3)_CO1-165.jpg | Detectado:  | Esperado: CO1-165 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804330_0.91_(51, 102, 3)_Z8S-813.jpg | Detectado:  | Esperado: Z8S-813 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804345_0.91_(46, 94, 3)_BLH-257.jpg | Detectado:  | Esperado: BLH-257 | Tiempo: 0.0187s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804371_0.9_(54, 113, 3)_V6E-258.jpg | Detectado:  | Esperado: V6E-258 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804443_0.91_(49, 96, 3)_Z51-510.jpg | Detectado: 251-510 | Esperado: Z51-510 | Tiempo: 0.0179s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804512_0.91_(39, 91, 3)_Z7T-469.jpg | Detectado:  | Esperado: Z7T-469 | Tiempo: 0.0206s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804516_0.92_(61, 118, 3)_Z1A-640.jpg | Detectado:  | Esperado: Z1A-640 | Tiempo: 0.0197s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805016_0.9_(49, 97, 3)_BWS-056.jpg | Detectado: BHS 056 | Esperado: BWS-056 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805048_0.9_(50, 96, 3)_VCL-405.jpg | Detectado:  | Esperado: VCL-405 | Tiempo: 0.0274s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805055_0.9_(53, 104, 3)_Z7W-234.jpg | Detectado:  | Esperado: Z7W-234 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805151_0.91_(50, 101, 3)_Z7W-377.jpg | Detectado:  | Esperado: Z7W-377 | Tiempo: 0.0217s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805212_0.91_(52, 105, 3)_Z7F-518.jpg | Detectado: 77F-518 | Esperado: Z7F-518 | Tiempo: 0.0220s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805218_0.9_(41, 88, 3)_Z7H-064.jpg | Detectado:  | Esperado: Z7H-064 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805271_0.9_(64, 111, 3)_Z1V-042.jpg | Detectado:  | Esperado: Z1V-042 | Tiempo: 0.0216s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805284_0.91_(52, 101, 3)_VAB-735.jpg | Detectado:  | Esperado: VAB-735 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805378_0.9_(47, 101, 3)_Z6E-393.jpg | Detectado:  | Esperado: Z6E-393 | Tiempo: 0.0227s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805538_0.9_(47, 98, 3)_Z7G-017.jpg | Detectado:  | Esperado: Z7G-017 | Tiempo: 0.0295s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805684_0.9_(48, 99, 3)_VCS-186.jpg | Detectado: [cs-186 | Esperado: VCS-186 | Tiempo: 0.0292s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805788_0.91_(48, 98, 3)_CRG-314.jpg | Detectado:  | Esperado: CRG-314 | Tiempo: 0.0222s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805904_0.92_(118, 124, 3)_V2X-710.jpg | Detectado:  | Esperado: V2X-710 | Tiempo: 0.0306s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806062_0.9_(47, 95, 3)_BKQ-659.jpg | Detectado: BKO-652 | Esperado: BKQ-659 | Tiempo: 0.0191s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806111_0.9_(49, 97, 3)_Z7F-621.jpg | Detectado: i76-621 | Esperado: Z7F-621 | Tiempo: 0.0360s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806151_0.91_(47, 98, 3)_Z5J-577.jpg | Detectado: 251-577 | Esperado: Z5J-577 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806181_0.9_(41, 100, 3)_VAQ-104.jpg | Detectado:  | Esperado: VAQ-104 | Tiempo: 0.0278s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806233_0.9_(49, 96, 3)_BWQ-500.jpg | Detectado:  | Esperado: BWQ-500 | Tiempo: 0.0181s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806243_0.91_(58, 110, 3)_Z7U-178.jpg | Detectado:  | Esperado: Z7U-178 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806300_0.9_(50, 101, 3)_AOT-720.jpg | Detectado:  | Esperado: AOT-720 | Tiempo: 0.0282s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806301_0.9_(53, 110, 3)_A0T-720.jpg | Detectado:  | Esperado: A0T-720 | Tiempo: 0.0215s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806307_0.9_(45, 91, 3)_T4M-134.jpg | Detectado:  | Esperado: T4M-134 | Tiempo: 0.0193s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806406_0.9_(47, 101, 3)_A4S-720.jpg | Detectado: 1us-720 | Esperado: A4S-720 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806558_0.9_(60, 116, 3)_ABU-720.jpg | Detectado:  | Esperado: ABU-720 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806583_0.9_(58, 110, 3)_Z7H-075.jpg | Detectado: 77h-075 | Esperado: Z7H-075 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806706_0.9_(45, 96, 3)_V71-023.jpg | Detectado:  | Esperado: V71-023 | Tiempo: 0.0201s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806714_0.91_(46, 100, 3)_A4S-720.jpg | Detectado:  | Esperado: A4S-720 | Tiempo: 0.0307s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806796_0.91_(44, 92, 3)_Z70-399.jpg | Detectado: 770-399 | Esperado: Z70-399 | Tiempo: 0.0224s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806835_0.9_(50, 100, 3)_D7W-870.jpg | Detectado: 071-870 | Esperado: D7W-870 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806839_0.91_(53, 104, 3)_Z2P-320.jpg | Detectado:  | Esperado: Z2P-320 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806845_0.91_(44, 98, 3)_A3C-786.jpg | Detectado:  | Esperado: A3C-786 | Tiempo: 0.0228s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806849_0.92_(49, 98, 3)_Z7P-354.jpg | Detectado: 77P-354 | Esperado: Z7P-354 | Tiempo: 0.0221s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806852_0.91_(66, 114, 3)_VBA-422.jpg | Detectado: UBA-422 | Esperado: VBA-422 | Tiempo: 0.0244s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806868_0.9_(46, 91, 3)_ACL-585.jpg | Detectado: ACL-585 | Esperado: ACL-585 | Tiempo: 0.0183s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755806984_0.9_(45, 92, 3)_Z5Z-532.jpg | Detectado:  | Esperado: Z5Z-532 | Tiempo: 0.0192s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807008_0.91_(44, 97, 3)_BEP-534.jpg | Detectado: BEP-534 | Esperado: BEP-534 | Tiempo: 0.0205s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755807086_0.91_(45, 90, 3)_Z4Y-618.jpg | Detectado: 74y-618 | Esperado: Z4Y-618 | Tiempo: 0.0172s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807186_0.9_(47, 95, 3)_Z7M-595.jpg | Detectado:  | Esperado: Z7M-595 | Tiempo: 0.0193s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807199_0.9_(46, 102, 3)_A5U-739.jpg | Detectado:  | Esperado: A5U-739 | Tiempo: 0.0280s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807204_0.9_(43, 89, 3)_M4B-467.jpg | Detectado:  | Esperado: M4B-467 | Tiempo: 0.0196s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807211_0.9_(44, 96, 3)_BEP-534.jpg | Detectado:  | Esperado: BEP-534 | Tiempo: 0.0196s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807470_0.91_(141, 148, 3)_A5U-739.jpg | Detectado:  | Esperado: A5U-739 | Tiempo: 0.0370s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807617_0.9_(56, 111, 3)_45K-770.jpg | Detectado:  | Esperado: 45K-770 | Tiempo: 0.0224s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807852_0.91_(53, 108, 3)_Z6W-329.jpg | Detectado:  | Esperado: Z6W-329 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807884_0.9_(52, 101, 3)_Z2Q-021.jpg | Detectado:  | Esperado: Z2Q-021 | Tiempo: 0.0229s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807907_0.9_(52, 99, 3)_C6M-147.jpg | Detectado:  | Esperado: C6M-147 | Tiempo: 0.0272s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808117_0.9_(49, 100, 3)_Z1I-540.jpg | Detectado: 711 540 | Esperado: Z1I-540 | Tiempo: 0.0225s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808131_0.92_(45, 93, 3)_ANG-059.jpg | Detectado: Ang-059 | Esperado: ANG-059 | Tiempo: 0.0194s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755808144_0.9_(46, 94, 3)_Z2Q-021.jpg | Detectado:  | Esperado: Z2Q-021 | Tiempo: 0.0192s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808175_0.91_(44, 89, 3)_F8Q-278.jpg | Detectado:  | Esperado: F8Q-278 | Tiempo: 0.0201s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808300_0.9_(46, 91, 3)_AK1-784.jpg | Detectado:  | Esperado: AK1-784 | Tiempo: 0.0179s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808414_0.9_(59, 111, 3)_F8Q-278.jpg | Detectado:  | Esperado: F8Q-278 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808461_0.91_(62, 116, 3)_CBA-659.jpg | Detectado: CBA-659 | Esperado: CBA-659 | Tiempo: 0.0351s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755808464_0.9_(50, 104, 3)_BUY-632.jpg | Detectado: BUY-632 | Esperado: BUY-632 | Tiempo: 0.0314s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755808477_0.91_(46, 95, 3)_BHB-015.jpg | Detectado: BHB-015 | Esperado: BHB-015 | Tiempo: 0.0194s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755808763_0.9_(54, 105, 3)_V5B-631.jpg | Detectado:  | Esperado: V5B-631 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808937_0.91_(46, 96, 3)_V8Y-171.jpg | Detectado:  | Esperado: V8Y-171 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808962_0.9_(46, 91, 3)_Z1T-535.jpg | Detectado: 211-535 | Esperado: Z1T-535 | Tiempo: 0.0185s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809021_0.9_(53, 108, 3)_Z40-588.jpg | Detectado:  | Esperado: Z40-588 | Tiempo: 0.0235s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809037_0.9_(61, 113, 3)_Z2N-738.jpg | Detectado:  | Esperado: Z2N-738 | Tiempo: 0.0232s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809250_0.9_(51, 99, 3)_S1B-772.jpg | Detectado:  | Esperado: S1B-772 | Tiempo: 0.0224s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809492_0.9_(38, 97, 3)_S1B-772.jpg | Detectado: S1B-772 | Esperado: S1B-772 | Tiempo: 0.0214s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755809743_0.9_(47, 93, 3)_Z11-272.jpg | Detectado: 711-272 | Esperado: Z11-272 | Tiempo: 0.0186s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809784_0.91_(49, 100, 3)_Z7B-669.jpg | Detectado: 77B-669 | Esperado: Z7B-669 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809796_0.91_(121, 126, 3)_Z1J-781.jpg | Detectado:  | Esperado: Z1J-781 | Tiempo: 0.0288s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809798_0.91_(46, 99, 3)_BXU-498.jpg | Detectado: BXU-498 | Esperado: BXU-498 | Tiempo: 0.0211s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755810071_0.9_(47, 99, 3)_F1N-370.jpg | Detectado:  | Esperado: F1N-370 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810077_0.9_(46, 97, 3)_Z6V-660.jpg | Detectado:  | Esperado: Z6V-660 | Tiempo: 0.0224s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810245_0.9_(48, 95, 3)_BJU-400.jpg | Detectado: BJU-400 | Esperado: BJU-400 | Tiempo: 0.0185s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755810246_0.9_(52, 98, 3)_BJL-400.jpg | Detectado:  | Esperado: BJL-400 | Tiempo: 0.0221s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810458_0.91_(50, 91, 3)_A2H-716.jpg | Detectado:  | Esperado: A2H-716 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810751_0.91_(42, 93, 3)_BKQ-659.jpg | Detectado: BKO 652 | Esperado: BKQ-659 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810833_0.9_(40, 90, 3)_Z5D-490.jpg | Detectado: 750-490 | Esperado: Z5D-490 | Tiempo: 0.0201s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810848_0.9_(64, 109, 3)_AJV-939.jpg | Detectado:  | Esperado: AJV-939 | Tiempo: 0.0297s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810946_0.91_(51, 99, 3)_Z5H-549.jpg | Detectado:  | Esperado: Z5H-549 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811078_0.9_(49, 99, 3)_D1I-153.jpg | Detectado: 011-153 | Esperado: D1I-153 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811276_0.91_(45, 97, 3)_Z1H-700.jpg | Detectado:  | Esperado: Z1H-700 | Tiempo: 0.0296s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811522_0.9_(46, 93, 3)_Z5D-172.jpg | Detectado: 750-172 | Esperado: Z5D-172 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811526_0.91_(45, 93, 3)_Z1H-700.jpg | Detectado:  | Esperado: Z1H-700 | Tiempo: 0.0128s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812430_0.9_(63, 118, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812435_0.9_(56, 114, 3)_ASD-757.jpg | Detectado:  | Esperado: ASD-757 | Tiempo: 0.0278s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812550_0.91_(55, 108, 3)_Z2Q-310.jpg | Detectado:  | Esperado: Z2Q-310 | Tiempo: 0.0192s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812560_0.9_(47, 95, 3)_F9L-089.jpg | Detectado:  | Esperado: F9L-089 | Tiempo: 0.0192s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812695_0.9_(48, 96, 3)_D9E-887.jpg | Detectado:  | Esperado: D9E-887 | Tiempo: 0.0178s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755813815_0.9_(44, 89, 3)_A1X-403.jpg | Detectado:  | Esperado: A1X-403 | Tiempo: 0.0264s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755819341_0.9_(51, 109, 3)_D2E-683.jpg | Detectado:  | Esperado: D2E-683 | Tiempo: 0.0292s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755819352_0.91_(49, 108, 3)_D2E-683.jpg | Detectado:  | Esperado: D2E-683 | Tiempo: 0.0298s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755862816_0.9_(48, 104, 3)_Z3V-720.jpg | Detectado: 731-720 | Esperado: Z3V-720 | Tiempo: 0.0231s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755862951_0.9_(43, 96, 3)_A5K-770.jpg | Detectado: ,5K-770 | Esperado: A5K-770 | Tiempo: 0.0215s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863223_0.9_(45, 94, 3)_BBP-662.jpg | Detectado: BBP-662 | Esperado: BBP-662 | Tiempo: 0.0204s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755863519_0.9_(46, 102, 3)_AOT-720.jpg | Detectado:  | Esperado: AOT-720 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863582_0.9_(50, 94, 3)_Z1D-784.jpg | Detectado:  | Esperado: Z1D-784 | Tiempo: 0.0187s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863701_0.91_(55, 111, 3)_Z1J-781.jpg | Detectado:  | Esperado: Z1J-781 | Tiempo: 0.0215s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863861_0.9_(50, 98, 3)_X2Z-199.jpg | Detectado: K27-799 | Esperado: X2Z-199 | Tiempo: 0.0242s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863881_0.9_(50, 100, 3)_X3J-746.jpg | Detectado:  | Esperado: X3J-746 | Tiempo: 0.0247s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863927_0.91_(46, 96, 3)_71H-700.jpg | Detectado:  | Esperado: 71H-700 | Tiempo: 0.0262s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863928_0.91_(47, 99, 3)_Z1H-700.jpg | Detectado:  | Esperado: Z1H-700 | Tiempo: 0.0285s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864056_0.9_(44, 94, 3)_BUX-273.jpg | Detectado: BUX 273 | Esperado: BUX-273 | Tiempo: 0.0194s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864122_0.9_(46, 92, 3)_77U-013.jpg | Detectado:  | Esperado: 77U-013 | Tiempo: 0.0178s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864123_0.9_(53, 104, 3)_Z7U-013.jpg | Detectado:  | Esperado: Z7U-013 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864190_0.9_(47, 98, 3)_Z5V-823.jpg | Detectado:  | Esperado: Z5V-823 | Tiempo: 0.0227s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864196_0.9_(51, 99, 3)_X4L-304.jpg | Detectado:  | Esperado: X4L-304 | Tiempo: 0.0357s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864262_0.91_(57, 109, 3)_Z7S-597.jpg | Detectado: 775-597 | Esperado: Z7S-597 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864280_0.91_(47, 95, 3)_Z5Y-572.jpg | Detectado:  | Esperado: Z5Y-572 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864463_0.91_(49, 99, 3)_Z6K-411.jpg | Detectado:  | Esperado: Z6K-411 | Tiempo: 0.0215s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864488_0.9_(57, 104, 3)_Z8C-206.jpg | Detectado:  | Esperado: Z8C-206 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864599_0.9_(58, 110, 3)_V7B-442.jpg | Detectado:  | Esperado: V7B-442 | Tiempo: 0.0294s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864637_0.91_(48, 94, 3)_81B-734.jpg | Detectado:  | Esperado: 81B-734 | Tiempo: 0.0265s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864638_0.91_(60, 109, 3)_B18-734.jpg | Detectado: 318-734 | Esperado: B18-734 | Tiempo: 0.0277s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864638_0.9_(57, 101, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864701_0.9_(53, 106, 3)_V4R-602.jpg | Detectado:  | Esperado: V4R-602 | Tiempo: 0.0347s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864720_0.9_(47, 94, 3)_Z6A-087.jpg | Detectado: 764-087 | Esperado: Z6A-087 | Tiempo: 0.0176s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755865999_0.9_(52, 101, 3)_Z7U-013.jpg | Detectado:  | Esperado: Z7U-013 | Tiempo: 0.0271s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866023_0.9_(48, 103, 3)_Z7X-877.jpg | Detectado: 27K-872 | Esperado: Z7X-877 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866028_0.9_(47, 96, 3)_Z3P-398.jpg | Detectado: 73P-398 | Esperado: Z3P-398 | Tiempo: 0.0194s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866032_0.91_(52, 108, 3)_Z6X-220.jpg | Detectado:  | Esperado: Z6X-220 | Tiempo: 0.0237s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866167_0.9_(49, 100, 3)_Z2M-424.jpg | Detectado:  | Esperado: Z2M-424 | Tiempo: 0.0204s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866170_0.9_(46, 92, 3)_BHP-297.jpg | Detectado: BHP 297 | Esperado: BHP-297 | Tiempo: 0.0188s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866191_0.9_(48, 98, 3)_BKQ-659.jpg | Detectado:  | Esperado: BKQ-659 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866271_0.9_(45, 98, 3)_Z3P-791.jpg | Detectado:  | Esperado: Z3P-791 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866274_0.9_(52, 105, 3)_Z5U-453.jpg | Detectado:  | Esperado: Z5U-453 | Tiempo: 0.0275s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866275_0.9_(66, 112, 3)_Z5L-453.jpg | Detectado:  | Esperado: Z5L-453 | Tiempo: 0.0345s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866307_0.91_(48, 96, 3)_Z50-343.jpg | Detectado: 750-343 | Esperado: Z50-343 | Tiempo: 0.0173s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866307_0.91_(56, 105, 3)_750-343.jpg | Detectado:  | Esperado: 750-343 | Tiempo: 0.0304s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866333_0.9_(56, 104, 3)_APH-716.jpg | Detectado:  | Esperado: APH-716 | Tiempo: 0.0187s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866336_0.91_(46, 98, 3)_V8V-084.jpg | Detectado: 78u-084 | Esperado: V8V-084 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866431_0.91_(53, 107, 3)_COG-679.jpg | Detectado: Co6-670 | Esperado: COG-679 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866477_0.9_(50, 100, 3)_APF-394.jpg | Detectado: ApF 394 | Esperado: APF-394 | Tiempo: 0.0321s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866484_0.9_(50, 104, 3)_Z3T-663.jpg | Detectado:  | Esperado: Z3T-663 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866521_0.92_(46, 94, 3)_75C-592.jpg | Detectado:  | Esperado: 75C-592 | Tiempo: 0.0184s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866566_0.9_(64, 110, 3)_Y3F-143.jpg | Detectado:  | Esperado: Y3F-143 | Tiempo: 0.0276s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866603_0.9_(46, 95, 3)_X1J-790.jpg | Detectado: K1j-790 | Esperado: X1J-790 | Tiempo: 0.0211s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866681_0.91_(48, 93, 3)_Z3P-326.jpg | Detectado: 7ap-326 | Esperado: Z3P-326 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866685_0.9_(48, 96, 3)_Z6F-642.jpg | Detectado: ioF-642 | Esperado: Z6F-642 | Tiempo: 0.0181s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866688_0.91_(55, 109, 3)_V6M-925.jpg | Detectado:  | Esperado: V6M-925 | Tiempo: 0.0252s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866691_0.91_(42, 96, 3)_X5J-730.jpg | Detectado:  | Esperado: X5J-730 | Tiempo: 0.0192s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866701_0.91_(51, 100, 3)_Z5D-490.jpg | Detectado: 250-490 | Esperado: Z5D-490 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866708_0.9_(47, 95, 3)_Z7T-469.jpg | Detectado: 771-469 | Esperado: Z7T-469 | Tiempo: 0.0194s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866735_0.9_(46, 95, 3)_Z5Q-767.jpg | Detectado:  | Esperado: Z5Q-767 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866769_0.9_(45, 97, 3)_Z7W-135.jpg | Detectado:  | Esperado: Z7W-135 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866846_0.91_(61, 109, 3)_AMO-819.jpg | Detectado:  | Esperado: AMO-819 | Tiempo: 0.0191s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866848_0.9_(47, 97, 3)_VCA-701.jpg | Detectado: NCA-201 | Esperado: VCA-701 | Tiempo: 0.0284s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866863_0.91_(48, 97, 3)_Z3E-444.jpg | Detectado: Zze-444 | Esperado: Z3E-444 | Tiempo: 0.0281s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866869_0.9_(49, 99, 3)_AUM-201.jpg | Detectado:  | Esperado: AUM-201 | Tiempo: 0.0190s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866962_0.9_(59, 110, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866976_0.9_(52, 108, 3)_B2U-796.jpg | Detectado:  | Esperado: B2U-796 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867013_0.9_(51, 99, 3)_BRV-568.jpg | Detectado:  | Esperado: BRV-568 | Tiempo: 0.0266s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867016_0.9_(47, 100, 3)_VOX-966.jpg | Detectado: Hoy 968 | Esperado: VOX-966 | Tiempo: 0.0280s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867062_0.9_(58, 110, 3)_Z7W-006.jpg | Detectado:  | Esperado: Z7W-006 | Tiempo: 0.0273s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867068_0.9_(46, 108, 3)_C8U-187.jpg | Detectado:  | Esperado: C8U-187 | Tiempo: 0.0259s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867099_0.9_(52, 102, 3)_A5Z-645.jpg | Detectado:  | Esperado: A5Z-645 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867103_0.9_(45, 90, 3)_ERA-728.jpg | Detectado: ERA 728 | Esperado: ERA-728 | Tiempo: 0.0196s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867108_0.9_(46, 94, 3)_V9Q-064.jpg | Detectado: 190-064 | Esperado: V9Q-064 | Tiempo: 0.0276s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867109_0.9_(55, 105, 3)_19Q-064.jpg | Detectado: 120-064 | Esperado: 19Q-064 | Tiempo: 0.0229s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867134_0.9_(64, 108, 3)_ABA-734.jpg | Detectado:  | Esperado: ABA-734 | Tiempo: 0.0255s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867157_0.9_(52, 103, 3)_Y3A-006.jpg | Detectado: KgA-006 | Esperado: Y3A-006 | Tiempo: 0.0190s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867182_0.9_(47, 92, 3)_Z6D-275.jpg | Detectado:  | Esperado: Z6D-275 | Tiempo: 0.0172s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867230_0.91_(55, 108, 3)_Z5F-631.jpg | Detectado: 75F-631 | Esperado: Z5F-631 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867236_0.91_(49, 97, 3)_Z7C-220.jpg | Detectado:  | Esperado: Z7C-220 | Tiempo: 0.0245s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867248_0.91_(109, 119, 3)_Z5J-714.jpg | Detectado:  | Esperado: Z5J-714 | Tiempo: 0.0393s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867315_0.91_(51, 98, 3)_F5H-768.jpg | Detectado:  | Esperado: F5H-768 | Tiempo: 0.0324s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867382_0.9_(64, 116, 3)_BDM-402.jpg | Detectado:  | Esperado: BDM-402 | Tiempo: 0.0243s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867393_0.9_(49, 95, 3)_VDY-836.jpg | Detectado:  | Esperado: VDY-836 | Tiempo: 0.0291s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867401_0.9_(53, 103, 3)_BYW-137.jpg | Detectado:  | Esperado: BYW-137 | Tiempo: 0.0227s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867409_0.91_(50, 96, 3)_Y2C-212.jpg | Detectado:  | Esperado: Y2C-212 | Tiempo: 0.0184s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867414_0.91_(55, 107, 3)_X50-334.jpg | Detectado:  | Esperado: X50-334 | Tiempo: 0.0217s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867417_0.91_(57, 112, 3)_Z4X-252.jpg | Detectado:  | Esperado: Z4X-252 | Tiempo: 0.0198s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867476_0.91_(47, 97, 3)_B71-205.jpg | Detectado: B7L-205 | Esperado: B71-205 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867500_0.9_(48, 110, 3)_A8D-764.jpg | Detectado: [80-764 | Esperado: A8D-764 | Tiempo: 0.0231s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867507_0.9_(54, 108, 3)_BLK-359.jpg | Detectado:  | Esperado: BLK-359 | Tiempo: 0.0258s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867579_0.9_(55, 111, 3)_Z5Z-557.jpg | Detectado:  | Esperado: Z5Z-557 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867603_0.9_(46, 108, 3)_A4M-799.jpg | Detectado:  | Esperado: A4M-799 | Tiempo: 0.0282s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867626_0.9_(51, 99, 3)_BEX-018.jpg | Detectado: BEX 028 | Esperado: BEX-018 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867644_0.9_(51, 92, 3)_VDS-785.jpg | Detectado: Mos 785 | Esperado: VDS-785 | Tiempo: 0.0227s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867691_0.9_(66, 116, 3)_Z5X-789.jpg | Detectado:  | Esperado: Z5X-789 | Tiempo: 0.0242s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867708_0.91_(47, 94, 3)_Z3V-367.jpg | Detectado:  | Esperado: Z3V-367 | Tiempo: 0.0188s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867716_0.9_(48, 95, 3)_Z4J-227.jpg | Detectado:  | Esperado: Z4J-227 | Tiempo: 0.0173s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867723_0.91_(51, 100, 3)_BYU-726.jpg | Detectado:  | Esperado: BYU-726 | Tiempo: 0.0229s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867725_0.91_(51, 109, 3)_V8J-173.jpg | Detectado:  | Esperado: V8J-173 | Tiempo: 0.0223s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867745_0.91_(53, 101, 3)_Z6B-834.jpg | Detectado: 26B-824 | Esperado: Z6B-834 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# ...
# Procesado: 1755868134_0.92_(48, 98, 3)_X3F-317.jpg | Detectado: KzF-317 | Esperado: X3F-317 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868141_0.9_(58, 111, 3)_Z3J-707.jpg | Detectado:  | Esperado: Z3J-707 | Tiempo: 0.0226s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868148_0.9_(60, 106, 3)_X3H-030.jpg | Detectado:  | Esperado: X3H-030 | Tiempo: 0.0227s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868151_0.9_(47, 95, 3)_Z7J-697.jpg | Detectado: 77J-627 | Esperado: Z7J-697 | Tiempo: 0.0312s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868156_0.9_(49, 92, 3)_AYJ-561.jpg | Detectado:  | Esperado: AYJ-561 | Tiempo: 0.0176s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868158_0.92_(55, 98, 3)_4YJ-561.jpg | Detectado:  | Esperado: 4YJ-561 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868169_0.91_(64, 112, 3)_S1B-772.jpg | Detectado: 81B-772 | Esperado: S1B-772 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868213_0.9_(47, 100, 3)_A5E-785.jpg | Detectado:  | Esperado: A5E-785 | Tiempo: 0.0290s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868214_0.91_(50, 106, 3)_45E-785.jpg | Detectado:  | Esperado: 45E-785 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868233_0.9_(51, 109, 3)_Z6E-393.jpg | Detectado:  | Esperado: Z6E-393 | Tiempo: 0.0286s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868237_0.9_(63, 115, 3)_V1H-723.jpg | Detectado:  | Esperado: V1H-723 | Tiempo: 0.0203s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868252_0.9_(49, 98, 3)_V5B-631.jpg | Detectado:  | Esperado: V5B-631 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868316_0.9_(56, 111, 3)_FOB-739.jpg | Detectado: Fob-739 | Esperado: FOB-739 | Tiempo: 0.0261s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755868367_0.9_(57, 105, 3)_Z4Q-197.jpg | Detectado: 240-192 | Esperado: Z4Q-197 | Tiempo: 0.0361s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868377_0.91_(52, 105, 3)_Z7U-204.jpg | Detectado:  | Esperado: Z7U-204 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868390_0.9_(59, 110, 3)_A7V-766.jpg | Detectado:  | Esperado: A7V-766 | Tiempo: 0.0293s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868410_0.9_(47, 98, 3)_Z3C-760.jpg | Detectado:  | Esperado: Z3C-760 | Tiempo: 0.0340s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868462_0.9_(51, 102, 3)_V9N-697.jpg | Detectado:  | Esperado: V9N-697 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868467_0.91_(46, 93, 3)_V8B-614.jpg | Detectado: 78B-614 | Esperado: V8B-614 | Tiempo: 0.0191s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868503_0.91_(50, 98, 3)_Z6L-717.jpg | Detectado:  | Esperado: Z6L-717 | Tiempo: 0.0283s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868523_0.9_(53, 105, 3)_Z7Z-085.jpg | Detectado: 777-085 | Esperado: Z7Z-085 | Tiempo: 0.0222s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868553_0.9_(51, 109, 3)_B2U-796.jpg | Detectado:  | Esperado: B2U-796 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868571_0.91_(48, 96, 3)_BRT-304.jpg | Detectado:  | Esperado: BRT-304 | Tiempo: 0.0174s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868575_0.91_(61, 110, 3)_ATO-102.jpg | Detectado:  | Esperado: ATO-102 | Tiempo: 0.0199s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868621_0.9_(56, 104, 3)_BBW-631.jpg | Detectado:  | Esperado: BBW-631 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868632_0.91_(44, 95, 3)_A9C-789.jpg | Detectado:  | Esperado: A9C-789 | Tiempo: 0.0190s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868683_0.9_(51, 101, 3)_Z3C-760.jpg | Detectado:  | Esperado: Z3C-760 | Tiempo: 0.0287s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868729_0.91_(51, 97, 3)_ICQ-067.jpg | Detectado:  | Esperado: ICQ-067 | Tiempo: 0.0230s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868766_0.9_(51, 102, 3)_AYA-568.jpg | Detectado:  | Esperado: AYA-568 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868769_0.9_(57, 106, 3)_AZH-270.jpg | Detectado:  | Esperado: AZH-270 | Tiempo: 0.0261s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868815_0.9_(51, 114, 3)_B30-733.jpg | Detectado:  | Esperado: B30-733 | Tiempo: 0.0288s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868871_0.91_(48, 97, 3)_Z7X-303.jpg | Detectado:  | Esperado: Z7X-303 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868919_0.9_(51, 100, 3)_Z4G-081.jpg | Detectado:  | Esperado: Z4G-081 | Tiempo: 0.0217s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868921_0.91_(61, 107, 3)_X3Y-506.jpg | Detectado: Kzy 506 | Esperado: X3Y-506 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868990_0.9_(48, 98, 3)_Z3W-660.jpg | Detectado:  | Esperado: Z3W-660 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869368_0.9_(59, 107, 3)_X3R-360.jpg | Detectado:  | Esperado: X3R-360 | Tiempo: 0.0200s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869377_0.9_(48, 93, 3)_D2R-594.jpg | Detectado:  | Esperado: D2R-594 | Tiempo: 0.0170s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869386_0.9_(49, 97, 3)_V7C-801.jpg | Detectado: V7C-801 | Esperado: V7C-801 | Tiempo: 0.0240s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755869394_0.9_(47, 96, 3)_Z5B-649.jpg | Detectado:  | Esperado: Z5B-649 | Tiempo: 0.0187s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869505_0.9_(126, 134, 3)_N2X-710.jpg | Detectado:  | Esperado: N2X-710 | Tiempo: 0.0411s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869536_0.91_(52, 103, 3)_Z8S-813.jpg | Detectado:  | Esperado: Z8S-813 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869570_0.9_(51, 107, 3)_Z4Q-021.jpg | Detectado:  | Esperado: Z4Q-021 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869582_0.91_(65, 116, 3)_Z8M-738.jpg | Detectado: 78/-738 | Esperado: Z8M-738 | Tiempo: 0.0352s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869632_0.9_(63, 114, 3)_Z5F-558.jpg | Detectado: 75F-558 | Esperado: Z5F-558 | Tiempo: 0.0197s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869679_0.9_(63, 113, 3)_V7C-801.jpg | Detectado: U7c-80] | Esperado: V7C-801 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869713_0.9_(60, 112, 3)_APF-394.jpg | Detectado: DpF-394 | Esperado: APF-394 | Tiempo: 0.0229s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870055_0.9_(48, 97, 3)_B2C-509.jpg | Detectado:  | Esperado: B2C-509 | Tiempo: 0.0280s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870085_0.9_(45, 94, 3)_Z7J-462.jpg | Detectado:  | Esperado: Z7J-462 | Tiempo: 0.0276s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870135_0.9_(51, 104, 3)_Z4T-372.jpg | Detectado: 741-372 | Esperado: Z4T-372 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870154_0.91_(48, 105, 3)_Y1L-742.jpg | Detectado:  | Esperado: Y1L-742 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870168_0.9_(54, 99, 3)_130-397.jpg | Detectado:  | Esperado: 130-397 | Tiempo: 0.0279s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870182_0.9_(47, 96, 3)_Z5T-688.jpg | Detectado: 251-688 | Esperado: Z5T-688 | Tiempo: 0.0193s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870240_0.9_(58, 108, 3)_Z6K-411.jpg | Detectado: Z6k-411 | Esperado: Z6K-411 | Tiempo: 0.0345s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755870251_0.91_(48, 97, 3)_45K-770.jpg | Detectado:  | Esperado: 45K-770 | Tiempo: 0.0271s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870281_0.9_(60, 105, 3)_V4F-244.jpg | Detectado: H4F-244 | Esperado: V4F-244 | Tiempo: 0.0245s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870289_0.91_(47, 92, 3)_Z7C-049.jpg | Detectado:  | Esperado: Z7C-049 | Tiempo: 0.0174s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870393_0.9_(50, 107, 3)_Y1L-742.jpg | Detectado:  | Esperado: Y1L-742 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870444_0.91_(48, 97, 3)_ACL-585.jpg | Detectado:  | Esperado: ACL-585 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870523_0.91_(50, 102, 3)_Z51-804.jpg | Detectado:  | Esperado: Z51-804 | Tiempo: 0.0217s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870633_0.9_(49, 99, 3)_Z8C-747.jpg | Detectado:  | Esperado: Z8C-747 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870662_0.91_(48, 96, 3)_AOT-720.jpg | Detectado:  | Esperado: AOT-720 | Tiempo: 0.0254s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870687_0.91_(67, 124, 3)_CDL-482.jpg | Detectado:  | Esperado: CDL-482 | Tiempo: 0.0304s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870769_0.9_(49, 99, 3)_Z7W-377.jpg | Detectado:  | Esperado: Z7W-377 | Tiempo: 0.0286s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870783_0.9_(48, 98, 3)_Z8C-206.jpg | Detectado:  | Esperado: Z8C-206 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870785_0.9_(119, 121, 3)_L8C-206.jpg | Detectado:  | Esperado: L8C-206 | Tiempo: 0.0285s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870826_0.9_(52, 102, 3)_V6M-597.jpg | Detectado: V6l 597 | Esperado: V6M-597 | Tiempo: 0.0277s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870914_0.9_(47, 99, 3)_AOT-720.jpg | Detectado:  | Esperado: AOT-720 | Tiempo: 0.0214s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871079_0.9_(62, 114, 3)_Z4J-763.jpg | Detectado:  | Esperado: Z4J-763 | Tiempo: 0.0189s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871103_0.9_(59, 110, 3)_S1B-589.jpg | Detectado:  | Esperado: S1B-589 | Tiempo: 0.0208s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871108_0.9_(52, 112, 3)_Z1J-781.jpg | Detectado:  | Esperado: Z1J-781 | Tiempo: 0.0206s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871139_0.9_(50, 96, 3)_BSV-176.jpg | Detectado: BsV 176 | Esperado: BSV-176 | Tiempo: 0.0171s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871157_0.92_(130, 134, 3)_L2N-738.jpg | Detectado: 724-730 | Esperado: L2N-738 | Tiempo: 0.0346s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871316_0.9_(51, 102, 3)_Z7M-111.jpg | Detectado:  | Esperado: Z7M-111 | Tiempo: 0.0274s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871358_0.9_(48, 96, 3)_CRO-577.jpg | Detectado: [RO 572 | Esperado: CRO-577 | Tiempo: 0.0173s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871447_0.9_(48, 101, 3)_V5S-570.jpg | Detectado:  | Esperado: V5S-570 | Tiempo: 0.0274s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871461_0.9_(46, 96, 3)_APF-394.jpg | Detectado: [pF 324 | Esperado: APF-394 | Tiempo: 0.0202s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871611_0.91_(57, 104, 3)_Z5V-413.jpg | Detectado:  | Esperado: Z5V-413 | Tiempo: 0.0212s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871634_0.9_(60, 108, 3)_V8J-069.jpg | Detectado:  | Esperado: V8J-069 | Tiempo: 0.0245s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871753_0.91_(60, 106, 3)_Z5L-091.jpg | Detectado:  | Esperado: Z5L-091 | Tiempo: 0.0304s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871801_0.9_(47, 93, 3)_Z7S-679.jpg | Detectado:  | Esperado: Z7S-679 | Tiempo: 0.0171s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871807_0.9_(48, 99, 3)_Z8A-540.jpg | Detectado:  | Esperado: Z8A-540 | Tiempo: 0.0210s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871813_0.9_(63, 107, 3)_Z5D-490.jpg | Detectado: 257-490 | Esperado: Z5D-490 | Tiempo: 0.0205s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871836_0.9_(58, 116, 3)_V3C-453.jpg | Detectado:  | Esperado: V3C-453 | Tiempo: 0.0273s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871886_0.9_(50, 104, 3)_Z6D-367.jpg | Detectado:  | Esperado: Z6D-367 | Tiempo: 0.0213s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871920_0.91_(63, 106, 3)_ASN-544.jpg | Detectado:  | Esperado: ASN-544 | Tiempo: 0.0198s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871984_0.91_(49, 95, 3)_Z7L-650.jpg | Detectado:  | Esperado: Z7L-650 | Tiempo: 0.0177s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872015_0.9_(61, 112, 3)_Z5D-360.jpg | Detectado: 750-360 | Esperado: Z5D-360 | Tiempo: 0.0226s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872070_0.9_(52, 103, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0218s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872110_0.9_(51, 96, 3)_VOT-812.jpg | Detectado: Vor-812 | Esperado: VOT-812 | Tiempo: 0.0172s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872180_0.9_(48, 98, 3)_A9K-715.jpg | Detectado:  | Esperado: A9K-715 | Tiempo: 0.0295s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872284_0.91_(145, 146, 3)_L10-760.jpg | Detectado:  | Esperado: L10-760 | Tiempo: 0.0350s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872299_0.9_(54, 103, 3)_Z5G-467.jpg | Detectado:  | Esperado: Z5G-467 | Tiempo: 0.0240s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872312_0.9_(50, 97, 3)_Z7X-826.jpg | Detectado: 77x 826 | Esperado: Z7X-826 | Tiempo: 0.0194s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872398_0.9_(49, 101, 3)_F3F-041.jpg | Detectado: EzF-041 | Esperado: F3F-041 | Tiempo: 0.0219s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872405_0.91_(59, 107, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0288s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872417_0.9_(49, 93, 3)_B31-104.jpg | Detectado:  | Esperado: B31-104 | Tiempo: 0.0261s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872482_0.9_(58, 109, 3)_CJS-373.jpg | Detectado:  | Esperado: CJS-373 | Tiempo: 0.0240s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872541_0.9_(123, 137, 3)_L10-760.jpg | Detectado: 7i0-760 | Esperado: L10-760 | Tiempo: 0.0301s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872551_0.9_(50, 98, 3)_Z7V-417.jpg | Detectado:  | Esperado: Z7V-417 | Tiempo: 0.0281s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872552_0.91_(62, 109, 3)_77V-417.jpg | Detectado:  | Esperado: 77V-417 | Tiempo: 0.0277s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872559_0.9_(46, 103, 3)_74K-739.jpg | Detectado:  | Esperado: 74K-739 | Tiempo: 0.0277s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872559_0.9_(52, 107, 3)_Z4K-739.jpg | Detectado:  | Esperado: Z4K-739 | Tiempo: 0.0282s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872606_0.91_(48, 99, 3)_CRO-577.jpg | Detectado:  | Esperado: CRO-577 | Tiempo: 0.0207s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872752_0.9_(51, 96, 3)_BKZ-705.jpg | Detectado:  | Esperado: BKZ-705 | Tiempo: 0.0168s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872828_0.9_(49, 94, 3)_Z2Q-310.jpg | Detectado: 720 310 | Esperado: Z2Q-310 | Tiempo: 0.0177s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872884_0.9_(51, 103, 3)_V1T-101.jpg | Detectado:  | Esperado: V1T-101 | Tiempo: 0.0206s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872968_0.91_(50, 96, 3)_C1A-878.jpg | Detectado: 614-878 | Esperado: C1A-878 | Tiempo: 0.0172s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873119_0.91_(46, 95, 3)_42E-705.jpg | Detectado:  | Esperado: 42E-705 | Tiempo: 0.0193s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873369_0.9_(56, 100, 3)_AFG-023.jpg | Detectado: Afg-023 | Esperado: AFG-023 | Tiempo: 0.0194s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755873449_0.9_(55, 105, 3)_Z5G-139.jpg | Detectado: 256-139 | Esperado: Z5G-139 | Tiempo: 0.0188s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873458_0.91_(51, 98, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.0206s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873467_0.9_(59, 112, 3)_BHB-015.jpg | Detectado:  | Esperado: BHB-015 | Tiempo: 0.0209s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873478_0.9_(47, 98, 3)_42E-705.jpg | Detectado:  | Esperado: 42E-705 | Tiempo: 0.0282s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873578_0.9_(56, 108, 3)_Z5X-789.jpg | Detectado: 75x-789 | Esperado: Z5X-789 | Tiempo: 0.0242s | Precisión: 0.0% | ❌ Incorrecto
#
# ✅ Resultados guardados en: resultados_easyOCR/resultados_easyocr.csv
# 📊 Resumen: 22/500 correctos (4.4%)
# ⏱️  Tiempo total: 11.5103s | Tiempo promedio: 0.0230s

# %% [markdown]
# ## TesseractOCR

# %% [markdown]
# ### Instalacion de TesseractOCR

# %%
# !pip install pytesseract pillow

# %% [markdown]
# ### Comprobar version de TesseractOCR

# %%
# !pip show pytesseract
# Out:
# Name: pytesseract
# Version: 0.3.13
# Summary: Python-tesseract is a python wrapper for Google's Tesseract-OCR
# Home-page: https://github.com/madmaze/pytesseract
# Author: Samuel Hoffstaetter
# Author-email: samuel@hoffstaetter.com
# License: Apache License 2.0
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages
# Requires: packaging, Pillow
# Required-by:

# %% [markdown]
# ### Probar con una imagen TesseractOCR (presicion y tiempo de inferencia)

# %%
import pytesseract
import cv2
import time
import os
import re

# Configuración
image_path = 'dataset/1755801131_0.9_(56, 113, 3)_A9K-715.jpg'

# Extraer texto esperado del nombre del archivo
filename = os.path.basename(image_path)
match = re.search(r'_([A-Z0-9-]+)\.(jpg|jpeg|png|bmp)$', filename, re.IGNORECASE)
expected_text = match.group(1) if match else "UNKNOWN"

# Configuración de Tesseract para placas
config_tesseract = '-l spa --psm 7 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-'

# Leer y preprocesar imagen
imagen = cv2.imread(image_path)
if imagen is None:
    print(f"❌ Error: No se pudo cargar la imagen en {image_path}")
    exit()

gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gris, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Realizar OCR y medir tiempo
start_time = time.time()
texto = pytesseract.image_to_string(thresh, config=config_tesseract)
inference_time = time.time() - start_time

# Limpiar texto detectado
detected_text = texto.strip().replace('\n', ' ').replace('\f', '')

# Calcular precisión
precision = 100.0 if expected_text.lower() == detected_text.lower() else 0.0
resultado = "✅ Correcto" if precision == 100.0 else "❌ Incorrecto"

# Mostrar resultados en tabla
print("\n" + "=" * 120)
print("RESULTADOS TesseractOCR")
print("=" * 120)
print(f"{'Imagen':<45} | {'Texto Detectado':<15} | {'Texto Esperado':<15} | {'Tiempo (s)':<12} | {'Precisión':<10} | {'Resultado':<12}")
print("-" * 120)
print(f"{image_path:<45} | {detected_text:<15} | {expected_text:<15} | {inference_time:<12.4f} | {precision:<10.1f}% | {resultado:<12}")
print("=" * 120)
# Out:
# ========================================================================================================================
# RESULTADOS TesseractOCR
# ========================================================================================================================
# Imagen                                        | Texto Detectado | Texto Esperado  | Tiempo (s)   | Precisión  | Resultado
# ------------------------------------------------------------------------------------------------------------------------
# dataset/1755801131_0.9_(56, 113, 3)_A9K-715.jpg | A9K-715         | A9K-715         | 0.0533       | 100.0     % | ✅ Correcto
# ========================================================================================================================

# %% [markdown]
# ### Probar con el dataset TesseractOCR (presicion y tiempo de inferencia)

# %%
import pytesseract
import cv2
import time
import warnings
import os
import glob
import re
import csv

# Configuración
dataset_path = 'dataset/'
image_extensions = ['*.jpg', '*.jpeg', '*.png', '*.bmp']
csv_filename = 'resultados_tesseractOCR/resultados_tesseractocr.csv'

# Crear carpeta de salida si no existe
os.makedirs('resultados_tesseractOCR', exist_ok=True)

# Obtener todas las imágenes del dataset
image_files = []
for ext in image_extensions:
    image_files.extend(glob.glob(os.path.join(dataset_path, ext)))

# Configuración de Tesseract para placas
config_tesseract = '-l spa --psm 7 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-'

print("Inicializando TesseractOCR...")
print(f"Total de imágenes a procesar: {len(image_files)}\n")

# Almacenar resultados
results_data = []
total_time = 0
correct_count = 0
total_images = len(image_files)

# Procesar cada imagen
for image_path in sorted(image_files):
    
    # Extraer el texto esperado del nombre del archivo
    filename = os.path.basename(image_path)
    match = re.search(r'_([A-Z0-9-]+)\.(jpg|jpeg|png|bmp)$', filename, re.IGNORECASE)
    expected_text = match.group(1) if match else "UNKNOWN"
    
    # Leer y preprocesar imagen
    imagen = cv2.imread(image_path)
    
    if imagen is None:
        detected_text = ""
        inference_time = 0
        print(f"❌ Error al cargar: {filename}")
    else:
        # Preprocesamiento
        gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
        _, thresh = cv2.threshold(gris, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        
        # Realizar OCR y medir tiempo
        start_time = time.time()
        texto = pytesseract.image_to_string(thresh, config=config_tesseract)
        inference_time = time.time() - start_time
        total_time += inference_time
        
        # Limpiar texto detectado
        detected_text = texto.strip().replace('\n', ' ').replace('\f', '')
    
    # Calcular precisión
    precision = 100.0 if expected_text.lower() == detected_text.lower() else 0.0
    resultado = "✅ Correcto" if precision == 100.0 else "❌ Incorrecto"
    
    if precision == 100.0:
        correct_count += 1
    
    # Guardar resultado
    results_data.append({
        'Imagen': image_path,
        'Texto Detectado': detected_text,
        'Texto Esperado': expected_text,
        'Tiempo (s)': f"{inference_time:.4f}",
        'Precisión (%)': f"{precision:.1f}",
        'Resultado': resultado
    })
    
    print(f"Procesado: {filename} | Detectado: {detected_text} | Esperado: {expected_text} | Tiempo: {inference_time:.4f}s | Precisión: {precision:.1f}% | {resultado}")

# Guardar resultados en CSV
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Imagen', 'Texto Detectado', 'Texto Esperado', 'Tiempo (s)', 'Precisión (%)', 'Resultado']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    writer.writerows(results_data)
    
    # Agregar línea vacía
    writer.writerow({})
    
    # Agregar resumen final
    incorrect_count = total_images - correct_count
    writer.writerow({
        'Imagen': '=== RESUMEN FINAL ===',
        'Texto Detectado': '',
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Total de imágenes',
        'Texto Detectado': str(total_images),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Correctos',
        'Texto Detectado': str(correct_count),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': f"{(correct_count/total_images)*100:.1f}",
        'Resultado': '✅'
    })
    writer.writerow({
        'Imagen': 'Incorrectos',
        'Texto Detectado': str(incorrect_count),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': f"{(incorrect_count/total_images)*100:.1f}",
        'Resultado': '❌'
    })
    writer.writerow({
        'Imagen': 'Tiempo total',
        'Texto Detectado': f"{total_time:.4f}s",
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Tiempo promedio',
        'Texto Detectado': f"{total_time/total_images:.4f}s",
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })

print(f"\n✅ Resultados guardados en: {csv_filename}")
print(f"📊 Resumen: {correct_count}/{total_images} correctos ({(correct_count/total_images)*100:.1f}%)")
print(f"⏱️  Tiempo total: {total_time:.4f}s | Tiempo promedio: {total_time/total_images:.4f}s")
# Out:
# Inicializando TesseractOCR...
# Total de imágenes a procesar: 500
#
# Procesado: 1755800220_0.9_(48, 104, 3)_BYJ-567.jpg | Detectado:  | Esperado: BYJ-567 | Tiempo: 0.0504s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800225_0.91_(44, 95, 3)_V71-023.jpg | Detectado:  | Esperado: V71-023 | Tiempo: 0.0570s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800256_0.9_(49, 104, 3)_Z4X-018.jpg | Detectado:  | Esperado: Z4X-018 | Tiempo: 0.0759s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800279_0.93_(64, 113, 3)_A8D-757.jpg | Detectado: 80-757 | Esperado: A8D-757 | Tiempo: 0.0562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800317_0.9_(45, 93, 3)_VAJ-632.jpg | Detectado:  | Esperado: VAJ-632 | Tiempo: 0.0563s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800323_0.9_(52, 105, 3)_CRO-577.jpg | Detectado:  | Esperado: CRO-577 | Tiempo: 0.0559s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800341_0.9_(44, 91, 3)_V8U-524.jpg | Detectado:  | Esperado: V8U-524 | Tiempo: 0.0510s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800344_0.91_(47, 96, 3)_Z7U-204.jpg | Detectado:  | Esperado: Z7U-204 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800351_0.91_(47, 93, 3)_BSV-176.jpg | Detectado:  | Esperado: BSV-176 | Tiempo: 0.0505s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800370_0.91_(52, 105, 3)_Z7P-666.jpg | Detectado: 77P-660 | Esperado: Z7P-666 | Tiempo: 0.0585s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800418_0.9_(53, 106, 3)_Z6A-203.jpg | Detectado:  | Esperado: Z6A-203 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800425_0.9_(58, 119, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800437_0.9_(60, 107, 3)_Z5B-752.jpg | Detectado:  | Esperado: Z5B-752 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800446_0.9_(49, 100, 3)_Z8Y-837.jpg | Detectado:  | Esperado: Z8Y-837 | Tiempo: 0.0572s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800450_0.9_(48, 96, 3)_Z7V-290.jpg | Detectado:  | Esperado: Z7V-290 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800459_0.9_(46, 92, 3)_Z6S-279.jpg | Detectado:  | Esperado: Z6S-279 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800467_0.91_(58, 105, 3)_B1B-164.jpg | Detectado:  | Esperado: B1B-164 | Tiempo: 0.0506s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800525_0.91_(45, 92, 3)_V9W-422.jpg | Detectado: 9N-422 | Esperado: V9W-422 | Tiempo: 0.0550s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800555_0.9_(44, 90, 3)_V8M-368.jpg | Detectado: VH-368 | Esperado: V8M-368 | Tiempo: 0.0571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800589_0.9_(46, 98, 3)_A8D-757.jpg | Detectado: 480-737 | Esperado: A8D-757 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800590_0.9_(54, 109, 3)_A80-757.jpg | Detectado:  | Esperado: A80-757 | Tiempo: 0.0505s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800700_0.91_(48, 100, 3)_Z5Q-106.jpg | Detectado:  | Esperado: Z5Q-106 | Tiempo: 0.0496s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800790_0.9_(43, 90, 3)_X4N-230.jpg | Detectado:  | Esperado: X4N-230 | Tiempo: 0.0581s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800793_0.91_(46, 92, 3)_V1I-104.jpg | Detectado:  | Esperado: V1I-104 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800797_0.9_(52, 103, 3)_AUU-101.jpg | Detectado: AU-101 | Esperado: AUU-101 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800807_0.9_(50, 104, 3)_X20-934.jpg | Detectado:  | Esperado: X20-934 | Tiempo: 0.0559s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800880_0.9_(44, 92, 3)_V31-163.jpg | Detectado:  | Esperado: V31-163 | Tiempo: 0.0538s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800883_0.9_(54, 104, 3)_Z6L-717.jpg | Detectado:  | Esperado: Z6L-717 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800887_0.9_(47, 97, 3)_Z7K-549.jpg | Detectado:  | Esperado: Z7K-549 | Tiempo: 0.0518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800893_0.9_(71, 106, 3)_Y3Q-595.jpg | Detectado: E | Esperado: Y3Q-595 | Tiempo: 0.0545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800912_0.9_(41, 96, 3)_F51-233.jpg | Detectado:  | Esperado: F51-233 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800941_0.9_(50, 100, 3)_B1N-742.jpg | Detectado: E1N-742 | Esperado: B1N-742 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800975_0.91_(58, 106, 3)_V7R-826.jpg | Detectado:  | Esperado: V7R-826 | Tiempo: 0.0512s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800978_0.91_(47, 96, 3)_Z4Q-197.jpg | Detectado:  | Esperado: Z4Q-197 | Tiempo: 0.0500s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801015_0.9_(48, 98, 3)_Z5G-496.jpg | Detectado:  | Esperado: Z5G-496 | Tiempo: 0.0504s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801088_0.9_(50, 109, 3)_Z5T-282.jpg | Detectado:  | Esperado: Z5T-282 | Tiempo: 0.0502s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801091_0.91_(46, 101, 3)_Z5V-445.jpg | Detectado:  | Esperado: Z5V-445 | Tiempo: 0.0505s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801123_0.9_(52, 100, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.0570s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801131_0.9_(56, 113, 3)_A9K-715.jpg | Detectado: A9K-715 | Esperado: A9K-715 | Tiempo: 0.0625s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801139_0.9_(47, 97, 3)_CBM-487.jpg | Detectado:  | Esperado: CBM-487 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801176_0.9_(50, 108, 3)_Z2G-146.jpg | Detectado: 776-146 | Esperado: Z2G-146 | Tiempo: 0.0590s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801183_0.9_(61, 112, 3)_Z2N-051.jpg | Detectado:  | Esperado: Z2N-051 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801190_0.9_(46, 98, 3)_V9K-468.jpg | Detectado: Y9K-468 | Esperado: V9K-468 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801207_0.91_(48, 101, 3)_Z3P-791.jpg | Detectado: 73P-701 | Esperado: Z3P-791 | Tiempo: 0.0571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801210_0.9_(49, 104, 3)_X3A-006.jpg | Detectado:  | Esperado: X3A-006 | Tiempo: 0.0538s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801223_0.91_(51, 101, 3)_Z8B-641.jpg | Detectado:  | Esperado: Z8B-641 | Tiempo: 0.0564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801236_0.9_(48, 97, 3)_X1J-790.jpg | Detectado:  | Esperado: X1J-790 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801286_0.9_(71, 116, 3)_F7F-087.jpg | Detectado:  | Esperado: F7F-087 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801294_0.91_(52, 106, 3)_A5G-752.jpg | Detectado: 456-757 | Esperado: A5G-752 | Tiempo: 0.0591s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801305_0.91_(48, 98, 3)_Z8U-888.jpg | Detectado:  | Esperado: Z8U-888 | Tiempo: 0.0533s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801306_0.91_(47, 102, 3)_Z8L-888.jpg | Detectado:  | Esperado: Z8L-888 | Tiempo: 0.0560s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801314_0.91_(50, 103, 3)_AUJ-187.jpg | Detectado:  | Esperado: AUJ-187 | Tiempo: 0.0552s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801315_0.9_(57, 110, 3)_AUJ-182.jpg | Detectado:  | Esperado: AUJ-182 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801327_0.91_(49, 100, 3)_Z6X-411.jpg | Detectado:  | Esperado: Z6X-411 | Tiempo: 0.0539s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801335_0.9_(62, 110, 3)_V71-023.jpg | Detectado:  | Esperado: V71-023 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801348_0.9_(50, 97, 3)_X1S-070.jpg | Detectado: 115-071 | Esperado: X1S-070 | Tiempo: 0.0608s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801389_0.91_(45, 93, 3)_VDS-785.jpg | Detectado: 105-789 | Esperado: VDS-785 | Tiempo: 0.0558s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801392_0.91_(54, 107, 3)_Z7M-355.jpg | Detectado:  | Esperado: Z7M-355 | Tiempo: 0.0548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801403_0.91_(54, 106, 3)_Z8B-617.jpg | Detectado:  | Esperado: Z8B-617 | Tiempo: 0.0552s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801417_0.91_(51, 103, 3)_D7W-870.jpg | Detectado: 074-870 | Esperado: D7W-870 | Tiempo: 0.0578s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801418_0.9_(57, 108, 3)_07W-870.jpg | Detectado: 07N-870 | Esperado: 07W-870 | Tiempo: 0.0585s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801426_0.9_(50, 102, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801434_0.91_(63, 120, 3)_A9K-715.jpg | Detectado: 19K-715 | Esperado: A9K-715 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801483_0.91_(50, 100, 3)_X4H-470.jpg | Detectado:  | Esperado: X4H-470 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801491_0.91_(47, 94, 3)_VCS-856.jpg | Detectado:  | Esperado: VCS-856 | Tiempo: 0.0568s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801494_0.91_(48, 101, 3)_BCF-122.jpg | Detectado:  | Esperado: BCF-122 | Tiempo: 0.0545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801529_0.9_(55, 104, 3)_Z5K-681.jpg | Detectado:  | Esperado: Z5K-681 | Tiempo: 0.0555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801534_0.91_(60, 117, 3)_Z2G-323.jpg | Detectado:  | Esperado: Z2G-323 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801565_0.91_(64, 115, 3)_Z5Q-118.jpg | Detectado:  | Esperado: Z5Q-118 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801570_0.9_(48, 97, 3)_X1J-790.jpg | Detectado: 13-790 | Esperado: X1J-790 | Tiempo: 0.0558s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801578_0.9_(46, 94, 3)_VAN-508.jpg | Detectado:  | Esperado: VAN-508 | Tiempo: 0.0561s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801584_0.9_(48, 99, 3)_CHH-339.jpg | Detectado: CHH-339 | Esperado: CHH-339 | Tiempo: 0.0579s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801586_0.9_(53, 100, 3)_Z6M-106.jpg | Detectado:  | Esperado: Z6M-106 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801598_0.92_(53, 108, 3)_A5G-752.jpg | Detectado: 456-757 | Esperado: A5G-752 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801647_0.92_(59, 102, 3)_Z7U-204.jpg | Detectado: 77204 | Esperado: Z7U-204 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801654_0.9_(49, 99, 3)_Z5G-467.jpg | Detectado:  | Esperado: Z5G-467 | Tiempo: 0.0548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801662_0.91_(73, 117, 3)_598-655.jpg | Detectado:  | Esperado: 598-655 | Tiempo: 0.0555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801663_0.9_(44, 89, 3)_71C-465.jpg | Detectado:  | Esperado: 71C-465 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801690_0.9_(41, 89, 3)_AXF-317.jpg | Detectado:  | Esperado: AXF-317 | Tiempo: 0.0515s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801695_0.9_(46, 96, 3)_X1Q-323.jpg | Detectado: 110-323 | Esperado: X1Q-323 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801744_0.9_(66, 118, 3)_Z20-326.jpg | Detectado:  | Esperado: Z20-326 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801790_0.91_(49, 103, 3)_Z6C-695.jpg | Detectado:  | Esperado: Z6C-695 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801795_0.91_(46, 94, 3)_Z3F-113.jpg | Detectado: SNE | Esperado: Z3F-113 | Tiempo: 0.0650s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801798_0.92_(53, 103, 3)_Z6K-059.jpg | Detectado:  | Esperado: Z6K-059 | Tiempo: 0.0558s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801801_0.91_(46, 97, 3)_D70-364.jpg | Detectado: 070-304 | Esperado: D70-364 | Tiempo: 0.0571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801812_0.91_(49, 101, 3)_Z7V-467.jpg | Detectado:  | Esperado: Z7V-467 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801843_0.91_(49, 100, 3)_Z7S-416.jpg | Detectado: 775-416 | Esperado: Z7S-416 | Tiempo: 0.0554s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801846_0.9_(49, 95, 3)_F4B-067.jpg | Detectado:  | Esperado: F4B-067 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801849_0.91_(53, 105, 3)_Z3V-367.jpg | Detectado:  | Esperado: Z3V-367 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801852_0.9_(52, 97, 3)_V71-420.jpg | Detectado:  | Esperado: V71-420 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801939_0.9_(48, 90, 3)_AYJ-561.jpg | Detectado:  | Esperado: AYJ-561 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802000_0.91_(48, 101, 3)_AMO-819.jpg | Detectado:  | Esperado: AMO-819 | Tiempo: 0.0511s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802022_0.9_(53, 103, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802033_0.91_(56, 107, 3)_CKS-489.jpg | Detectado:  | Esperado: CKS-489 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802038_0.9_(54, 103, 3)_C3S-449.jpg | Detectado: 35-440 | Esperado: C3S-449 | Tiempo: 0.0562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802073_0.91_(54, 106, 3)_Z7C-049.jpg | Detectado:  | Esperado: Z7C-049 | Tiempo: 0.0540s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802099_0.91_(54, 108, 3)_Z6B-834.jpg | Detectado:  | Esperado: Z6B-834 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802124_0.9_(60, 112, 3)_X3T-626.jpg | Detectado: 131-620 | Esperado: X3T-626 | Tiempo: 0.0582s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802133_0.91_(49, 97, 3)_VCF-677.jpg | Detectado:  | Esperado: VCF-677 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802142_0.9_(50, 100, 3)_D1I-153.jpg | Detectado: 11-153 | Esperado: D1I-153 | Tiempo: 0.0604s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802147_0.91_(46, 90, 3)_VBI-497.jpg | Detectado:  | Esperado: VBI-497 | Tiempo: 0.0560s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802161_0.91_(50, 99, 3)_V9N-697.jpg | Detectado:  | Esperado: V9N-697 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802166_0.9_(45, 102, 3)_V2N-829.jpg | Detectado: 120-827 | Esperado: V2N-829 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802269_0.91_(45, 93, 3)_ARE-297.jpg | Detectado:  | Esperado: ARE-297 | Tiempo: 0.0507s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802328_0.9_(49, 98, 3)_Z7N-143.jpg | Detectado:  | Esperado: Z7N-143 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802353_0.9_(62, 107, 3)_AAO-576.jpg | Detectado:  | Esperado: AAO-576 | Tiempo: 0.0591s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802410_0.91_(48, 95, 3)_BTB-292.jpg | Detectado:  | Esperado: BTB-292 | Tiempo: 0.0561s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802415_0.91_(44, 95, 3)_Z7Y-245.jpg | Detectado: 771-245 | Esperado: Z7Y-245 | Tiempo: 0.0574s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802418_0.9_(50, 104, 3)_BPW-164.jpg | Detectado: BPN-164 | Esperado: BPW-164 | Tiempo: 0.0569s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802421_0.91_(47, 92, 3)_BXI-161.jpg | Detectado:  | Esperado: BXI-161 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802433_0.9_(50, 98, 3)_V6Y-151.jpg | Detectado:  | Esperado: V6Y-151 | Tiempo: 0.0556s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802437_0.92_(48, 98, 3)_Z6Y-080.jpg | Detectado: 761-080 | Esperado: Z6Y-080 | Tiempo: 0.0586s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802496_0.91_(42, 90, 3)_Z5D-490.jpg | Detectado:  | Esperado: Z5D-490 | Tiempo: 0.0565s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802534_0.9_(41, 91, 3)_V4E-442.jpg | Detectado: V4E-462 | Esperado: V4E-442 | Tiempo: 0.0540s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802585_0.91_(42, 94, 3)_VBX-425.jpg | Detectado: VBX-429 | Esperado: VBX-425 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802589_0.9_(48, 98, 3)_Z4Q-264.jpg | Detectado:  | Esperado: Z4Q-264 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802592_0.91_(48, 98, 3)_BKQ-659.jpg | Detectado:  | Esperado: BKQ-659 | Tiempo: 0.0518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802597_0.9_(48, 98, 3)_S1B-589.jpg | Detectado:  | Esperado: S1B-589 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802608_0.91_(49, 97, 3)_BKM-032.jpg | Detectado:  | Esperado: BKM-032 | Tiempo: 0.0571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802629_0.9_(50, 106, 3)_AFL-039.jpg | Detectado:  | Esperado: AFL-039 | Tiempo: 0.0559s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802632_0.9_(47, 101, 3)_Z7F-326.jpg | Detectado:  | Esperado: Z7F-326 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802646_0.9_(65, 114, 3)_CJS-468.jpg | Detectado:  | Esperado: CJS-468 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802650_0.9_(58, 114, 3)_A2E-705.jpg | Detectado: 0570 | Esperado: A2E-705 | Tiempo: 0.0575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802708_0.9_(52, 102, 3)_BHG-267.jpg | Detectado: BH6-267 | Esperado: BHG-267 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802716_0.91_(47, 95, 3)_V4L-658.jpg | Detectado: V6L-658 | Esperado: V4L-658 | Tiempo: 0.0576s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802759_0.91_(54, 107, 3)_Z8V-787.jpg | Detectado: 781-787 | Esperado: Z8V-787 | Tiempo: 0.0606s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802859_0.9_(50, 97, 3)_Z3P-000.jpg | Detectado:  | Esperado: Z3P-000 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802962_0.91_(63, 114, 3)_Z6D-367.jpg | Detectado: 760-361 | Esperado: Z6D-367 | Tiempo: 0.0557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803016_0.9_(43, 91, 3)_V6J-526.jpg | Detectado: 167-570 | Esperado: V6J-526 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803044_0.9_(63, 111, 3)_Z6U-717.jpg | Detectado:  | Esperado: Z6U-717 | Tiempo: 0.0518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803089_0.9_(49, 97, 3)_Z7N-143.jpg | Detectado: 27-143 | Esperado: Z7N-143 | Tiempo: 0.0573s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803106_0.9_(58, 113, 3)_Z7W-178.jpg | Detectado:  | Esperado: Z7W-178 | Tiempo: 0.0541s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803124_0.9_(46, 92, 3)_Z1E-728.jpg | Detectado:  | Esperado: Z1E-728 | Tiempo: 0.0538s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803163_0.9_(54, 107, 3)_V1H-723.jpg | Detectado:  | Esperado: V1H-723 | Tiempo: 0.0518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803168_0.91_(53, 106, 3)_Z4Y-573.jpg | Detectado:  | Esperado: Z4Y-573 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803170_0.9_(45, 89, 3)_X3T-194.jpg | Detectado:  | Esperado: X3T-194 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803288_0.91_(47, 96, 3)_ASJ-523.jpg | Detectado:  | Esperado: ASJ-523 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803327_0.9_(50, 100, 3)_X3E-141.jpg | Detectado: N36-141 | Esperado: X3E-141 | Tiempo: 0.0556s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803417_0.9_(46, 96, 3)_Z1E-728.jpg | Detectado: 716-720 | Esperado: Z1E-728 | Tiempo: 0.0543s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803618_0.9_(61, 105, 3)_CEX-325.jpg | Detectado:  | Esperado: CEX-325 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803678_0.9_(46, 103, 3)_V1W-327.jpg | Detectado:  | Esperado: V1W-327 | Tiempo: 0.0506s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803683_0.9_(59, 118, 3)_Z5D-845.jpg | Detectado: 75L349 | Esperado: Z5D-845 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803692_0.9_(60, 105, 3)_BBT-930.jpg | Detectado: 801-930 | Esperado: BBT-930 | Tiempo: 0.0582s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803697_0.9_(67, 126, 3)_Z2E-770.jpg | Detectado:  | Esperado: Z2E-770 | Tiempo: 0.0685s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803736_0.9_(50, 103, 3)_BTQ-272.jpg | Detectado:  | Esperado: BTQ-272 | Tiempo: 0.0555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803790_0.9_(66, 113, 3)_Z3J-707.jpg | Detectado: 73-10 | Esperado: Z3J-707 | Tiempo: 0.0543s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803875_0.91_(47, 102, 3)_ANJ-150.jpg | Detectado:  | Esperado: ANJ-150 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803886_0.9_(45, 94, 3)_Z7X-826.jpg | Detectado:  | Esperado: Z7X-826 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803979_0.9_(45, 90, 3)_BVH-663.jpg | Detectado:  | Esperado: BVH-663 | Tiempo: 0.0548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803979_0.9_(48, 97, 3)_8VH-663.jpg | Detectado:  | Esperado: 8VH-663 | Tiempo: 0.0571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803985_0.9_(127, 139, 3)_L2E-770.jpg | Detectado: YU | Esperado: L2E-770 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804033_0.91_(51, 96, 3)_V4E-661.jpg | Detectado: UAE-064 | Esperado: V4E-661 | Tiempo: 0.0550s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804052_0.9_(54, 101, 3)_AUU-101.jpg | Detectado: AUL10S | Esperado: AUU-101 | Tiempo: 0.0539s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804067_0.91_(63, 110, 3)_Z7G-042.jpg | Detectado:  | Esperado: Z7G-042 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804076_0.9_(51, 103, 3)_BJG-541.jpg | Detectado:  | Esperado: BJG-541 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804125_0.91_(48, 101, 3)_Z3J-707.jpg | Detectado:  | Esperado: Z3J-707 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804178_0.91_(38, 89, 3)_AYH-261.jpg | Detectado: AVH-261 | Esperado: AYH-261 | Tiempo: 0.0550s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804192_0.9_(65, 116, 3)_V7C-801.jpg | Detectado:  | Esperado: V7C-801 | Tiempo: 0.0545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804243_0.9_(49, 94, 3)_Z7Y-445.jpg | Detectado:  | Esperado: Z7Y-445 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804326_0.9_(47, 98, 3)_CO1-165.jpg | Detectado:  | Esperado: CO1-165 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804330_0.91_(51, 102, 3)_Z8S-813.jpg | Detectado: 785-843 | Esperado: Z8S-813 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804345_0.91_(46, 94, 3)_BLH-257.jpg | Detectado:  | Esperado: BLH-257 | Tiempo: 0.0509s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804371_0.9_(54, 113, 3)_V6E-258.jpg | Detectado:  | Esperado: V6E-258 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804443_0.91_(49, 96, 3)_Z51-510.jpg | Detectado:  | Esperado: Z51-510 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804512_0.91_(39, 91, 3)_Z7T-469.jpg | Detectado: 771-469 | Esperado: Z7T-469 | Tiempo: 0.0552s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804516_0.92_(61, 118, 3)_Z1A-640.jpg | Detectado:  | Esperado: Z1A-640 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805016_0.9_(49, 97, 3)_BWS-056.jpg | Detectado:  | Esperado: BWS-056 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805048_0.9_(50, 96, 3)_VCL-405.jpg | Detectado:  | Esperado: VCL-405 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805055_0.9_(53, 104, 3)_Z7W-234.jpg | Detectado:  | Esperado: Z7W-234 | Tiempo: 0.0541s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805151_0.91_(50, 101, 3)_Z7W-377.jpg | Detectado:  | Esperado: Z7W-377 | Tiempo: 0.0510s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805212_0.91_(52, 105, 3)_Z7F-518.jpg | Detectado: 276-518 | Esperado: Z7F-518 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805218_0.9_(41, 88, 3)_Z7H-064.jpg | Detectado: 77H-06 | Esperado: Z7H-064 | Tiempo: 0.0596s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805271_0.9_(64, 111, 3)_Z1V-042.jpg | Detectado: 714-042 | Esperado: Z1V-042 | Tiempo: 0.0564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805284_0.91_(52, 101, 3)_VAB-735.jpg | Detectado: 148-735 | Esperado: VAB-735 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805378_0.9_(47, 101, 3)_Z6E-393.jpg | Detectado:  | Esperado: Z6E-393 | Tiempo: 0.0509s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805538_0.9_(47, 98, 3)_Z7G-017.jpg | Detectado:  | Esperado: Z7G-017 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805684_0.9_(48, 99, 3)_VCS-186.jpg | Detectado:  | Esperado: VCS-186 | Tiempo: 0.0528s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805788_0.91_(48, 98, 3)_CRG-314.jpg | Detectado:  | Esperado: CRG-314 | Tiempo: 0.0504s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805904_0.92_(118, 124, 3)_V2X-710.jpg | Detectado:  | Esperado: V2X-710 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806062_0.9_(47, 95, 3)_BKQ-659.jpg | Detectado:  | Esperado: BKQ-659 | Tiempo: 0.0501s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806111_0.9_(49, 97, 3)_Z7F-621.jpg | Detectado:  | Esperado: Z7F-621 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806151_0.91_(47, 98, 3)_Z5J-577.jpg | Detectado:  | Esperado: Z5J-577 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806181_0.9_(41, 100, 3)_VAQ-104.jpg | Detectado: A0-104 | Esperado: VAQ-104 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806233_0.9_(49, 96, 3)_BWQ-500.jpg | Detectado: 5NG-500 | Esperado: BWQ-500 | Tiempo: 0.0558s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806243_0.91_(58, 110, 3)_Z7U-178.jpg | Detectado:  | Esperado: Z7U-178 | Tiempo: 0.0571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806300_0.9_(50, 101, 3)_AOT-720.jpg | Detectado: 01-720 | Esperado: AOT-720 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806301_0.9_(53, 110, 3)_A0T-720.jpg | Detectado: 101-720 | Esperado: A0T-720 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806307_0.9_(45, 91, 3)_T4M-134.jpg | Detectado: 74-134 | Esperado: T4M-134 | Tiempo: 0.0569s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806406_0.9_(47, 101, 3)_A4S-720.jpg | Detectado:  | Esperado: A4S-720 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806558_0.9_(60, 116, 3)_ABU-720.jpg | Detectado:  | Esperado: ABU-720 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806583_0.9_(58, 110, 3)_Z7H-075.jpg | Detectado:  | Esperado: Z7H-075 | Tiempo: 0.0501s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806706_0.9_(45, 96, 3)_V71-023.jpg | Detectado:  | Esperado: V71-023 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806714_0.91_(46, 100, 3)_A4S-720.jpg | Detectado: 145-7201 | Esperado: A4S-720 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806796_0.91_(44, 92, 3)_Z70-399.jpg | Detectado: 270-309 | Esperado: Z70-399 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806835_0.9_(50, 100, 3)_D7W-870.jpg | Detectado:  | Esperado: D7W-870 | Tiempo: 0.0507s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806839_0.91_(53, 104, 3)_Z2P-320.jpg | Detectado:  | Esperado: Z2P-320 | Tiempo: 0.0545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806845_0.91_(44, 98, 3)_A3C-786.jpg | Detectado: 135790 | Esperado: A3C-786 | Tiempo: 0.0557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806849_0.92_(49, 98, 3)_Z7P-354.jpg | Detectado:  | Esperado: Z7P-354 | Tiempo: 0.0502s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806852_0.91_(66, 114, 3)_VBA-422.jpg | Detectado:  | Esperado: VBA-422 | Tiempo: 0.0507s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806868_0.9_(46, 91, 3)_ACL-585.jpg | Detectado: ACL-585 | Esperado: ACL-585 | Tiempo: 0.0535s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755806984_0.9_(45, 92, 3)_Z5Z-532.jpg | Detectado:  | Esperado: Z5Z-532 | Tiempo: 0.0553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807008_0.91_(44, 97, 3)_BEP-534.jpg | Detectado:  | Esperado: BEP-534 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807086_0.91_(45, 90, 3)_Z4Y-618.jpg | Detectado:  | Esperado: Z4Y-618 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807186_0.9_(47, 95, 3)_Z7M-595.jpg | Detectado: 774-595 | Esperado: Z7M-595 | Tiempo: 0.0561s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807199_0.9_(46, 102, 3)_A5U-739.jpg | Detectado:  | Esperado: A5U-739 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807204_0.9_(43, 89, 3)_M4B-467.jpg | Detectado:  | Esperado: M4B-467 | Tiempo: 0.0499s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807211_0.9_(44, 96, 3)_BEP-534.jpg | Detectado:  | Esperado: BEP-534 | Tiempo: 0.0505s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807470_0.91_(141, 148, 3)_A5U-739.jpg | Detectado: 5 | Esperado: A5U-739 | Tiempo: 0.0567s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807617_0.9_(56, 111, 3)_45K-770.jpg | Detectado: 454-770 | Esperado: 45K-770 | Tiempo: 0.0553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807852_0.91_(53, 108, 3)_Z6W-329.jpg | Detectado:  | Esperado: Z6W-329 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807884_0.9_(52, 101, 3)_Z2Q-021.jpg | Detectado: 70-021 | Esperado: Z2Q-021 | Tiempo: 0.0534s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807907_0.9_(52, 99, 3)_C6M-147.jpg | Detectado:  | Esperado: C6M-147 | Tiempo: 0.0515s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808117_0.9_(49, 100, 3)_Z1I-540.jpg | Detectado:  | Esperado: Z1I-540 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808131_0.92_(45, 93, 3)_ANG-059.jpg | Detectado:  | Esperado: ANG-059 | Tiempo: 0.0510s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808144_0.9_(46, 94, 3)_Z2Q-021.jpg | Detectado: 770-021 | Esperado: Z2Q-021 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808175_0.91_(44, 89, 3)_F8Q-278.jpg | Detectado:  | Esperado: F8Q-278 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808300_0.9_(46, 91, 3)_AK1-784.jpg | Detectado:  | Esperado: AK1-784 | Tiempo: 0.0583s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808414_0.9_(59, 111, 3)_F8Q-278.jpg | Detectado:  | Esperado: F8Q-278 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808461_0.91_(62, 116, 3)_CBA-659.jpg | Detectado: 84-659 | Esperado: CBA-659 | Tiempo: 0.0560s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808464_0.9_(50, 104, 3)_BUY-632.jpg | Detectado:  | Esperado: BUY-632 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808477_0.91_(46, 95, 3)_BHB-015.jpg | Detectado:  | Esperado: BHB-015 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808763_0.9_(54, 105, 3)_V5B-631.jpg | Detectado: 158-631 | Esperado: V5B-631 | Tiempo: 0.0580s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808937_0.91_(46, 96, 3)_V8Y-171.jpg | Detectado:  | Esperado: V8Y-171 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808962_0.9_(46, 91, 3)_Z1T-535.jpg | Detectado:  | Esperado: Z1T-535 | Tiempo: 0.0549s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809021_0.9_(53, 108, 3)_Z40-588.jpg | Detectado: 740-588 | Esperado: Z40-588 | Tiempo: 0.0558s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809037_0.9_(61, 113, 3)_Z2N-738.jpg | Detectado:  | Esperado: Z2N-738 | Tiempo: 0.0511s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809250_0.9_(51, 99, 3)_S1B-772.jpg | Detectado:  | Esperado: S1B-772 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809492_0.9_(38, 97, 3)_S1B-772.jpg | Detectado:  | Esperado: S1B-772 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809743_0.9_(47, 93, 3)_Z11-272.jpg | Detectado:  | Esperado: Z11-272 | Tiempo: 0.0534s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809784_0.91_(49, 100, 3)_Z7B-669.jpg | Detectado:  | Esperado: Z7B-669 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809796_0.91_(121, 126, 3)_Z1J-781.jpg | Detectado: W | Esperado: Z1J-781 | Tiempo: 0.0548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809798_0.91_(46, 99, 3)_BXU-498.jpg | Detectado: BXU-498 | Esperado: BXU-498 | Tiempo: 0.0555s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755810071_0.9_(47, 99, 3)_F1N-370.jpg | Detectado: FAN-370 | Esperado: F1N-370 | Tiempo: 0.0543s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810077_0.9_(46, 97, 3)_Z6V-660.jpg | Detectado: 768-660 | Esperado: Z6V-660 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810245_0.9_(48, 95, 3)_BJU-400.jpg | Detectado: 80-400 | Esperado: BJU-400 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810246_0.9_(52, 98, 3)_BJL-400.jpg | Detectado:  | Esperado: BJL-400 | Tiempo: 0.0512s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810458_0.91_(50, 91, 3)_A2H-716.jpg | Detectado: 74-110 | Esperado: A2H-716 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810751_0.91_(42, 93, 3)_BKQ-659.jpg | Detectado:  | Esperado: BKQ-659 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810833_0.9_(40, 90, 3)_Z5D-490.jpg | Detectado:  | Esperado: Z5D-490 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810848_0.9_(64, 109, 3)_AJV-939.jpg | Detectado:  | Esperado: AJV-939 | Tiempo: 0.0559s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810946_0.91_(51, 99, 3)_Z5H-549.jpg | Detectado:  | Esperado: Z5H-549 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811078_0.9_(49, 99, 3)_D1I-153.jpg | Detectado:  | Esperado: D1I-153 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811276_0.91_(45, 97, 3)_Z1H-700.jpg | Detectado: 718-700 | Esperado: Z1H-700 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811522_0.9_(46, 93, 3)_Z5D-172.jpg | Detectado:  | Esperado: Z5D-172 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811526_0.91_(45, 93, 3)_Z1H-700.jpg | Detectado: 714-700 | Esperado: Z1H-700 | Tiempo: 0.0564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812430_0.9_(63, 118, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812435_0.9_(56, 114, 3)_ASD-757.jpg | Detectado:  | Esperado: ASD-757 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812550_0.91_(55, 108, 3)_Z2Q-310.jpg | Detectado: 229-310 | Esperado: Z2Q-310 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812560_0.9_(47, 95, 3)_F9L-089.jpg | Detectado:  | Esperado: F9L-089 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812695_0.9_(48, 96, 3)_D9E-887.jpg | Detectado:  | Esperado: D9E-887 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755813815_0.9_(44, 89, 3)_A1X-403.jpg | Detectado:  | Esperado: A1X-403 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755819341_0.9_(51, 109, 3)_D2E-683.jpg | Detectado:  | Esperado: D2E-683 | Tiempo: 0.0512s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755819352_0.91_(49, 108, 3)_D2E-683.jpg | Detectado:  | Esperado: D2E-683 | Tiempo: 0.0553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755862816_0.9_(48, 104, 3)_Z3V-720.jpg | Detectado:  | Esperado: Z3V-720 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755862951_0.9_(43, 96, 3)_A5K-770.jpg | Detectado: 115K-770 | Esperado: A5K-770 | Tiempo: 0.0605s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863223_0.9_(45, 94, 3)_BBP-662.jpg | Detectado: PAP-662 | Esperado: BBP-662 | Tiempo: 0.0561s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863519_0.9_(46, 102, 3)_AOT-720.jpg | Detectado: 101-720 | Esperado: AOT-720 | Tiempo: 0.0550s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863582_0.9_(50, 94, 3)_Z1D-784.jpg | Detectado:  | Esperado: Z1D-784 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863701_0.91_(55, 111, 3)_Z1J-781.jpg | Detectado:  | Esperado: Z1J-781 | Tiempo: 0.0540s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863861_0.9_(50, 98, 3)_X2Z-199.jpg | Detectado:  | Esperado: X2Z-199 | Tiempo: 0.0573s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863881_0.9_(50, 100, 3)_X3J-746.jpg | Detectado: N3J-146 | Esperado: X3J-746 | Tiempo: 0.0567s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863927_0.91_(46, 96, 3)_71H-700.jpg | Detectado: 714-700 | Esperado: 71H-700 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863928_0.91_(47, 99, 3)_Z1H-700.jpg | Detectado: 714-700 | Esperado: Z1H-700 | Tiempo: 0.0552s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864056_0.9_(44, 94, 3)_BUX-273.jpg | Detectado:  | Esperado: BUX-273 | Tiempo: 0.0558s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864122_0.9_(46, 92, 3)_77U-013.jpg | Detectado:  | Esperado: 77U-013 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864123_0.9_(53, 104, 3)_Z7U-013.jpg | Detectado:  | Esperado: Z7U-013 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864190_0.9_(47, 98, 3)_Z5V-823.jpg | Detectado:  | Esperado: Z5V-823 | Tiempo: 0.0507s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864196_0.9_(51, 99, 3)_X4L-304.jpg | Detectado:  | Esperado: X4L-304 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864262_0.91_(57, 109, 3)_Z7S-597.jpg | Detectado: 275597 | Esperado: Z7S-597 | Tiempo: 0.0574s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864280_0.91_(47, 95, 3)_Z5Y-572.jpg | Detectado:  | Esperado: Z5Y-572 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864463_0.91_(49, 99, 3)_Z6K-411.jpg | Detectado:  | Esperado: Z6K-411 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864488_0.9_(57, 104, 3)_Z8C-206.jpg | Detectado:  | Esperado: Z8C-206 | Tiempo: 0.0507s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864599_0.9_(58, 110, 3)_V7B-442.jpg | Detectado:  | Esperado: V7B-442 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864637_0.91_(48, 94, 3)_81B-734.jpg | Detectado:  | Esperado: 81B-734 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864638_0.91_(60, 109, 3)_B18-734.jpg | Detectado:  | Esperado: B18-734 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864638_0.9_(57, 101, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864701_0.9_(53, 106, 3)_V4R-602.jpg | Detectado:  | Esperado: V4R-602 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864720_0.9_(47, 94, 3)_Z6A-087.jpg | Detectado: 764-097 | Esperado: Z6A-087 | Tiempo: 0.0548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755865999_0.9_(52, 101, 3)_Z7U-013.jpg | Detectado:  | Esperado: Z7U-013 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866023_0.9_(48, 103, 3)_Z7X-877.jpg | Detectado: Z7K-877 | Esperado: Z7X-877 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866028_0.9_(47, 96, 3)_Z3P-398.jpg | Detectado:  | Esperado: Z3P-398 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866032_0.91_(52, 108, 3)_Z6X-220.jpg | Detectado:  | Esperado: Z6X-220 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866167_0.9_(49, 100, 3)_Z2M-424.jpg | Detectado:  | Esperado: Z2M-424 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866170_0.9_(46, 92, 3)_BHP-297.jpg | Detectado:  | Esperado: BHP-297 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866191_0.9_(48, 98, 3)_BKQ-659.jpg | Detectado:  | Esperado: BKQ-659 | Tiempo: 0.0570s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866271_0.9_(45, 98, 3)_Z3P-791.jpg | Detectado:  | Esperado: Z3P-791 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866274_0.9_(52, 105, 3)_Z5U-453.jpg | Detectado: L5U- | Esperado: Z5U-453 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866275_0.9_(66, 112, 3)_Z5L-453.jpg | Detectado:  | Esperado: Z5L-453 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866307_0.91_(48, 96, 3)_Z50-343.jpg | Detectado:  | Esperado: Z50-343 | Tiempo: 0.0509s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866307_0.91_(56, 105, 3)_750-343.jpg | Detectado:  | Esperado: 750-343 | Tiempo: 0.0511s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866333_0.9_(56, 104, 3)_APH-716.jpg | Detectado:  | Esperado: APH-716 | Tiempo: 0.0539s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866336_0.91_(46, 98, 3)_V8V-084.jpg | Detectado: 8V-084 | Esperado: V8V-084 | Tiempo: 0.0586s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866431_0.91_(53, 107, 3)_COG-679.jpg | Detectado: C06-679 | Esperado: COG-679 | Tiempo: 0.0573s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866477_0.9_(50, 100, 3)_APF-394.jpg | Detectado:  | Esperado: APF-394 | Tiempo: 0.0555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866484_0.9_(50, 104, 3)_Z3T-663.jpg | Detectado:  | Esperado: Z3T-663 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866521_0.92_(46, 94, 3)_75C-592.jpg | Detectado:  | Esperado: 75C-592 | Tiempo: 0.0549s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866566_0.9_(64, 110, 3)_Y3F-143.jpg | Detectado: 14 | Esperado: Y3F-143 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866603_0.9_(46, 95, 3)_X1J-790.jpg | Detectado:  | Esperado: X1J-790 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866681_0.91_(48, 93, 3)_Z3P-326.jpg | Detectado:  | Esperado: Z3P-326 | Tiempo: 0.0564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866685_0.9_(48, 96, 3)_Z6F-642.jpg | Detectado:  | Esperado: Z6F-642 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866688_0.91_(55, 109, 3)_V6M-925.jpg | Detectado:  | Esperado: V6M-925 | Tiempo: 0.0532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866691_0.91_(42, 96, 3)_X5J-730.jpg | Detectado:  | Esperado: X5J-730 | Tiempo: 0.0553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866701_0.91_(51, 100, 3)_Z5D-490.jpg | Detectado:  | Esperado: Z5D-490 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866708_0.9_(47, 95, 3)_Z7T-469.jpg | Detectado: 771-469 | Esperado: Z7T-469 | Tiempo: 0.0572s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866735_0.9_(46, 95, 3)_Z5Q-767.jpg | Detectado:  | Esperado: Z5Q-767 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866769_0.9_(45, 97, 3)_Z7W-135.jpg | Detectado: 274-135 | Esperado: Z7W-135 | Tiempo: 0.0566s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866846_0.91_(61, 109, 3)_AMO-819.jpg | Detectado: 10-619 | Esperado: AMO-819 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866848_0.9_(47, 97, 3)_VCA-701.jpg | Detectado: 14CA-701 | Esperado: VCA-701 | Tiempo: 0.0532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866863_0.91_(48, 97, 3)_Z3E-444.jpg | Detectado:  | Esperado: Z3E-444 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866869_0.9_(49, 99, 3)_AUM-201.jpg | Detectado: AUN-201 | Esperado: AUM-201 | Tiempo: 0.0541s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866962_0.9_(59, 110, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.0504s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866976_0.9_(52, 108, 3)_B2U-796.jpg | Detectado:  | Esperado: B2U-796 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867013_0.9_(51, 99, 3)_BRV-568.jpg | Detectado:  | Esperado: BRV-568 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867016_0.9_(47, 100, 3)_VOX-966.jpg | Detectado: Y0Y-966 | Esperado: VOX-966 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867062_0.9_(58, 110, 3)_Z7W-006.jpg | Detectado:  | Esperado: Z7W-006 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867068_0.9_(46, 108, 3)_C8U-187.jpg | Detectado:  | Esperado: C8U-187 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867099_0.9_(52, 102, 3)_A5Z-645.jpg | Detectado:  | Esperado: A5Z-645 | Tiempo: 0.0541s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867103_0.9_(45, 90, 3)_ERA-728.jpg | Detectado:  | Esperado: ERA-728 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867108_0.9_(46, 94, 3)_V9Q-064.jpg | Detectado: 190-064 | Esperado: V9Q-064 | Tiempo: 0.0545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867109_0.9_(55, 105, 3)_19Q-064.jpg | Detectado:  | Esperado: 19Q-064 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867134_0.9_(64, 108, 3)_ABA-734.jpg | Detectado: 18734 | Esperado: ABA-734 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867157_0.9_(52, 103, 3)_Y3A-006.jpg | Detectado:  | Esperado: Y3A-006 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867182_0.9_(47, 92, 3)_Z6D-275.jpg | Detectado: 760-273 | Esperado: Z6D-275 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867230_0.91_(55, 108, 3)_Z5F-631.jpg | Detectado:  | Esperado: Z5F-631 | Tiempo: 0.0503s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867236_0.91_(49, 97, 3)_Z7C-220.jpg | Detectado:  | Esperado: Z7C-220 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867248_0.91_(109, 119, 3)_Z5J-714.jpg | Detectado: 51 | Esperado: Z5J-714 | Tiempo: 0.0534s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867315_0.91_(51, 98, 3)_F5H-768.jpg | Detectado:  | Esperado: F5H-768 | Tiempo: 0.0503s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867382_0.9_(64, 116, 3)_BDM-402.jpg | Detectado:  | Esperado: BDM-402 | Tiempo: 0.0511s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867393_0.9_(49, 95, 3)_VDY-836.jpg | Detectado:  | Esperado: VDY-836 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867401_0.9_(53, 103, 3)_BYW-137.jpg | Detectado:  | Esperado: BYW-137 | Tiempo: 0.0587s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867409_0.91_(50, 96, 3)_Y2C-212.jpg | Detectado:  | Esperado: Y2C-212 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867414_0.91_(55, 107, 3)_X50-334.jpg | Detectado:  | Esperado: X50-334 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867417_0.91_(57, 112, 3)_Z4X-252.jpg | Detectado: 744-252 | Esperado: Z4X-252 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867476_0.91_(47, 97, 3)_B71-205.jpg | Detectado:  | Esperado: B71-205 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867500_0.9_(48, 110, 3)_A8D-764.jpg | Detectado: 480-764 | Esperado: A8D-764 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867507_0.9_(54, 108, 3)_BLK-359.jpg | Detectado:  | Esperado: BLK-359 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867579_0.9_(55, 111, 3)_Z5Z-557.jpg | Detectado:  | Esperado: Z5Z-557 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867603_0.9_(46, 108, 3)_A4M-799.jpg | Detectado: 144-799 | Esperado: A4M-799 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867626_0.9_(51, 99, 3)_BEX-018.jpg | Detectado:  | Esperado: BEX-018 | Tiempo: 0.0510s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867644_0.9_(51, 92, 3)_VDS-785.jpg | Detectado: 1UDS-783 | Esperado: VDS-785 | Tiempo: 0.0569s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867691_0.9_(66, 116, 3)_Z5X-789.jpg | Detectado: 751-789 | Esperado: Z5X-789 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867708_0.91_(47, 94, 3)_Z3V-367.jpg | Detectado:  | Esperado: Z3V-367 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867716_0.9_(48, 95, 3)_Z4J-227.jpg | Detectado:  | Esperado: Z4J-227 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867723_0.91_(51, 100, 3)_BYU-726.jpg | Detectado:  | Esperado: BYU-726 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867725_0.91_(51, 109, 3)_V8J-173.jpg | Detectado:  | Esperado: V8J-173 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867745_0.91_(53, 101, 3)_Z6B-834.jpg | Detectado: 170P-834 | Esperado: Z6B-834 | Tiempo: 0.0538s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867762_0.9_(50, 102, 3)_Z3J-707.jpg | Detectado: 1733-70 | Esperado: Z3J-707 | Tiempo: 0.0568s | Precisión: 0.0% | ❌ Incorrecto
# ...
# Procesado: 1755868134_0.92_(48, 98, 3)_X3F-317.jpg | Detectado:  | Esperado: X3F-317 | Tiempo: 0.0552s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868141_0.9_(58, 111, 3)_Z3J-707.jpg | Detectado: 1737707 | Esperado: Z3J-707 | Tiempo: 0.0549s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868148_0.9_(60, 106, 3)_X3H-030.jpg | Detectado:  | Esperado: X3H-030 | Tiempo: 0.0517s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868151_0.9_(47, 95, 3)_Z7J-697.jpg | Detectado:  | Esperado: Z7J-697 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868156_0.9_(49, 92, 3)_AYJ-561.jpg | Detectado:  | Esperado: AYJ-561 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868158_0.92_(55, 98, 3)_4YJ-561.jpg | Detectado:  | Esperado: 4YJ-561 | Tiempo: 0.0559s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868169_0.91_(64, 112, 3)_S1B-772.jpg | Detectado:  | Esperado: S1B-772 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868213_0.9_(47, 100, 3)_A5E-785.jpg | Detectado:  | Esperado: A5E-785 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868214_0.91_(50, 106, 3)_45E-785.jpg | Detectado: 15-78 | Esperado: 45E-785 | Tiempo: 0.0545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868233_0.9_(51, 109, 3)_Z6E-393.jpg | Detectado:  | Esperado: Z6E-393 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868237_0.9_(63, 115, 3)_V1H-723.jpg | Detectado:  | Esperado: V1H-723 | Tiempo: 0.0539s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868252_0.9_(49, 98, 3)_V5B-631.jpg | Detectado: 158-031 | Esperado: V5B-631 | Tiempo: 0.0532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868316_0.9_(56, 111, 3)_FOB-739.jpg | Detectado: 08-739 | Esperado: FOB-739 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868367_0.9_(57, 105, 3)_Z4Q-197.jpg | Detectado:  | Esperado: Z4Q-197 | Tiempo: 0.0502s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868377_0.91_(52, 105, 3)_Z7U-204.jpg | Detectado: 770-204 | Esperado: Z7U-204 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868390_0.9_(59, 110, 3)_A7V-766.jpg | Detectado:  | Esperado: A7V-766 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868410_0.9_(47, 98, 3)_Z3C-760.jpg | Detectado:  | Esperado: Z3C-760 | Tiempo: 0.0505s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868462_0.9_(51, 102, 3)_V9N-697.jpg | Detectado:  | Esperado: V9N-697 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868467_0.91_(46, 93, 3)_V8B-614.jpg | Detectado:  | Esperado: V8B-614 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868503_0.91_(50, 98, 3)_Z6L-717.jpg | Detectado:  | Esperado: Z6L-717 | Tiempo: 0.0535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868523_0.9_(53, 105, 3)_Z7Z-085.jpg | Detectado:  | Esperado: Z7Z-085 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868553_0.9_(51, 109, 3)_B2U-796.jpg | Detectado: 8-7 9 Y | Esperado: B2U-796 | Tiempo: 0.0562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868571_0.91_(48, 96, 3)_BRT-304.jpg | Detectado:  | Esperado: BRT-304 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868575_0.91_(61, 110, 3)_ATO-102.jpg | Detectado: A70-102 | Esperado: ATO-102 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868621_0.9_(56, 104, 3)_BBW-631.jpg | Detectado:  | Esperado: BBW-631 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868632_0.91_(44, 95, 3)_A9C-789.jpg | Detectado:  | Esperado: A9C-789 | Tiempo: 0.0575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868683_0.9_(51, 101, 3)_Z3C-760.jpg | Detectado:  | Esperado: Z3C-760 | Tiempo: 0.0586s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868729_0.91_(51, 97, 3)_ICQ-067.jpg | Detectado:  | Esperado: ICQ-067 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868766_0.9_(51, 102, 3)_AYA-568.jpg | Detectado:  | Esperado: AYA-568 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868769_0.9_(57, 106, 3)_AZH-270.jpg | Detectado:  | Esperado: AZH-270 | Tiempo: 0.0518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868815_0.9_(51, 114, 3)_B30-733.jpg | Detectado:  | Esperado: B30-733 | Tiempo: 0.0512s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868871_0.91_(48, 97, 3)_Z7X-303.jpg | Detectado:  | Esperado: Z7X-303 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868919_0.9_(51, 100, 3)_Z4G-081.jpg | Detectado:  | Esperado: Z4G-081 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868921_0.91_(61, 107, 3)_X3Y-506.jpg | Detectado: 31-506 | Esperado: X3Y-506 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868990_0.9_(48, 98, 3)_Z3W-660.jpg | Detectado: 730-060 | Esperado: Z3W-660 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869368_0.9_(59, 107, 3)_X3R-360.jpg | Detectado:  | Esperado: X3R-360 | Tiempo: 0.0515s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869377_0.9_(48, 93, 3)_D2R-594.jpg | Detectado: 07A-594 | Esperado: D2R-594 | Tiempo: 0.0546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869386_0.9_(49, 97, 3)_V7C-801.jpg | Detectado:  | Esperado: V7C-801 | Tiempo: 0.0509s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869394_0.9_(47, 96, 3)_Z5B-649.jpg | Detectado:  | Esperado: Z5B-649 | Tiempo: 0.0528s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869505_0.9_(126, 134, 3)_N2X-710.jpg | Detectado: SET | Esperado: N2X-710 | Tiempo: 0.0646s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869536_0.91_(52, 103, 3)_Z8S-813.jpg | Detectado:  | Esperado: Z8S-813 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869570_0.9_(51, 107, 3)_Z4Q-021.jpg | Detectado:  | Esperado: Z4Q-021 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869582_0.91_(65, 116, 3)_Z8M-738.jpg | Detectado: 784-738 | Esperado: Z8M-738 | Tiempo: 0.0576s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869632_0.9_(63, 114, 3)_Z5F-558.jpg | Detectado: 756-558 | Esperado: Z5F-558 | Tiempo: 0.0557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869679_0.9_(63, 113, 3)_V7C-801.jpg | Detectado:  | Esperado: V7C-801 | Tiempo: 0.0526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869713_0.9_(60, 112, 3)_APF-394.jpg | Detectado:  | Esperado: APF-394 | Tiempo: 0.0562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870055_0.9_(48, 97, 3)_B2C-509.jpg | Detectado:  | Esperado: B2C-509 | Tiempo: 0.0555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870085_0.9_(45, 94, 3)_Z7J-462.jpg | Detectado:  | Esperado: Z7J-462 | Tiempo: 0.0519s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870135_0.9_(51, 104, 3)_Z4T-372.jpg | Detectado:  | Esperado: Z4T-372 | Tiempo: 0.0512s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870154_0.91_(48, 105, 3)_Y1L-742.jpg | Detectado:  | Esperado: Y1L-742 | Tiempo: 0.0518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870168_0.9_(54, 99, 3)_130-397.jpg | Detectado: 130-307 | Esperado: 130-397 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870182_0.9_(47, 96, 3)_Z5T-688.jpg | Detectado: 751-688 | Esperado: Z5T-688 | Tiempo: 0.0572s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870240_0.9_(58, 108, 3)_Z6K-411.jpg | Detectado:  | Esperado: Z6K-411 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870251_0.91_(48, 97, 3)_45K-770.jpg | Detectado: 145K-770 | Esperado: 45K-770 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870281_0.9_(60, 105, 3)_V4F-244.jpg | Detectado: VAE-244 | Esperado: V4F-244 | Tiempo: 0.0569s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870289_0.91_(47, 92, 3)_Z7C-049.jpg | Detectado:  | Esperado: Z7C-049 | Tiempo: 0.0565s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870393_0.9_(50, 107, 3)_Y1L-742.jpg | Detectado:  | Esperado: Y1L-742 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870444_0.91_(48, 97, 3)_ACL-585.jpg | Detectado: ACL-585 | Esperado: ACL-585 | Tiempo: 0.0592s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755870523_0.91_(50, 102, 3)_Z51-804.jpg | Detectado: 751-804 | Esperado: Z51-804 | Tiempo: 0.0532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870633_0.9_(49, 99, 3)_Z8C-747.jpg | Detectado: 780-747 | Esperado: Z8C-747 | Tiempo: 0.0557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870662_0.91_(48, 96, 3)_AOT-720.jpg | Detectado: 01-720 | Esperado: AOT-720 | Tiempo: 0.0549s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870687_0.91_(67, 124, 3)_CDL-482.jpg | Detectado:  | Esperado: CDL-482 | Tiempo: 0.0514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870769_0.9_(49, 99, 3)_Z7W-377.jpg | Detectado:  | Esperado: Z7W-377 | Tiempo: 0.0515s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870783_0.9_(48, 98, 3)_Z8C-206.jpg | Detectado:  | Esperado: Z8C-206 | Tiempo: 0.0575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870785_0.9_(119, 121, 3)_L8C-206.jpg | Detectado: SES | Esperado: L8C-206 | Tiempo: 0.0604s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870826_0.9_(52, 102, 3)_V6M-597.jpg | Detectado:  | Esperado: V6M-597 | Tiempo: 0.0536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870914_0.9_(47, 99, 3)_AOT-720.jpg | Detectado: 01-220 | Esperado: AOT-720 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871079_0.9_(62, 114, 3)_Z4J-763.jpg | Detectado: 74763 | Esperado: Z4J-763 | Tiempo: 0.0551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871103_0.9_(59, 110, 3)_S1B-589.jpg | Detectado:  | Esperado: S1B-589 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871108_0.9_(52, 112, 3)_Z1J-781.jpg | Detectado:  | Esperado: Z1J-781 | Tiempo: 0.0513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871139_0.9_(50, 96, 3)_BSV-176.jpg | Detectado:  | Esperado: BSV-176 | Tiempo: 0.0529s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871157_0.92_(130, 134, 3)_L2N-738.jpg | Detectado: Y | Esperado: L2N-738 | Tiempo: 0.0538s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871316_0.9_(51, 102, 3)_Z7M-111.jpg | Detectado:  | Esperado: Z7M-111 | Tiempo: 0.0523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871358_0.9_(48, 96, 3)_CRO-577.jpg | Detectado:  | Esperado: CRO-577 | Tiempo: 0.0512s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871447_0.9_(48, 101, 3)_V5S-570.jpg | Detectado:  | Esperado: V5S-570 | Tiempo: 0.0527s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871461_0.9_(46, 96, 3)_APF-394.jpg | Detectado:  | Esperado: APF-394 | Tiempo: 0.0524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871611_0.91_(57, 104, 3)_Z5V-413.jpg | Detectado:  | Esperado: Z5V-413 | Tiempo: 0.0538s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871634_0.9_(60, 108, 3)_V8J-069.jpg | Detectado:  | Esperado: V8J-069 | Tiempo: 0.0575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871753_0.91_(60, 106, 3)_Z5L-091.jpg | Detectado: 751-091 | Esperado: Z5L-091 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871801_0.9_(47, 93, 3)_Z7S-679.jpg | Detectado: 175-679 | Esperado: Z7S-679 | Tiempo: 0.0555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871807_0.9_(48, 99, 3)_Z8A-540.jpg | Detectado:  | Esperado: Z8A-540 | Tiempo: 0.0564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871813_0.9_(63, 107, 3)_Z5D-490.jpg | Detectado: 751-490 | Esperado: Z5D-490 | Tiempo: 0.0581s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871836_0.9_(58, 116, 3)_V3C-453.jpg | Detectado:  | Esperado: V3C-453 | Tiempo: 0.0544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871886_0.9_(50, 104, 3)_Z6D-367.jpg | Detectado:  | Esperado: Z6D-367 | Tiempo: 0.0675s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871920_0.91_(63, 106, 3)_ASN-544.jpg | Detectado:  | Esperado: ASN-544 | Tiempo: 0.0516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871984_0.91_(49, 95, 3)_Z7L-650.jpg | Detectado:  | Esperado: Z7L-650 | Tiempo: 0.0508s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872015_0.9_(61, 112, 3)_Z5D-360.jpg | Detectado: 750-360 | Esperado: Z5D-360 | Tiempo: 0.0528s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872070_0.9_(52, 103, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0515s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872110_0.9_(51, 96, 3)_VOT-812.jpg | Detectado:  | Esperado: VOT-812 | Tiempo: 0.0543s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872180_0.9_(48, 98, 3)_A9K-715.jpg | Detectado:  | Esperado: A9K-715 | Tiempo: 0.0522s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872284_0.91_(145, 146, 3)_L10-760.jpg | Detectado: Q | Esperado: L10-760 | Tiempo: 0.0530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872299_0.9_(54, 103, 3)_Z5G-467.jpg | Detectado:  | Esperado: Z5G-467 | Tiempo: 0.0561s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872312_0.9_(50, 97, 3)_Z7X-826.jpg | Detectado:  | Esperado: Z7X-826 | Tiempo: 0.0578s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872398_0.9_(49, 101, 3)_F3F-041.jpg | Detectado:  | Esperado: F3F-041 | Tiempo: 0.0525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872405_0.91_(59, 107, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.0575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872417_0.9_(49, 93, 3)_B31-104.jpg | Detectado: 831-104 | Esperado: B31-104 | Tiempo: 0.0575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872482_0.9_(58, 109, 3)_CJS-373.jpg | Detectado:  | Esperado: CJS-373 | Tiempo: 0.0553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872541_0.9_(123, 137, 3)_L10-760.jpg | Detectado: Q | Esperado: L10-760 | Tiempo: 0.0620s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872551_0.9_(50, 98, 3)_Z7V-417.jpg | Detectado:  | Esperado: Z7V-417 | Tiempo: 0.0586s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872552_0.91_(62, 109, 3)_77V-417.jpg | Detectado:  | Esperado: 77V-417 | Tiempo: 0.0609s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872559_0.9_(46, 103, 3)_74K-739.jpg | Detectado:  | Esperado: 74K-739 | Tiempo: 0.0547s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872559_0.9_(52, 107, 3)_Z4K-739.jpg | Detectado:  | Esperado: Z4K-739 | Tiempo: 0.0533s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872606_0.91_(48, 99, 3)_CRO-577.jpg | Detectado:  | Esperado: CRO-577 | Tiempo: 0.0548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872752_0.9_(51, 96, 3)_BKZ-705.jpg | Detectado:  | Esperado: BKZ-705 | Tiempo: 0.0531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872828_0.9_(49, 94, 3)_Z2Q-310.jpg | Detectado:  | Esperado: Z2Q-310 | Tiempo: 0.0520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872884_0.9_(51, 103, 3)_V1T-101.jpg | Detectado: 411-101 | Esperado: V1T-101 | Tiempo: 0.0581s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872968_0.91_(50, 96, 3)_C1A-878.jpg | Detectado: C44-878 | Esperado: C1A-878 | Tiempo: 0.0540s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873119_0.91_(46, 95, 3)_42E-705.jpg | Detectado: 1265709 | Esperado: 42E-705 | Tiempo: 0.0566s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873369_0.9_(56, 100, 3)_AFG-023.jpg | Detectado: AFG-023 | Esperado: AFG-023 | Tiempo: 0.0561s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755873449_0.9_(55, 105, 3)_Z5G-139.jpg | Detectado:  | Esperado: Z5G-139 | Tiempo: 0.0521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873458_0.91_(51, 98, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.0542s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873467_0.9_(59, 112, 3)_BHB-015.jpg | Detectado:  | Esperado: BHB-015 | Tiempo: 0.0537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873478_0.9_(47, 98, 3)_42E-705.jpg | Detectado: 176709 | Esperado: 42E-705 | Tiempo: 0.0619s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873578_0.9_(56, 108, 3)_Z5X-789.jpg | Detectado: 754-789 | Esperado: Z5X-789 | Tiempo: 0.0577s | Precisión: 0.0% | ❌ Incorrecto
#
# ✅ Resultados guardados en: resultados_tesseractOCR/resultados_tesseractocr.csv
# 📊 Resumen: 6/500 correctos (1.2%)
# ⏱️  Tiempo total: 27.0465s | Tiempo promedio: 0.0541s

# %% [markdown]
# ## PaddleOCR

# %% [markdown]
# ### Instalacion de PaddleOCR

# %%
# !pip install paddleocr

# %% [markdown]
# ### Comprobar version de PaddleOCR

# %%
# !pip show paddleocr
# Out:
# Name: paddleocr
# Version: 3.2.0
# Summary: Awesome multilingual OCR and document parsing toolkits based on PaddlePaddle
# Home-page: https://github.com/PaddlePaddle/PaddleOCR
# Author:
# Author-email: PaddlePaddle <Paddle-better@baidu.com>
# License: Apache License 2.0
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/torch2/lib/python3.10/site-packages
# Requires: paddlex, PyYAML, typing-extensions
# Required-by:

# %% [markdown]
# ### Probar con una imagen PaddleOCR (presicion y tiempo de inferencia)

# %%
from paddleocr import PaddleOCR
import time
import warnings
import os
import re

# Suprimir warnings y mensajes de info
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Configuración
image_path = 'dataset/1755800317_0.9_(45, 93, 3)_VAJ-632.jpg'

# Extraer texto esperado del nombre del archivo
filename = os.path.basename(image_path)
match = re.search(r'_([A-Z0-9-]+)\.(jpg|jpeg|png|bmp)$', filename, re.IGNORECASE)
expected_text = match.group(1) if match else "UNKNOWN"

# Inicializar PaddleOCR (sin show_log)
ocr = PaddleOCR(lang="es", use_angle_cls=True)

# Realizar OCR y medir tiempo
start_time = time.time()
resultados = ocr.ocr(image_path)
inference_time = time.time() - start_time

# Extraer textos detectados
detected_texts = []

for bloque in resultados:
    for texto, confianza in zip(bloque['rec_texts'], bloque['rec_scores']):
        detected_texts.append(texto)

valid_detections = [text for text in detected_texts]
detected_text = valid_detections[0] if valid_detections else ""

# Calcular precisión
precision = 100.0 if expected_text.lower() == detected_text.lower() else 0.0
resultado = "✅ Correcto" if precision == 100.0 else "❌ Incorrecto"

# Mostrar resultados en tabla
print("\n" + "=" * 120)
print("RESULTADOS PaddleOCR")
print("=" * 120)
print(f"{'Imagen':<45} | {'Texto Detectado':<15} | {'Texto Esperado':<15} | {'Tiempo (s)':<12} | {'Precisión':<10} | {'Resultado':<12}")
print("-" * 120)
print(f"{image_path:<45} | {detected_text:<15} | {expected_text:<15} | {inference_time:<12.4f} | {precision:<10.1f}% | {resultado:<12}")
print("=" * 120)
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-LCNet_x1_0_doc_ori`.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/UVDoc`.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-LCNet_x1_0_textline_ori`.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-OCRv5_server_det`.
# Creating model: ('latin_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/latin_PP-OCRv5_mobile_rec`.
# ========================================================================================================================
# RESULTADOS PaddleOCR
# ========================================================================================================================
# Imagen                                        | Texto Detectado | Texto Esperado  | Tiempo (s)   | Precisión  | Resultado
# ------------------------------------------------------------------------------------------------------------------------
# dataset/1755800317_0.9_(45, 93, 3)_VAJ-632.jpg | VAJ-632         | VAJ-632         | 0.3854       | 100.0     % | ✅ Correcto
# ========================================================================================================================

# %% [markdown]
# ### Probar con el dataset PaddleOCR (presicion y tiempo de inferencia)

# %%
from paddleocr import PaddleOCR
import time
import warnings
import os
import glob
import re
import csv

# Suprimir warnings y mensajes de info
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Configuración
dataset_path = 'dataset/'
image_extensions = ['*.jpg', '*.jpeg', '*.png', '*.bmp']
csv_filename = 'resultados_paddleOCR/resultados_paddleocr.csv'

# Crear carpeta de salida si no existe
os.makedirs('resultados_paddleOCR', exist_ok=True)

# Obtener todas las imágenes del dataset
image_files = []
for ext in image_extensions:
    image_files.extend(glob.glob(os.path.join(dataset_path, ext)))

print("Inicializando PaddleOCR...")
# Inicializar PaddleOCR
ocr = PaddleOCR(lang="es", use_angle_cls=True)
print(f"Total de imágenes a procesar: {len(image_files)}\n")

# Almacenar resultados
results_data = []
total_time = 0
correct_count = 0
total_images = len(image_files)

# Procesar cada imagen
for image_path in sorted(image_files):
    
    # Extraer el texto esperado del nombre del archivo
    filename = os.path.basename(image_path)
    match = re.search(r'_([A-Z0-9-]+)\.(jpg|jpeg|png|bmp)$', filename, re.IGNORECASE)
    expected_text = match.group(1) if match else "UNKNOWN"
    
    # Realizar OCR y medir tiempo
    start_time = time.time()
    resultados = ocr.ocr(image_path)
    inference_time = time.time() - start_time
    total_time += inference_time
    
    # Extraer textos detectados
    detected_texts = []
    for bloque in resultados:
        for texto, confianza in zip(bloque['rec_texts'], bloque['rec_scores']):
            detected_texts.append(texto)

    valid_detections = [text for text in detected_texts]
    detected_text = valid_detections[0] if valid_detections else ""
    
    # Calcular precisión
    precision = 100.0 if expected_text.lower() == detected_text.lower() else 0.0
    resultado = "✅ Correcto" if precision == 100.0 else "❌ Incorrecto"
    
    if precision == 100.0:
        correct_count += 1
    
    # Guardar resultado
    results_data.append({
        'Imagen': image_path,
        'Texto Detectado': detected_text,
        'Texto Esperado': expected_text,
        'Tiempo (s)': f"{inference_time:.4f}",
        'Precisión (%)': f"{precision:.1f}",
        'Resultado': resultado
    })
    
    print(f"Procesado: {filename} | Detectado: {detected_text} | Esperado: {expected_text} | Tiempo: {inference_time:.4f}s | Precisión: {precision:.1f}% | {resultado}")

# Guardar resultados en CSV
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Imagen', 'Texto Detectado', 'Texto Esperado', 'Tiempo (s)', 'Precisión (%)', 'Resultado']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    writer.writerows(results_data)
    
    # Agregar línea vacía
    writer.writerow({})
    
    # Agregar resumen final
    incorrect_count = total_images - correct_count
    writer.writerow({
        'Imagen': '=== RESUMEN FINAL ===',
        'Texto Detectado': '',
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Total de imágenes',
        'Texto Detectado': str(total_images),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Correctos',
        'Texto Detectado': str(correct_count),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': f"{(correct_count/total_images)*100:.1f}",
        'Resultado': '✅'
    })
    writer.writerow({
        'Imagen': 'Incorrectos',
        'Texto Detectado': str(incorrect_count),
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': f"{(incorrect_count/total_images)*100:.1f}",
        'Resultado': '❌'
    })
    writer.writerow({
        'Imagen': 'Tiempo total',
        'Texto Detectado': f"{total_time:.4f}s",
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })
    writer.writerow({
        'Imagen': 'Tiempo promedio',
        'Texto Detectado': f"{total_time/total_images:.4f}s",
        'Texto Esperado': '',
        'Tiempo (s)': '',
        'Precisión (%)': '',
        'Resultado': ''
    })

print(f"\n✅ Resultados guardados en: {csv_filename}")
print(f"📊 Resumen: {correct_count}/{total_images} correctos ({(correct_count/total_images)*100:.1f}%)")
print(f"⏱️  Tiempo total: {total_time:.4f}s | Tiempo promedio: {total_time/total_images:.4f}s")
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-LCNet_x1_0_doc_ori`.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/UVDoc`.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-LCNet_x1_0_textline_ori`.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/PP-OCRv5_server_det`.
# Creating model: ('latin_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/franspaxi/.paddlex/official_models/latin_PP-OCRv5_mobile_rec`.
# Inicializando PaddleOCR...
# Total de imágenes a procesar: 500
#
# Procesado: 1755800220_0.9_(48, 104, 3)_BYJ-567.jpg | Detectado: BYJ-56 | Esperado: BYJ-567 | Tiempo: 0.3641s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800225_0.91_(44, 95, 3)_V71-023.jpg | Detectado: V71-0 | Esperado: V71-023 | Tiempo: 0.2566s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800256_0.9_(49, 104, 3)_Z4X-018.jpg | Detectado: 4X-0 | Esperado: Z4X-018 | Tiempo: 0.2568s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800279_0.93_(64, 113, 3)_A8D-757.jpg | Detectado: A8D-75 | Esperado: A8D-757 | Tiempo: 0.2629s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800317_0.9_(45, 93, 3)_VAJ-632.jpg | Detectado: VAJ-632 | Esperado: VAJ-632 | Tiempo: 0.2622s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755800323_0.9_(52, 105, 3)_CRO-577.jpg | Detectado: CRO-57 | Esperado: CRO-577 | Tiempo: 0.2592s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800341_0.9_(44, 91, 3)_V8U-524.jpg | Detectado: V8U-52 | Esperado: V8U-524 | Tiempo: 0.2599s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800344_0.91_(47, 96, 3)_Z7U-204.jpg | Detectado: 27u-20 | Esperado: Z7U-204 | Tiempo: 0.2601s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800351_0.91_(47, 93, 3)_BSV-176.jpg | Detectado: BSV-17 | Esperado: BSV-176 | Tiempo: 0.2626s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800370_0.91_(52, 105, 3)_Z7P-666.jpg | Detectado: Z7P-66 | Esperado: Z7P-666 | Tiempo: 0.2602s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800418_0.9_(53, 106, 3)_Z6A-203.jpg | Detectado: Z6A-20: | Esperado: Z6A-203 | Tiempo: 0.2673s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800425_0.9_(58, 119, 3)_B3W-759.jpg | Detectado: 652-M£9 | Esperado: B3W-759 | Tiempo: 0.2576s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800437_0.9_(60, 107, 3)_Z5B-752.jpg | Detectado: 25B-75. | Esperado: Z5B-752 | Tiempo: 0.2576s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800446_0.9_(49, 100, 3)_Z8Y-837.jpg | Detectado: 228-187 | Esperado: Z8Y-837 | Tiempo: 0.2554s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800450_0.9_(48, 96, 3)_Z7V-290.jpg | Detectado: 067-M27 | Esperado: Z7V-290 | Tiempo: 0.2599s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800459_0.9_(46, 92, 3)_Z6S-279.jpg | Detectado: Z6S-27 | Esperado: Z6S-279 | Tiempo: 0.2581s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800467_0.91_(58, 105, 3)_B1B-164.jpg | Detectado:  | Esperado: B1B-164 | Tiempo: 0.1952s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800525_0.91_(45, 92, 3)_V9W-422.jpg | Detectado: 227-M62 | Esperado: V9W-422 | Tiempo: 0.2566s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800555_0.9_(44, 90, 3)_V8M-368.jpg | Detectado: /8M-36 | Esperado: V8M-368 | Tiempo: 0.2573s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800589_0.9_(46, 98, 3)_A8D-757.jpg | Detectado: 252-08 | Esperado: A8D-757 | Tiempo: 0.2620s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800590_0.9_(54, 109, 3)_A80-757.jpg | Detectado: S2-08 | Esperado: A80-757 | Tiempo: 0.2799s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800700_0.91_(48, 100, 3)_Z5Q-106.jpg | Detectado: Z5Q-106 | Esperado: Z5Q-106 | Tiempo: 0.2600s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755800790_0.9_(43, 90, 3)_X4N-230.jpg | Detectado: 1E2-N7 | Esperado: X4N-230 | Tiempo: 0.2642s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800793_0.91_(46, 92, 3)_V1I-104.jpg | Detectado: V1I-104 | Esperado: V1I-104 | Tiempo: 0.2588s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755800797_0.9_(52, 103, 3)_AUU-101.jpg | Detectado: uu-10: | Esperado: AUU-101 | Tiempo: 0.2563s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800807_0.9_(50, 104, 3)_X20-934.jpg | Detectado: X20-93 | Esperado: X20-934 | Tiempo: 0.2702s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800880_0.9_(44, 92, 3)_V31-163.jpg | Detectado: /31-16 | Esperado: V31-163 | Tiempo: 0.2618s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800883_0.9_(54, 104, 3)_Z6L-717.jpg | Detectado: Z6U-71 | Esperado: Z6L-717 | Tiempo: 0.2576s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800887_0.9_(47, 97, 3)_Z7K-549.jpg | Detectado:  | Esperado: Z7K-549 | Tiempo: 0.1964s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800893_0.9_(71, 106, 3)_Y3Q-595.jpg | Detectado:  | Esperado: Y3Q-595 | Tiempo: 0.1849s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800912_0.9_(41, 96, 3)_F51-233.jpg | Detectado: S22-31 | Esperado: F51-233 | Tiempo: 0.2617s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800941_0.9_(50, 100, 3)_B1N-742.jpg | Detectado: 272-NC | Esperado: B1N-742 | Tiempo: 0.2639s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800975_0.91_(58, 106, 3)_V7R-826.jpg | Detectado:  | Esperado: V7R-826 | Tiempo: 0.1993s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755800978_0.91_(47, 96, 3)_Z4Q-197.jpg | Detectado: Z4Q-197 | Esperado: Z4Q-197 | Tiempo: 0.2571s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801015_0.9_(48, 98, 3)_Z5G-496.jpg | Detectado: Z5G-49 | Esperado: Z5G-496 | Tiempo: 0.2609s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801088_0.9_(50, 109, 3)_Z5T-282.jpg | Detectado: Z5T-2 | Esperado: Z5T-282 | Tiempo: 0.2642s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801091_0.91_(46, 101, 3)_Z5V-445.jpg | Detectado: S57-15 | Esperado: Z5V-445 | Tiempo: 0.2598s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801123_0.9_(52, 100, 3)_W1A-763.jpg | Detectado: W1A-763 | Esperado: W1A-763 | Tiempo: 0.2576s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801131_0.9_(56, 113, 3)_A9K-715.jpg | Detectado: ST4-X6 | Esperado: A9K-715 | Tiempo: 0.2651s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801139_0.9_(47, 97, 3)_CBM-487.jpg | Detectado: 487-W82 | Esperado: CBM-487 | Tiempo: 0.2590s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801176_0.9_(50, 108, 3)_Z2G-146.jpg | Detectado: 2G-14 | Esperado: Z2G-146 | Tiempo: 0.2570s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801183_0.9_(61, 112, 3)_Z2N-051.jpg | Detectado: TSO-NS | Esperado: Z2N-051 | Tiempo: 0.2630s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801190_0.9_(46, 98, 3)_V9K-468.jpg | Detectado: 897-X6 | Esperado: V9K-468 | Tiempo: 0.2648s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801207_0.91_(48, 101, 3)_Z3P-791.jpg | Detectado: Z3P-79: | Esperado: Z3P-791 | Tiempo: 0.2645s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801210_0.9_(49, 104, 3)_X3A-006.jpg | Detectado: X3A-00 | Esperado: X3A-006 | Tiempo: 0.2596s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801223_0.91_(51, 101, 3)_Z8B-641.jpg | Detectado: Z8B-64. | Esperado: Z8B-641 | Tiempo: 0.2573s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801236_0.9_(48, 97, 3)_X1J-790.jpg | Detectado: D64-CL | Esperado: X1J-790 | Tiempo: 0.2675s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801286_0.9_(71, 116, 3)_F7F-087.jpg | Detectado: 280-32. | Esperado: F7F-087 | Tiempo: 0.2657s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801294_0.91_(52, 106, 3)_A5G-752.jpg | Detectado: A5G-75 | Esperado: A5G-752 | Tiempo: 0.2837s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801305_0.91_(48, 98, 3)_Z8U-888.jpg | Detectado: Z8U-88 | Esperado: Z8U-888 | Tiempo: 0.2624s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801306_0.91_(47, 102, 3)_Z8L-888.jpg | Detectado: 888-1187 | Esperado: Z8L-888 | Tiempo: 0.2580s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801314_0.91_(50, 103, 3)_AUJ-187.jpg | Detectado: AUJ-18 | Esperado: AUJ-187 | Tiempo: 0.2593s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801315_0.9_(57, 110, 3)_AUJ-182.jpg | Detectado: AUJ-187 | Esperado: AUJ-182 | Tiempo: 0.2513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801327_0.91_(49, 100, 3)_Z6X-411.jpg | Detectado:  | Esperado: Z6X-411 | Tiempo: 0.1865s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801335_0.9_(62, 110, 3)_V71-023.jpg | Detectado: O22-222 | Esperado: V71-023 | Tiempo: 0.2553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801348_0.9_(50, 97, 3)_X1S-070.jpg | Detectado: X1S-07 | Esperado: X1S-070 | Tiempo: 0.2596s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801389_0.91_(45, 93, 3)_VDS-785.jpg | Detectado: VDS-785 | Esperado: VDS-785 | Tiempo: 0.2573s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801392_0.91_(54, 107, 3)_Z7M-355.jpg | Detectado: Z7M-35: | Esperado: Z7M-355 | Tiempo: 0.2518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801403_0.91_(54, 106, 3)_Z8B-617.jpg | Detectado: Z8B-61 | Esperado: Z8B-617 | Tiempo: 0.2629s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801417_0.91_(51, 103, 3)_D7W-870.jpg | Detectado: 028-NZ0 | Esperado: D7W-870 | Tiempo: 0.2679s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801418_0.9_(57, 108, 3)_07W-870.jpg | Detectado:  | Esperado: 07W-870 | Tiempo: 0.1976s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801426_0.9_(50, 102, 3)_W1A-763.jpg | Detectado: 1A-7 | Esperado: W1A-763 | Tiempo: 0.2584s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801434_0.91_(63, 120, 3)_A9K-715.jpg | Detectado: ST2-X6V | Esperado: A9K-715 | Tiempo: 0.2663s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801483_0.91_(50, 100, 3)_X4H-470.jpg | Detectado:  | Esperado: X4H-470 | Tiempo: 0.1997s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801491_0.91_(47, 94, 3)_VCS-856.jpg | Detectado: VCS-85 | Esperado: VCS-856 | Tiempo: 0.2537s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801494_0.91_(48, 101, 3)_BCF-122.jpg | Detectado: BCF-122 | Esperado: BCF-122 | Tiempo: 0.2622s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801529_0.9_(55, 104, 3)_Z5K-681.jpg | Detectado: Z5K-68: | Esperado: Z5K-681 | Tiempo: 0.2603s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801534_0.91_(60, 117, 3)_Z2G-323.jpg | Detectado: Z2G-32. | Esperado: Z2G-323 | Tiempo: 0.2745s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801565_0.91_(64, 115, 3)_Z5Q-118.jpg | Detectado: Z5Q-11 | Esperado: Z5Q-118 | Tiempo: 0.2590s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801570_0.9_(48, 97, 3)_X1J-790.jpg | Detectado: X1J-790 | Esperado: X1J-790 | Tiempo: 0.2593s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801578_0.9_(46, 94, 3)_VAN-508.jpg | Detectado: VAN-50 | Esperado: VAN-508 | Tiempo: 0.2604s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801584_0.9_(48, 99, 3)_CHH-339.jpg | Detectado: CHW-33 | Esperado: CHH-339 | Tiempo: 0.2626s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801586_0.9_(53, 100, 3)_Z6M-106.jpg | Detectado: Z6M-106 | Esperado: Z6M-106 | Tiempo: 0.2630s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801598_0.92_(53, 108, 3)_A5G-752.jpg | Detectado:  | Esperado: A5G-752 | Tiempo: 0.1937s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801647_0.92_(59, 102, 3)_Z7U-204.jpg | Detectado: 702-127 | Esperado: Z7U-204 | Tiempo: 0.2557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801654_0.9_(49, 99, 3)_Z5G-467.jpg | Detectado: Z5G-4( | Esperado: Z5G-467 | Tiempo: 0.2699s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801662_0.91_(73, 117, 3)_598-655.jpg | Detectado:  | Esperado: 598-655 | Tiempo: 0.2008s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801663_0.9_(44, 89, 3)_71C-465.jpg | Detectado: Z1C-4€ | Esperado: 71C-465 | Tiempo: 0.2642s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801690_0.9_(41, 89, 3)_AXF-317.jpg | Detectado: AXF-31 | Esperado: AXF-317 | Tiempo: 0.2567s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801695_0.9_(46, 96, 3)_X1Q-323.jpg | Detectado: X1Q-32. | Esperado: X1Q-323 | Tiempo: 0.2595s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801744_0.9_(66, 118, 3)_Z20-326.jpg | Detectado: 20-326 | Esperado: Z20-326 | Tiempo: 0.2637s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801790_0.91_(49, 103, 3)_Z6C-695.jpg | Detectado: Z6C-69! | Esperado: Z6C-695 | Tiempo: 0.2603s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801795_0.91_(46, 94, 3)_Z3F-113.jpg | Detectado: 23F-113 | Esperado: Z3F-113 | Tiempo: 0.2656s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801798_0.92_(53, 103, 3)_Z6K-059.jpg | Detectado: 650-X97 | Esperado: Z6K-059 | Tiempo: 0.2601s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801801_0.91_(46, 97, 3)_D70-364.jpg | Detectado: D70-36 | Esperado: D70-364 | Tiempo: 0.2576s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801812_0.91_(49, 101, 3)_Z7V-467.jpg | Detectado: 297-M2 | Esperado: Z7V-467 | Tiempo: 0.2638s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801843_0.91_(49, 100, 3)_Z7S-416.jpg | Detectado: 9T7-S4Z | Esperado: Z7S-416 | Tiempo: 0.2577s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801846_0.9_(49, 95, 3)_F4B-067.jpg | Detectado: F4B-06 | Esperado: F4B-067 | Tiempo: 0.2562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801849_0.91_(53, 105, 3)_Z3V-367.jpg | Detectado: Z3V-367 | Esperado: Z3V-367 | Tiempo: 0.2702s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755801852_0.9_(52, 97, 3)_V71-420.jpg | Detectado: 027-120 | Esperado: V71-420 | Tiempo: 0.2496s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755801939_0.9_(48, 90, 3)_AYJ-561.jpg | Detectado: AYJ-56: | Esperado: AYJ-561 | Tiempo: 0.2620s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802000_0.91_(48, 101, 3)_AMO-819.jpg | Detectado: AMO-81 | Esperado: AMO-819 | Tiempo: 0.2579s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802022_0.9_(53, 103, 3)_B1B-734.jpg | Detectado: 722-858 | Esperado: B1B-734 | Tiempo: 0.2550s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802033_0.91_(56, 107, 3)_CKS-489.jpg | Detectado:  | Esperado: CKS-489 | Tiempo: 0.1922s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802038_0.9_(54, 103, 3)_C3S-449.jpg | Detectado:  | Esperado: C3S-449 | Tiempo: 0.1929s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802073_0.91_(54, 106, 3)_Z7C-049.jpg | Detectado: 670-327 | Esperado: Z7C-049 | Tiempo: 0.2624s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802099_0.91_(54, 108, 3)_Z6B-834.jpg | Detectado: Z6B-83 | Esperado: Z6B-834 | Tiempo: 0.2598s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802124_0.9_(60, 112, 3)_X3T-626.jpg | Detectado: (3T-62 | Esperado: X3T-626 | Tiempo: 0.2577s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802133_0.91_(49, 97, 3)_VCF-677.jpg | Detectado: VCF-67 | Esperado: VCF-677 | Tiempo: 0.2637s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802142_0.9_(50, 100, 3)_D1I-153.jpg | Detectado: D1I-15 | Esperado: D1I-153 | Tiempo: 0.2555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802147_0.91_(46, 90, 3)_VBI-497.jpg | Detectado: 267-18 | Esperado: VBI-497 | Tiempo: 0.2556s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802161_0.91_(50, 99, 3)_V9N-697.jpg | Detectado: V9N-69 | Esperado: V9N-697 | Tiempo: 0.2646s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802166_0.9_(45, 102, 3)_V2N-829.jpg | Detectado: 628-N2G | Esperado: V2N-829 | Tiempo: 0.2591s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802269_0.91_(45, 93, 3)_ARE-297.jpg | Detectado: P62-38 | Esperado: ARE-297 | Tiempo: 0.2526s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802328_0.9_(49, 98, 3)_Z7N-143.jpg | Detectado:  | Esperado: Z7N-143 | Tiempo: 0.1907s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802353_0.9_(62, 107, 3)_AAO-576.jpg | Detectado: A0-57 | Esperado: AAO-576 | Tiempo: 0.2499s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802410_0.91_(48, 95, 3)_BTB-292.jpg | Detectado: BTB-29 | Esperado: BTB-292 | Tiempo: 0.2661s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802415_0.91_(44, 95, 3)_Z7Y-245.jpg | Detectado: 172-245 | Esperado: Z7Y-245 | Tiempo: 0.2569s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802418_0.9_(50, 104, 3)_BPW-164.jpg | Detectado: BPW-1 | Esperado: BPW-164 | Tiempo: 0.2516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802421_0.91_(47, 92, 3)_BXI-161.jpg | Detectado: BXI-16: | Esperado: BXI-161 | Tiempo: 0.2624s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802433_0.9_(50, 98, 3)_V6Y-151.jpg | Detectado: CST-A90 | Esperado: V6Y-151 | Tiempo: 0.2525s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802437_0.92_(48, 98, 3)_Z6Y-080.jpg | Detectado: 080-A97 | Esperado: Z6Y-080 | Tiempo: 0.2531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802496_0.91_(42, 90, 3)_Z5D-490.jpg | Detectado: 25D-490 | Esperado: Z5D-490 | Tiempo: 0.2620s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802534_0.9_(41, 91, 3)_V4E-442.jpg | Detectado: 277-39 | Esperado: V4E-442 | Tiempo: 0.2636s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802585_0.91_(42, 94, 3)_VBX-425.jpg | Detectado:  | Esperado: VBX-425 | Tiempo: 0.1911s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802589_0.9_(48, 98, 3)_Z4Q-264.jpg | Detectado: 797-077 | Esperado: Z4Q-264 | Tiempo: 0.2546s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802592_0.91_(48, 98, 3)_BKQ-659.jpg | Detectado: BKQ-65 | Esperado: BKQ-659 | Tiempo: 0.2560s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802597_0.9_(48, 98, 3)_S1B-589.jpg | Detectado: S1B-58 | Esperado: S1B-589 | Tiempo: 0.2585s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802608_0.91_(49, 97, 3)_BKM-032.jpg | Detectado: CE-BXA | Esperado: BKM-032 | Tiempo: 0.2653s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802629_0.9_(50, 106, 3)_AFL-039.jpg | Detectado: FL-0; | Esperado: AFL-039 | Tiempo: 0.2639s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802632_0.9_(47, 101, 3)_Z7F-326.jpg | Detectado: 27F-32 | Esperado: Z7F-326 | Tiempo: 0.2636s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802646_0.9_(65, 114, 3)_CJS-468.jpg | Detectado: 897-SC) | Esperado: CJS-468 | Tiempo: 0.2539s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802650_0.9_(58, 114, 3)_A2E-705.jpg | Detectado:  | Esperado: A2E-705 | Tiempo: 0.2040s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802708_0.9_(52, 102, 3)_BHG-267.jpg | Detectado: BHG-26 | Esperado: BHG-267 | Tiempo: 0.2585s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802716_0.91_(47, 95, 3)_V4L-658.jpg | Detectado:  | Esperado: V4L-658 | Tiempo: 0.2022s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802759_0.91_(54, 107, 3)_Z8V-787.jpg | Detectado: Z8V-787 | Esperado: Z8V-787 | Tiempo: 0.2578s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755802859_0.9_(50, 97, 3)_Z3P-000.jpg | Detectado: Z3P-00 | Esperado: Z3P-000 | Tiempo: 0.2561s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755802962_0.91_(63, 114, 3)_Z6D-367.jpg | Detectado: Z6D-36 | Esperado: Z6D-367 | Tiempo: 0.2686s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803016_0.9_(43, 91, 3)_V6J-526.jpg | Detectado: V6J-52 | Esperado: V6J-526 | Tiempo: 0.2582s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803044_0.9_(63, 111, 3)_Z6U-717.jpg | Detectado: Z6U-71 | Esperado: Z6U-717 | Tiempo: 0.2559s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803089_0.9_(49, 97, 3)_Z7N-143.jpg | Detectado:  | Esperado: Z7N-143 | Tiempo: 0.1884s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803106_0.9_(58, 113, 3)_Z7W-178.jpg | Detectado: Z7H-1: | Esperado: Z7W-178 | Tiempo: 0.2574s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803124_0.9_(46, 92, 3)_Z1E-728.jpg | Detectado: 822-382 | Esperado: Z1E-728 | Tiempo: 0.2628s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803163_0.9_(54, 107, 3)_V1H-723.jpg | Detectado: 1H-72 | Esperado: V1H-723 | Tiempo: 0.2606s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803168_0.91_(53, 106, 3)_Z4Y-573.jpg | Detectado: 221-297 | Esperado: Z4Y-573 | Tiempo: 0.2560s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803170_0.9_(45, 89, 3)_X3T-194.jpg | Detectado: X3T-19 | Esperado: X3T-194 | Tiempo: 0.2583s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803288_0.91_(47, 96, 3)_ASJ-523.jpg | Detectado: ÄSJ-52 | Esperado: ASJ-523 | Tiempo: 0.2613s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803327_0.9_(50, 100, 3)_X3E-141.jpg | Detectado: X3E-141 | Esperado: X3E-141 | Tiempo: 0.2634s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755803417_0.9_(46, 96, 3)_Z1E-728.jpg | Detectado: 824-38 | Esperado: Z1E-728 | Tiempo: 0.2610s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803618_0.9_(61, 105, 3)_CEX-325.jpg | Detectado:  | Esperado: CEX-325 | Tiempo: 0.1803s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803678_0.9_(46, 103, 3)_V1W-327.jpg | Detectado: V1W-32 | Esperado: V1W-327 | Tiempo: 0.2629s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803683_0.9_(59, 118, 3)_Z5D-845.jpg | Detectado: Z5D-84: | Esperado: Z5D-845 | Tiempo: 0.2637s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803692_0.9_(60, 105, 3)_BBT-930.jpg | Detectado: 0£6-188 | Esperado: BBT-930 | Tiempo: 0.2564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803697_0.9_(67, 126, 3)_Z2E-770.jpg | Detectado:  | Esperado: Z2E-770 | Tiempo: 0.1937s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803736_0.9_(50, 103, 3)_BTQ-272.jpg | Detectado: BTQ-272 | Esperado: BTQ-272 | Tiempo: 0.2551s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755803790_0.9_(66, 113, 3)_Z3J-707.jpg | Detectado: Z3J-707 | Esperado: Z3J-707 | Tiempo: 0.2569s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755803875_0.91_(47, 102, 3)_ANJ-150.jpg | Detectado: NJ-15l | Esperado: ANJ-150 | Tiempo: 0.2553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803886_0.9_(45, 94, 3)_Z7X-826.jpg | Detectado: 27X-82 | Esperado: Z7X-826 | Tiempo: 0.2581s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803979_0.9_(45, 90, 3)_BVH-663.jpg | Detectado: BVH-66 | Esperado: BVH-663 | Tiempo: 0.2553s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803979_0.9_(48, 97, 3)_8VH-663.jpg | Detectado:  | Esperado: 8VH-663 | Tiempo: 0.1899s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755803985_0.9_(127, 139, 3)_L2E-770.jpg | Detectado: 2E-77 | Esperado: L2E-770 | Tiempo: 0.2785s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804033_0.91_(51, 96, 3)_V4E-661.jpg | Detectado: 99-35 | Esperado: V4E-661 | Tiempo: 0.2665s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804052_0.9_(54, 101, 3)_AUU-101.jpg | Detectado: zuu-10: | Esperado: AUU-101 | Tiempo: 0.2564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804067_0.91_(63, 110, 3)_Z7G-042.jpg | Detectado:  | Esperado: Z7G-042 | Tiempo: 0.1962s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804076_0.9_(51, 103, 3)_BJG-541.jpg | Detectado: BJG-54. | Esperado: BJG-541 | Tiempo: 0.2509s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804125_0.91_(48, 101, 3)_Z3J-707.jpg | Detectado: Z3J-707 | Esperado: Z3J-707 | Tiempo: 0.2624s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755804178_0.91_(38, 89, 3)_AYH-261.jpg | Detectado: T17-HA | Esperado: AYH-261 | Tiempo: 0.2577s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804192_0.9_(65, 116, 3)_V7C-801.jpg | Detectado: T8-3ZA | Esperado: V7C-801 | Tiempo: 0.2555s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804243_0.9_(49, 94, 3)_Z7Y-445.jpg | Detectado:  | Esperado: Z7Y-445 | Tiempo: 0.2027s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804326_0.9_(47, 98, 3)_CO1-165.jpg | Detectado:  | Esperado: CO1-165 | Tiempo: 0.1983s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804330_0.91_(51, 102, 3)_Z8S-813.jpg | Detectado: Z8S-81 | Esperado: Z8S-813 | Tiempo: 0.2513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804345_0.91_(46, 94, 3)_BLH-257.jpg | Detectado: G2-H | Esperado: BLH-257 | Tiempo: 0.2583s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804371_0.9_(54, 113, 3)_V6E-258.jpg | Detectado: G8-38 | Esperado: V6E-258 | Tiempo: 0.2570s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804443_0.91_(49, 96, 3)_Z51-510.jpg | Detectado: Z51-51 | Esperado: Z51-510 | Tiempo: 0.2580s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804512_0.91_(39, 91, 3)_Z7T-469.jpg | Detectado: 697-12 | Esperado: Z7T-469 | Tiempo: 0.2588s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755804516_0.92_(61, 118, 3)_Z1A-640.jpg | Detectado:  | Esperado: Z1A-640 | Tiempo: 0.1926s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805016_0.9_(49, 97, 3)_BWS-056.jpg | Detectado: BWS-05 | Esperado: BWS-056 | Tiempo: 0.2593s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805048_0.9_(50, 96, 3)_VCL-405.jpg | Detectado: VCL-40 | Esperado: VCL-405 | Tiempo: 0.2844s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805055_0.9_(53, 104, 3)_Z7W-234.jpg | Detectado: 7£Z-HZ7 | Esperado: Z7W-234 | Tiempo: 0.2725s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805151_0.91_(50, 101, 3)_Z7W-377.jpg | Detectado: Z7W-37 | Esperado: Z7W-377 | Tiempo: 0.2596s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805212_0.91_(52, 105, 3)_Z7F-518.jpg | Detectado: 8T5-327 | Esperado: Z7F-518 | Tiempo: 0.2562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805218_0.9_(41, 88, 3)_Z7H-064.jpg | Detectado: Z7H-06 | Esperado: Z7H-064 | Tiempo: 0.2565s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805271_0.9_(64, 111, 3)_Z1V-042.jpg | Detectado: 770- | Esperado: Z1V-042 | Tiempo: 0.2505s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805284_0.91_(52, 101, 3)_VAB-735.jpg | Detectado:  | Esperado: VAB-735 | Tiempo: 0.1985s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805378_0.9_(47, 101, 3)_Z6E-393.jpg | Detectado: Z6E-39 | Esperado: Z6E-393 | Tiempo: 0.2661s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805538_0.9_(47, 98, 3)_Z7G-017.jpg | Detectado: Z7G-0: | Esperado: Z7G-017 | Tiempo: 0.2516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805684_0.9_(48, 99, 3)_VCS-186.jpg | Detectado: VCS-18 | Esperado: VCS-186 | Tiempo: 0.2623s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805788_0.91_(48, 98, 3)_CRG-314.jpg | Detectado: CRG-31 | Esperado: CRG-314 | Tiempo: 0.2671s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755805904_0.92_(118, 124, 3)_V2X-710.jpg | Detectado: 247 | Esperado: V2X-710 | Tiempo: 0.2750s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806062_0.9_(47, 95, 3)_BKQ-659.jpg | Detectado: BKQ-65 | Esperado: BKQ-659 | Tiempo: 0.2566s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806111_0.9_(49, 97, 3)_Z7F-621.jpg | Detectado: Z7F-62: | Esperado: Z7F-621 | Tiempo: 0.2571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806151_0.91_(47, 98, 3)_Z5J-577.jpg | Detectado: 25J-57 | Esperado: Z5J-577 | Tiempo: 0.2611s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806181_0.9_(41, 100, 3)_VAQ-104.jpg | Detectado: VAQ-10 | Esperado: VAQ-104 | Tiempo: 0.2565s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806233_0.9_(49, 96, 3)_BWQ-500.jpg | Detectado: 05-0 | Esperado: BWQ-500 | Tiempo: 0.2628s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806243_0.91_(58, 110, 3)_Z7U-178.jpg | Detectado: Z7U-17 | Esperado: Z7U-178 | Tiempo: 0.2564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806300_0.9_(50, 101, 3)_AOT-720.jpg | Detectado: 22-108 | Esperado: AOT-720 | Tiempo: 0.2653s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806301_0.9_(53, 110, 3)_A0T-720.jpg | Detectado: AOT-720 | Esperado: A0T-720 | Tiempo: 0.2516s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806307_0.9_(45, 91, 3)_T4M-134.jpg | Detectado: 7ET-W7! | Esperado: T4M-134 | Tiempo: 0.2531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806406_0.9_(47, 101, 3)_A4S-720.jpg | Detectado: 022-S7 | Esperado: A4S-720 | Tiempo: 0.2634s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806558_0.9_(60, 116, 3)_ABU-720.jpg | Detectado:  | Esperado: ABU-720 | Tiempo: 0.1934s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806583_0.9_(58, 110, 3)_Z7H-075.jpg | Detectado: S20-H27 | Esperado: Z7H-075 | Tiempo: 0.2563s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806706_0.9_(45, 96, 3)_V71-023.jpg | Detectado: V7I-02: | Esperado: V71-023 | Tiempo: 0.2717s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806714_0.91_(46, 100, 3)_A4S-720.jpg | Detectado: 022-S7 | Esperado: A4S-720 | Tiempo: 0.2587s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806796_0.91_(44, 92, 3)_Z70-399.jpg | Detectado: 270-39 | Esperado: Z70-399 | Tiempo: 0.2569s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806835_0.9_(50, 100, 3)_D7W-870.jpg | Detectado: 028-N20 | Esperado: D7W-870 | Tiempo: 0.2685s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806839_0.91_(53, 104, 3)_Z2P-320.jpg | Detectado: Z2P-320 | Esperado: Z2P-320 | Tiempo: 0.2535s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755806845_0.91_(44, 98, 3)_A3C-786.jpg | Detectado: 982-3£ | Esperado: A3C-786 | Tiempo: 0.2626s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806849_0.92_(49, 98, 3)_Z7P-354.jpg | Detectado: Z7P-35 | Esperado: Z7P-354 | Tiempo: 0.2620s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806852_0.91_(66, 114, 3)_VBA-422.jpg | Detectado: /BA-42 | Esperado: VBA-422 | Tiempo: 0.2593s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755806868_0.9_(46, 91, 3)_ACL-585.jpg | Detectado: ACL-585 | Esperado: ACL-585 | Tiempo: 0.2630s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755806984_0.9_(45, 92, 3)_Z5Z-532.jpg | Detectado: 2E5-22 | Esperado: Z5Z-532 | Tiempo: 0.2683s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807008_0.91_(44, 97, 3)_BEP-534.jpg | Detectado: BEP-53 | Esperado: BEP-534 | Tiempo: 0.2639s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807086_0.91_(45, 90, 3)_Z4Y-618.jpg | Detectado: 8C9-A5 | Esperado: Z4Y-618 | Tiempo: 0.2597s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807186_0.9_(47, 95, 3)_Z7M-595.jpg | Detectado: S6S-W27 | Esperado: Z7M-595 | Tiempo: 0.2587s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807199_0.9_(46, 102, 3)_A5U-739.jpg | Detectado: 15U-739 | Esperado: A5U-739 | Tiempo: 0.2606s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807204_0.9_(43, 89, 3)_M4B-467.jpg | Detectado:  | Esperado: M4B-467 | Tiempo: 0.2023s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807211_0.9_(44, 96, 3)_BEP-534.jpg | Detectado: BEP-53 | Esperado: BEP-534 | Tiempo: 0.2632s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807470_0.91_(141, 148, 3)_A5U-739.jpg | Detectado: 51-73 | Esperado: A5U-739 | Tiempo: 0.2804s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807617_0.9_(56, 111, 3)_45K-770.jpg | Detectado:  | Esperado: 45K-770 | Tiempo: 0.2008s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807852_0.91_(53, 108, 3)_Z6W-329.jpg | Detectado: Z6W-3' | Esperado: Z6W-329 | Tiempo: 0.2531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807884_0.9_(52, 101, 3)_Z2Q-021.jpg | Detectado: Z2Q-02. | Esperado: Z2Q-021 | Tiempo: 0.2648s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755807907_0.9_(52, 99, 3)_C6M-147.jpg | Detectado: 6M-1 | Esperado: C6M-147 | Tiempo: 0.2571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808117_0.9_(49, 100, 3)_Z1I-540.jpg | Detectado: Z11-54 | Esperado: Z1I-540 | Tiempo: 0.2668s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808131_0.92_(45, 93, 3)_ANG-059.jpg | Detectado: ANG-05 | Esperado: ANG-059 | Tiempo: 0.2638s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808144_0.9_(46, 94, 3)_Z2Q-021.jpg | Detectado: Z2Q-02: | Esperado: Z2Q-021 | Tiempo: 0.2581s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808175_0.91_(44, 89, 3)_F8Q-278.jpg | Detectado: 927-08:3 | Esperado: F8Q-278 | Tiempo: 0.2775s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808300_0.9_(46, 91, 3)_AK1-784.jpg | Detectado: KI-784 | Esperado: AK1-784 | Tiempo: 0.2605s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808414_0.9_(59, 111, 3)_F8Q-278.jpg | Detectado: 8Q-27 | Esperado: F8Q-278 | Tiempo: 0.2632s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808461_0.91_(62, 116, 3)_CBA-659.jpg | Detectado: CBA-65 | Esperado: CBA-659 | Tiempo: 0.2728s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808464_0.9_(50, 104, 3)_BUY-632.jpg | Detectado: 729-A3 | Esperado: BUY-632 | Tiempo: 0.2717s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808477_0.91_(46, 95, 3)_BHB-015.jpg | Detectado: 3HB-01 | Esperado: BHB-015 | Tiempo: 0.2635s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808763_0.9_(54, 105, 3)_V5B-631.jpg | Detectado: 5B-63 | Esperado: V5B-631 | Tiempo: 0.2590s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755808937_0.91_(46, 96, 3)_V8Y-171.jpg | Detectado: V8Y-171 | Esperado: V8Y-171 | Tiempo: 0.2728s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755808962_0.9_(46, 91, 3)_Z1T-535.jpg | Detectado: Z1T-53. | Esperado: Z1T-535 | Tiempo: 0.2741s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809021_0.9_(53, 108, 3)_Z40-588.jpg | Detectado: Z40-58 | Esperado: Z40-588 | Tiempo: 0.2679s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809037_0.9_(61, 113, 3)_Z2N-738.jpg | Detectado: BEL-NZ | Esperado: Z2N-738 | Tiempo: 0.2600s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809250_0.9_(51, 99, 3)_S1B-772.jpg | Detectado: S1B-77 | Esperado: S1B-772 | Tiempo: 0.2577s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809492_0.9_(38, 97, 3)_S1B-772.jpg | Detectado: S1B-772 | Esperado: S1B-772 | Tiempo: 0.2588s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755809743_0.9_(47, 93, 3)_Z11-272.jpg | Detectado: 211-272 | Esperado: Z11-272 | Tiempo: 0.2719s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809784_0.91_(49, 100, 3)_Z7B-669.jpg | Detectado: Z7B-66 | Esperado: Z7B-669 | Tiempo: 0.2653s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809796_0.91_(121, 126, 3)_Z1J-781.jpg | Detectado: WJ-78 | Esperado: Z1J-781 | Tiempo: 0.2851s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755809798_0.91_(46, 99, 3)_BXU-498.jpg | Detectado: BXU-498 | Esperado: BXU-498 | Tiempo: 0.2572s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755810071_0.9_(47, 99, 3)_F1N-370.jpg | Detectado: F1N-370 | Esperado: F1N-370 | Tiempo: 0.2597s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755810077_0.9_(46, 97, 3)_Z6V-660.jpg | Detectado: 6V-66 | Esperado: Z6V-660 | Tiempo: 0.2579s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810245_0.9_(48, 95, 3)_BJU-400.jpg | Detectado: BJU-40L | Esperado: BJU-400 | Tiempo: 0.2690s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810246_0.9_(52, 98, 3)_BJL-400.jpg | Detectado: 007-nC8 | Esperado: BJL-400 | Tiempo: 0.2642s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810458_0.91_(50, 91, 3)_A2H-716.jpg | Detectado: A2H-71 | Esperado: A2H-716 | Tiempo: 0.2601s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810751_0.91_(42, 93, 3)_BKQ-659.jpg | Detectado: BKQ-6 | Esperado: BKQ-659 | Tiempo: 0.2736s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810833_0.9_(40, 90, 3)_Z5D-490.jpg | Detectado: Z5D-490 | Esperado: Z5D-490 | Tiempo: 0.2566s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755810848_0.9_(64, 109, 3)_AJV-939.jpg | Detectado: 6E6-AL | Esperado: AJV-939 | Tiempo: 0.2621s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755810946_0.91_(51, 99, 3)_Z5H-549.jpg | Detectado: Z5W-54 | Esperado: Z5H-549 | Tiempo: 0.2564s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811078_0.9_(49, 99, 3)_D1I-153.jpg | Detectado: 01I-1 | Esperado: D1I-153 | Tiempo: 0.2696s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811276_0.91_(45, 97, 3)_Z1H-700.jpg | Detectado: 002-HT | Esperado: Z1H-700 | Tiempo: 0.2703s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755811522_0.9_(46, 93, 3)_Z5D-172.jpg | Detectado: Z5D-172 | Esperado: Z5D-172 | Tiempo: 0.2659s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755811526_0.91_(45, 93, 3)_Z1H-700.jpg | Detectado: Z1H-700 | Esperado: Z1H-700 | Tiempo: 0.2683s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755812430_0.9_(63, 118, 3)_B3W-759.jpg | Detectado:  | Esperado: B3W-759 | Tiempo: 0.1911s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812435_0.9_(56, 114, 3)_ASD-757.jpg | Detectado: ISL-OIS | Esperado: ASD-757 | Tiempo: 0.2545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812550_0.91_(55, 108, 3)_Z2Q-310.jpg | Detectado:  | Esperado: Z2Q-310 | Tiempo: 0.1944s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812560_0.9_(47, 95, 3)_F9L-089.jpg | Detectado: 680-76: | Esperado: F9L-089 | Tiempo: 0.2520s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755812695_0.9_(48, 96, 3)_D9E-887.jpg | Detectado: 288-360 | Esperado: D9E-887 | Tiempo: 0.2630s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755813815_0.9_(44, 89, 3)_A1X-403.jpg | Detectado:  | Esperado: A1X-403 | Tiempo: 0.1912s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755819341_0.9_(51, 109, 3)_D2E-683.jpg | Detectado: D2E-68 | Esperado: D2E-683 | Tiempo: 0.2599s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755819352_0.91_(49, 108, 3)_D2E-683.jpg | Detectado:  | Esperado: D2E-683 | Tiempo: 0.1986s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755862816_0.9_(48, 104, 3)_Z3V-720.jpg | Detectado: 324-127 | Esperado: Z3V-720 | Tiempo: 0.2670s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755862951_0.9_(43, 96, 3)_A5K-770.jpg | Detectado: O22-X5 | Esperado: A5K-770 | Tiempo: 0.2534s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863223_0.9_(45, 94, 3)_BBP-662.jpg | Detectado: BBP-66. | Esperado: BBP-662 | Tiempo: 0.2664s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863519_0.9_(46, 102, 3)_AOT-720.jpg | Detectado: 22-B00 | Esperado: AOT-720 | Tiempo: 0.2682s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863582_0.9_(50, 94, 3)_Z1D-784.jpg | Detectado:  | Esperado: Z1D-784 | Tiempo: 0.1987s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863701_0.91_(55, 111, 3)_Z1J-781.jpg | Detectado: T82-CC | Esperado: Z1J-781 | Tiempo: 0.2531s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863861_0.9_(50, 98, 3)_X2Z-199.jpg | Detectado:  | Esperado: X2Z-199 | Tiempo: 0.2029s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863881_0.9_(50, 100, 3)_X3J-746.jpg | Detectado: X3J-746 | Esperado: X3J-746 | Tiempo: 0.2664s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755863927_0.91_(46, 96, 3)_71H-700.jpg | Detectado:  | Esperado: 71H-700 | Tiempo: 0.2073s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755863928_0.91_(47, 99, 3)_Z1H-700.jpg | Detectado:  | Esperado: Z1H-700 | Tiempo: 0.2139s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864056_0.9_(44, 94, 3)_BUX-273.jpg | Detectado:  | Esperado: BUX-273 | Tiempo: 0.1937s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864122_0.9_(46, 92, 3)_77U-013.jpg | Detectado: Z7U-0: | Esperado: 77U-013 | Tiempo: 0.2570s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864123_0.9_(53, 104, 3)_Z7U-013.jpg | Detectado: Z7U-01 | Esperado: Z7U-013 | Tiempo: 0.2592s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864190_0.9_(47, 98, 3)_Z5V-823.jpg | Detectado: 028-837 | Esperado: Z5V-823 | Tiempo: 0.2642s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864196_0.9_(51, 99, 3)_X4L-304.jpg | Detectado: 4L-30 | Esperado: X4L-304 | Tiempo: 0.2544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864262_0.91_(57, 109, 3)_Z7S-597.jpg | Detectado: Z7S-5 | Esperado: Z7S-597 | Tiempo: 0.2580s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864280_0.91_(47, 95, 3)_Z5Y-572.jpg | Detectado: 74S-A37 | Esperado: Z5Y-572 | Tiempo: 0.2536s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864463_0.91_(49, 99, 3)_Z6K-411.jpg | Detectado: Z6K-41 | Esperado: Z6K-411 | Tiempo: 0.2572s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864488_0.9_(57, 104, 3)_Z8C-206.jpg | Detectado: Z8C-20 | Esperado: Z8C-206 | Tiempo: 0.2626s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864599_0.9_(58, 110, 3)_V7B-442.jpg | Detectado:  | Esperado: V7B-442 | Tiempo: 0.1969s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864637_0.91_(48, 94, 3)_81B-734.jpg | Detectado:  | Esperado: 81B-734 | Tiempo: 0.1888s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864638_0.91_(60, 109, 3)_B18-734.jpg | Detectado:  | Esperado: B18-734 | Tiempo: 0.1936s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864638_0.9_(57, 101, 3)_B1B-734.jpg | Detectado: B1B | Esperado: B1B-734 | Tiempo: 0.2532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864701_0.9_(53, 106, 3)_V4R-602.jpg | Detectado: V4R-60 | Esperado: V4R-602 | Tiempo: 0.2673s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755864720_0.9_(47, 94, 3)_Z6A-087.jpg | Detectado: Z6A-08 | Esperado: Z6A-087 | Tiempo: 0.2672s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755865999_0.9_(52, 101, 3)_Z7U-013.jpg | Detectado: 27U-01 | Esperado: Z7U-013 | Tiempo: 0.2673s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866023_0.9_(48, 103, 3)_Z7X-877.jpg | Detectado: Z7X-87 | Esperado: Z7X-877 | Tiempo: 0.2668s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866028_0.9_(47, 96, 3)_Z3P-398.jpg | Detectado: 23P-39 | Esperado: Z3P-398 | Tiempo: 0.2646s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866032_0.91_(52, 108, 3)_Z6X-220.jpg | Detectado: 222-317 | Esperado: Z6X-220 | Tiempo: 0.2678s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866167_0.9_(49, 100, 3)_Z2M-424.jpg | Detectado: 27-W27 | Esperado: Z2M-424 | Tiempo: 0.2701s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866170_0.9_(46, 92, 3)_BHP-297.jpg | Detectado: BHP-2 | Esperado: BHP-297 | Tiempo: 0.2556s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866191_0.9_(48, 98, 3)_BKQ-659.jpg | Detectado:  | Esperado: BKQ-659 | Tiempo: 0.1928s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866271_0.9_(45, 98, 3)_Z3P-791.jpg | Detectado:  | Esperado: Z3P-791 | Tiempo: 0.2119s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866274_0.9_(52, 105, 3)_Z5U-453.jpg | Detectado: Z5U-45 | Esperado: Z5U-453 | Tiempo: 0.2548s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866275_0.9_(66, 112, 3)_Z5L-453.jpg | Detectado:  | Esperado: Z5L-453 | Tiempo: 0.1939s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866307_0.91_(48, 96, 3)_Z50-343.jpg | Detectado: Z50-34. | Esperado: Z50-343 | Tiempo: 0.2614s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866307_0.91_(56, 105, 3)_750-343.jpg | Detectado: 250-34 | Esperado: 750-343 | Tiempo: 0.2534s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866333_0.9_(56, 104, 3)_APH-716.jpg | Detectado:  | Esperado: APH-716 | Tiempo: 0.1918s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866336_0.91_(46, 98, 3)_V8V-084.jpg | Detectado: 80-18 | Esperado: V8V-084 | Tiempo: 0.2557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866431_0.91_(53, 107, 3)_COG-679.jpg | Detectado: COG-67 | Esperado: COG-679 | Tiempo: 0.2565s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866477_0.9_(50, 100, 3)_APF-394.jpg | Detectado: 4PF-39 | Esperado: APF-394 | Tiempo: 0.2656s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866484_0.9_(50, 104, 3)_Z3T-663.jpg | Detectado: 3T-66 | Esperado: Z3T-663 | Tiempo: 0.2592s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866521_0.92_(46, 94, 3)_75C-592.jpg | Detectado: 75C-59 | Esperado: 75C-592 | Tiempo: 0.2521s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866566_0.9_(64, 110, 3)_Y3F-143.jpg | Detectado:  | Esperado: Y3F-143 | Tiempo: 0.1916s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866603_0.9_(46, 95, 3)_X1J-790.jpg | Detectado: 062-CL | Esperado: X1J-790 | Tiempo: 0.2539s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866681_0.91_(48, 93, 3)_Z3P-326.jpg | Detectado: Z3P-32 | Esperado: Z3P-326 | Tiempo: 0.2633s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866685_0.9_(48, 96, 3)_Z6F-642.jpg | Detectado: 26F-64 | Esperado: Z6F-642 | Tiempo: 0.2560s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866688_0.91_(55, 109, 3)_V6M-925.jpg | Detectado: S26-W93 | Esperado: V6M-925 | Tiempo: 0.2585s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866691_0.91_(42, 96, 3)_X5J-730.jpg | Detectado:  | Esperado: X5J-730 | Tiempo: 0.2029s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866701_0.91_(51, 100, 3)_Z5D-490.jpg | Detectado: Z5D-49 | Esperado: Z5D-490 | Tiempo: 0.2650s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866708_0.9_(47, 95, 3)_Z7T-469.jpg | Detectado: Z7T-46 | Esperado: Z7T-469 | Tiempo: 0.2665s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866735_0.9_(46, 95, 3)_Z5Q-767.jpg | Detectado: 292-05 | Esperado: Z5Q-767 | Tiempo: 0.2554s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866769_0.9_(45, 97, 3)_Z7W-135.jpg | Detectado:  | Esperado: Z7W-135 | Tiempo: 0.1965s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866846_0.91_(61, 109, 3)_AMO-819.jpg | Detectado:  | Esperado: AMO-819 | Tiempo: 0.1916s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866848_0.9_(47, 97, 3)_VCA-701.jpg | Detectado: CA-70 | Esperado: VCA-701 | Tiempo: 0.2523s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866863_0.91_(48, 97, 3)_Z3E-444.jpg | Detectado:  | Esperado: Z3E-444 | Tiempo: 0.1895s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866869_0.9_(49, 99, 3)_AUM-201.jpg | Detectado: T22-W | Esperado: AUM-201 | Tiempo: 0.2535s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866962_0.9_(59, 110, 3)_B3W-759.jpg | Detectado: 6S2-828 | Esperado: B3W-759 | Tiempo: 0.2575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755866976_0.9_(52, 108, 3)_B2U-796.jpg | Detectado: 62-12 | Esperado: B2U-796 | Tiempo: 0.2649s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867013_0.9_(51, 99, 3)_BRV-568.jpg | Detectado:  | Esperado: BRV-568 | Tiempo: 0.1900s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867016_0.9_(47, 100, 3)_VOX-966.jpg | Detectado:  | Esperado: VOX-966 | Tiempo: 0.1899s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867062_0.9_(58, 110, 3)_Z7W-006.jpg | Detectado: 900-M27 | Esperado: Z7W-006 | Tiempo: 0.2601s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867068_0.9_(46, 108, 3)_C8U-187.jpg | Detectado:  | Esperado: C8U-187 | Tiempo: 0.1967s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867099_0.9_(52, 102, 3)_A5Z-645.jpg | Detectado:  | Esperado: A5Z-645 | Tiempo: 0.1859s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867103_0.9_(45, 90, 3)_ERA-728.jpg | Detectado: RA-72 | Esperado: ERA-728 | Tiempo: 0.2545s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867108_0.9_(46, 94, 3)_V9Q-064.jpg | Detectado: /9Q-06 | Esperado: V9Q-064 | Tiempo: 0.2638s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867109_0.9_(55, 105, 3)_19Q-064.jpg | Detectado: /9Q-0 | Esperado: 19Q-064 | Tiempo: 0.2544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867134_0.9_(64, 108, 3)_ABA-734.jpg | Detectado:  | Esperado: ABA-734 | Tiempo: 0.1903s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867157_0.9_(52, 103, 3)_Y3A-006.jpg | Detectado: X3A-00 | Esperado: Y3A-006 | Tiempo: 0.2612s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867182_0.9_(47, 92, 3)_Z6D-275.jpg | Detectado: Z6D-27 | Esperado: Z6D-275 | Tiempo: 0.2577s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867230_0.91_(55, 108, 3)_Z5F-631.jpg | Detectado: Z5F-631 | Esperado: Z5F-631 | Tiempo: 0.2668s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755867236_0.91_(49, 97, 3)_Z7C-220.jpg | Detectado: Z7C-220 | Esperado: Z7C-220 | Tiempo: 0.2587s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755867248_0.91_(109, 119, 3)_Z5J-714.jpg | Detectado: 50-71 | Esperado: Z5J-714 | Tiempo: 0.2608s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867315_0.91_(51, 98, 3)_F5H-768.jpg | Detectado: 5H-76 | Esperado: F5H-768 | Tiempo: 0.2628s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867382_0.9_(64, 116, 3)_BDM-402.jpg | Detectado: 07-WQ | Esperado: BDM-402 | Tiempo: 0.2591s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867393_0.9_(49, 95, 3)_VDY-836.jpg | Detectado: DY-836 | Esperado: VDY-836 | Tiempo: 0.2624s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867401_0.9_(53, 103, 3)_BYW-137.jpg | Detectado:  | Esperado: BYW-137 | Tiempo: 0.1867s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867409_0.91_(50, 96, 3)_Y2C-212.jpg | Detectado: Y2C-21 | Esperado: Y2C-212 | Tiempo: 0.2606s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755867414_0.91_(55, 107, 3)_X50-334.jpg | Detectado: X50 | Esperado: X50-334 | Tiempo: 0.3488s | Precisión: 0.0% | ❌ Incorrecto
# ...
# Procesado: 1755868148_0.9_(60, 106, 3)_X3H-030.jpg | Detectado: (3H-O) | Esperado: X3H-030 | Tiempo: 0.2575s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868151_0.9_(47, 95, 3)_Z7J-697.jpg | Detectado: Z7J-69 | Esperado: Z7J-697 | Tiempo: 0.2694s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868156_0.9_(49, 92, 3)_AYJ-561.jpg | Detectado: J-5 | Esperado: AYJ-561 | Tiempo: 0.2675s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868158_0.92_(55, 98, 3)_4YJ-561.jpg | Detectado: YJ-56. | Esperado: 4YJ-561 | Tiempo: 0.2562s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868169_0.91_(64, 112, 3)_S1B-772.jpg | Detectado: 222-889 | Esperado: S1B-772 | Tiempo: 0.2664s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868213_0.9_(47, 100, 3)_A5E-785.jpg | Detectado: S82-35 | Esperado: A5E-785 | Tiempo: 0.2696s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868214_0.91_(50, 106, 3)_45E-785.jpg | Detectado:  | Esperado: 45E-785 | Tiempo: 0.1874s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868233_0.9_(51, 109, 3)_Z6E-393.jpg | Detectado: Z6E-39 | Esperado: Z6E-393 | Tiempo: 0.2697s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868237_0.9_(63, 115, 3)_V1H-723.jpg | Detectado: 1H-7 | Esperado: V1H-723 | Tiempo: 0.2611s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868252_0.9_(49, 98, 3)_V5B-631.jpg | Detectado: /5B-63: | Esperado: V5B-631 | Tiempo: 0.2714s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868316_0.9_(56, 111, 3)_FOB-739.jpg | Detectado: OB-7 | Esperado: FOB-739 | Tiempo: 0.2682s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868367_0.9_(57, 105, 3)_Z4Q-197.jpg | Detectado: Z4Q-197 | Esperado: Z4Q-197 | Tiempo: 0.2657s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755868377_0.91_(52, 105, 3)_Z7U-204.jpg | Detectado: Z7U-20 | Esperado: Z7U-204 | Tiempo: 0.2645s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868390_0.9_(59, 110, 3)_A7V-766.jpg | Detectado:  | Esperado: A7V-766 | Tiempo: 0.2035s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868410_0.9_(47, 98, 3)_Z3C-760.jpg | Detectado:  | Esperado: Z3C-760 | Tiempo: 0.1999s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868462_0.9_(51, 102, 3)_V9N-697.jpg | Detectado:  | Esperado: V9N-697 | Tiempo: 0.2032s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868467_0.91_(46, 93, 3)_V8B-614.jpg | Detectado: V8B-61 | Esperado: V8B-614 | Tiempo: 0.2668s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868503_0.91_(50, 98, 3)_Z6L-717.jpg | Detectado: 260-7: | Esperado: Z6L-717 | Tiempo: 0.2544s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868523_0.9_(53, 105, 3)_Z7Z-085.jpg | Detectado: 7Z-08 | Esperado: Z7Z-085 | Tiempo: 0.2655s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868553_0.9_(51, 109, 3)_B2U-796.jpg | Detectado: 62-nz | Esperado: B2U-796 | Tiempo: 0.2588s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868571_0.91_(48, 96, 3)_BRT-304.jpg | Detectado: BRT-304 | Esperado: BRT-304 | Tiempo: 0.2524s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755868575_0.91_(61, 110, 3)_ATO-102.jpg | Detectado: TO-10 | Esperado: ATO-102 | Tiempo: 0.2704s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868621_0.9_(56, 104, 3)_BBW-631.jpg | Detectado:  | Esperado: BBW-631 | Tiempo: 0.2013s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868632_0.91_(44, 95, 3)_A9C-789.jpg | Detectado: 682-96 | Esperado: A9C-789 | Tiempo: 0.2506s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868683_0.9_(51, 101, 3)_Z3C-760.jpg | Detectado:  | Esperado: Z3C-760 | Tiempo: 0.1911s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868729_0.91_(51, 97, 3)_ICQ-067.jpg | Detectado: VCQ-06 | Esperado: ICQ-067 | Tiempo: 0.2571s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868766_0.9_(51, 102, 3)_AYA-568.jpg | Detectado:  | Esperado: AYA-568 | Tiempo: 0.2007s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868769_0.9_(57, 106, 3)_AZH-270.jpg | Detectado: ZH-27 | Esperado: AZH-270 | Tiempo: 0.2668s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868815_0.9_(51, 114, 3)_B30-733.jpg | Detectado: 34-228 | Esperado: B30-733 | Tiempo: 0.2676s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868871_0.91_(48, 97, 3)_Z7X-303.jpg | Detectado: Z7X-30 | Esperado: Z7X-303 | Tiempo: 0.2679s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868919_0.9_(51, 100, 3)_Z4G-081.jpg | Detectado: 74G-08 | Esperado: Z4G-081 | Tiempo: 0.2659s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868921_0.91_(61, 107, 3)_X3Y-506.jpg | Detectado:  | Esperado: X3Y-506 | Tiempo: 0.2042s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755868990_0.9_(48, 98, 3)_Z3W-660.jpg | Detectado: 099-M£ | Esperado: Z3W-660 | Tiempo: 0.2504s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869368_0.9_(59, 107, 3)_X3R-360.jpg | Detectado: (3R-360 | Esperado: X3R-360 | Tiempo: 0.2683s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869377_0.9_(48, 93, 3)_D2R-594.jpg | Detectado: D2R-59 | Esperado: D2R-594 | Tiempo: 0.2682s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869386_0.9_(49, 97, 3)_V7C-801.jpg | Detectado: V7C-80 | Esperado: V7C-801 | Tiempo: 0.2696s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869394_0.9_(47, 96, 3)_Z5B-649.jpg | Detectado: Z5B-64 | Esperado: Z5B-649 | Tiempo: 0.2715s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869505_0.9_(126, 134, 3)_N2X-710.jpg | Detectado: 2X-71 | Esperado: N2X-710 | Tiempo: 0.2912s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869536_0.91_(52, 103, 3)_Z8S-813.jpg | Detectado: Z8S-81 | Esperado: Z8S-813 | Tiempo: 0.2655s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869570_0.9_(51, 107, 3)_Z4Q-021.jpg | Detectado: 220-077 | Esperado: Z4Q-021 | Tiempo: 0.2678s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869582_0.91_(65, 116, 3)_Z8M-738.jpg | Detectado: Z8M-738 | Esperado: Z8M-738 | Tiempo: 0.2631s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755869632_0.9_(63, 114, 3)_Z5F-558.jpg | Detectado: Z5F-55 | Esperado: Z5F-558 | Tiempo: 0.2663s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869679_0.9_(63, 113, 3)_V7C-801.jpg | Detectado: V7C-80 | Esperado: V7C-801 | Tiempo: 0.2594s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755869713_0.9_(60, 112, 3)_APF-394.jpg | Detectado: APF-394 | Esperado: APF-394 | Tiempo: 0.2563s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755870055_0.9_(48, 97, 3)_B2C-509.jpg | Detectado: B2C-50 | Esperado: B2C-509 | Tiempo: 0.2600s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870085_0.9_(45, 94, 3)_Z7J-462.jpg | Detectado: 27J-46 | Esperado: Z7J-462 | Tiempo: 0.2647s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870135_0.9_(51, 104, 3)_Z4T-372.jpg | Detectado:  | Esperado: Z4T-372 | Tiempo: 0.1992s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870154_0.91_(48, 105, 3)_Y1L-742.jpg | Detectado: 264-7L | Esperado: Y1L-742 | Tiempo: 0.2638s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870168_0.9_(54, 99, 3)_130-397.jpg | Detectado: /30-39 | Esperado: 130-397 | Tiempo: 0.2640s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870182_0.9_(47, 96, 3)_Z5T-688.jpg | Detectado: Z5T-68 | Esperado: Z5T-688 | Tiempo: 0.2622s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870240_0.9_(58, 108, 3)_Z6K-411.jpg | Detectado:  | Esperado: Z6K-411 | Tiempo: 0.2009s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870251_0.91_(48, 97, 3)_45K-770.jpg | Detectado: O22-XS | Esperado: 45K-770 | Tiempo: 0.2500s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870281_0.9_(60, 105, 3)_V4F-244.jpg | Detectado:  | Esperado: V4F-244 | Tiempo: 0.2045s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870289_0.91_(47, 92, 3)_Z7C-049.jpg | Detectado: Z7C-0 | Esperado: Z7C-049 | Tiempo: 0.2524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870393_0.9_(50, 107, 3)_Y1L-742.jpg | Detectado: 274-7L | Esperado: Y1L-742 | Tiempo: 0.2684s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870444_0.91_(48, 97, 3)_ACL-585.jpg | Detectado: GTS-75 | Esperado: ACL-585 | Tiempo: 0.2663s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870523_0.91_(50, 102, 3)_Z51-804.jpg | Detectado: 78-I5 | Esperado: Z51-804 | Tiempo: 0.2693s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870633_0.9_(49, 99, 3)_Z8C-747.jpg | Detectado: Z8C-747 | Esperado: Z8C-747 | Tiempo: 0.2679s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755870662_0.91_(48, 96, 3)_AOT-720.jpg | Detectado: AOT-72 | Esperado: AOT-720 | Tiempo: 0.2687s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870687_0.91_(67, 124, 3)_CDL-482.jpg | Detectado: CDU-48 | Esperado: CDL-482 | Tiempo: 0.2592s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870769_0.9_(49, 99, 3)_Z7W-377.jpg | Detectado: Z7W-3 | Esperado: Z7W-377 | Tiempo: 0.2700s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870783_0.9_(48, 98, 3)_Z8C-206.jpg | Detectado: Z8C-20 | Esperado: Z8C-206 | Tiempo: 0.2665s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870785_0.9_(119, 121, 3)_L8C-206.jpg | Detectado:  | Esperado: L8C-206 | Tiempo: 0.2248s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870826_0.9_(52, 102, 3)_V6M-597.jpg | Detectado:  | Esperado: V6M-597 | Tiempo: 0.1919s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755870914_0.9_(47, 99, 3)_AOT-720.jpg | Detectado: OT-72 | Esperado: AOT-720 | Tiempo: 0.2623s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871079_0.9_(62, 114, 3)_Z4J-763.jpg | Detectado: £94-04 | Esperado: Z4J-763 | Tiempo: 0.2669s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871103_0.9_(59, 110, 3)_S1B-589.jpg | Detectado: 1B-58 | Esperado: S1B-589 | Tiempo: 0.2696s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871108_0.9_(52, 112, 3)_Z1J-781.jpg | Detectado: 282-LL7 | Esperado: Z1J-781 | Tiempo: 0.2702s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871139_0.9_(50, 96, 3)_BSV-176.jpg | Detectado: BSV-17 | Esperado: BSV-176 | Tiempo: 0.2679s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871157_0.92_(130, 134, 3)_L2N-738.jpg | Detectado: 2M-73 | Esperado: L2N-738 | Tiempo: 0.2834s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871316_0.9_(51, 102, 3)_Z7M-111.jpg | Detectado:  | Esperado: Z7M-111 | Tiempo: 0.1968s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871358_0.9_(48, 96, 3)_CRO-577.jpg | Detectado: CRO-577 | Esperado: CRO-577 | Tiempo: 0.2556s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755871447_0.9_(48, 101, 3)_V5S-570.jpg | Detectado: V5S-570 | Esperado: V5S-570 | Tiempo: 0.2671s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755871461_0.9_(46, 96, 3)_APF-394.jpg | Detectado: APF-394 | Esperado: APF-394 | Tiempo: 0.2692s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755871611_0.91_(57, 104, 3)_Z5V-413.jpg | Detectado: 25V-413 | Esperado: Z5V-413 | Tiempo: 0.2651s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871634_0.9_(60, 108, 3)_V8J-069.jpg | Detectado:  | Esperado: V8J-069 | Tiempo: 0.2033s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871753_0.91_(60, 106, 3)_Z5L-091.jpg | Detectado: T60-757 | Esperado: Z5L-091 | Tiempo: 0.2591s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871801_0.9_(47, 93, 3)_Z7S-679.jpg | Detectado: Z7S-67 | Esperado: Z7S-679 | Tiempo: 0.2524s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871807_0.9_(48, 99, 3)_Z8A-540.jpg | Detectado: Z8A-540 | Esperado: Z8A-540 | Tiempo: 0.2696s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755871813_0.9_(63, 107, 3)_Z5D-490.jpg | Detectado:  | Esperado: Z5D-490 | Tiempo: 0.1942s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871836_0.9_(58, 116, 3)_V3C-453.jpg | Detectado: 347-328 | Esperado: V3C-453 | Tiempo: 0.2641s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871886_0.9_(50, 104, 3)_Z6D-367.jpg | Detectado: Z6D-36 | Esperado: Z6D-367 | Tiempo: 0.2655s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871920_0.91_(63, 106, 3)_ASN-544.jpg | Detectado: SN-54 | Esperado: ASN-544 | Tiempo: 0.2604s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755871984_0.91_(49, 95, 3)_Z7L-650.jpg | Detectado: Z7L-65 | Esperado: Z7L-650 | Tiempo: 0.2532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872015_0.9_(61, 112, 3)_Z5D-360.jpg | Detectado: 36 | Esperado: Z5D-360 | Tiempo: 0.3557s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872070_0.9_(52, 103, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.2033s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872110_0.9_(51, 96, 3)_VOT-812.jpg | Detectado: VOT-812 | Esperado: VOT-812 | Tiempo: 0.2508s | Precisión: 100.0% | ✅ Correcto
# Procesado: 1755872180_0.9_(48, 98, 3)_A9K-715.jpg | Detectado: ST4-X6 | Esperado: A9K-715 | Tiempo: 0.2703s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872284_0.91_(145, 146, 3)_L10-760.jpg | Detectado: 10-76 | Esperado: L10-760 | Tiempo: 0.2988s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872299_0.9_(54, 103, 3)_Z5G-467.jpg | Detectado: Z5G-46 | Esperado: Z5G-467 | Tiempo: 0.2551s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872312_0.9_(50, 97, 3)_Z7X-826.jpg | Detectado:  | Esperado: Z7X-826 | Tiempo: 0.2047s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872398_0.9_(49, 101, 3)_F3F-041.jpg | Detectado: F3F-04 | Esperado: F3F-041 | Tiempo: 0.2533s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872405_0.91_(59, 107, 3)_B1B-734.jpg | Detectado:  | Esperado: B1B-734 | Tiempo: 0.1870s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872417_0.9_(49, 93, 3)_B31-104.jpg | Detectado: B3I-10 | Esperado: B31-104 | Tiempo: 0.2532s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872482_0.9_(58, 109, 3)_CJS-373.jpg | Detectado: JS-37 | Esperado: CJS-373 | Tiempo: 0.2530s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872541_0.9_(123, 137, 3)_L10-760.jpg | Detectado: 9L-0 | Esperado: L10-760 | Tiempo: 0.2866s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872551_0.9_(50, 98, 3)_Z7V-417.jpg | Detectado: ∠T5-ML | Esperado: Z7V-417 | Tiempo: 0.2685s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872552_0.91_(62, 109, 3)_77V-417.jpg | Detectado: 2T4-M2 | Esperado: 77V-417 | Tiempo: 0.2710s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872559_0.9_(46, 103, 3)_74K-739.jpg | Detectado: 622-X7 | Esperado: 74K-739 | Tiempo: 0.2677s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872559_0.9_(52, 107, 3)_Z4K-739.jpg | Detectado: 622-X7 | Esperado: Z4K-739 | Tiempo: 0.2513s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872606_0.91_(48, 99, 3)_CRO-577.jpg | Detectado: CRO-57 | Esperado: CRO-577 | Tiempo: 0.2549s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872752_0.9_(51, 96, 3)_BKZ-705.jpg | Detectado:  | Esperado: BKZ-705 | Tiempo: 0.2023s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872828_0.9_(49, 94, 3)_Z2Q-310.jpg | Detectado: 22Q-310 | Esperado: Z2Q-310 | Tiempo: 0.2518s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872884_0.9_(51, 103, 3)_V1T-101.jpg | Detectado:  | Esperado: V1T-101 | Tiempo: 0.2021s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755872968_0.91_(50, 96, 3)_C1A-878.jpg | Detectado: C1A- | Esperado: C1A-878 | Tiempo: 0.2692s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873119_0.91_(46, 95, 3)_42E-705.jpg | Detectado:  | Esperado: 42E-705 | Tiempo: 0.2021s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873369_0.9_(56, 100, 3)_AFG-023.jpg | Detectado:  | Esperado: AFG-023 | Tiempo: 0.1833s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873449_0.9_(55, 105, 3)_Z5G-139.jpg | Detectado: Z5G-13 | Esperado: Z5G-139 | Tiempo: 0.2602s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873458_0.91_(51, 98, 3)_W1A-763.jpg | Detectado:  | Esperado: W1A-763 | Tiempo: 0.2012s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873467_0.9_(59, 112, 3)_BHB-015.jpg | Detectado: BHB | Esperado: BHB-015 | Tiempo: 0.2514s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873478_0.9_(47, 98, 3)_42E-705.jpg | Detectado: 2Es70 | Esperado: 42E-705 | Tiempo: 0.2598s | Precisión: 0.0% | ❌ Incorrecto
# Procesado: 1755873578_0.9_(56, 108, 3)_Z5X-789.jpg | Detectado:  | Esperado: Z5X-789 | Tiempo: 0.2042s | Precisión: 0.0% | ❌ Incorrecto
#
# ✅ Resultados guardados en: resultados_paddleOCR/resultados_paddleocr.csv
# 📊 Resumen: 43/500 correctos (8.6%)
# ⏱️  Tiempo total: 125.0649s | Tiempo promedio: 0.2501s

# %% [markdown]
# ## Resultado finales (ver el .txt en la carpeta resultados_finales)
